# %% [markdown]
# Packages

# %%
import networkx as nx
import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
from scipy.spatial import Delaunay
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# Data to create graphs

# %%
#final_dataframes = pickle.load(open("final_dataframes.pkl", "rb"))
final_dataframes = pickle.load(open("data_prep/one_year.pkl", "rb"))

# %%
# Define the train ratio
train_ratio = 0.7  # 80% training data
lookback = 50
pred_horizon = 5
df_dict = final_dataframes

# Split each DataFrame into training and testing parts based on time
df_dict_train = {}
df_dict_test = {}
for key, df in final_dataframes.items():
    n_time_steps = len(df['traffic_flow'])
    train_size = int(n_time_steps * train_ratio)
    df_train = df.iloc[:train_size].copy()
    df_test = df.iloc[train_size:].copy()
    df_dict_train[key] = df_train
    df_dict_test[key] = df_test


def create_sliding_window_data(df_dict, lookback, pred_horizon):
    X_dict = {}
    y_dict = {}
    for key, df in df_dict.items():
        node_series = df['traffic_flow'].values
        X_node = []
        y_node = []
        for i in range(len(node_series) - lookback - pred_horizon + 1):
            X_node.append(node_series[i:i + lookback])  # Input: Lookback window
            y_node.append(node_series[i + lookback:i + lookback + pred_horizon])  # Output: Next step(s)
        X_dict[key] = np.array(X_node)
        y_dict[key] = np.array(y_node)
    return X_dict, y_dict

# Generate sliding window data for training and testing sets
X_train_dict, y_train_dict = create_sliding_window_data(df_dict_train, lookback, pred_horizon)
X_test_dict, y_test_dict = create_sliding_window_data(df_dict_test, lookback, pred_horizon)

# %%
def clean_graph(graph):
    # Remove self-loops
    graph = graph.copy()  # Avoid modifying the
    self_loops = list(nx.selfloop_edges(graph))
    graph.remove_edges_from(self_loops)
    
    # Remove duplicate edges (not necessary for undirected graphs in NetworkX)
    # Here just in case your graph is directed or you need further verification
    edges_to_remove = []
    for u, v, data in graph.edges(data=True):
        if graph.number_of_edges(u, v) > 1:  # More than one edge exists
            edges_to_remove.append((u, v))
    
    graph.remove_edges_from(edges_to_remove)
    largest_component = max(nx.connected_components(graph), key=len)
    graph = graph.subgraph(largest_component)

    print(f"Removed {len(self_loops)} self-loops and {len(edges_to_remove)} duplicate edges. Choose the Largest Component: {len(largest_component)} nodes.")
    # extract largest component

    return graph

def create_correlation_graph(df_dict_full, df_dict_train, threshold=0.5, weighted=False,degree=4):
    """
    Create a correlation graph with a maximum degree constraint using only the training data for correlations.
    """
    correlation_graph = nx.Graph()
    correlations_dict = {}

    # Add nodes to the graph using the full data
    for key, df in df_dict_full.items():
        correlation_graph.add_node(
            key,
            x=df['Xkoordinat'].iloc[0],
            y=df['Ykoordinat'].iloc[0],
            traffic_flow=df['traffic_flow'].values  # Full traffic data
        )

    # Calculate correlations using the training data
    for key1, df1_train in df_dict_train.items():
        for key2, df2_train in df_dict_train.items():
            if key1 >= key2:  # Avoid duplicate computations
                continue
            correlation = np.corrcoef(df1_train['traffic_flow'], df2_train['traffic_flow'])[0, 1]
            correlations_dict[key1, key2] = correlation
            correlations_dict[key2, key1] = correlation  # Symmetric for undirected graph

    # Add edges based on correlation, enforcing degree constraint
    for key1 in df_dict_full.keys():
        # Sort potential connections by correlation (highest first)
        potential_edges = [
            (key2, correlations_dict[key1, key2])
            for key2 in df_dict_full.keys() if key1 != key2 and (key1, key2) in correlations_dict
        ]
        potential_edges = sorted(potential_edges, key=lambda x: -x[1])  # Sort by descending correlation

        for key2, corr in potential_edges:
            if correlation_graph.degree[key1] < degree and correlation_graph.degree[key2] < degree:
                if corr > threshold:
                    if weighted:
                        correlation_graph.add_edge(key1, key2, weight=corr)
                    else:
                        correlation_graph.add_edge(key1, key2)

    # Clean graph
    correlation_graph = clean_graph(correlation_graph)
    return correlation_graph, correlations_dict

def create_distance_graph(df_dict, weighted=False, degree=4):
    """
    Create a distance graph with a maximum degree constraint.
    """
    distance_graph = nx.Graph()
    distance_dict = {}

    # Add nodes to the graph
    for key, df in df_dict.items():
        distance_graph.add_node(
            key, 
            x=df['Xkoordinat'].iloc[0], 
            y=df['Ykoordinat'].iloc[0], 
            traffic_flow=df['traffic_flow'].values
        )

    # Calculate distances and store in a dictionary
    for key1, df1 in df_dict.items():
        for key2, df2 in df_dict.items():
            if key1 == key2:
                continue
            idx = df1['traffic_flow'].first_valid_index()
            distance = math.sqrt(
                (df1['Xkoordinat'][idx] - df2['Xkoordinat'][idx])**2 +
                (df1['Ykoordinat'][idx] - df2['Ykoordinat'][idx])**2
            )
            distance_dict[key1, key2] = distance

    # Add edges based on distance, enforcing degree constraint
    threshold = (sum(distance_dict.values()) / len(distance_dict)) * 2  # Distance threshold
    for key1 in df_dict.keys():
        # Sort potential connections by distance (shortest first)
        potential_edges = [
            (key2, distance_dict[key1, key2])
            for key2 in df_dict.keys() if key1 != key2 and (key1, key2) in distance_dict
        ]
        potential_edges = sorted(potential_edges, key=lambda x: x[1])  # Sort by ascending distance
        
        for key2, dist in potential_edges:
            if distance_graph.degree[key1] < degree and distance_graph.degree[key2] < degree:
                if dist < threshold:
                    if weighted:
                        max_distance = max(distance_dict.values())
                        min_distance = min(distance_dict.values())
                        normalised_distance = (dist - min_distance) / (max_distance - min_distance)
                        distance_graph.add_edge(key1, key2, weight=normalised_distance)
                    else:
                        distance_graph.add_edge(key1, key2)

    # Clean graph
    distance_graph = clean_graph(distance_graph)
    return distance_graph, distance_dict

def create_fully_connected_graph(df_dict):
    # Connect every node to every other node without weights 
    fully_connected_graph = nx.complete_graph(len(df_dict))

    # Add attributes to the nodes
    for i, (key, df) in enumerate(df_dict.items()):
        fully_connected_graph.nodes[i]['x'] = df['Xkoordinat'].iloc[0]
        fully_connected_graph.nodes[i]['y'] = df['Ykoordinat'].iloc[0]
        fully_connected_graph.nodes[i]['traffic_flow'] = df['traffic_flow'].values
        
    return fully_connected_graph, None

def create_fully_connected_graph_RANDOM_WEIGHTS(df_dict):
    # Connect every node to every other node without weights 
    fully_connected_graph = nx.complete_graph(len(df_dict))

    # Add attributes to the nodes
    for i, (key, df) in enumerate(df_dict.items()):
        fully_connected_graph.nodes[i]['x'] = df['Xkoordinat'].iloc[0]
        fully_connected_graph.nodes[i]['y'] = df['Ykoordinat'].iloc[0]
        fully_connected_graph.nodes[i]['traffic_flow'] = df['traffic_flow'].values

    # Add random weights to the edges
    for u, v in fully_connected_graph.edges:
        fully_connected_graph[u][v]['weight'] = np.random.rand()
        
    return fully_connected_graph, nx.get_edge_attributes(fully_connected_graph, 'weight')

import networkx as nx
import numpy as np
from scipy.spatial import Delaunay
from sklearn.metrics.pairwise import cosine_similarity


def create_adaptive_threshold_graph(df_dict_full, df_dict_train, threshold_factor=1.0, weighted=False, degree=4):
    """
    Create a graph using an adaptive threshold based on the mean and std of correlations.
    """
    graph = nx.Graph()
    correlations = {}

    # Add nodes
    for key, df in df_dict_full.items():
        graph.add_node(
            key,
            x=df['Xkoordinat'].iloc[0],
            y=df['Ykoordinat'].iloc[0],
            traffic_flow=df['traffic_flow'].values
        )

    # Compute correlations
    for key1, df1_train in df_dict_train.items():
        for key2, df2_train in df_dict_train.items():
            if key1 >= key2:
                continue
            correlation = np.corrcoef(df1_train['traffic_flow'], df2_train['traffic_flow'])[0, 1]
            correlations[key1, key2] = correlation
            correlations[key2, key1] = correlation

    # Calculate adaptive threshold
    corr_values = np.array(list(correlations.values()))
    adaptive_threshold = np.mean(corr_values) + threshold_factor * np.std(corr_values)

    # Add edges based on adaptive threshold and degree constraint
    for key1 in df_dict_full.keys():
        potential_edges = [
            (key2, correlations[key1, key2])
            for key2 in df_dict_full.keys() if key1 != key2 and (key1, key2) in correlations
        ]
        potential_edges = sorted(potential_edges, key=lambda x: -x[1])

        for key2, corr in potential_edges:
            if graph.degree[key1] < degree and graph.degree[key2] < degree:
                if corr > adaptive_threshold:
                    if weighted:
                        graph.add_edge(key1, key2, weight=corr)
                    else:
                        graph.add_edge(key1, key2)

    graph = clean_graph(graph)
    return graph, None


def create_cosine_similarity_graph(df_dict, weighted=False, degree=4):
    """
    Create a graph based on cosine similarity between node features.
    """
    graph = nx.Graph()
    feature_vectors = {}
    similarities = {}

    # Add nodes and collect feature vectors
    for key, df in df_dict.items():
        graph.add_node(
            key,
            x=df['Xkoordinat'].iloc[0],
            y=df['Ykoordinat'].iloc[0],
            traffic_flow=df['traffic_flow'].values
        )
        feature_vectors[key] = df['traffic_flow'].values

    # Compute cosine similarities
    keys = list(feature_vectors.keys())
    vectors = np.array([feature_vectors[key] for key in keys])
    similarity_matrix = cosine_similarity(vectors)

    for i, key1 in enumerate(keys):
        for j, key2 in enumerate(keys):
            if i >= j:
                continue
            similarities[key1, key2] = similarity_matrix[i, j]
            similarities[key2, key1] = similarity_matrix[i, j]

    # Add edges based on similarity and degree constraint
    for key1 in df_dict.keys():
        potential_edges = [
            (key2, similarities[key1, key2])
            for key2 in df_dict.keys() if key1 != key2 and (key1, key2) in similarities
        ]
        potential_edges = sorted(potential_edges, key=lambda x: -x[1])

        for key2, sim in potential_edges:
            if graph.degree[key1] < degree and graph.degree[key2] < degree:
                if weighted:
                    graph.add_edge(key1, key2, weight=sim)
                else:
                    graph.add_edge(key1, key2)

    graph = clean_graph(graph)
    return graph, None

def create_dynamic_weight_graph(df_dict, lookback, pred_horizon, adaptive_factor=1.0, max_degree=4):
    """
    Create a graph with dynamic weights based on adaptive thresholds.
    
    Args:
        df_dict (dict): Dictionary of DataFrames with time-series data.
        lookback (int): Number of time steps to look back.
        pred_horizon (int): Number of time steps to predict.
        adaptive_factor (float): Factor to scale the adaptive threshold.
        max_degree (int): Maximum degree for each node in the graph.
        
    Returns:
        dynamic_graph (nx.Graph): The graph with dynamic weights.
        weight_dict (dict): Dictionary of dynamic weights for each edge.
    """
    dynamic_graph = nx.Graph()
    weight_dict = {}
    
    # Add nodes with attributes
    for key, df in df_dict.items():
        dynamic_graph.add_node(
            key,
            x=df['Xkoordinat'].iloc[0],
            y=df['Ykoordinat'].iloc[0],
            traffic_flow=df['traffic_flow'].values
        )
    
    # Compute dynamic weights for each pair of nodes
    for key1, df1 in df_dict.items():
        for key2, df2 in df_dict.items():
            if key1 == key2:
                continue
            
            # Extract sliding window data
            series1 = df1['traffic_flow'].values
            series2 = df2['traffic_flow'].values
            weights = []
            
            for i in range(len(series1) - lookback - pred_horizon + 1):
                window1 = series1[i:i + lookback]
                window2 = series2[i:i + lookback]
                corr = np.corrcoef(window1, window2)[0, 1]
                weights.append(corr)
            
            # Calculate average weight and set adaptive threshold
            avg_weight = np.mean(weights)
            threshold = adaptive_factor * avg_weight
            
            if avg_weight > threshold:
                weight_dict[key1, key2] = avg_weight
                dynamic_graph.add_edge(key1, key2, weight=avg_weight)
    
    # Apply degree constraint
    for node in dynamic_graph.nodes:
        edges = sorted(
            dynamic_graph.edges(node, data=True),
            key=lambda x: x[2]['weight'],
            reverse=True
        )
        if len(edges) > max_degree:
            for edge in edges[max_degree:]:
                dynamic_graph.remove_edge(edge[0], edge[1])
    
    # Clean the graph
    dynamic_graph = clean_graph(dynamic_graph)
    return dynamic_graph, weight_dict


adaptive_graph, _ = create_adaptive_threshold_graph(final_dataframes, df_dict_train, threshold_factor=0.2, weighted=True)
cosine_graph, _ = create_cosine_similarity_graph(df_dict_train, weighted=True)
adaptive_graph_dynamic_weights, weights_dict_adaptive = create_dynamic_weight_graph(final_dataframes, lookback, pred_horizon, adaptive_factor=1.0, max_degree=4)
# Out:
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 26 nodes.
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 32 nodes.
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 32 nodes.

# %%
 = create_dynamic_weight_graph(final_dataframes, lookback, pred_horizon, adaptive_factor=1.0, max_degree=4)

# %%
# Plot the graphs
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Adaptive threshold graph
nx.draw(
    adaptive_graph,
    # pos shouold be spring layout
    pos=nx.spring_layout(adaptive_graph),
    ax=axs[0],
    node_size=50,
    with_labels=False
)
axs[0].set_title("Adaptive Threshold Graph")


# Cosine similarity graph
nx.draw(
    cosine_graph,
    pos=nx.spring_layout(cosine_graph),
    ax=axs[2],
    node_size=50,
    with_labels=False
)
axs[2].set_title("Cosine Similarity Graph")
# Out:
# Text(0.5, 1.0, 'Cosine Similarity Graph')

# %%
# Other graphs
distance_graph_weighted, distance_dict = create_distance_graph(final_dataframes, weighted=True, degree=4)
distance_graph_unweighted, _ = create_distance_graph(final_dataframes, weighted=False, degree=4)

correlation_graph_weighted, correlation_dict = create_correlation_graph(df_dict_full=df_dict, df_dict_train=df_dict_train, threshold=0.7, weighted=True, degree=10)
#correlation_graph_unweighted, _ = create_correlation_graph(df_dict_full=df_dict, df_dict_train=df_dict_train, threshold=0.7, weighted=False, degree=10)

fully_connected_graph, _ = create_fully_connected_graph(final_dataframes)
#fully_connected_graph_RANDOM_WEIGHTS, fully_connected_weights = create_fully_connected_graph_RANDOM_WEIGHTS(final_dataframes)
# Out:
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 16 nodes.
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 16 nodes.
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 31 nodes.

# %% [markdown]
# Plot Graphs if wanted

# %%
# # Plot the Correlation graph without labels or edge attributes, use a spring layout, with a title that explain how they where plotted
# plt.figure(figsize=(6, 6))
# plt.title("Correlation Graph with Spring Layout")
# pos = nx.spring_layout(correlation_graph_weighted)
# nx.draw(correlation_graph_weighted, pos, with_labels=False, node_size=50, node_color='blue', edge_color='gray')
# plt.show()

# # Extract positions from the graph's node attributes
# pos = {node: (data['x'], data['y']) for node, data in distance_graph_weighted.nodes(data=True)}
# x_values = [coord[0] for coord in pos.values()]
# y_values = [coord[1] for coord in pos.values()]
# plt.figure(figsize=(8, 8))
# plt.title("Distance Graph with Geographic Layout", fontsize=14)


# plt.grid(True, linestyle='--', alpha=0.5)
# plt.scatter(x_values, y_values, c='blue', s=50, label='Nodes')
# for edge in distance_graph_weighted.edges():
#     x_coords = [pos[edge[0]][0], pos[edge[1]][0]]
#     y_coords = [pos[edge[0]][1], pos[edge[1]][1]]
#     plt.plot(x_coords, y_coords, color='gray', alpha=0.7)
# plt.xlabel("X Coordinate", fontsize=12)
# plt.ylabel("Y Coordinate", fontsize=12)
# plt.legend()
# plt.show()


# # Plot the Correlation graph without labels or edge attributes, use a spring layout, with a title that explain how they where plotted
# plt.figure(figsize=(6, 6))
# plt.title("Fully Connected Graph with Spring Layout")
# pos = nx.spring_layout(fully_connected_graph)
# nx.draw(fully_connected_graph, pos, with_labels=False, node_size=50, node_color='blue', edge_color='gray')
# plt.show()

# %% [markdown]
# ## Model Section

# %%
import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from torch.optim import Adam
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.model_selection import train_test_split

# %% [markdown]
# Create Data

# %%
# Prepare sliding window data
X_train_dict, y_train_dict = create_sliding_window_data(df_dict_train, lookback, pred_horizon)
X_test_dict, y_test_dict = create_sliding_window_data(df_dict_test, lookback, pred_horizon)

# Combine data from all nodes
X_train_list = []
y_train_list = []
for key in X_train_dict:
    X_train_list.append(X_train_dict[key])
    y_train_list.append(y_train_dict[key])

X_train = np.concatenate(X_train_list, axis=0)
y_train = np.concatenate(y_train_list, axis=0)

X_test_list = []
y_test_list = []
for key in X_test_dict:
    X_test_list.append(X_test_dict[key])
    y_test_list.append(y_test_dict[key])

X_test = np.concatenate(X_test_list, axis=0)
y_test = np.concatenate(y_test_list, axis=0)

# Split training data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.1, random_state=42
)

# Convert to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float)
y_train = torch.tensor(y_train, dtype=torch.float)

X_val = torch.tensor(X_val, dtype=torch.float)
y_val = torch.tensor(y_val, dtype=torch.float)

X_test = torch.tensor(X_test, dtype=torch.float)
y_test = torch.tensor(y_test, dtype=torch.float)

# Prepare graph edges with integer mapping
node_mapping = {node: idx for idx, node in enumerate(correlation_graph_weighted.nodes())}

edge_index = torch.tensor(
    [[node_mapping[edge[0]], node_mapping[edge[1]]] for edge in correlation_graph_weighted.edges],
    dtype=torch.long
).t().contiguous()

# Create PyTorch Geometric Data objects
train_data = Data(x=X_train, edge_index=edge_index, y=y_train.view(-1, pred_horizon))
val_data = Data(x=X_val, edge_index=edge_index, y=y_val.view(-1, pred_horizon))
test_data = Data(x=X_test, edge_index=edge_index, y=y_test.view(-1, pred_horizon))

# %% [markdown]
# Helper Function to create train and test dataset in a deterministic way

# %%
# Define GNN model
class Baseline(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.fc = torch.nn.Linear(hidden_channels, out_channels)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        x = self.fc(x)
        return x

class ImprovedBaseline(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, dropout_rate=0.2):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.dropout = torch.nn.Dropout(p=dropout_rate)
        self.fc = torch.nn.Linear(hidden_channels, out_channels)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.bn1(x)
        x = self.dropout(x)
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = self.bn2(x)
        x = self.dropout(x)
        x = self.fc(x)
        return x

class Baseline_updatet(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.fc = torch.nn.Linear(hidden_channels, out_channels)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = self.conv3(x, edge_index)
        x = self.fc(x)
        return x


# Define GNN model
class TrafficGCN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.conv4 = GCNConv(hidden_channels, hidden_channels)
        self.fc = torch.nn.Linear(hidden_channels, out_channels)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        x = self.conv4(x, edge_index)
        x = self.fc(x)
        return x

# %%
def split_dataframes(df_dict, train_ratio=0.7):
    """
    Splits each DataFrame in df_dict into training and testing parts based on time indices.

    Returns:
        df_dict_train: Dictionary of training DataFrames.
        df_dict_test: Dictionary of testing DataFrames.
    """
    df_dict_train = {}
    df_dict_test = {}
    for key, df in df_dict.items():
        n_time_steps = len(df['traffic_flow'])
        train_size = int(n_time_steps * train_ratio)
        df_train = df.iloc[:train_size].copy()
        df_test = df.iloc[train_size:].copy()
        df_dict_train[key] = df_train
        df_dict_test[key] = df_test
    return df_dict_train, df_dict_test

def combine_node_data(X_dict, y_dict):
    """
    Combines data from all nodes.

    Returns:
        X_combined: Combined input sequences from all nodes.
        y_combined: Combined target sequences from all nodes.
    """
    X_list = []
    y_list = []
    for key in X_dict:
        X_list.append(X_dict[key])
        y_list.append(y_dict[key])
    X_combined = np.concatenate(X_list, axis=0)
    y_combined = np.concatenate(y_list, axis=0)
    return X_combined, y_combined

def convert_to_tensors_and_split(X, y, val_ratio=0.1, random_state=42):
    """
    Converts data to PyTorch tensors and splits into train and validation sets.

    Returns:
        X_train: Training input tensor.
        X_val: Validation input tensor.
        y_train: Training target tensor.
        y_val: Validation target tensor.
    """
    # Convert to PyTorch tensors
    X_tensor = torch.tensor(X, dtype=torch.float)
    y_tensor = torch.tensor(y, dtype=torch.float)

    # Split into training and validation sets
    X_train, X_val, y_train, y_val = train_test_split(
        X_tensor, y_tensor, test_size=val_ratio, random_state=random_state
    )
    return X_train, X_val, y_train, y_val

def prepare_pyg_data(X_train, y_train, X_val, y_val, X_test, y_test, edge_index, pred_horizon):
    """
    Prepares PyTorch Geometric Data objects for training, validation, and testing.

    Returns:
        train_data: Data object for training.
        val_data: Data object for validation.
        test_data: Data object for testing.
    """
    train_data = Data(x=X_train, edge_index=edge_index, y=y_train.view(-1, pred_horizon))
    val_data = Data(x=X_val, edge_index=edge_index, y=y_val.view(-1, pred_horizon))
    test_data = Data(x=X_test, edge_index=edge_index, y=y_test.view(-1, pred_horizon))
    return train_data, val_data, test_data


train_ratio = 0.7  # 70% training data
df_dict_train, df_dict_test = split_dataframes(final_dataframes, train_ratio)
amount_degrees = 10
# Models to evaluate
graph_models = {
    "Distance_Weighted": lambda: create_distance_graph(final_dataframes, weighted=True, degree=amount_degrees),
    #"Distance_Unweighted": lambda: create_distance_graph(final_dataframes, weighted=False, degree=amount_degrees),
    "Correlation_Weighted": lambda: create_correlation_graph(final_dataframes, df_dict_train, threshold=0.6, weighted=True, degree=amount_degrees),
    #"Correlation_Unweighted": lambda: create_correlation_graph(final_dataframes, threshold=0.6, weighted=False, degree=amount_degrees),
    #"Fully_Connected": lambda: (create_fully_connected_graph(final_dataframes), None),
    #"Fully_Connected_random_weights": lambda: (create_fully_connected_graph_RANDOM_WEIGHTS(final_dataframes)),
    "Adaptive_Threshold": lambda: create_adaptive_threshold_graph(final_dataframes, df_dict_train, threshold_factor=0.2, weighted=True, degree=amount_degrees),
    "Cosine_Similarity": lambda: create_cosine_similarity_graph(df_dict_train, weighted=True, degree=amount_degrees),
    "Dynamic_Weight": lambda: create_dynamic_weight_graph(df_dict_train, lookback, pred_horizon, adaptive_factor=1.0, max_degree=amount_degrees),
}

# Initialize results dictionary
results = {}

# Model parameters
hc = 32
lookback = 100
pred_horizon = 1

# Train and evaluate each model
for model_name, graph_fn in graph_models.items():
    print(f"Running model: {model_name}")
    
    # Create graph and prepare data
    graph, _ = graph_fn()

    node_mapping = {node: idx for idx, node in enumerate(graph.nodes())}
    
    edge_index = torch.tensor(
        [[node_mapping[edge[0]], node_mapping[edge[1]]] for edge in graph.edges],
        dtype=torch.long
    ).t().contiguous()
    
    # Create sliding window data per node for training and testing
    X_train_dict, y_train_dict = create_sliding_window_data(df_dict_train, lookback, pred_horizon)
    X_test_dict, y_test_dict = create_sliding_window_data(df_dict_test, lookback, pred_horizon)
    
    # Combine data from all nodes
    X_train, y_train = combine_node_data(X_train_dict, y_train_dict)
    X_test, y_test = combine_node_data(X_test_dict, y_test_dict)
    
    # Convert to tensors and split training data into train and validation sets
    X_train, X_val, y_train, y_val = convert_to_tensors_and_split(X_train, y_train, val_ratio=0.1, random_state=42)
    
    # Convert test data to tensors
    X_test = torch.tensor(X_test, dtype=torch.float)
    y_test = torch.tensor(y_test, dtype=torch.float)
    
    print(f"{model_name} - Training samples: {X_train.shape[0]}")
    print(f"{model_name} - Validation samples: {X_val.shape[0]}")
    print(f"{model_name} - Test samples: {X_test.shape[0]}")
    
    # Prepare PyTorch Geometric Data objects
    train_data, val_data, test_data = prepare_pyg_data(X_train, y_train, X_val, y_val, X_test, y_test, edge_index, pred_horizon)
    
    # Initialize model
    model = TrafficGCN(in_channels=lookback, hidden_channels=hc, out_channels=pred_horizon)
    optimizer = Adam(model.parameters(), lr=0.001)
    criterion = torch.nn.MSELoss()
    
    # Train model
    train_losses = []
    val_losses = []
    for epoch in range(500):
        optimizer.zero_grad()
        
        # Training
        model.train()
        out = model(train_data)
        train_loss = criterion(out, train_data.y)
        train_loss.backward()
        optimizer.step()
        
        # Validation
        model.eval()
        with torch.no_grad():
            val_out = model(val_data)
            val_loss = criterion(val_out, val_data.y)
        
        # Track losses
        train_losses.append(train_loss.item())
        val_losses.append(val_loss.item())
        
        if epoch % 1 == 0:
            print(f"{model_name} - Epoch {epoch}: Train Loss: {train_loss.item()}, Val Loss: {val_loss.item()}")
    
    # Evaluate on test data
    model.eval()
    with torch.no_grad():
        test_out = model(test_data)
        test_loss = criterion(test_out, test_data.y)
        actual_values = test_data.y.cpu().numpy()
        predicted_values = test_out.cpu().numpy()
    
    print(f"{model_name} - Test Loss: {test_loss.item()}")
    
    # Save results
    results[model_name] = {
        "train_losses": train_losses,
        "val_losses": val_losses,
        "test_loss": test_loss.item(),
        "actual_values": actual_values,
        "predicted_values": predicted_values
    }
# Out:
# Running model: Distance_Weighted
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 31 nodes.
# Distance_Weighted - Training samples: 691603
# Distance_Weighted - Validation samples: 76845
# Distance_Weighted - Test samples: 327520
# Distance_Weighted - Epoch 0: Train Loss: 32785.46484375, Val Loss: 28639.599609375
# Distance_Weighted - Epoch 1: Train Loss: 28188.1875, Val Loss: 24306.748046875
# Distance_Weighted - Epoch 2: Train Loss: 23900.431640625, Val Loss: 20397.41015625
# Distance_Weighted - Epoch 3: Train Loss: 20030.38671875, Val Loss: 16941.154296875
# Distance_Weighted - Epoch 4: Train Loss: 16613.36328125, Val Loss: 13992.5341796875
# Distance_Weighted - Epoch 5: Train Loss: 13698.404296875, Val Loss: 11683.3759765625
# Distance_Weighted - Epoch 6: Train Loss: 11420.3046875, Val Loss: 10175.11328125
# Distance_Weighted - Epoch 7: Train Loss: 9946.7216796875, Val Loss: 9462.8486328125
# Distance_Weighted - Epoch 8: Train Loss: 9271.3251953125, Val Loss: 9291.96875
# Distance_Weighted - Epoch 9: Train Loss: 9134.2685546875, Val Loss: 9243.80078125
# Distance_Weighted - Epoch 10: Train Loss: 9116.3896484375, Val Loss: 8957.546875
# Distance_Weighted - Epoch 11: Train Loss: 8852.3720703125, Val Loss: 8299.1767578125
# Distance_Weighted - Epoch 12: Train Loss: 8204.6455078125, Val Loss: 7354.951171875
# Distance_Weighted - Epoch 13: Train Loss: 7262.69091796875, Val Loss: 6324.66650390625
# Distance_Weighted - Epoch 14: Train Loss: 6227.55859375, Val Loss: 5403.349609375
# Distance_Weighted - Epoch 15: Train Loss: 5298.2568359375, Val Loss: 4720.8720703125
# Distance_Weighted - Epoch 16: Train Loss: 4606.1474609375, Val Loss: 4314.66015625
# Distance_Weighted - Epoch 17: Train Loss: 4191.21826171875, Val Loss: 4138.74951171875
# Distance_Weighted - Epoch 18: Train Loss: 4007.95068359375, Val Loss: 4094.396728515625
# Distance_Weighted - Epoch 19: Train Loss: 3959.494873046875, Val Loss: 4071.907958984375
# Distance_Weighted - Epoch 20: Train Loss: 3936.306396484375, Val Loss: 3991.75146484375
# Distance_Weighted - Epoch 21: Train Loss: 3858.243896484375, Val Loss: 3824.540771484375
# Distance_Weighted - Epoch 22: Train Loss: 3696.700927734375, Val Loss: 3588.812255859375
# Distance_Weighted - Epoch 23: Train Loss: 3470.2451171875, Val Loss: 3330.686279296875
# Distance_Weighted - Epoch 24: Train Loss: 3225.692626953125, Val Loss: 3101.66259765625
# Distance_Weighted - Epoch 25: Train Loss: 3014.33154296875, Val Loss: 2939.3193359375
# Distance_Weighted - Epoch 26: Train Loss: 2872.138671875, Val Loss: 2853.292236328125
# Distance_Weighted - Epoch 27: Train Loss: 2805.99169921875, Val Loss: 2818.753662109375
# Distance_Weighted - Epoch 28: Train Loss: 2788.744140625, Val Loss: 2788.33251953125
# Distance_Weighted - Epoch 29: Train Loss: 2771.25439453125, Val Loss: 2720.135986328125
# Distance_Weighted - Epoch 30: Train Loss: 2711.530029296875, Val Loss: 2603.198486328125
# Distance_Weighted - Epoch 31: Train Loss: 2597.987060546875, Val Loss: 2456.564697265625
# Distance_Weighted - Epoch 32: Train Loss: 2450.737060546875, Val Loss: 2313.564453125
# Distance_Weighted - Epoch 33: Train Loss: 2305.856201171875, Val Loss: 2203.454833984375
# Distance_Weighted - Epoch 34: Train Loss: 2194.566650390625, Val Loss: 2138.6953125
# Distance_Weighted - Epoch 35: Train Loss: 2129.903076171875, Val Loss: 2110.14013671875
# Distance_Weighted - Epoch 36: Train Loss: 2103.239990234375, Val Loss: 2094.22119140625
# Distance_Weighted - Epoch 37: Train Loss: 2091.149169921875, Val Loss: 2066.053466796875
# Distance_Weighted - Epoch 38: Train Loss: 2067.993408203125, Val Loss: 2011.0416259765625
# Distance_Weighted - Epoch 39: Train Loss: 2019.213623046875, Val Loss: 1932.6968994140625
# Distance_Weighted - Epoch 40: Train Loss: 1947.6702880859375, Val Loss: 1848.2181396484375
# Distance_Weighted - Epoch 41: Train Loss: 1870.4683837890625, Val Loss: 1778.040283203125
# Distance_Weighted - Epoch 42: Train Loss: 1807.6832275390625, Val Loss: 1733.2548828125
# Distance_Weighted - Epoch 43: Train Loss: 1769.3167724609375, Val Loss: 1707.8072509765625
# Distance_Weighted - Epoch 44: Train Loss: 1748.85107421875, Val Loss: 1684.3232421875
# Distance_Weighted - Epoch 45: Train Loss: 1728.6160888671875, Val Loss: 1648.684814453125
# Distance_Weighted - Epoch 46: Train Loss: 1694.291259765625, Val Loss: 1600.8367919921875
# Distance_Weighted - Epoch 47: Train Loss: 1646.255859375, Val Loss: 1553.8145751953125
# Distance_Weighted - Epoch 48: Train Loss: 1597.8577880859375, Val Loss: 1520.91552734375
# Distance_Weighted - Epoch 49: Train Loss: 1563.349609375, Val Loss: 1504.96240234375
# Distance_Weighted - Epoch 50: Train Loss: 1545.8653564453125, Val Loss: 1494.8782958984375
# Distance_Weighted - Epoch 51: Train Loss: 1535.1796875, Val Loss: 1476.5123291015625
# Distance_Weighted - Epoch 52: Train Loss: 1517.053955078125, Val Loss: 1444.4765625
# Distance_Weighted - Epoch 53: Train Loss: 1486.2001953125, Val Loss: 1406.1405029296875
# Distance_Weighted - Epoch 54: Train Loss: 1449.713134765625, Val Loss: 1373.244873046875
# Distance_Weighted - Epoch 55: Train Loss: 1418.8914794921875, Val Loss: 1350.8487548828125
# Distance_Weighted - Epoch 56: Train Loss: 1398.2705078125, Val Loss: 1333.7867431640625
# Distance_Weighted - Epoch 57: Train Loss: 1382.3577880859375, Val Loss: 1313.559326171875
# Distance_Weighted - Epoch 58: Train Loss: 1362.3990478515625, Val Loss: 1287.4779052734375
# Distance_Weighted - Epoch 59: Train Loss: 1335.814453125, Val Loss: 1260.8587646484375
# Distance_Weighted - Epoch 60: Train Loss: 1308.1571044921875, Val Loss: 1240.27490234375
# Distance_Weighted - Epoch 61: Train Loss: 1286.335693359375, Val Loss: 1226.5009765625
# Distance_Weighted - Epoch 62: Train Loss: 1271.4368896484375, Val Loss: 1213.8958740234375
# Distance_Weighted - Epoch 63: Train Loss: 1258.0675048828125, Val Loss: 1196.9635009765625
# Distance_Weighted - Epoch 64: Train Loss: 1240.9093017578125, Val Loss: 1176.29248046875
# Distance_Weighted - Epoch 65: Train Loss: 1220.3021240234375, Val Loss: 1156.619384765625
# Distance_Weighted - Epoch 66: Train Loss: 1200.8909912109375, Val Loss: 1141.0709228515625
# Distance_Weighted - Epoch 67: Train Loss: 1185.741943359375, Val Loss: 1128.10888671875
# Distance_Weighted - Epoch 68: Train Loss: 1172.9866943359375, Val Loss: 1113.837646484375
# Distance_Weighted - Epoch 69: Train Loss: 1158.71240234375, Val Loss: 1097.4063720703125
# Distance_Weighted - Epoch 70: Train Loss: 1141.84521484375, Val Loss: 1081.506103515625
# Distance_Weighted - Epoch 71: Train Loss: 1125.1451416015625, Val Loss: 1068.5634765625
# Distance_Weighted - Epoch 72: Train Loss: 1111.3192138671875, Val Loss: 1057.5179443359375
# Distance_Weighted - Epoch 73: Train Loss: 1099.6202392578125, Val Loss: 1045.2755126953125
# Distance_Weighted - Epoch 74: Train Loss: 1087.0531005859375, Val Loss: 1030.67822265625
# Distance_Weighted - Epoch 75: Train Loss: 1072.484375, Val Loss: 1015.8495483398438
# Distance_Weighted - Epoch 76: Train Loss: 1057.930908203125, Val Loss: 1003.0579833984375
# Distance_Weighted - Epoch 77: Train Loss: 1045.4200439453125, Val Loss: 991.7371215820312
# Distance_Weighted - Epoch 78: Train Loss: 1034.154541015625, Val Loss: 979.9945068359375
# Distance_Weighted - Epoch 79: Train Loss: 1022.1055297851562, Val Loss: 967.692138671875
# Distance_Weighted - Epoch 80: Train Loss: 1009.1691284179688, Val Loss: 956.3679809570312
# Distance_Weighted - Epoch 81: Train Loss: 997.1251220703125, Val Loss: 946.5355834960938
# Distance_Weighted - Epoch 82: Train Loss: 986.6697998046875, Val Loss: 936.609619140625
# Distance_Weighted - Epoch 83: Train Loss: 976.3827514648438, Val Loss: 925.4756469726562
# Distance_Weighted - Epoch 84: Train Loss: 965.1250610351562, Val Loss: 914.147705078125
# Distance_Weighted - Epoch 85: Train Loss: 953.8314819335938, Val Loss: 903.8793334960938
# Distance_Weighted - Epoch 86: Train Loss: 943.6726684570312, Val Loss: 894.2417602539062
# Distance_Weighted - Epoch 87: Train Loss: 934.0860595703125, Val Loss: 884.2816772460938
# Distance_Weighted - Epoch 88: Train Loss: 924.0034790039062, Val Loss: 874.3728637695312
# Distance_Weighted - Epoch 89: Train Loss: 913.8046264648438, Val Loss: 865.3517456054688
# Distance_Weighted - Epoch 90: Train Loss: 904.458984375, Val Loss: 856.8643798828125
# Distance_Weighted - Epoch 91: Train Loss: 895.7218017578125, Val Loss: 847.951904296875
# Distance_Weighted - Epoch 92: Train Loss: 886.6947021484375, Val Loss: 838.8605346679688
# Distance_Weighted - Epoch 93: Train Loss: 877.5809326171875, Val Loss: 830.46923828125
# Distance_Weighted - Epoch 94: Train Loss: 869.143798828125, Val Loss: 822.7078247070312
# Distance_Weighted - Epoch 95: Train Loss: 861.1971435546875, Val Loss: 814.9940185546875
# Distance_Weighted - Epoch 96: Train Loss: 853.125732421875, Val Loss: 807.5062255859375
# Distance_Weighted - Epoch 97: Train Loss: 845.1527709960938, Val Loss: 800.6276245117188
# Distance_Weighted - Epoch 98: Train Loss: 837.7636108398438, Val Loss: 793.9370727539062
# Distance_Weighted - Epoch 99: Train Loss: 830.6654052734375, Val Loss: 786.9537963867188
# Distance_Weighted - Epoch 100: Train Loss: 823.4317626953125, Val Loss: 780.0184936523438
# Distance_Weighted - Epoch 101: Train Loss: 816.3390502929688, Val Loss: 773.522705078125
# Distance_Weighted - Epoch 102: Train Loss: 809.691162109375, Val Loss: 767.2468872070312
# Distance_Weighted - Epoch 103: Train Loss: 803.169677734375, Val Loss: 761.057373046875
# Distance_Weighted - Epoch 104: Train Loss: 796.6180419921875, Val Loss: 755.1998291015625
# Distance_Weighted - Epoch 105: Train Loss: 790.3551025390625, Val Loss: 749.632568359375
# Distance_Weighted - Epoch 106: Train Loss: 784.4044189453125, Val Loss: 743.976806640625
# Distance_Weighted - Epoch 107: Train Loss: 778.4703979492188, Val Loss: 738.3403930664062
# Distance_Weighted - Epoch 108: Train Loss: 772.61767578125, Val Loss: 732.9924926757812
# Distance_Weighted - Epoch 109: Train Loss: 767.0575561523438, Val Loss: 727.8897705078125
# Distance_Weighted - Epoch 110: Train Loss: 761.6483154296875, Val Loss: 722.9095458984375
# Distance_Weighted - Epoch 111: Train Loss: 756.2703857421875, Val Loss: 718.167236328125
# Distance_Weighted - Epoch 112: Train Loss: 751.09130859375, Val Loss: 713.5787353515625
# Distance_Weighted - Epoch 113: Train Loss: 746.1177368164062, Val Loss: 708.917724609375
# Distance_Weighted - Epoch 114: Train Loss: 741.1719360351562, Val Loss: 704.2802734375
# Distance_Weighted - Epoch 115: Train Loss: 736.3089599609375, Val Loss: 699.8153686523438
# Distance_Weighted - Epoch 116: Train Loss: 731.630126953125, Val Loss: 695.485595703125
# Distance_Weighted - Epoch 117: Train Loss: 727.032470703125, Val Loss: 691.28076171875
# Distance_Weighted - Epoch 118: Train Loss: 722.4815673828125, Val Loss: 687.2372436523438
# Distance_Weighted - Epoch 119: Train Loss: 718.0824584960938, Val Loss: 683.2567138671875
# Distance_Weighted - Epoch 120: Train Loss: 713.7928466796875, Val Loss: 679.2498779296875
# Distance_Weighted - Epoch 121: Train Loss: 709.5396728515625, Val Loss: 675.3287963867188
# Distance_Weighted - Epoch 122: Train Loss: 705.3875122070312, Val Loss: 671.5452880859375
# Distance_Weighted - Epoch 123: Train Loss: 701.344482421875, Val Loss: 667.8678588867188
# Distance_Weighted - Epoch 124: Train Loss: 697.3470458984375, Val Loss: 664.3016357421875
# Distance_Weighted - Epoch 125: Train Loss: 693.4337768554688, Val Loss: 660.8153686523438
# Distance_Weighted - Epoch 126: Train Loss: 689.6221923828125, Val Loss: 657.3156127929688
# Distance_Weighted - Epoch 127: Train Loss: 685.8572387695312, Val Loss: 653.8277587890625
# Distance_Weighted - Epoch 128: Train Loss: 682.14697265625, Val Loss: 650.4291381835938
# Distance_Weighted - Epoch 129: Train Loss: 678.5210571289062, Val Loss: 647.105712890625
# Distance_Weighted - Epoch 130: Train Loss: 674.9434204101562, Val Loss: 643.864013671875
# Distance_Weighted - Epoch 131: Train Loss: 671.4159545898438, Val Loss: 640.709716796875
# Distance_Weighted - Epoch 132: Train Loss: 667.959228515625, Val Loss: 637.5677490234375
# Distance_Weighted - Epoch 133: Train Loss: 664.5394897460938, Val Loss: 634.3777465820312
# Distance_Weighted - Epoch 134: Train Loss: 661.1565551757812, Val Loss: 631.2401123046875
# Distance_Weighted - Epoch 135: Train Loss: 657.849853515625, Val Loss: 628.242431640625
# Distance_Weighted - Epoch 136: Train Loss: 654.6032104492188, Val Loss: 625.38720703125
# Distance_Weighted - Epoch 137: Train Loss: 651.4296875, Val Loss: 622.6239624023438
# Distance_Weighted - Epoch 138: Train Loss: 648.3884887695312, Val Loss: 619.8553466796875
# Distance_Weighted - Epoch 139: Train Loss: 645.4182739257812, Val Loss: 617.0347290039062
# Distance_Weighted - Epoch 140: Train Loss: 642.4727172851562, Val Loss: 614.1865844726562
# Distance_Weighted - Epoch 141: Train Loss: 639.539794921875, Val Loss: 611.3751831054688
# Distance_Weighted - Epoch 142: Train Loss: 636.6255493164062, Val Loss: 608.6851196289062
# Distance_Weighted - Epoch 143: Train Loss: 633.7719116210938, Val Loss: 606.11474609375
# Distance_Weighted - Epoch 144: Train Loss: 631.0145263671875, Val Loss: 603.5969848632812
# Distance_Weighted - Epoch 145: Train Loss: 628.322265625, Val Loss: 601.0964965820312
# Distance_Weighted - Epoch 146: Train Loss: 625.6854248046875, Val Loss: 598.6336059570312
# Distance_Weighted - Epoch 147: Train Loss: 623.0878295898438, Val Loss: 596.2060546875
# Distance_Weighted - Epoch 148: Train Loss: 620.5077514648438, Val Loss: 593.8023071289062
# Distance_Weighted - Epoch 149: Train Loss: 617.9490356445312, Val Loss: 591.4031372070312
# Distance_Weighted - Epoch 150: Train Loss: 615.4296264648438, Val Loss: 589.0214233398438
# Distance_Weighted - Epoch 151: Train Loss: 612.94384765625, Val Loss: 586.663330078125
# Distance_Weighted - Epoch 152: Train Loss: 610.5050048828125, Val Loss: 584.3438720703125
# Distance_Weighted - Epoch 153: Train Loss: 608.1197509765625, Val Loss: 582.073974609375
# Distance_Weighted - Epoch 154: Train Loss: 605.775146484375, Val Loss: 579.8267211914062
# Distance_Weighted - Epoch 155: Train Loss: 603.4623413085938, Val Loss: 577.5819702148438
# Distance_Weighted - Epoch 156: Train Loss: 601.1810302734375, Val Loss: 575.358642578125
# Distance_Weighted - Epoch 157: Train Loss: 598.9274291992188, Val Loss: 573.1801147460938
# Distance_Weighted - Epoch 158: Train Loss: 596.6988525390625, Val Loss: 571.046142578125
# Distance_Weighted - Epoch 159: Train Loss: 594.489013671875, Val Loss: 568.9530639648438
# Distance_Weighted - Epoch 160: Train Loss: 592.2813110351562, Val Loss: 566.81005859375
# Distance_Weighted - Epoch 161: Train Loss: 590.0595703125, Val Loss: 564.7214965820312
# Distance_Weighted - Epoch 162: Train Loss: 587.8185424804688, Val Loss: 562.5922241210938
# Distance_Weighted - Epoch 163: Train Loss: 585.4136962890625, Val Loss: 560.234619140625
# Distance_Weighted - Epoch 164: Train Loss: 582.579345703125, Val Loss: 557.905517578125
# Distance_Weighted - Epoch 165: Train Loss: 579.6307373046875, Val Loss: 556.7726440429688
# Distance_Weighted - Epoch 166: Train Loss: 577.4557495117188, Val Loss: 554.3111572265625
# Distance_Weighted - Epoch 167: Train Loss: 574.896728515625, Val Loss: 551.5713500976562
# Distance_Weighted - Epoch 168: Train Loss: 572.5043334960938, Val Loss: 549.3375244140625
# Distance_Weighted - Epoch 169: Train Loss: 570.4298095703125, Val Loss: 547.5715942382812
# Distance_Weighted - Epoch 170: Train Loss: 568.3860473632812, Val Loss: 545.6853637695312
# Distance_Weighted - Epoch 171: Train Loss: 566.0236206054688, Val Loss: 543.776611328125
# Distance_Weighted - Epoch 172: Train Loss: 563.737060546875, Val Loss: 542.0296630859375
# Distance_Weighted - Epoch 173: Train Loss: 561.7898559570312, Val Loss: 539.7990112304688
# Distance_Weighted - Epoch 174: Train Loss: 559.5106201171875, Val Loss: 537.5195922851562
# Distance_Weighted - Epoch 175: Train Loss: 557.3125610351562, Val Loss: 535.3468627929688
# Distance_Weighted - Epoch 176: Train Loss: 555.2891845703125, Val Loss: 533.0789794921875
# Distance_Weighted - Epoch 177: Train Loss: 553.0162963867188, Val Loss: 531.2802734375
# Distance_Weighted - Epoch 178: Train Loss: 550.8235473632812, Val Loss: 529.7771606445312
# Distance_Weighted - Epoch 179: Train Loss: 548.9321899414062, Val Loss: 527.6903076171875
# Distance_Weighted - Epoch 180: Train Loss: 546.8765258789062, Val Loss: 525.458984375
# Distance_Weighted - Epoch 181: Train Loss: 544.8523559570312, Val Loss: 523.5825805664062
# Distance_Weighted - Epoch 182: Train Loss: 542.8695068359375, Val Loss: 521.73388671875
# Distance_Weighted - Epoch 183: Train Loss: 540.7756958007812, Val Loss: 519.9411010742188
# Distance_Weighted - Epoch 184: Train Loss: 538.7013549804688, Val Loss: 518.2776489257812
# Distance_Weighted - Epoch 185: Train Loss: 536.7356567382812, Val Loss: 516.5592041015625
# Distance_Weighted - Epoch 186: Train Loss: 534.8209228515625, Val Loss: 514.6695556640625
# Distance_Weighted - Epoch 187: Train Loss: 532.8935546875, Val Loss: 512.7713012695312
# Distance_Weighted - Epoch 188: Train Loss: 530.9992065429688, Val Loss: 510.94952392578125
# Distance_Weighted - Epoch 189: Train Loss: 529.1047973632812, Val Loss: 509.18499755859375
# Distance_Weighted - Epoch 190: Train Loss: 527.218017578125, Val Loss: 507.4732360839844
# Distance_Weighted - Epoch 191: Train Loss: 525.3863525390625, Val Loss: 505.79937744140625
# Distance_Weighted - Epoch 192: Train Loss: 523.6185302734375, Val Loss: 504.1628112792969
# Distance_Weighted - Epoch 193: Train Loss: 521.866943359375, Val Loss: 502.54095458984375
# Distance_Weighted - Epoch 194: Train Loss: 520.1240844726562, Val Loss: 500.9555358886719
# Distance_Weighted - Epoch 195: Train Loss: 518.3754272460938, Val Loss: 499.3653869628906
# Distance_Weighted - Epoch 196: Train Loss: 516.638671875, Val Loss: 497.77587890625
# Distance_Weighted - Epoch 197: Train Loss: 514.9392700195312, Val Loss: 496.1738586425781
# Distance_Weighted - Epoch 198: Train Loss: 513.2722778320312, Val Loss: 494.5970153808594
# Distance_Weighted - Epoch 199: Train Loss: 511.640380859375, Val Loss: 493.05926513671875
# Distance_Weighted - Epoch 200: Train Loss: 510.0377197265625, Val Loss: 491.57440185546875
# Distance_Weighted - Epoch 201: Train Loss: 508.43292236328125, Val Loss: 490.1429138183594
# Distance_Weighted - Epoch 202: Train Loss: 506.8387145996094, Val Loss: 488.7181701660156
# Distance_Weighted - Epoch 203: Train Loss: 505.2598876953125, Val Loss: 487.3288269042969
# Distance_Weighted - Epoch 204: Train Loss: 503.7108459472656, Val Loss: 485.9284973144531
# Distance_Weighted - Epoch 205: Train Loss: 502.1822204589844, Val Loss: 484.45477294921875
# Distance_Weighted - Epoch 206: Train Loss: 500.6549377441406, Val Loss: 482.9599304199219
# Distance_Weighted - Epoch 207: Train Loss: 499.1486511230469, Val Loss: 481.5146484375
# Distance_Weighted - Epoch 208: Train Loss: 497.67742919921875, Val Loss: 480.0947265625
# Distance_Weighted - Epoch 209: Train Loss: 496.2320251464844, Val Loss: 478.7632141113281
# Distance_Weighted - Epoch 210: Train Loss: 494.8172912597656, Val Loss: 477.4980163574219
# Distance_Weighted - Epoch 211: Train Loss: 493.4208679199219, Val Loss: 476.2675476074219
# Distance_Weighted - Epoch 212: Train Loss: 492.0492248535156, Val Loss: 475.0741271972656
# Distance_Weighted - Epoch 213: Train Loss: 490.7106628417969, Val Loss: 473.90399169921875
# Distance_Weighted - Epoch 214: Train Loss: 489.3898010253906, Val Loss: 472.7353515625
# Distance_Weighted - Epoch 215: Train Loss: 488.09625244140625, Val Loss: 471.58447265625
# Distance_Weighted - Epoch 216: Train Loss: 486.82403564453125, Val Loss: 470.45013427734375
# Distance_Weighted - Epoch 217: Train Loss: 485.5721130371094, Val Loss: 469.3318176269531
# Distance_Weighted - Epoch 218: Train Loss: 484.3321533203125, Val Loss: 468.2386474609375
# Distance_Weighted - Epoch 219: Train Loss: 483.10504150390625, Val Loss: 467.160400390625
# Distance_Weighted - Epoch 220: Train Loss: 481.90179443359375, Val Loss: 466.0926208496094
# Distance_Weighted - Epoch 221: Train Loss: 480.7144775390625, Val Loss: 465.0315246582031
# Distance_Weighted - Epoch 222: Train Loss: 479.54193115234375, Val Loss: 463.97064208984375
# Distance_Weighted - Epoch 223: Train Loss: 478.3838195800781, Val Loss: 462.9305725097656
# Distance_Weighted - Epoch 224: Train Loss: 477.244140625, Val Loss: 461.9095458984375
# Distance_Weighted - Epoch 225: Train Loss: 476.1209716796875, Val Loss: 460.9076843261719
# Distance_Weighted - Epoch 226: Train Loss: 475.0138854980469, Val Loss: 459.9305725097656
# Distance_Weighted - Epoch 227: Train Loss: 473.92205810546875, Val Loss: 458.9688720703125
# Distance_Weighted - Epoch 228: Train Loss: 472.8450622558594, Val Loss: 458.02630615234375
# Distance_Weighted - Epoch 229: Train Loss: 471.78369140625, Val Loss: 457.08135986328125
# Distance_Weighted - Epoch 230: Train Loss: 470.7367858886719, Val Loss: 456.1498718261719
# Distance_Weighted - Epoch 231: Train Loss: 469.70245361328125, Val Loss: 455.22088623046875
# Distance_Weighted - Epoch 232: Train Loss: 468.6805725097656, Val Loss: 454.3021545410156
# Distance_Weighted - Epoch 233: Train Loss: 467.6724548339844, Val Loss: 453.4026794433594
# Distance_Weighted - Epoch 234: Train Loss: 466.67901611328125, Val Loss: 452.5157775878906
# Distance_Weighted - Epoch 235: Train Loss: 465.697509765625, Val Loss: 451.6448059082031
# Distance_Weighted - Epoch 236: Train Loss: 464.7280578613281, Val Loss: 450.78076171875
# Distance_Weighted - Epoch 237: Train Loss: 463.7678527832031, Val Loss: 449.9281311035156
# Distance_Weighted - Epoch 238: Train Loss: 462.81658935546875, Val Loss: 449.07916259765625
# Distance_Weighted - Epoch 239: Train Loss: 461.87615966796875, Val Loss: 448.24609375
# Distance_Weighted - Epoch 240: Train Loss: 460.9475402832031, Val Loss: 447.4172058105469
# Distance_Weighted - Epoch 241: Train Loss: 460.033447265625, Val Loss: 446.60711669921875
# Distance_Weighted - Epoch 242: Train Loss: 459.13470458984375, Val Loss: 445.817626953125
# Distance_Weighted - Epoch 243: Train Loss: 458.2604675292969, Val Loss: 445.0990295410156
# Distance_Weighted - Epoch 244: Train Loss: 457.4303894042969, Val Loss: 444.3663024902344
# Distance_Weighted - Epoch 245: Train Loss: 456.6409912109375, Val Loss: 443.672119140625
# Distance_Weighted - Epoch 246: Train Loss: 455.8360290527344, Val Loss: 442.78997802734375
# Distance_Weighted - Epoch 247: Train Loss: 454.9048767089844, Val Loss: 441.9558410644531
# Distance_Weighted - Epoch 248: Train Loss: 453.9718322753906, Val Loss: 441.28399658203125
# Distance_Weighted - Epoch 249: Train Loss: 453.20135498046875, Val Loss: 440.6502380371094
# Distance_Weighted - Epoch 250: Train Loss: 452.5108337402344, Val Loss: 439.9349365234375
# Distance_Weighted - Epoch 251: Train Loss: 451.66754150390625, Val Loss: 439.1076965332031
# Distance_Weighted - Epoch 252: Train Loss: 450.7801513671875, Val Loss: 438.4275207519531
# Distance_Weighted - Epoch 253: Train Loss: 450.0345458984375, Val Loss: 437.8309020996094
# Distance_Weighted - Epoch 254: Train Loss: 449.33282470703125, Val Loss: 437.04547119140625
# Distance_Weighted - Epoch 255: Train Loss: 448.52923583984375, Val Loss: 436.3138122558594
# Distance_Weighted - Epoch 256: Train Loss: 447.71868896484375, Val Loss: 435.6803894042969
# Distance_Weighted - Epoch 257: Train Loss: 447.00640869140625, Val Loss: 434.9954528808594
# Distance_Weighted - Epoch 258: Train Loss: 446.2872009277344, Val Loss: 434.3311767578125
# Distance_Weighted - Epoch 259: Train Loss: 445.5130310058594, Val Loss: 433.6542053222656
# Distance_Weighted - Epoch 260: Train Loss: 444.7622985839844, Val Loss: 433.0271301269531
# Distance_Weighted - Epoch 261: Train Loss: 444.0663757324219, Val Loss: 432.4097595214844
# Distance_Weighted - Epoch 262: Train Loss: 443.3442077636719, Val Loss: 431.72186279296875
# Distance_Weighted - Epoch 263: Train Loss: 442.5960998535156, Val Loss: 431.0914306640625
# Distance_Weighted - Epoch 264: Train Loss: 441.8777770996094, Val Loss: 430.49365234375
# Distance_Weighted - Epoch 265: Train Loss: 441.18731689453125, Val Loss: 429.8533020019531
# Distance_Weighted - Epoch 266: Train Loss: 440.4842834472656, Val Loss: 429.2230529785156
# Distance_Weighted - Epoch 267: Train Loss: 439.7735595703125, Val Loss: 428.6168518066406
# Distance_Weighted - Epoch 268: Train Loss: 439.08331298828125, Val Loss: 428.0306701660156
# Distance_Weighted - Epoch 269: Train Loss: 438.4130554199219, Val Loss: 427.442626953125
# Distance_Weighted - Epoch 270: Train Loss: 437.73492431640625, Val Loss: 426.8367004394531
# Distance_Weighted - Epoch 271: Train Loss: 437.0528259277344, Val Loss: 426.26483154296875
# Distance_Weighted - Epoch 272: Train Loss: 436.380859375, Val Loss: 425.71649169921875
# Distance_Weighted - Epoch 273: Train Loss: 435.7201232910156, Val Loss: 425.13812255859375
# Distance_Weighted - Epoch 274: Train Loss: 435.0591125488281, Val Loss: 424.59521484375
# Distance_Weighted - Epoch 275: Train Loss: 434.3929748535156, Val Loss: 424.0262451171875
# Distance_Weighted - Epoch 276: Train Loss: 433.731201171875, Val Loss: 423.44781494140625
# Distance_Weighted - Epoch 277: Train Loss: 433.0787048339844, Val Loss: 422.8871154785156
# Distance_Weighted - Epoch 278: Train Loss: 432.4350891113281, Val Loss: 422.3321838378906
# Distance_Weighted - Epoch 279: Train Loss: 431.79559326171875, Val Loss: 421.7975158691406
# Distance_Weighted - Epoch 280: Train Loss: 431.1580505371094, Val Loss: 421.24859619140625
# Distance_Weighted - Epoch 281: Train Loss: 430.51934814453125, Val Loss: 420.7351379394531
# Distance_Weighted - Epoch 282: Train Loss: 429.88543701171875, Val Loss: 420.2121887207031
# Distance_Weighted - Epoch 283: Train Loss: 429.2597351074219, Val Loss: 419.6727294921875
# Distance_Weighted - Epoch 284: Train Loss: 428.6379699707031, Val Loss: 419.1514892578125
# Distance_Weighted - Epoch 285: Train Loss: 428.0210876464844, Val Loss: 418.63427734375
# Distance_Weighted - Epoch 286: Train Loss: 427.41107177734375, Val Loss: 418.1379089355469
# Distance_Weighted - Epoch 287: Train Loss: 426.8104553222656, Val Loss: 417.6177062988281
# Distance_Weighted - Epoch 288: Train Loss: 426.2186279296875, Val Loss: 417.12054443359375
# Distance_Weighted - Epoch 289: Train Loss: 425.6367492675781, Val Loss: 416.608642578125
# Distance_Weighted - Epoch 290: Train Loss: 425.0679626464844, Val Loss: 416.16845703125
# Distance_Weighted - Epoch 291: Train Loss: 424.5101318359375, Val Loss: 415.66253662109375
# Distance_Weighted - Epoch 292: Train Loss: 423.9626159667969, Val Loss: 415.2637634277344
# Distance_Weighted - Epoch 293: Train Loss: 423.4229736328125, Val Loss: 414.7519836425781
# Distance_Weighted - Epoch 294: Train Loss: 422.8908386230469, Val Loss: 414.323974609375
# Distance_Weighted - Epoch 295: Train Loss: 422.3399658203125, Val Loss: 413.79638671875
# Distance_Weighted - Epoch 296: Train Loss: 421.77093505859375, Val Loss: 413.27520751953125
# Distance_Weighted - Epoch 297: Train Loss: 421.1563415527344, Val Loss: 412.70599365234375
# Distance_Weighted - Epoch 298: Train Loss: 420.533203125, Val Loss: 412.2184143066406
# Distance_Weighted - Epoch 299: Train Loss: 419.94903564453125, Val Loss: 411.7674865722656
# Distance_Weighted - Epoch 300: Train Loss: 419.4169006347656, Val Loss: 411.3102722167969
# Distance_Weighted - Epoch 301: Train Loss: 418.9173278808594, Val Loss: 410.91748046875
# Distance_Weighted - Epoch 302: Train Loss: 418.4144287109375, Val Loss: 410.43408203125
# Distance_Weighted - Epoch 303: Train Loss: 417.8839111328125, Val Loss: 409.97308349609375
# Distance_Weighted - Epoch 304: Train Loss: 417.3124694824219, Val Loss: 409.4315490722656
# Distance_Weighted - Epoch 305: Train Loss: 416.73095703125, Val Loss: 408.9510192871094
# Distance_Weighted - Epoch 306: Train Loss: 416.1598205566406, Val Loss: 408.4732971191406
# Distance_Weighted - Epoch 307: Train Loss: 415.61920166015625, Val Loss: 408.01068115234375
# Distance_Weighted - Epoch 308: Train Loss: 415.1059875488281, Val Loss: 407.5993347167969
# Distance_Weighted - Epoch 309: Train Loss: 414.6144714355469, Val Loss: 407.1903076171875
# Distance_Weighted - Epoch 310: Train Loss: 414.15130615234375, Val Loss: 406.808837890625
# Distance_Weighted - Epoch 311: Train Loss: 413.7080078125, Val Loss: 406.40966796875
# Distance_Weighted - Epoch 312: Train Loss: 413.2757568359375, Val Loss: 406.0520935058594
# Distance_Weighted - Epoch 313: Train Loss: 412.82208251953125, Val Loss: 405.6034851074219
# Distance_Weighted - Epoch 314: Train Loss: 412.3440246582031, Val Loss: 405.1578063964844
# Distance_Weighted - Epoch 315: Train Loss: 411.838134765625, Val Loss: 404.6972961425781
# Distance_Weighted - Epoch 316: Train Loss: 411.3250732421875, Val Loss: 404.235595703125
# Distance_Weighted - Epoch 317: Train Loss: 410.811767578125, Val Loss: 403.8038330078125
# Distance_Weighted - Epoch 318: Train Loss: 410.3346862792969, Val Loss: 403.4338684082031
# Distance_Weighted - Epoch 319: Train Loss: 409.89849853515625, Val Loss: 403.08599853515625
# Distance_Weighted - Epoch 320: Train Loss: 409.49456787109375, Val Loss: 402.7395324707031
# Distance_Weighted - Epoch 321: Train Loss: 409.10516357421875, Val Loss: 402.39410400390625
# Distance_Weighted - Epoch 322: Train Loss: 408.7278137207031, Val Loss: 402.0898132324219
# Distance_Weighted - Epoch 323: Train Loss: 408.3550109863281, Val Loss: 401.7203063964844
# Distance_Weighted - Epoch 324: Train Loss: 407.9544982910156, Val Loss: 401.3612365722656
# Distance_Weighted - Epoch 325: Train Loss: 407.53973388671875, Val Loss: 400.9388732910156
# Distance_Weighted - Epoch 326: Train Loss: 407.1024475097656, Val Loss: 400.58282470703125
# Distance_Weighted - Epoch 327: Train Loss: 406.663818359375, Val Loss: 400.14056396484375
# Distance_Weighted - Epoch 328: Train Loss: 406.22320556640625, Val Loss: 399.7829895019531
# Distance_Weighted - Epoch 329: Train Loss: 405.8035888671875, Val Loss: 399.43060302734375
# Distance_Weighted - Epoch 330: Train Loss: 405.4064025878906, Val Loss: 399.0732116699219
# Distance_Weighted - Epoch 331: Train Loss: 405.03125, Val Loss: 398.7630310058594
# Distance_Weighted - Epoch 332: Train Loss: 404.6728210449219, Val Loss: 398.3958740234375
# Distance_Weighted - Epoch 333: Train Loss: 404.3255920410156, Val Loss: 398.1612854003906
# Distance_Weighted - Epoch 334: Train Loss: 403.990478515625, Val Loss: 397.7796936035156
# Distance_Weighted - Epoch 335: Train Loss: 403.6573791503906, Val Loss: 397.5684509277344
# Distance_Weighted - Epoch 336: Train Loss: 403.323974609375, Val Loss: 397.1674499511719
# Distance_Weighted - Epoch 337: Train Loss: 402.9661560058594, Val Loss: 396.9295959472656
# Distance_Weighted - Epoch 338: Train Loss: 402.5903625488281, Val Loss: 396.474609375
# Distance_Weighted - Epoch 339: Train Loss: 402.18865966796875, Val Loss: 396.1943054199219
# Distance_Weighted - Epoch 340: Train Loss: 401.7781066894531, Val Loss: 395.7913513183594
# Distance_Weighted - Epoch 341: Train Loss: 401.37298583984375, Val Loss: 395.4745788574219
# Distance_Weighted - Epoch 342: Train Loss: 400.986572265625, Val Loss: 395.1288146972656
# Distance_Weighted - Epoch 343: Train Loss: 400.6271667480469, Val Loss: 394.8241882324219
# Distance_Weighted - Epoch 344: Train Loss: 400.2862548828125, Val Loss: 394.559814453125
# Distance_Weighted - Epoch 345: Train Loss: 399.9593200683594, Val Loss: 394.2149658203125
# Distance_Weighted - Epoch 346: Train Loss: 399.63763427734375, Val Loss: 393.9865417480469
# Distance_Weighted - Epoch 347: Train Loss: 399.32147216796875, Val Loss: 393.6518249511719
# Distance_Weighted - Epoch 348: Train Loss: 399.0110168457031, Val Loss: 393.43304443359375
# Distance_Weighted - Epoch 349: Train Loss: 398.7047119140625, Val Loss: 393.05718994140625
# Distance_Weighted - Epoch 350: Train Loss: 398.3880615234375, Val Loss: 392.83209228515625
# Distance_Weighted - Epoch 351: Train Loss: 398.063232421875, Val Loss: 392.44464111328125
# Distance_Weighted - Epoch 352: Train Loss: 397.7149658203125, Val Loss: 392.1629638671875
# Distance_Weighted - Epoch 353: Train Loss: 397.35711669921875, Val Loss: 391.7659606933594
# Distance_Weighted - Epoch 354: Train Loss: 396.9870910644531, Val Loss: 391.4759521484375
# Distance_Weighted - Epoch 355: Train Loss: 396.6307373046875, Val Loss: 391.1365051269531
# Distance_Weighted - Epoch 356: Train Loss: 396.28729248046875, Val Loss: 390.84515380859375
# Distance_Weighted - Epoch 357: Train Loss: 395.96478271484375, Val Loss: 390.5902404785156
# Distance_Weighted - Epoch 358: Train Loss: 395.6588439941406, Val Loss: 390.2994689941406
# Distance_Weighted - Epoch 359: Train Loss: 395.36285400390625, Val Loss: 390.0505676269531
# Distance_Weighted - Epoch 360: Train Loss: 395.0726623535156, Val Loss: 389.73602294921875
# Distance_Weighted - Epoch 361: Train Loss: 394.7767639160156, Val Loss: 389.50494384765625
# Distance_Weighted - Epoch 362: Train Loss: 394.47796630859375, Val Loss: 389.1731872558594
# Distance_Weighted - Epoch 363: Train Loss: 394.1690673828125, Val Loss: 388.9133605957031
# Distance_Weighted - Epoch 364: Train Loss: 393.85833740234375, Val Loss: 388.5926818847656
# Distance_Weighted - Epoch 365: Train Loss: 393.54559326171875, Val Loss: 388.3179626464844
# Distance_Weighted - Epoch 366: Train Loss: 393.2350769042969, Val Loss: 387.98822021484375
# Distance_Weighted - Epoch 367: Train Loss: 392.9277038574219, Val Loss: 387.7234802246094
# Distance_Weighted - Epoch 368: Train Loss: 392.62176513671875, Val Loss: 387.4290466308594
# Distance_Weighted - Epoch 369: Train Loss: 392.3199157714844, Val Loss: 387.1519470214844
# Distance_Weighted - Epoch 370: Train Loss: 392.0206604003906, Val Loss: 386.8518981933594
# Distance_Weighted - Epoch 371: Train Loss: 391.726318359375, Val Loss: 386.5884094238281
# Distance_Weighted - Epoch 372: Train Loss: 391.43359375, Val Loss: 386.3072204589844
# Distance_Weighted - Epoch 373: Train Loss: 391.14239501953125, Val Loss: 386.0395812988281
# Distance_Weighted - Epoch 374: Train Loss: 390.8511047363281, Val Loss: 385.7652282714844
# Distance_Weighted - Epoch 375: Train Loss: 390.5610046386719, Val Loss: 385.4965515136719
# Distance_Weighted - Epoch 376: Train Loss: 390.27374267578125, Val Loss: 385.2098693847656
# Distance_Weighted - Epoch 377: Train Loss: 389.9881286621094, Val Loss: 384.93511962890625
# Distance_Weighted - Epoch 378: Train Loss: 389.704345703125, Val Loss: 384.674072265625
# Distance_Weighted - Epoch 379: Train Loss: 389.4218444824219, Val Loss: 384.3990783691406
# Distance_Weighted - Epoch 380: Train Loss: 389.1412048339844, Val Loss: 384.1304016113281
# Distance_Weighted - Epoch 381: Train Loss: 388.86358642578125, Val Loss: 383.8587341308594
# Distance_Weighted - Epoch 382: Train Loss: 388.58856201171875, Val Loss: 383.6242370605469
# Distance_Weighted - Epoch 383: Train Loss: 388.31842041015625, Val Loss: 383.3519287109375
# Distance_Weighted - Epoch 384: Train Loss: 388.0567932128906, Val Loss: 383.1625671386719
# Distance_Weighted - Epoch 385: Train Loss: 387.8109130859375, Val Loss: 382.9239196777344
# Distance_Weighted - Epoch 386: Train Loss: 387.5897216796875, Val Loss: 382.8293151855469
# Distance_Weighted - Epoch 387: Train Loss: 387.4215087890625, Val Loss: 382.6885986328125
# Distance_Weighted - Epoch 388: Train Loss: 387.3671569824219, Val Loss: 383.0044860839844
# Distance_Weighted - Epoch 389: Train Loss: 387.51470947265625, Val Loss: 383.1312255859375
# Distance_Weighted - Epoch 390: Train Loss: 387.8542785644531, Val Loss: 383.87506103515625
# Distance_Weighted - Epoch 391: Train Loss: 388.3384094238281, Val Loss: 383.3848876953125
# Distance_Weighted - Epoch 392: Train Loss: 388.12725830078125, Val Loss: 382.6172790527344
# Distance_Weighted - Epoch 393: Train Loss: 387.0419006347656, Val Loss: 381.1570739746094
# Distance_Weighted - Epoch 394: Train Loss: 385.703369140625, Val Loss: 380.8321228027344
# Distance_Weighted - Epoch 395: Train Loss: 385.3422546386719, Val Loss: 381.4555969238281
# Distance_Weighted - Epoch 396: Train Loss: 385.8372497558594, Val Loss: 381.4093933105469
# Distance_Weighted - Epoch 397: Train Loss: 386.02801513671875, Val Loss: 380.9732360839844
# Distance_Weighted - Epoch 398: Train Loss: 385.3299255371094, Val Loss: 379.958251953125
# Distance_Weighted - Epoch 399: Train Loss: 384.4251403808594, Val Loss: 379.7684020996094
# Distance_Weighted - Epoch 400: Train Loss: 384.2260437011719, Val Loss: 380.1744079589844
# Distance_Weighted - Epoch 401: Train Loss: 384.49481201171875, Val Loss: 379.8803405761719
# Distance_Weighted - Epoch 402: Train Loss: 384.3729248046875, Val Loss: 379.4132995605469
# Distance_Weighted - Epoch 403: Train Loss: 383.73394775390625, Val Loss: 378.8627624511719
# Distance_Weighted - Epoch 404: Train Loss: 383.233154296875, Val Loss: 378.8232421875
# Distance_Weighted - Epoch 405: Train Loss: 383.2292785644531, Val Loss: 379.0154724121094
# Distance_Weighted - Epoch 406: Train Loss: 383.2828674316406, Val Loss: 378.5498046875
# Distance_Weighted - Epoch 407: Train Loss: 382.9327392578125, Val Loss: 378.166015625
# Distance_Weighted - Epoch 408: Train Loss: 382.4294738769531, Val Loss: 377.9461975097656
# Distance_Weighted - Epoch 409: Train Loss: 382.18896484375, Val Loss: 377.8788757324219
# Distance_Weighted - Epoch 410: Train Loss: 382.1759948730469, Val Loss: 377.879638671875
# Distance_Weighted - Epoch 411: Train Loss: 382.04376220703125, Val Loss: 377.4210510253906
# Distance_Weighted - Epoch 412: Train Loss: 381.6661682128906, Val Loss: 377.1476745605469
# Distance_Weighted - Epoch 413: Train Loss: 381.3208312988281, Val Loss: 377.0343933105469
# Distance_Weighted - Epoch 414: Train Loss: 381.1756896972656, Val Loss: 376.8815612792969
# Distance_Weighted - Epoch 415: Train Loss: 381.0916748046875, Val Loss: 376.7812194824219
# Distance_Weighted - Epoch 416: Train Loss: 380.8791198730469, Val Loss: 376.400146484375
# Distance_Weighted - Epoch 417: Train Loss: 380.551513671875, Val Loss: 376.1847229003906
# Distance_Weighted - Epoch 418: Train Loss: 380.29498291015625, Val Loss: 376.0965576171875
# Distance_Weighted - Epoch 419: Train Loss: 380.1564025878906, Val Loss: 375.9104919433594
# Distance_Weighted - Epoch 420: Train Loss: 380.0173645019531, Val Loss: 375.7793884277344
# Distance_Weighted - Epoch 421: Train Loss: 379.7912902832031, Val Loss: 375.4719543457031
# Distance_Weighted - Epoch 422: Train Loss: 379.51837158203125, Val Loss: 375.2754211425781
# Distance_Weighted - Epoch 423: Train Loss: 379.29931640625, Val Loss: 375.1628723144531
# Distance_Weighted - Epoch 424: Train Loss: 379.1464538574219, Val Loss: 374.9588928222656
# Distance_Weighted - Epoch 425: Train Loss: 378.98480224609375, Val Loss: 374.8291320800781
# Distance_Weighted - Epoch 426: Train Loss: 378.77496337890625, Val Loss: 374.5533142089844
# Distance_Weighted - Epoch 427: Train Loss: 378.5348815917969, Val Loss: 374.3700866699219
# Distance_Weighted - Epoch 428: Train Loss: 378.3254089355469, Val Loss: 374.2419738769531
# Distance_Weighted - Epoch 429: Train Loss: 378.157958984375, Val Loss: 374.0509033203125
# Distance_Weighted - Epoch 430: Train Loss: 377.991455078125, Val Loss: 373.913818359375
# Distance_Weighted - Epoch 431: Train Loss: 377.7934875488281, Val Loss: 373.6745910644531
# Distance_Weighted - Epoch 432: Train Loss: 377.5746765136719, Val Loss: 373.49945068359375
# Distance_Weighted - Epoch 433: Train Loss: 377.3720703125, Val Loss: 373.34869384765625
# Distance_Weighted - Epoch 434: Train Loss: 377.1961975097656, Val Loss: 373.1500549316406
# Distance_Weighted - Epoch 435: Train Loss: 377.0257263183594, Val Loss: 373.0146179199219
# Distance_Weighted - Epoch 436: Train Loss: 376.8399658203125, Val Loss: 372.78759765625
# Distance_Weighted - Epoch 437: Train Loss: 376.63775634765625, Val Loss: 372.6201171875
# Distance_Weighted - Epoch 438: Train Loss: 376.4371032714844, Val Loss: 372.4456787109375
# Distance_Weighted - Epoch 439: Train Loss: 376.2528991699219, Val Loss: 372.25830078125
# Distance_Weighted - Epoch 440: Train Loss: 376.0797424316406, Val Loss: 372.12493896484375
# Distance_Weighted - Epoch 441: Train Loss: 375.9027099609375, Val Loss: 371.9143981933594
# Distance_Weighted - Epoch 442: Train Loss: 375.71490478515625, Val Loss: 371.75537109375
# Distance_Weighted - Epoch 443: Train Loss: 375.5223083496094, Val Loss: 371.56500244140625
# Distance_Weighted - Epoch 444: Train Loss: 375.3344421386719, Val Loss: 371.39385986328125
# Distance_Weighted - Epoch 445: Train Loss: 375.1557922363281, Val Loss: 371.24981689453125
# Distance_Weighted - Epoch 446: Train Loss: 374.9820861816406, Val Loss: 371.0617980957031
# Distance_Weighted - Epoch 447: Train Loss: 374.806640625, Val Loss: 370.92193603515625
# Distance_Weighted - Epoch 448: Train Loss: 374.6260986328125, Val Loss: 370.7377624511719
# Distance_Weighted - Epoch 449: Train Loss: 374.4432678222656, Val Loss: 370.5790100097656
# Distance_Weighted - Epoch 450: Train Loss: 374.2629089355469, Val Loss: 370.4144592285156
# Distance_Weighted - Epoch 451: Train Loss: 374.0875549316406, Val Loss: 370.24200439453125
# Distance_Weighted - Epoch 452: Train Loss: 373.9151306152344, Val Loss: 370.0980224609375
# Distance_Weighted - Epoch 453: Train Loss: 373.74237060546875, Val Loss: 369.91876220703125
# Distance_Weighted - Epoch 454: Train Loss: 373.5677795410156, Val Loss: 369.7688903808594
# Distance_Weighted - Epoch 455: Train Loss: 373.39251708984375, Val Loss: 369.5958251953125
# Distance_Weighted - Epoch 456: Train Loss: 373.2172546386719, Val Loss: 369.4468078613281
# Distance_Weighted - Epoch 457: Train Loss: 373.0437316894531, Val Loss: 369.28741455078125
# Distance_Weighted - Epoch 458: Train Loss: 372.87200927734375, Val Loss: 369.12835693359375
# Distance_Weighted - Epoch 459: Train Loss: 372.7020568847656, Val Loss: 368.9842529296875
# Distance_Weighted - Epoch 460: Train Loss: 372.5330810546875, Val Loss: 368.8236389160156
# Distance_Weighted - Epoch 461: Train Loss: 372.3646545410156, Val Loss: 368.6767272949219
# Distance_Weighted - Epoch 462: Train Loss: 372.1960144042969, Val Loss: 368.5158996582031
# Distance_Weighted - Epoch 463: Train Loss: 372.0279235839844, Val Loss: 368.37139892578125
# Distance_Weighted - Epoch 464: Train Loss: 371.86053466796875, Val Loss: 368.22113037109375
# Distance_Weighted - Epoch 465: Train Loss: 371.6943054199219, Val Loss: 368.072265625
# Distance_Weighted - Epoch 466: Train Loss: 371.52911376953125, Val Loss: 367.9246826171875
# Distance_Weighted - Epoch 467: Train Loss: 371.3650207519531, Val Loss: 367.7699890136719
# Distance_Weighted - Epoch 468: Train Loss: 371.2015686035156, Val Loss: 367.624267578125
# Distance_Weighted - Epoch 469: Train Loss: 371.0389709472656, Val Loss: 367.46600341796875
# Distance_Weighted - Epoch 470: Train Loss: 370.8768310546875, Val Loss: 367.31744384765625
# Distance_Weighted - Epoch 471: Train Loss: 370.715576171875, Val Loss: 367.1577453613281
# Distance_Weighted - Epoch 472: Train Loss: 370.55548095703125, Val Loss: 367.0097961425781
# Distance_Weighted - Epoch 473: Train Loss: 370.3963928222656, Val Loss: 366.8559265136719
# Distance_Weighted - Epoch 474: Train Loss: 370.23828125, Val Loss: 366.7059631347656
# Distance_Weighted - Epoch 475: Train Loss: 370.0811462402344, Val Loss: 366.5584411621094
# Distance_Weighted - Epoch 476: Train Loss: 369.9247741699219, Val Loss: 366.41143798828125
# Distance_Weighted - Epoch 477: Train Loss: 369.76910400390625, Val Loss: 366.261962890625
# Distance_Weighted - Epoch 478: Train Loss: 369.6140441894531, Val Loss: 366.1102600097656
# Distance_Weighted - Epoch 479: Train Loss: 369.4595947265625, Val Loss: 365.9638366699219
# Distance_Weighted - Epoch 480: Train Loss: 369.3057556152344, Val Loss: 365.8163757324219
# Distance_Weighted - Epoch 481: Train Loss: 369.15283203125, Val Loss: 365.6731872558594
# Distance_Weighted - Epoch 482: Train Loss: 369.0008850097656, Val Loss: 365.5235595703125
# Distance_Weighted - Epoch 483: Train Loss: 368.84942626953125, Val Loss: 365.3841247558594
# Distance_Weighted - Epoch 484: Train Loss: 368.6990051269531, Val Loss: 365.2415771484375
# Distance_Weighted - Epoch 485: Train Loss: 368.5492248535156, Val Loss: 365.10504150390625
# Distance_Weighted - Epoch 486: Train Loss: 368.4004211425781, Val Loss: 364.957763671875
# Distance_Weighted - Epoch 487: Train Loss: 368.2528991699219, Val Loss: 364.8248291015625
# Distance_Weighted - Epoch 488: Train Loss: 368.106201171875, Val Loss: 364.68096923828125
# Distance_Weighted - Epoch 489: Train Loss: 367.9606628417969, Val Loss: 364.5513916015625
# Distance_Weighted - Epoch 490: Train Loss: 367.8161926269531, Val Loss: 364.4044189453125
# Distance_Weighted - Epoch 491: Train Loss: 367.6729431152344, Val Loss: 364.28564453125
# Distance_Weighted - Epoch 492: Train Loss: 367.5313720703125, Val Loss: 364.1388854980469
# Distance_Weighted - Epoch 493: Train Loss: 367.3920593261719, Val Loss: 364.0298767089844
# Distance_Weighted - Epoch 494: Train Loss: 367.2563171386719, Val Loss: 363.8786926269531
# Distance_Weighted - Epoch 495: Train Loss: 367.12518310546875, Val Loss: 363.793701171875
# Distance_Weighted - Epoch 496: Train Loss: 367.0016784667969, Val Loss: 363.6409606933594
# Distance_Weighted - Epoch 497: Train Loss: 366.88848876953125, Val Loss: 363.5908508300781
# Distance_Weighted - Epoch 498: Train Loss: 366.7886047363281, Val Loss: 363.4569396972656
# Distance_Weighted - Epoch 499: Train Loss: 366.7113342285156, Val Loss: 363.485107421875
# Distance_Weighted - Test Loss: 309.5686950683594
# Running model: Correlation_Weighted
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 31 nodes.
# Correlation_Weighted - Training samples: 691603
# Correlation_Weighted - Validation samples: 76845
# Correlation_Weighted - Test samples: 327520
# Correlation_Weighted - Epoch 0: Train Loss: 25503.7265625, Val Loss: 20199.888671875
# Correlation_Weighted - Epoch 1: Train Loss: 20129.751953125, Val Loss: 15537.099609375
# Correlation_Weighted - Epoch 2: Train Loss: 15516.8837890625, Val Loss: 11963.330078125
# Correlation_Weighted - Epoch 3: Train Loss: 11977.775390625, Val Loss: 9559.6083984375
# Correlation_Weighted - Epoch 4: Train Loss: 9601.2294921875, Val Loss: 8282.5263671875
# Correlation_Weighted - Epoch 5: Train Loss: 8345.0478515625, Val Loss: 7845.47119140625
# Correlation_Weighted - Epoch 6: Train Loss: 7921.56884765625, Val Loss: 7700.1181640625
# Correlation_Weighted - Epoch 7: Train Loss: 7785.37939453125, Val Loss: 7369.94189453125
# Correlation_Weighted - Epoch 8: Train Loss: 7459.90380859375, Val Loss: 6682.28125
# Correlation_Weighted - Epoch 9: Train Loss: 6775.806640625, Val Loss: 5752.00732421875
# Correlation_Weighted - Epoch 10: Train Loss: 5846.8623046875, Val Loss: 4811.220703125
# Correlation_Weighted - Epoch 11: Train Loss: 4903.09326171875, Val Loss: 4063.961181640625
# Correlation_Weighted - Epoch 12: Train Loss: 4149.41357421875, Val Loss: 3603.576904296875
# Correlation_Weighted - Epoch 13: Train Loss: 3680.375732421875, Val Loss: 3404.021728515625
# Correlation_Weighted - Epoch 14: Train Loss: 3472.52197265625, Val Loss: 3375.904541015625
# Correlation_Weighted - Epoch 15: Train Loss: 3437.596435546875, Val Loss: 3407.63720703125
# Correlation_Weighted - Epoch 16: Train Loss: 3463.813720703125, Val Loss: 3413.785400390625
# Correlation_Weighted - Epoch 17: Train Loss: 3466.606201171875, Val Loss: 3353.2041015625
# Correlation_Weighted - Epoch 18: Train Loss: 3405.867919921875, Val Loss: 3224.112548828125
# Correlation_Weighted - Epoch 19: Train Loss: 3279.075927734375, Val Loss: 3053.47119140625
# Correlation_Weighted - Epoch 20: Train Loss: 3112.487060546875, Val Loss: 2882.87158203125
# Correlation_Weighted - Epoch 21: Train Loss: 2947.244140625, Val Loss: 2752.556396484375
# Correlation_Weighted - Epoch 22: Train Loss: 2823.5234375, Val Loss: 2685.833984375
# Correlation_Weighted - Epoch 23: Train Loss: 2763.719482421875, Val Loss: 2677.91845703125
# Correlation_Weighted - Epoch 24: Train Loss: 2762.296875, Val Loss: 2697.631591796875
# Correlation_Weighted - Epoch 25: Train Loss: 2786.734619140625, Val Loss: 2701.612548828125
# Correlation_Weighted - Epoch 26: Train Loss: 2793.749755859375, Val Loss: 2659.341064453125
# Correlation_Weighted - Epoch 27: Train Loss: 2752.656494140625, Val Loss: 2567.891845703125
# Correlation_Weighted - Epoch 28: Train Loss: 2660.626953125, Val Loss: 2449.568115234375
# Correlation_Weighted - Epoch 29: Train Loss: 2540.20361328125, Val Loss: 2336.03369140625
# Correlation_Weighted - Epoch 30: Train Loss: 2423.626708984375, Val Loss: 2250.8125
# ...
# Cosine_Similarity - Epoch 323: Train Loss: 398.2908935546875, Val Loss: 428.4124755859375
# Cosine_Similarity - Epoch 324: Train Loss: 397.9437255859375, Val Loss: 428.48919677734375
# Cosine_Similarity - Epoch 325: Train Loss: 397.5769958496094, Val Loss: 427.72021484375
# Cosine_Similarity - Epoch 326: Train Loss: 397.1990051269531, Val Loss: 427.7065124511719
# Cosine_Similarity - Epoch 327: Train Loss: 396.81243896484375, Val Loss: 427.021728515625
# Cosine_Similarity - Epoch 328: Train Loss: 396.42779541015625, Val Loss: 426.9013671875
# Cosine_Similarity - Epoch 329: Train Loss: 396.04803466796875, Val Loss: 426.37078857421875
# Cosine_Similarity - Epoch 330: Train Loss: 395.6783752441406, Val Loss: 426.13214111328125
# Cosine_Similarity - Epoch 331: Train Loss: 395.3194274902344, Val Loss: 425.7551574707031
# Cosine_Similarity - Epoch 332: Train Loss: 394.9708251953125, Val Loss: 425.3984375
# Cosine_Similarity - Epoch 333: Train Loss: 394.6304626464844, Val Loss: 425.1577453613281
# Cosine_Similarity - Epoch 334: Train Loss: 394.296630859375, Val Loss: 424.7193298339844
# Cosine_Similarity - Epoch 335: Train Loss: 393.968017578125, Val Loss: 424.5997009277344
# Cosine_Similarity - Epoch 336: Train Loss: 393.6439208984375, Val Loss: 424.0816955566406
# Cosine_Similarity - Epoch 337: Train Loss: 393.323974609375, Val Loss: 424.0433349609375
# Cosine_Similarity - Epoch 338: Train Loss: 393.0076599121094, Val Loss: 423.4597473144531
# Cosine_Similarity - Epoch 339: Train Loss: 392.6980895996094, Val Loss: 423.5333557128906
# Cosine_Similarity - Epoch 340: Train Loss: 392.4001159667969, Val Loss: 422.8751525878906
# Cosine_Similarity - Epoch 341: Train Loss: 392.1191101074219, Val Loss: 423.1324462890625
# Cosine_Similarity - Epoch 342: Train Loss: 391.8626708984375, Val Loss: 422.3522033691406
# Cosine_Similarity - Epoch 343: Train Loss: 391.6446228027344, Val Loss: 422.9176025390625
# Cosine_Similarity - Epoch 344: Train Loss: 391.47900390625, Val Loss: 421.984619140625
# Cosine_Similarity - Epoch 345: Train Loss: 391.3971252441406, Val Loss: 423.0683898925781
# Cosine_Similarity - Epoch 346: Train Loss: 391.41058349609375, Val Loss: 421.98565673828125
# Cosine_Similarity - Epoch 347: Train Loss: 391.58001708984375, Val Loss: 423.7767333984375
# Cosine_Similarity - Epoch 348: Train Loss: 391.8345031738281, Val Loss: 422.36993408203125
# Cosine_Similarity - Epoch 349: Train Loss: 392.1551513671875, Val Loss: 424.27716064453125
# Cosine_Similarity - Epoch 350: Train Loss: 392.122802734375, Val Loss: 421.88336181640625
# Cosine_Similarity - Epoch 351: Train Loss: 391.6484680175781, Val Loss: 422.44415283203125
# Cosine_Similarity - Epoch 352: Train Loss: 390.4389343261719, Val Loss: 419.7688293457031
# Cosine_Similarity - Epoch 353: Train Loss: 389.0613098144531, Val Loss: 419.467529296875
# Cosine_Similarity - Epoch 354: Train Loss: 388.0245666503906, Val Loss: 419.0873718261719
# Cosine_Similarity - Epoch 355: Train Loss: 387.6798400878906, Val Loss: 418.7364501953125
# Cosine_Similarity - Epoch 356: Train Loss: 387.87054443359375, Val Loss: 420.0427551269531
# Cosine_Similarity - Epoch 357: Train Loss: 388.1410217285156, Val Loss: 418.8057556152344
# Cosine_Similarity - Epoch 358: Train Loss: 388.1339416503906, Val Loss: 419.58477783203125
# Cosine_Similarity - Epoch 359: Train Loss: 387.60247802734375, Val Loss: 417.7486267089844
# Cosine_Similarity - Epoch 360: Train Loss: 386.8040466308594, Val Loss: 417.65960693359375
# Cosine_Similarity - Epoch 361: Train Loss: 386.04327392578125, Val Loss: 417.0749816894531
# Cosine_Similarity - Epoch 362: Train Loss: 385.6330871582031, Val Loss: 416.6916809082031
# Cosine_Similarity - Epoch 363: Train Loss: 385.5674133300781, Val Loss: 417.4389343261719
# Cosine_Similarity - Epoch 364: Train Loss: 385.61004638671875, Val Loss: 416.4970397949219
# Cosine_Similarity - Epoch 365: Train Loss: 385.5400390625, Val Loss: 417.1800842285156
# Cosine_Similarity - Epoch 366: Train Loss: 385.198974609375, Val Loss: 415.8668212890625
# Cosine_Similarity - Epoch 367: Train Loss: 384.6925048828125, Val Loss: 415.9551696777344
# Cosine_Similarity - Epoch 368: Train Loss: 384.1444396972656, Val Loss: 415.2619934082031
# Cosine_Similarity - Epoch 369: Train Loss: 383.7322692871094, Val Loss: 414.95526123046875
# Cosine_Similarity - Epoch 370: Train Loss: 383.4974365234375, Val Loss: 415.19293212890625
# Cosine_Similarity - Epoch 371: Train Loss: 383.3761291503906, Val Loss: 414.507080078125
# Cosine_Similarity - Epoch 372: Train Loss: 383.2586364746094, Val Loss: 415.0288391113281
# Cosine_Similarity - Epoch 373: Train Loss: 383.0461730957031, Val Loss: 414.0675354003906
# Cosine_Similarity - Epoch 374: Train Loss: 382.7391052246094, Val Loss: 414.33624267578125
# Cosine_Similarity - Epoch 375: Train Loss: 382.3572692871094, Val Loss: 413.5238952636719
# Cosine_Similarity - Epoch 376: Train Loss: 381.97528076171875, Val Loss: 413.4366149902344
# Cosine_Similarity - Epoch 377: Train Loss: 381.6419372558594, Val Loss: 413.16729736328125
# Cosine_Similarity - Epoch 378: Train Loss: 381.37799072265625, Val Loss: 412.7973937988281
# Cosine_Similarity - Epoch 379: Train Loss: 381.1643981933594, Val Loss: 412.9904479980469
# Cosine_Similarity - Epoch 380: Train Loss: 380.9727478027344, Val Loss: 412.36865234375
# Cosine_Similarity - Epoch 381: Train Loss: 380.7716064453125, Val Loss: 412.6849365234375
# Cosine_Similarity - Epoch 382: Train Loss: 380.5384521484375, Val Loss: 411.9100646972656
# Cosine_Similarity - Epoch 383: Train Loss: 380.2702941894531, Val Loss: 412.11224365234375
# Cosine_Similarity - Epoch 384: Train Loss: 379.9728698730469, Val Loss: 411.39691162109375
# Cosine_Similarity - Epoch 385: Train Loss: 379.6649475097656, Val Loss: 411.4245910644531
# Cosine_Similarity - Epoch 386: Train Loss: 379.36376953125, Val Loss: 410.9531555175781
# Cosine_Similarity - Epoch 387: Train Loss: 379.0780029296875, Val Loss: 410.81646728515625
# Cosine_Similarity - Epoch 388: Train Loss: 378.8092956542969, Val Loss: 410.614990234375
# Cosine_Similarity - Epoch 389: Train Loss: 378.5584411621094, Val Loss: 410.3218688964844
# Cosine_Similarity - Epoch 390: Train Loss: 378.3249206542969, Val Loss: 410.3223876953125
# Cosine_Similarity - Epoch 391: Train Loss: 378.101806640625, Val Loss: 409.8928527832031
# Cosine_Similarity - Epoch 392: Train Loss: 377.8795471191406, Val Loss: 409.9867858886719
# Cosine_Similarity - Epoch 393: Train Loss: 377.656982421875, Val Loss: 409.4392395019531
# Cosine_Similarity - Epoch 394: Train Loss: 377.432861328125, Val Loss: 409.5903625488281
# Cosine_Similarity - Epoch 395: Train Loss: 377.21026611328125, Val Loss: 408.9794006347656
# Cosine_Similarity - Epoch 396: Train Loss: 376.9896545410156, Val Loss: 409.21929931640625
# Cosine_Similarity - Epoch 397: Train Loss: 376.77581787109375, Val Loss: 408.5591125488281
# Cosine_Similarity - Epoch 398: Train Loss: 376.5738525390625, Val Loss: 408.9377746582031
# Cosine_Similarity - Epoch 399: Train Loss: 376.38250732421875, Val Loss: 408.17596435546875
# Cosine_Similarity - Epoch 400: Train Loss: 376.21124267578125, Val Loss: 408.73699951171875
# Cosine_Similarity - Epoch 401: Train Loss: 376.0670471191406, Val Loss: 407.8251953125
# Cosine_Similarity - Epoch 402: Train Loss: 375.9593505859375, Val Loss: 408.6902160644531
# Cosine_Similarity - Epoch 403: Train Loss: 375.9010925292969, Val Loss: 407.639892578125
# Cosine_Similarity - Epoch 404: Train Loss: 375.92254638671875, Val Loss: 409.0019226074219
# Cosine_Similarity - Epoch 405: Train Loss: 376.0164794921875, Val Loss: 407.7653503417969
# Cosine_Similarity - Epoch 406: Train Loss: 376.2131652832031, Val Loss: 409.6582336425781
# Cosine_Similarity - Epoch 407: Train Loss: 376.43682861328125, Val Loss: 408.0754699707031
# Cosine_Similarity - Epoch 408: Train Loss: 376.6965637207031, Val Loss: 410.07373046875
# Cosine_Similarity - Epoch 409: Train Loss: 376.7064208984375, Val Loss: 407.8063659667969
# Cosine_Similarity - Epoch 410: Train Loss: 376.4598693847656, Val Loss: 408.9669189453125
# Cosine_Similarity - Epoch 411: Train Loss: 375.6929016113281, Val Loss: 406.3353576660156
# Cosine_Similarity - Epoch 412: Train Loss: 374.6695861816406, Val Loss: 406.4783935546875
# Cosine_Similarity - Epoch 413: Train Loss: 373.6188659667969, Val Loss: 405.1780700683594
# Cosine_Similarity - Epoch 414: Train Loss: 372.9193115234375, Val Loss: 404.998046875
# Cosine_Similarity - Epoch 415: Train Loss: 372.6802978515625, Val Loss: 405.6255187988281
# Cosine_Similarity - Epoch 416: Train Loss: 372.79705810546875, Val Loss: 404.9705505371094
# Cosine_Similarity - Epoch 417: Train Loss: 373.0340270996094, Val Loss: 406.2846984863281
# Cosine_Similarity - Epoch 418: Train Loss: 373.1322326660156, Val Loss: 404.842041015625
# Cosine_Similarity - Epoch 419: Train Loss: 372.98004150390625, Val Loss: 405.63702392578125
# Cosine_Similarity - Epoch 420: Train Loss: 372.5240173339844, Val Loss: 403.9993591308594
# Cosine_Similarity - Epoch 421: Train Loss: 371.9278259277344, Val Loss: 404.1239318847656
# Cosine_Similarity - Epoch 422: Train Loss: 371.37249755859375, Val Loss: 403.4476013183594
# Cosine_Similarity - Epoch 423: Train Loss: 371.0085144042969, Val Loss: 403.1867370605469
# Cosine_Similarity - Epoch 424: Train Loss: 370.8592529296875, Val Loss: 403.6235656738281
# Cosine_Similarity - Epoch 425: Train Loss: 370.8437805175781, Val Loss: 402.93389892578125
# Cosine_Similarity - Epoch 426: Train Loss: 370.84893798828125, Val Loss: 403.7529602050781
# Cosine_Similarity - Epoch 427: Train Loss: 370.771728515625, Val Loss: 402.6274108886719
# Cosine_Similarity - Epoch 428: Train Loss: 370.579345703125, Val Loss: 403.2004699707031
# Cosine_Similarity - Epoch 429: Train Loss: 370.2706298828125, Val Loss: 402.056640625
# Cosine_Similarity - Epoch 430: Train Loss: 369.90557861328125, Val Loss: 402.2590026855469
# Cosine_Similarity - Epoch 431: Train Loss: 369.5505676269531, Val Loss: 401.61138916015625
# Cosine_Similarity - Epoch 432: Train Loss: 369.2475891113281, Val Loss: 401.5044250488281
# Cosine_Similarity - Epoch 433: Train Loss: 369.01837158203125, Val Loss: 401.46685791015625
# Cosine_Similarity - Epoch 434: Train Loss: 368.8520202636719, Val Loss: 401.0589904785156
# Cosine_Similarity - Epoch 435: Train Loss: 368.7243347167969, Val Loss: 401.3983154296875
# Cosine_Similarity - Epoch 436: Train Loss: 368.6080627441406, Val Loss: 400.70025634765625
# Cosine_Similarity - Epoch 437: Train Loss: 368.4817810058594, Val Loss: 401.1727600097656
# Cosine_Similarity - Epoch 438: Train Loss: 368.3311462402344, Val Loss: 400.31903076171875
# Cosine_Similarity - Epoch 439: Train Loss: 368.1498107910156, Val Loss: 400.7802429199219
# Cosine_Similarity - Epoch 440: Train Loss: 367.94122314453125, Val Loss: 399.93994140625
# Cosine_Similarity - Epoch 441: Train Loss: 367.7144775390625, Val Loss: 400.3059997558594
# Cosine_Similarity - Epoch 442: Train Loss: 367.4784240722656, Val Loss: 399.5786437988281
# Cosine_Similarity - Epoch 443: Train Loss: 367.2411193847656, Val Loss: 399.79248046875
# Cosine_Similarity - Epoch 444: Train Loss: 367.0071716308594, Val Loss: 399.2100830078125
# Cosine_Similarity - Epoch 445: Train Loss: 366.7819519042969, Val Loss: 399.2643737792969
# Cosine_Similarity - Epoch 446: Train Loss: 366.5662841796875, Val Loss: 398.8421325683594
# Cosine_Similarity - Epoch 447: Train Loss: 366.3594665527344, Val Loss: 398.7848205566406
# Cosine_Similarity - Epoch 448: Train Loss: 366.1597900390625, Val Loss: 398.5078430175781
# Cosine_Similarity - Epoch 449: Train Loss: 365.96514892578125, Val Loss: 398.3705749511719
# Cosine_Similarity - Epoch 450: Train Loss: 365.7738342285156, Val Loss: 398.19061279296875
# Cosine_Similarity - Epoch 451: Train Loss: 365.5850524902344, Val Loss: 397.97503662109375
# Cosine_Similarity - Epoch 452: Train Loss: 365.3992919921875, Val Loss: 397.861328125
# Cosine_Similarity - Epoch 453: Train Loss: 365.2163391113281, Val Loss: 397.5903015136719
# Cosine_Similarity - Epoch 454: Train Loss: 365.0332946777344, Val Loss: 397.5370178222656
# Cosine_Similarity - Epoch 455: Train Loss: 364.8515930175781, Val Loss: 397.2165832519531
# Cosine_Similarity - Epoch 456: Train Loss: 364.6729736328125, Val Loss: 397.2373352050781
# Cosine_Similarity - Epoch 457: Train Loss: 364.4986267089844, Val Loss: 396.8310241699219
# Cosine_Similarity - Epoch 458: Train Loss: 364.33026123046875, Val Loss: 396.9770202636719
# Cosine_Similarity - Epoch 459: Train Loss: 364.1708068847656, Val Loss: 396.475341796875
# Cosine_Similarity - Epoch 460: Train Loss: 364.0285339355469, Val Loss: 396.8539123535156
# Cosine_Similarity - Epoch 461: Train Loss: 363.9161682128906, Val Loss: 396.1985778808594
# Cosine_Similarity - Epoch 462: Train Loss: 363.8569641113281, Val Loss: 397.038818359375
# Cosine_Similarity - Epoch 463: Train Loss: 363.88592529296875, Val Loss: 396.1845703125
# Cosine_Similarity - Epoch 464: Train Loss: 364.0791320800781, Val Loss: 398.015625
# Cosine_Similarity - Epoch 465: Train Loss: 364.5393371582031, Val Loss: 397.12884521484375
# Cosine_Similarity - Epoch 466: Train Loss: 365.4694519042969, Val Loss: 400.9512634277344
# Cosine_Similarity - Epoch 467: Train Loss: 366.9543151855469, Val Loss: 400.23834228515625
# Cosine_Similarity - Epoch 468: Train Loss: 369.21795654296875, Val Loss: 405.8702697753906
# Cosine_Similarity - Epoch 469: Train Loss: 371.295166015625, Val Loss: 403.0381774902344
# Cosine_Similarity - Epoch 470: Train Loss: 372.40533447265625, Val Loss: 404.467529296875
# Cosine_Similarity - Epoch 471: Train Loss: 369.9627990722656, Val Loss: 397.05889892578125
# Cosine_Similarity - Epoch 472: Train Loss: 365.5855407714844, Val Loss: 395.17242431640625
# Cosine_Similarity - Epoch 473: Train Loss: 362.0849914550781, Val Loss: 395.2275085449219
# Cosine_Similarity - Epoch 474: Train Loss: 362.099609375, Val Loss: 395.9880676269531
# Cosine_Similarity - Epoch 475: Train Loss: 364.49853515625, Val Loss: 400.0118103027344
# Cosine_Similarity - Epoch 476: Train Loss: 366.0169372558594, Val Loss: 396.3592834472656
# Cosine_Similarity - Epoch 477: Train Loss: 364.95123291015625, Val Loss: 395.64849853515625
# Cosine_Similarity - Epoch 478: Train Loss: 362.2029724121094, Val Loss: 393.5482482910156
# Cosine_Similarity - Epoch 479: Train Loss: 360.7762145996094, Val Loss: 393.7528076171875
# Cosine_Similarity - Epoch 480: Train Loss: 361.6075134277344, Val Loss: 396.6786193847656
# Cosine_Similarity - Epoch 481: Train Loss: 362.9552917480469, Val Loss: 394.5651550292969
# Cosine_Similarity - Epoch 482: Train Loss: 362.8780822753906, Val Loss: 394.6716613769531
# Cosine_Similarity - Epoch 483: Train Loss: 361.3103332519531, Val Loss: 392.6463623046875
# Cosine_Similarity - Epoch 484: Train Loss: 360.0753173828125, Val Loss: 392.60491943359375
# Cosine_Similarity - Epoch 485: Train Loss: 360.2233581542969, Val Loss: 394.5494384765625
# Cosine_Similarity - Epoch 486: Train Loss: 361.029052734375, Val Loss: 393.2215270996094
# Cosine_Similarity - Epoch 487: Train Loss: 361.1953125, Val Loss: 393.8240966796875
# Cosine_Similarity - Epoch 488: Train Loss: 360.34832763671875, Val Loss: 392.05029296875
# Cosine_Similarity - Epoch 489: Train Loss: 359.41888427734375, Val Loss: 391.8813171386719
# Cosine_Similarity - Epoch 490: Train Loss: 359.2315979003906, Val Loss: 392.94415283203125
# Cosine_Similarity - Epoch 491: Train Loss: 359.62884521484375, Val Loss: 392.03607177734375
# Cosine_Similarity - Epoch 492: Train Loss: 359.845458984375, Val Loss: 392.8447265625
# Cosine_Similarity - Epoch 493: Train Loss: 359.4466552734375, Val Loss: 391.40301513671875
# Cosine_Similarity - Epoch 494: Train Loss: 358.793701171875, Val Loss: 391.3557434082031
# Cosine_Similarity - Epoch 495: Train Loss: 358.43560791015625, Val Loss: 391.75311279296875
# Cosine_Similarity - Epoch 496: Train Loss: 358.5155029296875, Val Loss: 391.1421203613281
# Cosine_Similarity - Epoch 497: Train Loss: 358.6844482421875, Val Loss: 391.9230041503906
# Cosine_Similarity - Epoch 498: Train Loss: 358.55853271484375, Val Loss: 390.71533203125
# Cosine_Similarity - Epoch 499: Train Loss: 358.16632080078125, Val Loss: 390.8019104003906
# Cosine_Similarity - Test Loss: 308.39495849609375

# %%
# Print the last loss of each model
for model_name, result in results.items():
    print(f"{model_name} - Test Loss: {result['test_loss']}")
# Out:
# Distance_Weighted - Test Loss: 309.5686950683594
# Correlation_Weighted - Test Loss: 328.77764892578125
# Adaptive_Threshold - Test Loss: 294.1219482421875
# Delaunay - Test Loss: 312.79595947265625
# Cosine_Similarity - Test Loss: 308.39495849609375

# %%
# Combined plot for train and validation losses
plt.figure(figsize=(12, 8))
for model_name, result in results.items():
    plt.plot(result['train_losses'][20:200], label=f'{model_name} - Training Loss')
    # also print the last value as a reference
    print(f"{model_name} - Last Training Loss: {result['train_losses'][-1]}")
plt.title("Training Loss for All Models")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.yscale('log')
plt.legend(loc='upper right')
plt.show()

# Combined actual vs predicted plots in subplots
fig, axs = plt.subplots(len(results), 1, figsize=(12, 8), sharex=True)
fig.suptitle("Actual vs Predicted Traffic Flow (200-point Intervals)")
start = np.random.randint(0, 267410)
end = start + 1600

for idx, (model_name, result) in enumerate(results.items()):
    actual = result['actual_values']
    predicted = result['predicted_values']

    axs[idx].plot(actual[start:end], label='Actual')
    axs[idx].plot(predicted[start:end], label='Predicted')
    axs[idx].set_title(f"{model_name}")
    axs[idx].set_ylabel("Traffic Flow")
    axs[idx].legend(loc='upper left')


plt.xlabel("Time Steps")
plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust layout to fit title
plt.show()
# Out:
# Distance_Weighted - Last Training Loss: 366.7113342285156
# Correlation_Weighted - Last Training Loss: 370.7662353515625
# Adaptive_Threshold - Last Training Loss: 339.3997497558594
# Delaunay - Last Training Loss: 363.0671691894531
# Cosine_Similarity - Last Training Loss: 358.16632080078125

# %%
# Initialize model, optimizer, and loss function
hc = 32
#model = Baseline_updatet(in_channels=lookback, hidden_channels=hc, out_channels=pred_horizon, dropout_rate=0.5)
model = TrafficGCN(in_channels=lookback, hidden_channels=hc, out_channels=pred_horizon)
optimizer = Adam(model.parameters(), lr=0.01, amsgrad=False)
criterion = torch.nn.MSELoss()
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10, cooldown=10)

# Early stopping parameters
early_stopping_patience = 50
best_val_loss = float('inf')
epochs_no_improve = 0

# Initialize lists to store training and validation losses and metrics
train_losses = []
val_losses = []
train_maes = []
val_maes = []
train_rmses = []
val_rmses = []

# Lists to store actual and predicted values for plotting
actual_values = []
predicted_values = []


# Training loop with validation and early stopping
model.train()
print("Lookback: ", lookback, " Pred Horizon: ", pred_horizon, " Hidden Channels: ", hc)
for epoch in range(1_000):
    optimizer.zero_grad()
    
    # Forward pass on training data
    out = model(train_data)
    train_loss = criterion(out, train_data.y)
    train_rmse = torch.sqrt(train_loss).item()
    train_mae = torch.mean(torch.abs(out - train_data.y)).item()
    
    # Backward pass
    train_loss.backward()
    optimizer.step()
    
    # Evaluate on validation set
    model.eval()
    with torch.no_grad():
        val_out = model(val_data)
        val_loss = criterion(val_out, val_data.y)
        val_rmse = torch.sqrt(val_loss).item()
        val_mae = torch.mean(torch.abs(val_out - val_data.y)).item()

        # Store actual and predicted values after each epoch
        actual_values = val_data.y.cpu().numpy()
        predicted_values = val_out.cpu().numpy()
    
    model.train()  # Switch back to training mode

    # Learning rate scheduling
    scheduler.step(val_loss)

    # Store losses and metrics for plotting
    train_losses.append(train_loss.item())
    val_losses.append(val_loss.item())
    train_maes.append(train_mae)
    val_maes.append(val_mae)
    train_rmses.append(train_rmse)
    val_rmses.append(val_rmse)
    
    # Early stopping check
    if val_loss.item() < best_val_loss:
        best_val_loss = val_loss.item()
        epochs_no_improve = 0
    else:
        epochs_no_improve += 1
        if epochs_no_improve >= early_stopping_patience:
            print(f"Early stopping at epoch {epoch}")
            break

    # Get current learning rate
    current_lr = optimizer.param_groups[0]['lr']

    # Print loss and metrics every 10 epochs
    if epoch % 1 == 0:
        print(f"Epoch {epoch}, LR: { optimizer.param_groups[0]['lr']:.6f}, Train Loss: {train_loss.item():.2f}, "
              f"Val Loss: {val_loss.item():.2f}, Train MAE: {train_mae:.2f}, "
              f"Val MAE: {val_mae:.2f}")

# %%
# Eval model
model.eval()
test_out = model(test_data)
test_loss = criterion(test_out, test_data.y)
test_rmse = torch.sqrt(test_loss).item()
test_mae = torch.mean(torch.abs(test_out - test_data.y)).item()
print(f"Test Loss: {test_loss.item():.2f}, Test MAE: {test_mae:.2f}, Test RMSE: {test_rmse:.2f}")
# Out:
# Test Loss: 308.39, Test MAE: 8.88, Test RMSE: 17.56

# %%
# Plot training and validation losses
plt.figure(figsize=(10, 6))
plt.plot(train_losses[10:250], label='Train Loss')
plt.plot(val_losses[10:250], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training and validation RMSE
plt.figure(figsize=(10, 6))
plt.plot(train_rmses[10:250], label='Train RMSE')  
plt.plot(val_rmses[10:250], label='Validation RMSE')
plt.xlabel('Epoch')
plt.ylabel('RMSE')
plt.legend()
plt.show()

# Plot training and validation MAE
plt.figure(figsize=(10, 6))
plt.plot(train_maes[10:250], label='Train MAE')
plt.plot(val_maes[10:250], label='Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 12
#      10 # Plot training and validation RMSE
#      11 plt.figure(figsize=(10, 6))
# ---> 12 plt.plot(train_rmses[10:250], label='Train RMSE')
#      13 plt.plot(val_rmses[10:250], label='Validation RMSE')
#      14 plt.xlabel('Epoch')
#
# NameError: name 'train_rmses' is not defined

# %%
# Convert actual and predicted values to numpy arrays for plotting
actual_values_stack = np.vstack(actual_values)
predicted_values_stack = np.vstack(predicted_values)

# Flatten the predicted and actual values
actual_values_flat = actual_values_stack.reshape(-1)
predicted_values_flat = predicted_values_stack.reshape(-1)

# Plot the difference between actual and predicted values
plt.figure(figsize=(12, 4))
plt.title("Difference between Actual and Predicted Traffic Flow (Flattened)")
plt.plot(predicted_values_flat[0:200] - actual_values_flat[0:200])
plt.show()

# Plot predicted vs actual traffic flow
plt.figure(figsize=(12, 4))
plt.title("Predicted vs Actual Traffic Flow (Flattened)")
plt.plot(predicted_values_flat[0:200], label='Predicted')
plt.plot(actual_values_flat[0:200], label='Actual')
plt.legend()
plt.show()

# Scatter plot
plt.figure(figsize=(5, 5))
plt.scatter(predicted_values_flat[:2000], actual_values_flat[:2000], s=10)
plt.xlabel('Predicted Traffic Flow')
plt.ylabel('Actual Traffic Flow')
plt.title('Predicted vs Actual Traffic Flow (Flattened)')
plt.show()

# %%
# Flatten the sequences
actual_values_flat = actual_values_stack.reshape(-1)
predicted_values_flat = predicted_values_stack.reshape(-1)

# Make 4 subplots showing 4 randomly chosen intervals of 250 predictions
fig, axs = plt.subplots(4, 1, figsize=(12, 6))
fig.suptitle('Predicted vs Actual Traffic Flow in Random Intervals (Flattened)')

interval_length = 1000  # You can adjust this value
start = np.random.randint(0, len(predicted_values_flat) - interval_length)
for i, ax in enumerate(axs.flat):
    
    end = start + interval_length

    ax.plot(predicted_values_flat[start:end], label='Predicted')
    ax.plot(actual_values_flat[start:end], label='Actual')
    ax.set_title(f'Interval {i+1}')
    ax.legend()

plt.tight_layout()
plt.show()
