# %% [markdown]
# Packages

# %%
import networkx as nx
import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
from scipy.spatial import Delaunay
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# Data to create graphs

# %%
#final_dataframes = pickle.load(open("final_dataframes.pkl", "rb"))
final_dataframes = pickle.load(open("data_prep/one_year.pkl", "rb"))

# %%
# Define the train ratio
train_ratio = 0.7  # 80% training data
lookback = 50
pred_horizon = 5
df_dict = final_dataframes

# Split each DataFrame into training and testing parts based on time
df_dict_train = {}
df_dict_test = {}
for key, df in final_dataframes.items():
    n_time_steps = len(df['traffic_flow'])
    train_size = int(n_time_steps * train_ratio)
    df_train = df.iloc[:train_size].copy()
    df_test = df.iloc[train_size:].copy()
    df_dict_train[key] = df_train
    df_dict_test[key] = df_test


def create_sliding_window_data(df_dict, lookback, pred_horizon):
    X_dict = {}
    y_dict = {}
    for key, df in df_dict.items():
        node_series = df['traffic_flow'].values
        X_node = []
        y_node = []
        for i in range(len(node_series) - lookback - pred_horizon + 1):
            X_node.append(node_series[i:i + lookback])  # Input: Lookback window
            y_node.append(node_series[i + lookback:i + lookback + pred_horizon])  # Output: Next step(s)
        X_dict[key] = np.array(X_node)
        y_dict[key] = np.array(y_node)
    return X_dict, y_dict

# Generate sliding window data for training and testing sets
X_train_dict, y_train_dict = create_sliding_window_data(df_dict_train, lookback, pred_horizon)
X_test_dict, y_test_dict = create_sliding_window_data(df_dict_test, lookback, pred_horizon)

# %%
def clean_graph(graph):
    # Remove self-loops
    graph = graph.copy()  # Avoid modifying the
    self_loops = list(nx.selfloop_edges(graph))
    graph.remove_edges_from(self_loops)
    
    # Remove duplicate edges (not necessary for undirected graphs in NetworkX)
    # Here just in case your graph is directed or you need further verification
    edges_to_remove = []
    for u, v, data in graph.edges(data=True):
        if graph.number_of_edges(u, v) > 1:  # More than one edge exists
            edges_to_remove.append((u, v))
    
    graph.remove_edges_from(edges_to_remove)
    largest_component = max(nx.connected_components(graph), key=len)
    graph = graph.subgraph(largest_component)

    print(f"Removed {len(self_loops)} self-loops and {len(edges_to_remove)} duplicate edges. Choose the Largest Component: {len(largest_component)} nodes.")
    # extract largest component

    return graph

def create_correlation_graph(df_dict_full, df_dict_train, threshold=0.5, weighted=False,degree=4):
    """
    Create a correlation graph with a maximum degree constraint using only the training data for correlations.
    """
    correlation_graph = nx.Graph()
    correlations_dict = {}

    # Add nodes to the graph using the full data
    for key, df in df_dict_full.items():
        correlation_graph.add_node(
            key,
            x=df['Xkoordinat'].iloc[0],
            y=df['Ykoordinat'].iloc[0],
            traffic_flow=df['traffic_flow'].values  # Full traffic data
        )

    # Calculate correlations using the training data
    for key1, df1_train in df_dict_train.items():
        for key2, df2_train in df_dict_train.items():
            if key1 >= key2:  # Avoid duplicate computations
                continue
            correlation = np.corrcoef(df1_train['traffic_flow'], df2_train['traffic_flow'])[0, 1]
            correlations_dict[key1, key2] = correlation
            correlations_dict[key2, key1] = correlation  # Symmetric for undirected graph

    # Add edges based on correlation, enforcing degree constraint
    for key1 in df_dict_full.keys():
        # Sort potential connections by correlation (highest first)
        potential_edges = [
            (key2, correlations_dict[key1, key2])
            for key2 in df_dict_full.keys() if key1 != key2 and (key1, key2) in correlations_dict
        ]
        potential_edges = sorted(potential_edges, key=lambda x: -x[1])  # Sort by descending correlation

        for key2, corr in potential_edges:
            if correlation_graph.degree[key1] < degree and correlation_graph.degree[key2] < degree:
                if corr > threshold:
                    if weighted:
                        correlation_graph.add_edge(key1, key2, weight=corr)
                    else:
                        correlation_graph.add_edge(key1, key2)

    # Clean graph
    correlation_graph = clean_graph(correlation_graph)
    return correlation_graph, correlations_dict

def create_distance_graph(df_dict, weighted=False, degree=4):
    """
    Create a distance graph with a maximum degree constraint.
    """
    distance_graph = nx.Graph()
    distance_dict = {}

    # Add nodes to the graph
    for key, df in df_dict.items():
        distance_graph.add_node(
            key, 
            x=df['Xkoordinat'].iloc[0], 
            y=df['Ykoordinat'].iloc[0], 
            traffic_flow=df['traffic_flow'].values
        )

    # Calculate distances and store in a dictionary
    for key1, df1 in df_dict.items():
        for key2, df2 in df_dict.items():
            if key1 == key2:
                continue
            idx = df1['traffic_flow'].first_valid_index()
            distance = math.sqrt(
                (df1['Xkoordinat'][idx] - df2['Xkoordinat'][idx])**2 +
                (df1['Ykoordinat'][idx] - df2['Ykoordinat'][idx])**2
            )
            distance_dict[key1, key2] = distance

    # Add edges based on distance, enforcing degree constraint
    threshold = (sum(distance_dict.values()) / len(distance_dict)) * 2  # Distance threshold
    for key1 in df_dict.keys():
        # Sort potential connections by distance (shortest first)
        potential_edges = [
            (key2, distance_dict[key1, key2])
            for key2 in df_dict.keys() if key1 != key2 and (key1, key2) in distance_dict
        ]
        potential_edges = sorted(potential_edges, key=lambda x: x[1])  # Sort by ascending distance
        
        for key2, dist in potential_edges:
            if distance_graph.degree[key1] < degree and distance_graph.degree[key2] < degree:
                if dist < threshold:
                    if weighted:
                        max_distance = max(distance_dict.values())
                        min_distance = min(distance_dict.values())
                        normalised_distance = (dist - min_distance) / (max_distance - min_distance)
                        distance_graph.add_edge(key1, key2, weight=normalised_distance)
                    else:
                        distance_graph.add_edge(key1, key2)

    # Clean graph
    distance_graph = clean_graph(distance_graph)
    return distance_graph, distance_dict

def create_fully_connected_graph(df_dict):
    # Connect every node to every other node without weights 
    fully_connected_graph = nx.complete_graph(len(df_dict))

    # Add attributes to the nodes
    for i, (key, df) in enumerate(df_dict.items()):
        fully_connected_graph.nodes[i]['x'] = df['Xkoordinat'].iloc[0]
        fully_connected_graph.nodes[i]['y'] = df['Ykoordinat'].iloc[0]
        fully_connected_graph.nodes[i]['traffic_flow'] = df['traffic_flow'].values
        
    return fully_connected_graph, None

def create_fully_connected_graph_RANDOM_WEIGHTS(df_dict):
    # Connect every node to every other node without weights 
    fully_connected_graph = nx.complete_graph(len(df_dict))

    # Add attributes to the nodes
    for i, (key, df) in enumerate(df_dict.items()):
        fully_connected_graph.nodes[i]['x'] = df['Xkoordinat'].iloc[0]
        fully_connected_graph.nodes[i]['y'] = df['Ykoordinat'].iloc[0]
        fully_connected_graph.nodes[i]['traffic_flow'] = df['traffic_flow'].values

    # Add random weights to the edges
    for u, v in fully_connected_graph.edges:
        fully_connected_graph[u][v]['weight'] = np.random.rand()
        
    return fully_connected_graph, nx.get_edge_attributes(fully_connected_graph, 'weight')

import networkx as nx
import numpy as np
from scipy.spatial import Delaunay
from sklearn.metrics.pairwise import cosine_similarity


def create_adaptive_threshold_graph(df_dict_full, df_dict_train, threshold_factor=1.0, weighted=False, degree=4):
    """
    Create a graph using an adaptive threshold based on the mean and std of correlations.
    """
    graph = nx.Graph()
    correlations = {}

    # Add nodes
    for key, df in df_dict_full.items():
        graph.add_node(
            key,
            x=df['Xkoordinat'].iloc[0],
            y=df['Ykoordinat'].iloc[0],
            traffic_flow=df['traffic_flow'].values
        )

    # Compute correlations
    for key1, df1_train in df_dict_train.items():
        for key2, df2_train in df_dict_train.items():
            if key1 >= key2:
                continue
            correlation = np.corrcoef(df1_train['traffic_flow'], df2_train['traffic_flow'])[0, 1]
            correlations[key1, key2] = correlation
            correlations[key2, key1] = correlation

    # Calculate adaptive threshold
    corr_values = np.array(list(correlations.values()))
    adaptive_threshold = np.mean(corr_values) + threshold_factor * np.std(corr_values)

    # Add edges based on adaptive threshold and degree constraint
    for key1 in df_dict_full.keys():
        potential_edges = [
            (key2, correlations[key1, key2])
            for key2 in df_dict_full.keys() if key1 != key2 and (key1, key2) in correlations
        ]
        potential_edges = sorted(potential_edges, key=lambda x: -x[1])

        for key2, corr in potential_edges:
            if graph.degree[key1] < degree and graph.degree[key2] < degree:
                if corr > adaptive_threshold:
                    if weighted:
                        graph.add_edge(key1, key2, weight=corr)
                    else:
                        graph.add_edge(key1, key2)

    graph = clean_graph(graph)
    return graph, None


def create_cosine_similarity_graph(df_dict, weighted=False, degree=4):
    """
    Create a graph based on cosine similarity between node features.
    """
    graph = nx.Graph()
    feature_vectors = {}
    similarities = {}

    # Add nodes and collect feature vectors
    for key, df in df_dict.items():
        graph.add_node(
            key,
            x=df['Xkoordinat'].iloc[0],
            y=df['Ykoordinat'].iloc[0],
            traffic_flow=df['traffic_flow'].values
        )
        feature_vectors[key] = df['traffic_flow'].values

    # Compute cosine similarities
    keys = list(feature_vectors.keys())
    vectors = np.array([feature_vectors[key] for key in keys])
    similarity_matrix = cosine_similarity(vectors)

    for i, key1 in enumerate(keys):
        for j, key2 in enumerate(keys):
            if i >= j:
                continue
            similarities[key1, key2] = similarity_matrix[i, j]
            similarities[key2, key1] = similarity_matrix[i, j]

    # Add edges based on similarity and degree constraint
    for key1 in df_dict.keys():
        potential_edges = [
            (key2, similarities[key1, key2])
            for key2 in df_dict.keys() if key1 != key2 and (key1, key2) in similarities
        ]
        potential_edges = sorted(potential_edges, key=lambda x: -x[1])

        for key2, sim in potential_edges:
            if graph.degree[key1] < degree and graph.degree[key2] < degree:
                if weighted:
                    graph.add_edge(key1, key2, weight=sim)
                else:
                    graph.add_edge(key1, key2)

    graph = clean_graph(graph)
    return graph, None

def create_dynamic_weight_graph(df_dict, lookback, pred_horizon, adaptive_factor=1.0, max_degree=4):
    """
    Create a graph with dynamic weights based on adaptive thresholds.
    
    Args:
        df_dict (dict): Dictionary of DataFrames with time-series data.
        lookback (int): Number of time steps to look back.
        pred_horizon (int): Number of time steps to predict.
        adaptive_factor (float): Factor to scale the adaptive threshold.
        max_degree (int): Maximum degree for each node in the graph.
        
    Returns:
        dynamic_graph (nx.Graph): The graph with dynamic weights.
        weight_dict (dict): Dictionary of dynamic weights for each edge.
    """
    import itertools
    dynamic_graph = nx.Graph()
    weight_dict = {}

    # Add nodes with attributes
    for key, df in df_dict.items():
        dynamic_graph.add_node(
            key,
            x=df['Xkoordinat'].iloc[0],
            y=df['Ykoordinat'].iloc[0],
            traffic_flow=df['traffic_flow'].values
        )

    # Precompute sliding windows for all nodes
    sliding_windows = {
        key: np.lib.stride_tricks.sliding_window_view(
            df['traffic_flow'].values, lookback
        )[:-pred_horizon]
        for key, df in df_dict.items()
    }

    # Compute dynamic weights for each pair of nodes using combinations
    for key1, key2 in itertools.combinations(df_dict.keys(), 2):
        windows1 = sliding_windows[key1]
        windows2 = sliding_windows[key2]

        # Compute correlations for sliding windows
        corr = np.array([np.corrcoef(w1, w2)[0, 1] for w1, w2 in zip(windows1, windows2)])
        avg_weight = np.nanmean(corr)  # Use nanmean to handle NaNs in correlations

        # Set adaptive threshold and add edge if criteria met
        threshold = adaptive_factor * avg_weight
        if avg_weight > threshold:
            weight_dict[key1, key2] = avg_weight
            dynamic_graph.add_edge(key1, key2, weight=avg_weight)

    # Apply degree constraint
    for node in dynamic_graph.nodes:
        edges = sorted(
            dynamic_graph.edges(node, data=True),
            key=lambda x: x[2]['weight'],
            reverse=True
        )
        if len(edges) > max_degree:
            for edge in edges[max_degree:]:
                dynamic_graph.remove_edge(edge[0], edge[1])

    # Clean the graph
    dynamic_graph = clean_graph(dynamic_graph)
    return dynamic_graph, weight_dict

def TOTAL_RANDOM_RANDOM_WEIGHTS(df_dict, degrees=32):
    # Initialize a graph
    num_nodes = len(df_dict)
    graph = nx.Graph()

    # Add nodes with attributes
    for i, (key, df) in enumerate(df_dict.items()):
        graph.add_node(i, x=df['Xkoordinat'].iloc[0], y=df['Ykoordinat'].iloc[0], traffic_flow=df['traffic_flow'].values)

    # Randomly add edges while respecting degree constraints
    nodes = list(graph.nodes)
    max_attempts = num_nodes * degrees * 10  # Safety limit to prevent infinite loops
    attempts = 0

    while any(graph.degree(n) < degrees for n in nodes):
        u, v = np.random.choice(nodes, size=2, replace=False)
        # Add an edge only if it doesn't exist and both nodes are under degree limit
        if not graph.has_edge(u, v) and graph.degree(u) < degrees and graph.degree(v) < degrees:
            graph.add_edge(u, v, weight=np.random.rand())
        
        attempts += 1
        if attempts >= max_attempts:
            print("Warning: Maximum attempts reached, stopping early.")
            break

    # Return the graph and edge weights
    return graph, nx.get_edge_attributes(graph, 'weight')

adaptive_graph, _ = create_adaptive_threshold_graph(final_dataframes, df_dict_train, threshold_factor=0.2, weighted=True)
cosine_graph, _ = create_cosine_similarity_graph(df_dict_train, weighted=True)
random_graph, random_weights = TOTAL_RANDOM_RANDOM_WEIGHTS(df_dict_train)
# Out:
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 26 nodes.
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 32 nodes.
# Warning: Maximum attempts reached, stopping early.

# %%
adaptive_graph_dynamic_weights, weights_dict_adaptive = create_dynamic_weight_graph(final_dataframes, lookback, pred_horizon, adaptive_factor=0.2, max_degree=6)
# Out:
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 29 nodes.

# %%
# Plot the graphs
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Adaptive threshold graph
nx.draw(
    adaptive_graph,
    # pos shouold be spring layout
    pos=nx.spring_layout(adaptive_graph),
    ax=axs[0],
    node_size=50,
    with_labels=False
)
axs[0].set_title("Adaptive Threshold Graph")


# Cosine similarity graph
nx.draw(
    cosine_graph,
    pos=nx.spring_layout(cosine_graph),
    ax=axs[2],
    node_size=50,
    with_labels=False
)
axs[2].set_title("Cosine Similarity Graph")

# Dynamic weight graph
nx.draw(
    adaptive_graph_dynamic_weights,
    pos=nx.spring_layout(adaptive_graph_dynamic_weights),
    ax=axs[1],
    node_size=50,
    with_labels=False
)
axs[1].set_title("Dynamic Weight Graph")
# Out:
# Text(0.5, 1.0, 'Dynamic Weight Graph')

# %%
# Other graphs
distance_graph_weighted, distance_dict = create_distance_graph(final_dataframes, weighted=True, degree=4)
distance_graph_unweighted, _ = create_distance_graph(final_dataframes, weighted=False, degree=4)

correlation_graph_weighted, correlation_dict = create_correlation_graph(df_dict_full=df_dict, df_dict_train=df_dict_train, threshold=0.7, weighted=True, degree=10)
#correlation_graph_unweighted, _ = create_correlation_graph(df_dict_full=df_dict, df_dict_train=df_dict_train, threshold=0.7, weighted=False, degree=10)

fully_connected_graph, _ = create_fully_connected_graph(final_dataframes)
#fully_connected_graph_RANDOM_WEIGHTS, fully_connected_weights = create_fully_connected_graph_RANDOM_WEIGHTS(final_dataframes)
# Out:
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 16 nodes.
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 16 nodes.
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 31 nodes.

# %% [markdown]
# Plot Graphs if wanted

# %%
# # Plot the Correlation graph without labels or edge attributes, use a spring layout, with a title that explain how they where plotted
# plt.figure(figsize=(6, 6))
# plt.title("Correlation Graph with Spring Layout")
# pos = nx.spring_layout(correlation_graph_weighted)
# nx.draw(correlation_graph_weighted, pos, with_labels=False, node_size=50, node_color='blue', edge_color='gray')
# plt.show()

# # Extract positions from the graph's node attributes
# pos = {node: (data['x'], data['y']) for node, data in distance_graph_weighted.nodes(data=True)}
# x_values = [coord[0] for coord in pos.values()]
# y_values = [coord[1] for coord in pos.values()]
# plt.figure(figsize=(8, 8))
# plt.title("Distance Graph with Geographic Layout", fontsize=14)


# plt.grid(True, linestyle='--', alpha=0.5)
# plt.scatter(x_values, y_values, c='blue', s=50, label='Nodes')
# for edge in distance_graph_weighted.edges():
#     x_coords = [pos[edge[0]][0], pos[edge[1]][0]]
#     y_coords = [pos[edge[0]][1], pos[edge[1]][1]]
#     plt.plot(x_coords, y_coords, color='gray', alpha=0.7)
# plt.xlabel("X Coordinate", fontsize=12)
# plt.ylabel("Y Coordinate", fontsize=12)
# plt.legend()
# plt.show()


# # Plot the Correlation graph without labels or edge attributes, use a spring layout, with a title that explain how they where plotted
# plt.figure(figsize=(6, 6))
# plt.title("Fully Connected Graph with Spring Layout")
# pos = nx.spring_layout(fully_connected_graph)
# nx.draw(fully_connected_graph, pos, with_labels=False, node_size=50, node_color='blue', edge_color='gray')
# plt.show()

# %% [markdown]
# ## Model Section

# %%
import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from torch.optim import Adam
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.model_selection import train_test_split

# %% [markdown]
# Create Data

# %%
# Prepare sliding window data
X_train_dict, y_train_dict = create_sliding_window_data(df_dict_train, lookback, pred_horizon)
X_test_dict, y_test_dict = create_sliding_window_data(df_dict_test, lookback, pred_horizon)

# Combine data from all nodes
X_train_list = []
y_train_list = []
for key in X_train_dict:
    X_train_list.append(X_train_dict[key])
    y_train_list.append(y_train_dict[key])

X_train = np.concatenate(X_train_list, axis=0)
y_train = np.concatenate(y_train_list, axis=0)

X_test_list = []
y_test_list = []
for key in X_test_dict:
    X_test_list.append(X_test_dict[key])
    y_test_list.append(y_test_dict[key])

X_test = np.concatenate(X_test_list, axis=0)
y_test = np.concatenate(y_test_list, axis=0)

# Split training data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.1, random_state=42
)

# Convert to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float)
y_train = torch.tensor(y_train, dtype=torch.float)

X_val = torch.tensor(X_val, dtype=torch.float)
y_val = torch.tensor(y_val, dtype=torch.float)

X_test = torch.tensor(X_test, dtype=torch.float)
y_test = torch.tensor(y_test, dtype=torch.float)

# Prepare graph edges with integer mapping
node_mapping = {node: idx for idx, node in enumerate(correlation_graph_weighted.nodes())}

edge_index = torch.tensor(
    [[node_mapping[edge[0]], node_mapping[edge[1]]] for edge in correlation_graph_weighted.edges],
    dtype=torch.long
).t().contiguous()

# Create PyTorch Geometric Data objects
train_data = Data(x=X_train, edge_index=edge_index, y=y_train.view(-1, pred_horizon))
val_data = Data(x=X_val, edge_index=edge_index, y=y_val.view(-1, pred_horizon))
test_data = Data(x=X_test, edge_index=edge_index, y=y_test.view(-1, pred_horizon))

# %% [markdown]
# Helper Function to create train and test dataset in a deterministic way

# %%
# Define GNN model
class Baseline(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.fc = torch.nn.Linear(hidden_channels, out_channels)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        x = self.fc(x)
        return x

class ImprovedBaseline(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, dropout_rate=0.2):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.dropout = torch.nn.Dropout(p=dropout_rate)
        self.fc = torch.nn.Linear(hidden_channels, out_channels)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.bn1(x)
        x = self.dropout(x)
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = self.bn2(x)
        x = self.dropout(x)
        x = self.fc(x)
        return x

class Baseline_updatet(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.fc = torch.nn.Linear(hidden_channels, out_channels)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = self.conv3(x, edge_index)
        x = self.fc(x)
        return x


# Define GNN model
class TrafficGCN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.conv4 = GCNConv(hidden_channels, hidden_channels)
        self.fc = torch.nn.Linear(hidden_channels, out_channels)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        x = self.conv4(x, edge_index)
        x = self.fc(x)
        return x

# %%
def split_dataframes(df_dict, train_ratio=0.7):
    """
    Splits each DataFrame in df_dict into training and testing parts based on time indices.

    Returns:
        df_dict_train: Dictionary of training DataFrames.
        df_dict_test: Dictionary of testing DataFrames.
    """
    df_dict_train = {}
    df_dict_test = {}
    for key, df in df_dict.items():
        n_time_steps = len(df['traffic_flow'])
        train_size = int(n_time_steps * train_ratio)
        df_train = df.iloc[:train_size].copy()
        df_test = df.iloc[train_size:].copy()
        df_dict_train[key] = df_train
        df_dict_test[key] = df_test
    return df_dict_train, df_dict_test

def combine_node_data(X_dict, y_dict):
    """
    Combines data from all nodes.

    Returns:
        X_combined: Combined input sequences from all nodes.
        y_combined: Combined target sequences from all nodes.
    """
    X_list = []
    y_list = []
    for key in X_dict:
        X_list.append(X_dict[key])
        y_list.append(y_dict[key])
    X_combined = np.concatenate(X_list, axis=0)
    y_combined = np.concatenate(y_list, axis=0)
    return X_combined, y_combined

def convert_to_tensors_and_split(X, y, val_ratio=0.1, random_state=42):
    """
    Converts data to PyTorch tensors and splits into train and validation sets.

    Returns:
        X_train: Training input tensor.
        X_val: Validation input tensor.
        y_train: Training target tensor.
        y_val: Validation target tensor.
    """
    # Convert to PyTorch tensors
    X_tensor = torch.tensor(X, dtype=torch.float)
    y_tensor = torch.tensor(y, dtype=torch.float)

    # Split into training and validation sets
    X_train, X_val, y_train, y_val = train_test_split(
        X_tensor, y_tensor, test_size=val_ratio, random_state=random_state
    )
    return X_train, X_val, y_train, y_val

def prepare_pyg_data(X_train, y_train, X_val, y_val, X_test, y_test, edge_index, pred_horizon):
    """
    Prepares PyTorch Geometric Data objects for training, validation, and testing.

    Returns:
        train_data: Data object for training.
        val_data: Data object for validation.
        test_data: Data object for testing.
    """
    train_data = Data(x=X_train, edge_index=edge_index, y=y_train.view(-1, pred_horizon))
    val_data = Data(x=X_val, edge_index=edge_index, y=y_val.view(-1, pred_horizon))
    test_data = Data(x=X_test, edge_index=edge_index, y=y_test.view(-1, pred_horizon))
    return train_data, val_data, test_data


train_ratio = 0.7  # 70% training data
df_dict_train, df_dict_test = split_dataframes(final_dataframes, train_ratio)
amount_degrees = 10
# Models to evaluate
graph_models = {
    "Distance_Weighted": lambda: create_distance_graph(final_dataframes, weighted=True, degree=amount_degrees),
    #"Distance_Unweighted": lambda: create_distance_graph(final_dataframes, weighted=False, degree=amount_degrees),
    #"Correlation_Weighted": lambda: create_correlation_graph(final_dataframes, df_dict_train, threshold=0.6, weighted=True, degree=amount_degrees),
    #"Correlation_Unweighted": lambda: create_correlation_graph(final_dataframes, threshold=0.6, weighted=False, degree=amount_degrees),
    #"Fully_Connected": lambda: (create_fully_connected_graph(final_dataframes), None),
    #"Fully_Connected_random_weights": lambda: (create_fully_connected_graph_RANDOM_WEIGHTS(final_dataframes)),
    "Adaptive_Threshold": lambda: create_adaptive_threshold_graph(final_dataframes, df_dict_train, threshold_factor=0.2, weighted=True, degree=amount_degrees),
    #"Cosine_Similarity": lambda: create_cosine_similarity_graph(df_dict_train, weighted=True, degree=amount_degrees),
    "Dynamic_Weight": lambda: create_dynamic_weight_graph(df_dict_train, lookback, pred_horizon, adaptive_factor=0.2, max_degree=amount_degrees),
}

# Initialize results dictionary
results = {}

# Model parameters
hc = 32
lookback = 100
pred_horizon = 100

# Train and evaluate each model
for model_name, graph_fn in graph_models.items():
    print(f"Running model: {model_name}")
    
    # Create graph and prepare data
    graph, _ = graph_fn()

    node_mapping = {node: idx for idx, node in enumerate(graph.nodes())}
    
    edge_index = torch.tensor(
        [[node_mapping[edge[0]], node_mapping[edge[1]]] for edge in graph.edges],
        dtype=torch.long
    ).t().contiguous()
    
    # Create sliding window data per node for training and testing
    X_train_dict, y_train_dict = create_sliding_window_data(df_dict_train, lookback, pred_horizon)
    X_test_dict, y_test_dict = create_sliding_window_data(df_dict_test, lookback, pred_horizon)
    
    # Combine data from all nodes
    X_train, y_train = combine_node_data(X_train_dict, y_train_dict)
    X_test, y_test = combine_node_data(X_test_dict, y_test_dict)
    
    # Convert to tensors and split training data into train and validation sets
    X_train, X_val, y_train, y_val = convert_to_tensors_and_split(X_train, y_train, val_ratio=0.1, random_state=42)
    
    # Convert test data to tensors
    X_test = torch.tensor(X_test, dtype=torch.float)
    y_test = torch.tensor(y_test, dtype=torch.float)
    
    print(f"{model_name} - Training samples: {X_train.shape[0]}")
    print(f"{model_name} - Validation samples: {X_val.shape[0]}")
    print(f"{model_name} - Test samples: {X_test.shape[0]}")
    
    # Prepare PyTorch Geometric Data objects
    train_data, val_data, test_data = prepare_pyg_data(X_train, y_train, X_val, y_val, X_test, y_test, edge_index, pred_horizon)
    
    # Initialize model
    model = TrafficGCN(in_channels=lookback, hidden_channels=hc, out_channels=pred_horizon)
    optimizer = Adam(model.parameters(), lr=0.001)
    criterion = torch.nn.MSELoss()
    
    # Train model
    train_losses = []
    val_losses = []
    for epoch in range(500):
        optimizer.zero_grad()
        
        # Training
        model.train()
        out = model(train_data)
        train_loss = criterion(out, train_data.y)
        train_loss.backward()
        optimizer.step()
        
        # Validation
        model.eval()
        with torch.no_grad():
            val_out = model(val_data)
            val_loss = criterion(val_out, val_data.y)
        
        # Track losses
        train_losses.append(train_loss.item())
        val_losses.append(val_loss.item())
        
        if epoch % 1 == 0:
            print(f"{model_name} - Epoch {epoch}: Train Loss: {train_loss.item()}, Val Loss: {val_loss.item()}")
    
    # Evaluate on test data
    model.eval()
    with torch.no_grad():
        test_out = model(test_data)
        test_loss = criterion(test_out, test_data.y)
        actual_values = test_data.y.cpu().numpy()
        predicted_values = test_out.cpu().numpy()
    
    print(f"{model_name} - Test Loss: {test_loss.item()}")
    
    # Save results
    results[model_name] = {
        "train_losses": train_losses,
        "val_losses": val_losses,
        "test_loss": test_loss.item(),
        "actual_values": actual_values,
        "predicted_values": predicted_values
    }
# Out:
# Running model: Distance_Weighted
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 31 nodes.
# Distance_Weighted - Training samples: 688752
# Distance_Weighted - Validation samples: 76528
# Distance_Weighted - Test samples: 324352
# Distance_Weighted - Epoch 0: Train Loss: 36132.42578125, Val Loss: 35353.52734375
# Distance_Weighted - Epoch 1: Train Loss: 35192.68359375, Val Loss: 34564.47265625
# Distance_Weighted - Epoch 2: Train Loss: 34404.0, Val Loss: 33856.05078125
# Distance_Weighted - Epoch 3: Train Loss: 33696.08203125, Val Loss: 33168.58984375
# Distance_Weighted - Epoch 4: Train Loss: 33008.8359375, Val Loss: 32455.94140625
# Distance_Weighted - Epoch 5: Train Loss: 32296.37109375, Val Loss: 31688.935546875
# Distance_Weighted - Epoch 6: Train Loss: 31530.98046875, Val Loss: 30860.025390625
# Distance_Weighted - Epoch 7: Train Loss: 30704.712890625, Val Loss: 29978.37109375
# Distance_Weighted - Epoch 8: Train Loss: 29826.646484375, Val Loss: 29062.478515625
# Distance_Weighted - Epoch 9: Train Loss: 28915.517578125, Val Loss: 28133.77734375
# Distance_Weighted - Epoch 10: Train Loss: 27992.666015625, Val Loss: 27211.453125
# Distance_Weighted - Epoch 11: Train Loss: 27076.78125, Val Loss: 26307.962890625
# Distance_Weighted - Epoch 12: Train Loss: 26179.5546875, Val Loss: 25422.29296875
# Distance_Weighted - Epoch 13: Train Loss: 25299.7734375, Val Loss: 24543.375
# Distance_Weighted - Epoch 14: Train Loss: 24426.154296875, Val Loss: 23663.1015625
# Distance_Weighted - Epoch 15: Train Loss: 23549.955078125, Val Loss: 22783.9921875
# Distance_Weighted - Epoch 16: Train Loss: 22674.17578125, Val Loss: 21918.763671875
# Distance_Weighted - Epoch 17: Train Loss: 21811.234375, Val Loss: 21080.4140625
# Distance_Weighted - Epoch 18: Train Loss: 20974.671875, Val Loss: 20278.994140625
# Distance_Weighted - Epoch 19: Train Loss: 20174.666015625, Val Loss: 19516.375
# Distance_Weighted - Epoch 20: Train Loss: 19413.619140625, Val Loss: 18787.80859375
# Distance_Weighted - Epoch 21: Train Loss: 18687.099609375, Val Loss: 18087.03515625
# Distance_Weighted - Epoch 22: Train Loss: 17988.9921875, Val Loss: 17411.271484375
# Distance_Weighted - Epoch 23: Train Loss: 17316.50390625, Val Loss: 16762.380859375
# Distance_Weighted - Epoch 24: Train Loss: 16671.392578125, Val Loss: 16144.345703125
# Distance_Weighted - Epoch 25: Train Loss: 16057.498046875, Val Loss: 15559.345703125
# Distance_Weighted - Epoch 26: Train Loss: 15476.787109375, Val Loss: 15005.55078125
# Distance_Weighted - Epoch 27: Train Loss: 14927.0380859375, Val Loss: 14479.0810546875
# Distance_Weighted - Epoch 28: Train Loss: 14404.0439453125, Val Loss: 13977.8330078125
# Distance_Weighted - Epoch 29: Train Loss: 13905.2587890625, Val Loss: 13502.8955078125
# Distance_Weighted - Epoch 30: Train Loss: 13431.7392578125, Val Loss: 13057.123046875
# Distance_Weighted - Epoch 31: Train Loss: 12986.73828125, Val Loss: 12642.3564453125
# Distance_Weighted - Epoch 32: Train Loss: 12572.521484375, Val Loss: 12257.33203125
# Distance_Weighted - Epoch 33: Train Loss: 12188.03515625, Val Loss: 11898.73828125
# Distance_Weighted - Epoch 34: Train Loss: 11830.0859375, Val Loss: 11564.0537109375
# Distance_Weighted - Epoch 35: Train Loss: 11496.1103515625, Val Loss: 11251.443359375
# Distance_Weighted - Epoch 36: Train Loss: 11184.4697265625, Val Loss: 10959.7841796875
# Distance_Weighted - Epoch 37: Train Loss: 10893.90234375, Val Loss: 10687.2373046875
# Distance_Weighted - Epoch 38: Train Loss: 10622.4521484375, Val Loss: 10430.8154296875
# Distance_Weighted - Epoch 39: Train Loss: 10366.984375, Val Loss: 10187.7197265625
# Distance_Weighted - Epoch 40: Train Loss: 10124.5390625, Val Loss: 9956.4013671875
# Distance_Weighted - Epoch 41: Train Loss: 9893.5830078125, Val Loss: 9736.63671875
# Distance_Weighted - Epoch 42: Train Loss: 9673.966796875, Val Loss: 9528.0703125
# Distance_Weighted - Epoch 43: Train Loss: 9465.5576171875, Val Loss: 9329.3466796875
# Distance_Weighted - Epoch 44: Train Loss: 9267.166015625, Val Loss: 9138.48046875
# Distance_Weighted - Epoch 45: Train Loss: 9076.8525390625, Val Loss: 8953.951171875
# Distance_Weighted - Epoch 46: Train Loss: 8893.078125, Val Loss: 8775.458984375
# Distance_Weighted - Epoch 47: Train Loss: 8715.4169921875, Val Loss: 8603.287109375
# Distance_Weighted - Epoch 48: Train Loss: 8544.09765625, Val Loss: 8437.5576171875
# Distance_Weighted - Epoch 49: Train Loss: 8379.119140625, Val Loss: 8277.76171875
# Distance_Weighted - Epoch 50: Train Loss: 8219.88671875, Val Loss: 8123.14501953125
# Distance_Weighted - Epoch 51: Train Loss: 8065.65087890625, Val Loss: 7973.357421875
# Distance_Weighted - Epoch 52: Train Loss: 7916.099609375, Val Loss: 7828.48291015625
# Distance_Weighted - Epoch 53: Train Loss: 7771.38134765625, Val Loss: 7688.60302734375
# Distance_Weighted - Epoch 54: Train Loss: 7631.568359375, Val Loss: 7553.30810546875
# Distance_Weighted - Epoch 55: Train Loss: 7496.35595703125, Val Loss: 7422.13134765625
# Distance_Weighted - Epoch 56: Train Loss: 7365.33935546875, Val Loss: 7295.02001953125
# Distance_Weighted - Epoch 57: Train Loss: 7238.46142578125, Val Loss: 7172.25146484375
# Distance_Weighted - Epoch 58: Train Loss: 7115.974609375, Val Loss: 7054.1259765625
# Distance_Weighted - Epoch 59: Train Loss: 6998.06103515625, Val Loss: 6940.56787109375
# Distance_Weighted - Epoch 60: Train Loss: 6884.64111328125, Val Loss: 6831.44482421875
# Distance_Weighted - Epoch 61: Train Loss: 6775.5341796875, Val Loss: 6726.66455078125
# Distance_Weighted - Epoch 62: Train Loss: 6670.685546875, Val Loss: 6626.23583984375
# Distance_Weighted - Epoch 63: Train Loss: 6570.1533203125, Val Loss: 6530.14306640625
# Distance_Weighted - Epoch 64: Train Loss: 6473.9013671875, Val Loss: 6438.123046875
# Distance_Weighted - Epoch 65: Train Loss: 6381.73095703125, Val Loss: 6350.033203125
# Distance_Weighted - Epoch 66: Train Loss: 6293.5458984375, Val Loss: 6265.9638671875
# Distance_Weighted - Epoch 67: Train Loss: 6209.45068359375, Val Loss: 6186.06494140625
# Distance_Weighted - Epoch 68: Train Loss: 6129.54736328125, Val Loss: 6110.3291015625
# Distance_Weighted - Epoch 69: Train Loss: 6053.751953125, Val Loss: 6038.529296875
# Distance_Weighted - Epoch 70: Train Loss: 5981.84033203125, Val Loss: 5970.48486328125
# Distance_Weighted - Epoch 71: Train Loss: 5913.64599609375, Val Loss: 5906.15234375
# Distance_Weighted - Epoch 72: Train Loss: 5849.10986328125, Val Loss: 5845.42626953125
# Distance_Weighted - Epoch 73: Train Loss: 5788.1865234375, Val Loss: 5788.06201171875
# Distance_Weighted - Epoch 74: Train Loss: 5730.71484375, Val Loss: 5733.8720703125
# Distance_Weighted - Epoch 75: Train Loss: 5676.49072265625, Val Loss: 5682.6884765625
# Distance_Weighted - Epoch 76: Train Loss: 5625.38330078125, Val Loss: 5634.48681640625
# Distance_Weighted - Epoch 77: Train Loss: 5577.310546875, Val Loss: 5589.1689453125
# Distance_Weighted - Epoch 78: Train Loss: 5532.15576171875, Val Loss: 5546.61376953125
# Distance_Weighted - Epoch 79: Train Loss: 5489.7587890625, Val Loss: 5506.75634765625
# Distance_Weighted - Epoch 80: Train Loss: 5450.02001953125, Val Loss: 5469.568359375
# Distance_Weighted - Epoch 81: Train Loss: 5412.9248046875, Val Loss: 5434.92724609375
# Distance_Weighted - Epoch 82: Train Loss: 5378.37060546875, Val Loss: 5402.4794921875
# Distance_Weighted - Epoch 83: Train Loss: 5346.02197265625, Val Loss: 5371.89111328125
# Distance_Weighted - Epoch 84: Train Loss: 5315.55908203125, Val Loss: 5343.02685546875
# Distance_Weighted - Epoch 85: Train Loss: 5286.85791015625, Val Loss: 5315.89501953125
# Distance_Weighted - Epoch 86: Train Loss: 5259.912109375, Val Loss: 5290.501953125
# Distance_Weighted - Epoch 87: Train Loss: 5234.724609375, Val Loss: 5266.79296875
# Distance_Weighted - Epoch 88: Train Loss: 5211.2177734375, Val Loss: 5244.6474609375
# Distance_Weighted - Epoch 89: Train Loss: 5189.26171875, Val Loss: 5223.91357421875
# Distance_Weighted - Epoch 90: Train Loss: 5168.6962890625, Val Loss: 5204.4404296875
# Distance_Weighted - Epoch 91: Train Loss: 5149.39794921875, Val Loss: 5186.11572265625
# Distance_Weighted - Epoch 92: Train Loss: 5131.251953125, Val Loss: 5168.8603515625
# Distance_Weighted - Epoch 93: Train Loss: 5114.185546875, Val Loss: 5152.6083984375
# Distance_Weighted - Epoch 94: Train Loss: 5098.14501953125, Val Loss: 5137.31787109375
# Distance_Weighted - Epoch 95: Train Loss: 5083.0625, Val Loss: 5122.93017578125
# Distance_Weighted - Epoch 96: Train Loss: 5068.85791015625, Val Loss: 5109.35400390625
# Distance_Weighted - Epoch 97: Train Loss: 5055.435546875, Val Loss: 5096.4814453125
# Distance_Weighted - Epoch 98: Train Loss: 5042.69580078125, Val Loss: 5084.2021484375
# Distance_Weighted - Epoch 99: Train Loss: 5030.52685546875, Val Loss: 5072.41552734375
# Distance_Weighted - Epoch 100: Train Loss: 5018.84814453125, Val Loss: 5061.07666015625
# Distance_Weighted - Epoch 101: Train Loss: 5007.61328125, Val Loss: 5050.17626953125
# Distance_Weighted - Epoch 102: Train Loss: 4996.796875, Val Loss: 5039.6689453125
# Distance_Weighted - Epoch 103: Train Loss: 4986.36767578125, Val Loss: 5029.4951171875
# Distance_Weighted - Epoch 104: Train Loss: 4976.2841796875, Val Loss: 5019.63232421875
# Distance_Weighted - Epoch 105: Train Loss: 4966.49755859375, Val Loss: 5010.01513671875
# Distance_Weighted - Epoch 106: Train Loss: 4956.9853515625, Val Loss: 5000.64013671875
# Distance_Weighted - Epoch 107: Train Loss: 4947.7119140625, Val Loss: 4991.5205078125
# Distance_Weighted - Epoch 108: Train Loss: 4938.66455078125, Val Loss: 4982.63330078125
# Distance_Weighted - Epoch 109: Train Loss: 4929.84912109375, Val Loss: 4973.96484375
# Distance_Weighted - Epoch 110: Train Loss: 4921.2470703125, Val Loss: 4965.49560546875
# Distance_Weighted - Epoch 111: Train Loss: 4912.8310546875, Val Loss: 4957.1767578125
# Distance_Weighted - Epoch 112: Train Loss: 4904.564453125, Val Loss: 4948.97900390625
# Distance_Weighted - Epoch 113: Train Loss: 4896.4091796875, Val Loss: 4940.8486328125
# Distance_Weighted - Epoch 114: Train Loss: 4888.33544921875, Val Loss: 4932.76904296875
# Distance_Weighted - Epoch 115: Train Loss: 4880.326171875, Val Loss: 4924.748046875
# Distance_Weighted - Epoch 116: Train Loss: 4872.3681640625, Val Loss: 4916.775390625
# Distance_Weighted - Epoch 117: Train Loss: 4864.4580078125, Val Loss: 4908.849609375
# Distance_Weighted - Epoch 118: Train Loss: 4856.595703125, Val Loss: 4900.9716796875
# Distance_Weighted - Epoch 119: Train Loss: 4848.775390625, Val Loss: 4893.134765625
# Distance_Weighted - Epoch 120: Train Loss: 4840.9892578125, Val Loss: 4885.333984375
# Distance_Weighted - Epoch 121: Train Loss: 4833.232421875, Val Loss: 4877.5498046875
# Distance_Weighted - Epoch 122: Train Loss: 4825.4853515625, Val Loss: 4869.7607421875
# Distance_Weighted - Epoch 123: Train Loss: 4817.73681640625, Val Loss: 4861.96875
# Distance_Weighted - Epoch 124: Train Loss: 4809.978515625, Val Loss: 4854.1513671875
# Distance_Weighted - Epoch 125: Train Loss: 4802.20947265625, Val Loss: 4846.31298828125
# Distance_Weighted - Epoch 126: Train Loss: 4794.42822265625, Val Loss: 4838.45068359375
# Distance_Weighted - Epoch 127: Train Loss: 4786.6298828125, Val Loss: 4830.5712890625
# Distance_Weighted - Epoch 128: Train Loss: 4778.8095703125, Val Loss: 4822.6767578125
# Distance_Weighted - Epoch 129: Train Loss: 4770.96728515625, Val Loss: 4814.7666015625
# Distance_Weighted - Epoch 130: Train Loss: 4763.10498046875, Val Loss: 4806.82958984375
# Distance_Weighted - Epoch 131: Train Loss: 4755.22119140625, Val Loss: 4798.861328125
# Distance_Weighted - Epoch 132: Train Loss: 4747.3134765625, Val Loss: 4790.86181640625
# Distance_Weighted - Epoch 133: Train Loss: 4739.376953125, Val Loss: 4782.833984375
# Distance_Weighted - Epoch 134: Train Loss: 4731.412109375, Val Loss: 4774.7880859375
# Distance_Weighted - Epoch 135: Train Loss: 4723.4140625, Val Loss: 4766.71533203125
# Distance_Weighted - Epoch 136: Train Loss: 4715.38427734375, Val Loss: 4758.60791015625
# Distance_Weighted - Epoch 137: Train Loss: 4707.32421875, Val Loss: 4750.45263671875
# Distance_Weighted - Epoch 138: Train Loss: 4699.22900390625, Val Loss: 4742.2412109375
# Distance_Weighted - Epoch 139: Train Loss: 4691.09814453125, Val Loss: 4733.98046875
# Distance_Weighted - Epoch 140: Train Loss: 4682.92578125, Val Loss: 4725.6787109375
# Distance_Weighted - Epoch 141: Train Loss: 4674.71240234375, Val Loss: 4717.33251953125
# Distance_Weighted - Epoch 142: Train Loss: 4666.4560546875, Val Loss: 4708.93310546875
# Distance_Weighted - Epoch 143: Train Loss: 4658.1484375, Val Loss: 4700.48046875
# Distance_Weighted - Epoch 144: Train Loss: 4649.78662109375, Val Loss: 4691.98046875
# Distance_Weighted - Epoch 145: Train Loss: 4641.369140625, Val Loss: 4683.42724609375
# Distance_Weighted - Epoch 146: Train Loss: 4632.892578125, Val Loss: 4674.814453125
# Distance_Weighted - Epoch 147: Train Loss: 4624.357421875, Val Loss: 4666.14404296875
# Distance_Weighted - Epoch 148: Train Loss: 4615.76123046875, Val Loss: 4657.41650390625
# Distance_Weighted - Epoch 149: Train Loss: 4607.1044921875, Val Loss: 4648.62646484375
# Distance_Weighted - Epoch 150: Train Loss: 4598.39013671875, Val Loss: 4639.7744140625
# Distance_Weighted - Epoch 151: Train Loss: 4589.61181640625, Val Loss: 4630.8544921875
# Distance_Weighted - Epoch 152: Train Loss: 4580.76953125, Val Loss: 4621.85693359375
# Distance_Weighted - Epoch 153: Train Loss: 4571.8583984375, Val Loss: 4612.79296875
# Distance_Weighted - Epoch 154: Train Loss: 4562.8798828125, Val Loss: 4603.66552734375
# Distance_Weighted - Epoch 155: Train Loss: 4553.83544921875, Val Loss: 4594.4833984375
# Distance_Weighted - Epoch 156: Train Loss: 4544.72509765625, Val Loss: 4585.23681640625
# Distance_Weighted - Epoch 157: Train Loss: 4535.5478515625, Val Loss: 4575.93359375
# Distance_Weighted - Epoch 158: Train Loss: 4526.31103515625, Val Loss: 4566.57373046875
# Distance_Weighted - Epoch 159: Train Loss: 4517.013671875, Val Loss: 4557.15234375
# Distance_Weighted - Epoch 160: Train Loss: 4507.650390625, Val Loss: 4547.66796875
# Distance_Weighted - Epoch 161: Train Loss: 4498.22314453125, Val Loss: 4538.12060546875
# Distance_Weighted - Epoch 162: Train Loss: 4488.7333984375, Val Loss: 4528.51025390625
# Distance_Weighted - Epoch 163: Train Loss: 4479.185546875, Val Loss: 4518.83251953125
# Distance_Weighted - Epoch 164: Train Loss: 4469.57861328125, Val Loss: 4509.08544921875
# Distance_Weighted - Epoch 165: Train Loss: 4459.91455078125, Val Loss: 4499.28271484375
# Distance_Weighted - Epoch 166: Train Loss: 4450.1953125, Val Loss: 4489.4267578125
# Distance_Weighted - Epoch 167: Train Loss: 4440.4228515625, Val Loss: 4479.5224609375
# Distance_Weighted - Epoch 168: Train Loss: 4430.60205078125, Val Loss: 4469.572265625
# Distance_Weighted - Epoch 169: Train Loss: 4420.7353515625, Val Loss: 4459.56494140625
# Distance_Weighted - Epoch 170: Train Loss: 4410.822265625, Val Loss: 4449.50830078125
# Distance_Weighted - Epoch 171: Train Loss: 4400.8642578125, Val Loss: 4439.4111328125
# Distance_Weighted - Epoch 172: Train Loss: 4390.86572265625, Val Loss: 4429.28173828125
# Distance_Weighted - Epoch 173: Train Loss: 4380.8310546875, Val Loss: 4419.1142578125
# Distance_Weighted - Epoch 174: Train Loss: 4370.76025390625, Val Loss: 4408.92138671875
# Distance_Weighted - Epoch 175: Train Loss: 4360.65869140625, Val Loss: 4398.69921875
# Distance_Weighted - Epoch 176: Train Loss: 4350.5263671875, Val Loss: 4388.44580078125
# Distance_Weighted - Epoch 177: Train Loss: 4340.36962890625, Val Loss: 4378.16552734375
# Distance_Weighted - Epoch 178: Train Loss: 4330.19189453125, Val Loss: 4367.86279296875
# Distance_Weighted - Epoch 179: Train Loss: 4319.994140625, Val Loss: 4357.5380859375
# Distance_Weighted - Epoch 180: Train Loss: 4309.779296875, Val Loss: 4347.20361328125
# Distance_Weighted - Epoch 181: Train Loss: 4299.55078125, Val Loss: 4336.861328125
# Distance_Weighted - Epoch 182: Train Loss: 4289.31396484375, Val Loss: 4326.509765625
# Distance_Weighted - Epoch 183: Train Loss: 4279.06982421875, Val Loss: 4316.1513671875
# Distance_Weighted - Epoch 184: Train Loss: 4268.8193359375, Val Loss: 4305.79150390625
# Distance_Weighted - Epoch 185: Train Loss: 4258.56884765625, Val Loss: 4295.41943359375
# Distance_Weighted - Epoch 186: Train Loss: 4248.31787109375, Val Loss: 4285.0478515625
# Distance_Weighted - Epoch 187: Train Loss: 4238.07373046875, Val Loss: 4274.685546875
# Distance_Weighted - Epoch 188: Train Loss: 4227.837890625, Val Loss: 4264.330078125
# Distance_Weighted - Epoch 189: Train Loss: 4217.611328125, Val Loss: 4253.97998046875
# Distance_Weighted - Epoch 190: Train Loss: 4207.396484375, Val Loss: 4243.64208984375
# Distance_Weighted - Epoch 191: Train Loss: 4197.1943359375, Val Loss: 4233.31640625
# Distance_Weighted - Epoch 192: Train Loss: 4187.0107421875, Val Loss: 4223.009765625
# Distance_Weighted - Epoch 193: Train Loss: 4176.84423828125, Val Loss: 4212.72802734375
# Distance_Weighted - Epoch 194: Train Loss: 4166.70068359375, Val Loss: 4202.46728515625
# Distance_Weighted - Epoch 195: Train Loss: 4156.57958984375, Val Loss: 4192.2294921875
# Distance_Weighted - Epoch 196: Train Loss: 4146.48193359375, Val Loss: 4182.01171875
# Distance_Weighted - Epoch 197: Train Loss: 4136.40771484375, Val Loss: 4171.818359375
# Distance_Weighted - Epoch 198: Train Loss: 4126.36376953125, Val Loss: 4161.65966796875
# Distance_Weighted - Epoch 199: Train Loss: 4116.3486328125, Val Loss: 4151.541015625
# Distance_Weighted - Epoch 200: Train Loss: 4106.36328125, Val Loss: 4141.45947265625
# Distance_Weighted - Epoch 201: Train Loss: 4096.41162109375, Val Loss: 4131.40576171875
# Distance_Weighted - Epoch 202: Train Loss: 4086.495849609375, Val Loss: 4121.3916015625
# Distance_Weighted - Epoch 203: Train Loss: 4076.61767578125, Val Loss: 4111.423828125
# Distance_Weighted - Epoch 204: Train Loss: 4066.77978515625, Val Loss: 4101.5
# Distance_Weighted - Epoch 205: Train Loss: 4056.9833984375, Val Loss: 4091.60888671875
# Distance_Weighted - Epoch 206: Train Loss: 4047.23193359375, Val Loss: 4081.751708984375
# Distance_Weighted - Epoch 207: Train Loss: 4037.5234375, Val Loss: 4071.938232421875
# Distance_Weighted - Epoch 208: Train Loss: 4027.85986328125, Val Loss: 4062.173095703125
# Distance_Weighted - Epoch 209: Train Loss: 4018.240966796875, Val Loss: 4052.45654296875
# Distance_Weighted - Epoch 210: Train Loss: 4008.668701171875, Val Loss: 4042.78662109375
# Distance_Weighted - Epoch 211: Train Loss: 3999.14453125, Val Loss: 4033.16357421875
# Distance_Weighted - Epoch 212: Train Loss: 3989.66796875, Val Loss: 4023.5771484375
# Distance_Weighted - Epoch 213: Train Loss: 3980.2431640625, Val Loss: 4014.0380859375
# Distance_Weighted - Epoch 214: Train Loss: 3970.8720703125, Val Loss: 4004.54736328125
# Distance_Weighted - Epoch 215: Train Loss: 3961.553466796875, Val Loss: 3995.11474609375
# Distance_Weighted - Epoch 216: Train Loss: 3952.288818359375, Val Loss: 3985.734375
# Distance_Weighted - Epoch 217: Train Loss: 3943.080078125, Val Loss: 3976.402587890625
# Distance_Weighted - Epoch 218: Train Loss: 3933.927490234375, Val Loss: 3967.120361328125
# Distance_Weighted - Epoch 219: Train Loss: 3924.831298828125, Val Loss: 3957.893310546875
# Distance_Weighted - Epoch 220: Train Loss: 3915.7939453125, Val Loss: 3948.72802734375
# Distance_Weighted - Epoch 221: Train Loss: 3906.8173828125, Val Loss: 3939.626953125
# Distance_Weighted - Epoch 222: Train Loss: 3897.90478515625, Val Loss: 3930.58349609375
# Distance_Weighted - Epoch 223: Train Loss: 3889.05615234375, Val Loss: 3921.6015625
# Distance_Weighted - Epoch 224: Train Loss: 3880.26953125, Val Loss: 3912.688720703125
# Distance_Weighted - Epoch 225: Train Loss: 3871.544677734375, Val Loss: 3903.84130859375
# Distance_Weighted - Epoch 226: Train Loss: 3862.88037109375, Val Loss: 3895.068115234375
# Distance_Weighted - Epoch 227: Train Loss: 3854.278564453125, Val Loss: 3886.358154296875
# Distance_Weighted - Epoch 228: Train Loss: 3845.739013671875, Val Loss: 3877.70849609375
# Distance_Weighted - Epoch 229: Train Loss: 3837.26123046875, Val Loss: 3869.121826171875
# Distance_Weighted - Epoch 230: Train Loss: 3828.843505859375, Val Loss: 3860.593505859375
# Distance_Weighted - Epoch 231: Train Loss: 3820.48681640625, Val Loss: 3852.12451171875
# Distance_Weighted - Epoch 232: Train Loss: 3812.191162109375, Val Loss: 3843.7041015625
# Distance_Weighted - Epoch 233: Train Loss: 3803.958984375, Val Loss: 3835.34521484375
# Distance_Weighted - Epoch 234: Train Loss: 3795.788330078125, Val Loss: 3827.059326171875
# Distance_Weighted - Epoch 235: Train Loss: 3787.68115234375, Val Loss: 3818.84130859375
# Distance_Weighted - Epoch 236: Train Loss: 3779.638671875, Val Loss: 3810.693603515625
# Distance_Weighted - Epoch 237: Train Loss: 3771.658203125, Val Loss: 3802.60888671875
# Distance_Weighted - Epoch 238: Train Loss: 3763.74267578125, Val Loss: 3794.59423828125
# Distance_Weighted - Epoch 239: Train Loss: 3755.892578125, Val Loss: 3786.644287109375
# Distance_Weighted - Epoch 240: Train Loss: 3748.10546875, Val Loss: 3778.7607421875
# Distance_Weighted - Epoch 241: Train Loss: 3740.381591796875, Val Loss: 3770.94287109375
# Distance_Weighted - Epoch 242: Train Loss: 3732.7236328125, Val Loss: 3763.197021484375
# Distance_Weighted - Epoch 243: Train Loss: 3725.12939453125, Val Loss: 3755.515625
# Distance_Weighted - Epoch 244: Train Loss: 3717.598388671875, Val Loss: 3747.895751953125
# Distance_Weighted - Epoch 245: Train Loss: 3710.129150390625, Val Loss: 3740.336669921875
# Distance_Weighted - Epoch 246: Train Loss: 3702.72119140625, Val Loss: 3732.85302734375
# Distance_Weighted - Epoch 247: Train Loss: 3695.372314453125, Val Loss: 3725.434814453125
# Distance_Weighted - Epoch 248: Train Loss: 3688.082275390625, Val Loss: 3718.072021484375
# Distance_Weighted - Epoch 249: Train Loss: 3680.849853515625, Val Loss: 3710.7587890625
# Distance_Weighted - Epoch 250: Train Loss: 3673.673828125, Val Loss: 3703.498046875
# Distance_Weighted - Epoch 251: Train Loss: 3666.552734375, Val Loss: 3696.297607421875
# Distance_Weighted - Epoch 252: Train Loss: 3659.48388671875, Val Loss: 3689.15087890625
# Distance_Weighted - Epoch 253: Train Loss: 3652.460205078125, Val Loss: 3682.046630859375
# Distance_Weighted - Epoch 254: Train Loss: 3645.4794921875, Val Loss: 3674.982421875
# Distance_Weighted - Epoch 255: Train Loss: 3638.53125, Val Loss: 3667.921142578125
# Distance_Weighted - Epoch 256: Train Loss: 3631.617919921875, Val Loss: 3660.84228515625
# Distance_Weighted - Epoch 257: Train Loss: 3624.702392578125, Val Loss: 3653.76416015625
# Distance_Weighted - Epoch 258: Train Loss: 3617.800048828125, Val Loss: 3646.796875
# Distance_Weighted - Epoch 259: Train Loss: 3611.02783203125, Val Loss: 3639.8916015625
# Distance_Weighted - Epoch 260: Train Loss: 3604.306884765625, Val Loss: 3632.991455078125
# Distance_Weighted - Epoch 261: Train Loss: 3597.55078125, Val Loss: 3626.1845703125
# Distance_Weighted - Epoch 262: Train Loss: 3590.841796875, Val Loss: 3619.49267578125
# Distance_Weighted - Epoch 263: Train Loss: 3584.22900390625, Val Loss: 3612.83251953125
# Distance_Weighted - Epoch 264: Train Loss: 3577.65625, Val Loss: 3606.20166015625
# Distance_Weighted - Epoch 265: Train Loss: 3571.109130859375, Val Loss: 3599.61572265625
# Distance_Weighted - Epoch 266: Train Loss: 3564.595703125, Val Loss: 3593.044921875
# Distance_Weighted - Epoch 267: Train Loss: 3558.119384765625, Val Loss: 3586.42724609375
# Distance_Weighted - Epoch 268: Train Loss: 3551.669189453125, Val Loss: 3579.8037109375
# Distance_Weighted - Epoch 269: Train Loss: 3545.244140625, Val Loss: 3573.240478515625
# Distance_Weighted - Epoch 270: Train Loss: 3538.862548828125, Val Loss: 3566.751708984375
# Distance_Weighted - Epoch 271: Train Loss: 3532.52783203125, Val Loss: 3560.31201171875
# Distance_Weighted - Epoch 272: Train Loss: 3526.237060546875, Val Loss: 3553.944580078125
# Distance_Weighted - Epoch 273: Train Loss: 3519.98388671875, Val Loss: 3547.68212890625
# Distance_Weighted - Epoch 274: Train Loss: 3513.772216796875, Val Loss: 3541.486328125
# Distance_Weighted - Epoch 275: Train Loss: 3507.603515625, Val Loss: 3535.27734375
# Distance_Weighted - Epoch 276: Train Loss: 3501.4697265625, Val Loss: 3529.061767578125
# Distance_Weighted - Epoch 277: Train Loss: 3495.374755859375, Val Loss: 3522.8828125
# Distance_Weighted - Epoch 278: Train Loss: 3489.313720703125, Val Loss: 3516.74853515625
# Distance_Weighted - Epoch 279: Train Loss: 3483.292724609375, Val Loss: 3510.6416015625
# Distance_Weighted - Epoch 280: Train Loss: 3477.315673828125, Val Loss: 3504.57568359375
# Distance_Weighted - Epoch 281: Train Loss: 3471.38037109375, Val Loss: 3498.5791015625
# Distance_Weighted - Epoch 282: Train Loss: 3465.477294921875, Val Loss: 3492.634033203125
# Distance_Weighted - Epoch 283: Train Loss: 3459.609619140625, Val Loss: 3486.71142578125
# Distance_Weighted - Epoch 284: Train Loss: 3453.77685546875, Val Loss: 3480.829833984375
# Distance_Weighted - Epoch 285: Train Loss: 3447.983642578125, Val Loss: 3474.9990234375
# Distance_Weighted - Epoch 286: Train Loss: 3442.226806640625, Val Loss: 3469.195556640625
# Distance_Weighted - Epoch 287: Train Loss: 3436.50439453125, Val Loss: 3463.404052734375
# Distance_Weighted - Epoch 288: Train Loss: 3430.8173828125, Val Loss: 3457.645263671875
# Distance_Weighted - Epoch 289: Train Loss: 3425.16455078125, Val Loss: 3451.92822265625
# Distance_Weighted - Epoch 290: Train Loss: 3419.5400390625, Val Loss: 3446.239501953125
# Distance_Weighted - Epoch 291: Train Loss: 3413.945068359375, Val Loss: 3440.5849609375
# Distance_Weighted - Epoch 292: Train Loss: 3408.379150390625, Val Loss: 3434.974609375
# Distance_Weighted - Epoch 293: Train Loss: 3402.84130859375, Val Loss: 3429.39013671875
# Distance_Weighted - Epoch 294: Train Loss: 3397.33251953125, Val Loss: 3423.80712890625
# Distance_Weighted - Epoch 295: Train Loss: 3391.85205078125, Val Loss: 3418.253662109375
# Distance_Weighted - Epoch 296: Train Loss: 3386.3984375, Val Loss: 3412.740234375
# Distance_Weighted - Epoch 297: Train Loss: 3380.968994140625, Val Loss: 3407.2490234375
# Distance_Weighted - Epoch 298: Train Loss: 3375.566162109375, Val Loss: 3401.772216796875
# Distance_Weighted - Epoch 299: Train Loss: 3370.188720703125, Val Loss: 3396.32373046875
# Distance_Weighted - Epoch 300: Train Loss: 3364.834228515625, Val Loss: 3390.901123046875
# Distance_Weighted - Epoch 301: Train Loss: 3359.50244140625, Val Loss: 3385.50732421875
# Distance_Weighted - Epoch 302: Train Loss: 3354.18994140625, Val Loss: 3380.15673828125
# Distance_Weighted - Epoch 303: Train Loss: 3348.898681640625, Val Loss: 3374.832763671875
# Distance_Weighted - Epoch 304: Train Loss: 3343.62890625, Val Loss: 3369.517822265625
# Distance_Weighted - Epoch 305: Train Loss: 3338.380126953125, Val Loss: 3364.209228515625
# Distance_Weighted - Epoch 306: Train Loss: 3333.151611328125, Val Loss: 3358.92333984375
# Distance_Weighted - Epoch 307: Train Loss: 3327.941162109375, Val Loss: 3353.651123046875
# Distance_Weighted - Epoch 308: Train Loss: 3322.750244140625, Val Loss: 3348.3994140625
# Distance_Weighted - Epoch 309: Train Loss: 3317.575927734375, Val Loss: 3343.164306640625
# Distance_Weighted - Epoch 310: Train Loss: 3312.41845703125, Val Loss: 3337.942626953125
# Distance_Weighted - Epoch 311: Train Loss: 3307.28271484375, Val Loss: 3332.748779296875
# Distance_Weighted - Epoch 312: Train Loss: 3302.166748046875, Val Loss: 3327.58740234375
# Distance_Weighted - Epoch 313: Train Loss: 3297.075439453125, Val Loss: 3322.4501953125
# Distance_Weighted - Epoch 314: Train Loss: 3292.01171875, Val Loss: 3317.33740234375
# Distance_Weighted - Epoch 315: Train Loss: 3286.97216796875, Val Loss: 3312.243408203125
# Distance_Weighted - Epoch 316: Train Loss: 3281.9599609375, Val Loss: 3307.19384765625
# Distance_Weighted - Epoch 317: Train Loss: 3276.971435546875, Val Loss: 3302.163330078125
# Distance_Weighted - Epoch 318: Train Loss: 3272.0087890625, Val Loss: 3297.13720703125
# Distance_Weighted - Epoch 319: Train Loss: 3267.068603515625, Val Loss: 3292.130615234375
# Distance_Weighted - Epoch 320: Train Loss: 3262.1513671875, Val Loss: 3287.14599609375
# Distance_Weighted - Epoch 321: Train Loss: 3257.25390625, Val Loss: 3282.181640625
# Distance_Weighted - Epoch 322: Train Loss: 3252.3798828125, Val Loss: 3277.240234375
# Distance_Weighted - Epoch 323: Train Loss: 3247.527099609375, Val Loss: 3272.308349609375
# Distance_Weighted - Epoch 324: Train Loss: 3242.69580078125, Val Loss: 3267.384521484375
# Distance_Weighted - Epoch 325: Train Loss: 3237.88623046875, Val Loss: 3262.529296875
# Distance_Weighted - Epoch 326: Train Loss: 3233.09765625, Val Loss: 3257.679443359375
# Distance_Weighted - Epoch 327: Train Loss: 3228.32861328125, Val Loss: 3252.83349609375
# Distance_Weighted - Epoch 328: Train Loss: 3223.581298828125, Val Loss: 3248.020263671875
# Distance_Weighted - Epoch 329: Train Loss: 3218.85400390625, Val Loss: 3243.184326171875
# Distance_Weighted - Epoch 330: Train Loss: 3214.146484375, Val Loss: 3238.433837890625
# Distance_Weighted - Epoch 331: Train Loss: 3209.456298828125, Val Loss: 3233.664794921875
# Distance_Weighted - Epoch 332: Train Loss: 3204.784423828125, Val Loss: 3228.933349609375
# Distance_Weighted - Epoch 333: Train Loss: 3200.1298828125, Val Loss: 3224.208251953125
# Distance_Weighted - Epoch 334: Train Loss: 3195.495361328125, Val Loss: 3219.499755859375
# Distance_Weighted - Epoch 335: Train Loss: 3190.8759765625, Val Loss: 3214.819091796875
# Distance_Weighted - Epoch 336: Train Loss: 3186.273681640625, Val Loss: 3210.145263671875
# Distance_Weighted - Epoch 337: Train Loss: 3181.687744140625, Val Loss: 3205.5390625
# Distance_Weighted - Epoch 338: Train Loss: 3177.11767578125, Val Loss: 3200.927734375
# Distance_Weighted - Epoch 339: Train Loss: 3172.56494140625, Val Loss: 3196.31005859375
# Distance_Weighted - Epoch 340: Train Loss: 3168.03271484375, Val Loss: 3191.728515625
# Distance_Weighted - Epoch 341: Train Loss: 3163.513427734375, Val Loss: 3187.130615234375
# Distance_Weighted - Epoch 342: Train Loss: 3159.01171875, Val Loss: 3182.55517578125
# Distance_Weighted - Epoch 343: Train Loss: 3154.526611328125, Val Loss: 3178.0068359375
# Distance_Weighted - Epoch 344: Train Loss: 3150.059326171875, Val Loss: 3173.468994140625
# Distance_Weighted - Epoch 345: Train Loss: 3145.607177734375, Val Loss: 3168.964599609375
# Distance_Weighted - Epoch 346: Train Loss: 3141.172119140625, Val Loss: 3164.474609375
# Distance_Weighted - Epoch 347: Train Loss: 3136.7529296875, Val Loss: 3160.016357421875
# Distance_Weighted - Epoch 348: Train Loss: 3132.346923828125, Val Loss: 3155.55615234375
# Distance_Weighted - Epoch 349: Train Loss: 3127.955078125, Val Loss: 3151.106689453125
# Distance_Weighted - Epoch 350: Train Loss: 3123.57861328125, Val Loss: 3146.67138671875
# Distance_Weighted - Epoch 351: Train Loss: 3119.216552734375, Val Loss: 3142.27734375
# Distance_Weighted - Epoch 352: Train Loss: 3114.870849609375, Val Loss: 3137.90966796875
# Distance_Weighted - Epoch 353: Train Loss: 3110.539794921875, Val Loss: 3133.516845703125
# Distance_Weighted - Epoch 354: Train Loss: 3106.22265625, Val Loss: 3129.2021484375
# Distance_Weighted - Epoch 355: Train Loss: 3101.918701171875, Val Loss: 3124.8359375
# Distance_Weighted - Epoch 356: Train Loss: 3097.62841796875, Val Loss: 3120.527587890625
# Distance_Weighted - Epoch 357: Train Loss: 3093.35498046875, Val Loss: 3116.17822265625
# Distance_Weighted - Epoch 358: Train Loss: 3089.0927734375, Val Loss: 3111.93408203125
# Distance_Weighted - Epoch 359: Train Loss: 3084.848388671875, Val Loss: 3107.578369140625
# Distance_Weighted - Epoch 360: Train Loss: 3080.608642578125, Val Loss: 3103.32861328125
# Distance_Weighted - Epoch 361: Train Loss: 3076.3759765625, Val Loss: 3098.9990234375
# Distance_Weighted - Epoch 362: Train Loss: 3072.144775390625, Val Loss: 3094.756591796875
# Distance_Weighted - Epoch 363: Train Loss: 3067.9296875, Val Loss: 3090.481689453125
# Distance_Weighted - Epoch 364: Train Loss: 3063.73291015625, Val Loss: 3086.23583984375
# Distance_Weighted - Epoch 365: Train Loss: 3059.552978515625, Val Loss: 3082.05810546875
# Distance_Weighted - Epoch 366: Train Loss: 3055.381103515625, Val Loss: 3077.7939453125
# Distance_Weighted - Epoch 367: Train Loss: 3051.2119140625, Val Loss: 3073.595458984375
# Distance_Weighted - Epoch 368: Train Loss: 3047.0546875, Val Loss: 3069.41650390625
# Distance_Weighted - Epoch 369: Train Loss: 3042.91064453125, Val Loss: 3065.256591796875
# Distance_Weighted - Epoch 370: Train Loss: 3038.78466796875, Val Loss: 3061.115478515625
# Distance_Weighted - Epoch 371: Train Loss: 3034.674072265625, Val Loss: 3056.96240234375
# Distance_Weighted - Epoch 372: Train Loss: 3030.578857421875, Val Loss: 3052.871826171875
# Distance_Weighted - Epoch 373: Train Loss: 3026.4912109375, Val Loss: 3048.71435546875
# Distance_Weighted - Epoch 374: Train Loss: 3022.41259765625, Val Loss: 3044.628173828125
# Distance_Weighted - Epoch 375: Train Loss: 3018.343017578125, Val Loss: 3040.54443359375
# Distance_Weighted - Epoch 376: Train Loss: 3014.28857421875, Val Loss: 3036.444091796875
# Distance_Weighted - Epoch 377: Train Loss: 3010.248046875, Val Loss: 3032.3818359375
# Distance_Weighted - Epoch 378: Train Loss: 3006.22412109375, Val Loss: 3028.29443359375
# Distance_Weighted - Epoch 379: Train Loss: 3002.212646484375, Val Loss: 3024.309814453125
# Distance_Weighted - Epoch 380: Train Loss: 2998.212890625, Val Loss: 3020.218017578125
# Distance_Weighted - Epoch 381: Train Loss: 2994.22314453125, Val Loss: 3016.253173828125
# Distance_Weighted - Epoch 382: Train Loss: 2990.24560546875, Val Loss: 3012.2158203125
# Distance_Weighted - Epoch 383: Train Loss: 2986.281982421875, Val Loss: 3008.2412109375
# Distance_Weighted - Epoch 384: Train Loss: 2982.333251953125, Val Loss: 3004.23681640625
# Distance_Weighted - Epoch 385: Train Loss: 2978.40283203125, Val Loss: 3000.293212890625
# Distance_Weighted - Epoch 386: Train Loss: 2974.486083984375, Val Loss: 2996.323974609375
# Distance_Weighted - Epoch 387: Train Loss: 2970.584716796875, Val Loss: 2992.405029296875
# Distance_Weighted - Epoch 388: Train Loss: 2966.69970703125, Val Loss: 2988.464111328125
# Distance_Weighted - Epoch 389: Train Loss: 2962.833740234375, Val Loss: 2984.627197265625
# Distance_Weighted - Epoch 390: Train Loss: 2958.997314453125, Val Loss: 2980.690673828125
# Distance_Weighted - Epoch 391: Train Loss: 2955.201904296875, Val Loss: 2976.979248046875
# Distance_Weighted - Epoch 392: Train Loss: 2951.440673828125, Val Loss: 2973.036865234375
# Distance_Weighted - Epoch 393: Train Loss: 2947.690185546875, Val Loss: 2969.315673828125
# Distance_Weighted - Epoch 394: Train Loss: 2943.877685546875, Val Loss: 2965.320068359375
# Distance_Weighted - Epoch 395: Train Loss: 2940.020751953125, Val Loss: 2961.478515625
# Distance_Weighted - Epoch 396: Train Loss: 2936.20068359375, Val Loss: 2957.7890625
# Distance_Weighted - Epoch 397: Train Loss: 2932.4609375, Val Loss: 2953.906005859375
# Distance_Weighted - Epoch 398: Train Loss: 2928.763427734375, Val Loss: 2950.307861328125
# Distance_Weighted - Epoch 399: Train Loss: 2925.044189453125, Val Loss: 2946.442138671875
# Distance_Weighted - Epoch 400: Train Loss: 2921.3251953125, Val Loss: 2942.694580078125
# Distance_Weighted - Epoch 401: Train Loss: 2917.631591796875, Val Loss: 2939.0732421875
# Distance_Weighted - Epoch 402: Train Loss: 2913.97119140625, Val Loss: 2935.20947265625
# Distance_Weighted - Epoch 403: Train Loss: 2910.300048828125, Val Loss: 2931.615966796875
# Distance_Weighted - Epoch 404: Train Loss: 2906.616455078125, Val Loss: 2927.88818359375
# Distance_Weighted - Epoch 405: Train Loss: 2902.966796875, Val Loss: 2924.236572265625
# Distance_Weighted - Epoch 406: Train Loss: 2899.3623046875, Val Loss: 2920.712646484375
# Distance_Weighted - Epoch 407: Train Loss: 2895.77392578125, Val Loss: 2916.951416015625
# Distance_Weighted - Epoch 408: Train Loss: 2892.168212890625, Val Loss: 2913.40625
# Distance_Weighted - Epoch 409: Train Loss: 2888.547119140625, Val Loss: 2909.728759765625
# Distance_Weighted - Epoch 410: Train Loss: 2884.94677734375, Val Loss: 2906.122802734375
# Distance_Weighted - Epoch 411: Train Loss: 2881.386962890625, Val Loss: 2902.632080078125
# Distance_Weighted - Epoch 412: Train Loss: 2877.853271484375, Val Loss: 2898.9638671875
# Distance_Weighted - Epoch 413: Train Loss: 2874.318359375, Val Loss: 2895.48486328125
# Distance_Weighted - Epoch 414: Train Loss: 2870.77294921875, Val Loss: 2891.862060546875
# Distance_Weighted - Epoch 415: Train Loss: 2867.234130859375, Val Loss: 2888.333740234375
# Distance_Weighted - Epoch 416: Train Loss: 2863.719970703125, Val Loss: 2884.854248046875
# Distance_Weighted - Epoch 417: Train Loss: 2860.235107421875, Val Loss: 2881.2607421875
# Distance_Weighted - Epoch 418: Train Loss: 2856.76513671875, Val Loss: 2877.862548828125
# Distance_Weighted - Epoch 419: Train Loss: 2853.298828125, Val Loss: 2874.26806640625
# Distance_Weighted - Epoch 420: Train Loss: 2849.835693359375, Val Loss: 2870.855224609375
# Distance_Weighted - Epoch 421: Train Loss: 2846.3798828125, Val Loss: 2867.32373046875
# Distance_Weighted - Epoch 422: Train Loss: 2842.939453125, Val Loss: 2863.882568359375
# Distance_Weighted - Epoch 423: Train Loss: 2839.517822265625, Val Loss: 2860.485595703125
# Distance_Weighted - Epoch 424: Train Loss: 2836.11181640625, Val Loss: 2857.014404296875
# Distance_Weighted - Epoch 425: Train Loss: 2832.717529296875, Val Loss: 2853.6748046875
# Distance_Weighted - Epoch 426: Train Loss: 2829.33349609375, Val Loss: 2850.170166015625
# Distance_Weighted - Epoch 427: Train Loss: 2825.954833984375, Val Loss: 2846.84423828125
# Distance_Weighted - Epoch 428: Train Loss: 2822.582275390625, Val Loss: 2843.38134765625
# Distance_Weighted - Epoch 429: Train Loss: 2819.22021484375, Val Loss: 2840.045654296875
# Distance_Weighted - Epoch 430: Train Loss: 2815.869873046875, Val Loss: 2836.68603515625
# Distance_Weighted - Epoch 431: Train Loss: 2812.5322265625, Val Loss: 2833.33642578125
# Distance_Weighted - Epoch 432: Train Loss: 2809.21484375, Val Loss: 2830.063720703125
# Distance_Weighted - Epoch 433: Train Loss: 2805.9189453125, Val Loss: 2826.671630859375
# Distance_Weighted - Epoch 434: Train Loss: 2802.6474609375, Val Loss: 2823.537109375
# Distance_Weighted - Epoch 435: Train Loss: 2799.427734375, Val Loss: 2820.22802734375
# Distance_Weighted - Epoch 436: Train Loss: 2796.33251953125, Val Loss: 2817.552734375
# Distance_Weighted - Epoch 437: Train Loss: 2793.4736328125, Val Loss: 2814.631591796875
# Distance_Weighted - Epoch 438: Train Loss: 2790.834228515625, Val Loss: 2811.839599609375
# Distance_Weighted - Epoch 439: Train Loss: 2787.941650390625, Val Loss: 2808.1513671875
# Distance_Weighted - Epoch 440: Train Loss: 2784.270263671875, Val Loss: 2803.934326171875
# Distance_Weighted - Epoch 441: Train Loss: 2780.316650390625, Val Loss: 2801.0712890625
# Distance_Weighted - Epoch 442: Train Loss: 2777.207763671875, Val Loss: 2798.302001953125
# Distance_Weighted - Epoch 443: Train Loss: 2774.633544921875, Val Loss: 2794.983154296875
# Distance_Weighted - Epoch 444: Train Loss: 2771.369384765625, Val Loss: 2791.422119140625
# Distance_Weighted - Epoch 445: Train Loss: 2767.72607421875, Val Loss: 2788.215087890625
# Distance_Weighted - Epoch 446: Train Loss: 2764.7431640625, Val Loss: 2785.521484375
# Distance_Weighted - Epoch 447: Train Loss: 2761.997314453125, Val Loss: 2782.196044921875
# Distance_Weighted - Epoch 448: Train Loss: 2758.765380859375, Val Loss: 2778.73681640625
# Distance_Weighted - Epoch 449: Train Loss: 2755.40087890625, Val Loss: 2775.89990234375
# Distance_Weighted - Epoch 450: Train Loss: 2752.483642578125, Val Loss: 2772.888671875
# Distance_Weighted - Epoch 451: Train Loss: 2749.659912109375, Val Loss: 2769.69287109375
# Distance_Weighted - Epoch 452: Train Loss: 2746.448974609375, Val Loss: 2766.484619140625
# Distance_Weighted - Epoch 453: Train Loss: 2743.261962890625, Val Loss: 2763.4912109375
# Distance_Weighted - Epoch 454: Train Loss: 2740.4423828125, Val Loss: 2760.64501953125
# Distance_Weighted - Epoch 455: Train Loss: 2737.53564453125, Val Loss: 2757.400634765625
# Distance_Weighted - Epoch 456: Train Loss: 2734.375732421875, Val Loss: 2754.231689453125
# Distance_Weighted - Epoch 457: Train Loss: 2731.3369140625, Val Loss: 2751.429931640625
# Distance_Weighted - Epoch 458: Train Loss: 2728.48876953125, Val Loss: 2748.408935546875
# Distance_Weighted - Epoch 459: Train Loss: 2725.584228515625, Val Loss: 2745.32275390625
# Distance_Weighted - Epoch 460: Train Loss: 2722.522216796875, Val Loss: 2742.3037109375
# Distance_Weighted - Epoch 461: Train Loss: 2719.500244140625, Val Loss: 2739.338134765625
# Distance_Weighted - Epoch 462: Train Loss: 2716.639404296875, Val Loss: 2736.427490234375
# Distance_Weighted - Epoch 463: Train Loss: 2713.75048828125, Val Loss: 2733.351318359375
# Distance_Weighted - Epoch 464: Train Loss: 2710.6923828125, Val Loss: 2730.29833984375
# Distance_Weighted - Epoch 465: Train Loss: 2707.641357421875, Val Loss: 2727.27734375
# Distance_Weighted - Epoch 466: Train Loss: 2704.6845703125, Val Loss: 2724.254150390625
# Distance_Weighted - Epoch 467: Train Loss: 2701.712890625, Val Loss: 2721.162841796875
# Distance_Weighted - Epoch 468: Train Loss: 2698.664794921875, Val Loss: 2717.950439453125
# Distance_Weighted - Epoch 469: Train Loss: 2695.60693359375, Val Loss: 2714.916748046875
# Distance_Weighted - Epoch 470: Train Loss: 2692.610107421875, Val Loss: 2711.92236328125
# Distance_Weighted - Epoch 471: Train Loss: 2689.66796875, Val Loss: 2708.844482421875
# Distance_Weighted - Epoch 472: Train Loss: 2686.729248046875, Val Loss: 2705.83642578125
# Distance_Weighted - Epoch 473: Train Loss: 2683.76171875, Val Loss: 2702.765380859375
# Distance_Weighted - Epoch 474: Train Loss: 2680.796142578125, Val Loss: 2699.759521484375
# Distance_Weighted - Epoch 475: Train Loss: 2677.861572265625, Val Loss: 2696.7705078125
# Distance_Weighted - Epoch 476: Train Loss: 2674.925537109375, Val Loss: 2693.692138671875
# Distance_Weighted - Epoch 477: Train Loss: 2671.97216796875, Val Loss: 2690.689697265625
# Distance_Weighted - Epoch 478: Train Loss: 2669.025390625, Val Loss: 2687.69287109375
# Distance_Weighted - Epoch 479: Train Loss: 2666.11181640625, Val Loss: 2684.786865234375
# Distance_Weighted - Epoch 480: Train Loss: 2663.245361328125, Val Loss: 2681.925048828125
# Distance_Weighted - Epoch 481: Train Loss: 2660.404052734375, Val Loss: 2679.046630859375
# Distance_Weighted - Epoch 482: Train Loss: 2657.567138671875, Val Loss: 2676.1904296875
# Distance_Weighted - Epoch 483: Train Loss: 2654.727783203125, Val Loss: 2673.282958984375
# Distance_Weighted - Epoch 484: Train Loss: 2651.902587890625, Val Loss: 2670.467529296875
# Distance_Weighted - Epoch 485: Train Loss: 2649.099609375, Val Loss: 2667.65869140625
# Distance_Weighted - Epoch 486: Train Loss: 2646.31640625, Val Loss: 2664.8515625
# Distance_Weighted - Epoch 487: Train Loss: 2643.543701171875, Val Loss: 2662.0869140625
# Distance_Weighted - Epoch 488: Train Loss: 2640.77734375, Val Loss: 2659.2822265625
# Distance_Weighted - Epoch 489: Train Loss: 2638.01611328125, Val Loss: 2656.5458984375
# Distance_Weighted - Epoch 490: Train Loss: 2635.262451171875, Val Loss: 2653.778076171875
# Distance_Weighted - Epoch 491: Train Loss: 2632.517333984375, Val Loss: 2651.026123046875
# Distance_Weighted - Epoch 492: Train Loss: 2629.7841796875, Val Loss: 2648.286376953125
# Distance_Weighted - Epoch 493: Train Loss: 2627.063232421875, Val Loss: 2645.532958984375
# Distance_Weighted - Epoch 494: Train Loss: 2624.353271484375, Val Loss: 2642.79345703125
# Distance_Weighted - Epoch 495: Train Loss: 2621.650390625, Val Loss: 2640.0595703125
# Distance_Weighted - Epoch 496: Train Loss: 2618.95458984375, Val Loss: 2637.377685546875
# Distance_Weighted - Epoch 497: Train Loss: 2616.2666015625, Val Loss: 2634.68408203125
# Distance_Weighted - Epoch 498: Train Loss: 2613.588134765625, Val Loss: 2631.96533203125
# Distance_Weighted - Epoch 499: Train Loss: 2610.916748046875, Val Loss: 2629.26416015625
# Distance_Weighted - Test Loss: 2461.025390625
# Running model: Adaptive_Threshold
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 28 nodes.
# Adaptive_Threshold - Training samples: 688752
# Adaptive_Threshold - Validation samples: 76528
# Adaptive_Threshold - Test samples: 324352
# Adaptive_Threshold - Epoch 0: Train Loss: 35577.48828125, Val Loss: 34993.10546875
# Adaptive_Threshold - Epoch 1: Train Loss: 34847.62109375, Val Loss: 34320.546875
# Adaptive_Threshold - Epoch 2: Train Loss: 34174.80078125, Val Loss: 33637.98828125
# Adaptive_Threshold - Epoch 3: Train Loss: 33493.13671875, Val Loss: 32911.36328125
# Adaptive_Threshold - Epoch 4: Train Loss: 32768.30859375, Val Loss: 32123.140625
# Adaptive_Threshold - Epoch 5: Train Loss: 31982.421875, Val Loss: 31265.1328125
# Adaptive_Threshold - Epoch 6: Train Loss: 31127.515625, Val Loss: 30339.3671875
# Adaptive_Threshold - Epoch 7: Train Loss: 30205.412109375, Val Loss: 29355.8984375
# Adaptive_Threshold - Epoch 8: Train Loss: 29226.48828125, Val Loss: 28334.34375
# Adaptive_Threshold - Epoch 9: Train Loss: 28210.23828125, Val Loss: 27305.01171875
# Adaptive_Threshold - Epoch 10: Train Loss: 27186.8515625, Val Loss: 26299.5234375
# Adaptive_Threshold - Epoch 11: Train Loss: 26187.857421875, Val Loss: 25343.802734375
# Adaptive_Threshold - Epoch 12: Train Loss: 25238.97265625, Val Loss: 24451.69921875
# Adaptive_Threshold - Epoch 13: Train Loss: 24353.91796875, Val Loss: 23619.5859375
# Adaptive_Threshold - Epoch 14: Train Loss: 23528.40234375, Val Loss: 22824.96875
# Adaptive_Threshold - Epoch 15: Train Loss: 22739.73046875, Val Loss: 22039.177734375
# Adaptive_Threshold - Epoch 16: Train Loss: 21958.71484375, Val Loss: 21244.658203125
# Adaptive_Threshold - Epoch 17: Train Loss: 21167.669921875, Val Loss: 20442.85546875
# Adaptive_Threshold - Epoch 18: Train Loss: 20368.390625, Val Loss: 19650.71875
# Adaptive_Threshold - Epoch 19: Train Loss: 19577.767578125, Val Loss: 18889.0078125
# Adaptive_Threshold - Epoch 20: Train Loss: 18816.69140625, Val Loss: 18174.220703125
# Adaptive_Threshold - Epoch 21: Train Loss: 18101.912109375, Val Loss: 17513.00390625
# Adaptive_Threshold - Epoch 22: Train Loss: 17440.48046875, Val Loss: 16901.193359375
# Adaptive_Threshold - Epoch 23: Train Loss: 16828.49609375, Val Loss: 16327.734375
# Adaptive_Threshold - Epoch 24: Train Loss: 16255.265625, Val Loss: 15781.640625
# Adaptive_Threshold - Epoch 25: Train Loss: 15710.1015625, Val Loss: 15258.1806640625
# Adaptive_Threshold - Epoch 26: Train Loss: 15188.17578125, Val Loss: 14759.9208984375
# Adaptive_Threshold - Epoch 27: Train Loss: 14691.884765625, Val Loss: 14293.7578125
# Adaptive_Threshold - Epoch 28: Train Loss: 14228.03515625, Val Loss: 13865.625
# Adaptive_Threshold - Epoch 29: Train Loss: 13802.302734375, Val Loss: 13475.166015625
# Adaptive_Threshold - Epoch 30: Train Loss: 13414.0966796875, Val Loss: 13115.4404296875
# Adaptive_Threshold - Epoch 31: Train Loss: 13056.0302734375, Val Loss: 12777.201171875
# Adaptive_Threshold - Epoch 32: Train Loss: 12718.5791015625, Val Loss: 12455.0546875
# Adaptive_Threshold - Epoch 33: Train Loss: 12396.298828125, Val Loss: 12149.7099609375
# Adaptive_Threshold - Epoch 34: Train Loss: 12090.142578125, Val Loss: 11865.0263671875
# Adaptive_Threshold - Epoch 35: Train Loss: 11804.1376953125, Val Loss: 11602.59375
# Adaptive_Threshold - Epoch 36: Train Loss: 11540.26171875, Val Loss: 11359.4345703125
# Adaptive_Threshold - Epoch 37: Train Loss: 11295.8525390625, Val Loss: 11129.5908203125
# Adaptive_Threshold - Epoch 38: Train Loss: 11065.166015625, Val Loss: 10907.7109375
# Adaptive_Threshold - Epoch 39: Train Loss: 10842.921875, Val Loss: 10691.501953125
# Adaptive_Threshold - Epoch 40: Train Loss: 10626.8984375, Val Loss: 10482.109375
# Adaptive_Threshold - Epoch 41: Train Loss: 10418.1044921875, Val Loss: 10281.798828125
# Adaptive_Threshold - Epoch 42: Train Loss: 10218.59375, Val Loss: 10091.298828125
# Adaptive_Threshold - Epoch 43: Train Loss: 10028.8720703125, Val Loss: 9908.357421875
# Adaptive_Threshold - Epoch 44: Train Loss: 9846.466796875, Val Loss: 9728.8759765625
# Adaptive_Threshold - Epoch 45: Train Loss: 9667.1865234375, Val Loss: 9550.0654296875
# Adaptive_Threshold - Epoch 46: Train Loss: 9488.142578125, Val Loss: 9371.91796875
# Adaptive_Threshold - Epoch 47: Train Loss: 9309.484375, Val Loss: 9196.25
# Adaptive_Threshold - Epoch 48: Train Loss: 9133.1962890625, Val Loss: 9024.27734375
# Adaptive_Threshold - Epoch 49: Train Loss: 8960.71484375, Val Loss: 8855.49609375
# Adaptive_Threshold - Epoch 50: Train Loss: 8791.734375, Val Loss: 8688.3779296875
# Adaptive_Threshold - Epoch 51: Train Loss: 8624.796875, Val Loss: 8522.1357421875
# Adaptive_Threshold - Epoch 52: Train Loss: 8459.1220703125, Val Loss: 8357.41796875
# Adaptive_Threshold - Epoch 53: Train Loss: 8295.3466796875, Val Loss: 8195.6728515625
# Adaptive_Threshold - Epoch 54: Train Loss: 8134.78125, Val Loss: 8037.75830078125
# Adaptive_Threshold - Epoch 55: Train Loss: 7978.06201171875, Val Loss: 7883.32470703125
# Adaptive_Threshold - Epoch 56: Train Loss: 7824.6494140625, Val Loss: 7731.6552734375
# Adaptive_Threshold - Epoch 57: Train Loss: 7673.71142578125, Val Loss: 7582.9140625
# Adaptive_Threshold - Epoch 58: Train Loss: 7525.38330078125, Val Loss: 7438.3486328125
# Adaptive_Threshold - Epoch 59: Train Loss: 7380.9853515625, Val Loss: 7299.111328125
# Adaptive_Threshold - Epoch 60: Train Loss: 7241.89599609375, Val Loss: 7165.537109375
# Adaptive_Threshold - Epoch 61: Train Loss: 7108.59326171875, Val Loss: 7037.08740234375
# Adaptive_Threshold - Epoch 62: Train Loss: 6980.60400390625, Val Loss: 6913.26416015625
# Adaptive_Threshold - Epoch 63: Train Loss: 6857.462890625, Val Loss: 6794.1796875
# Adaptive_Threshold - Epoch 64: Train Loss: 6739.36865234375, Val Loss: 6680.64306640625
# Adaptive_Threshold - Epoch 65: Train Loss: 6626.998046875, Val Loss: 6573.26904296875
# Adaptive_Threshold - Epoch 66: Train Loss: 6520.80908203125, Val Loss: 6472.021484375
# Adaptive_Threshold - Epoch 67: Train Loss: 6420.552734375, Val Loss: 6376.419921875
# Adaptive_Threshold - Epoch 68: Train Loss: 6325.650390625, Val Loss: 6286.1689453125
# Adaptive_Threshold - Epoch 69: Train Loss: 6235.810546875, Val Loss: 6201.32666015625
# Adaptive_Threshold - Epoch 70: Train Loss: 6151.146484375, Val Loss: 6121.9326171875
# Adaptive_Threshold - Epoch 71: Train Loss: 6071.8408203125, Val Loss: 6047.64013671875
# Adaptive_Threshold - Epoch 72: Train Loss: 5997.6943359375, Val Loss: 5977.912109375
# Adaptive_Threshold - Epoch 73: Train Loss: 5928.24169921875, Val Loss: 5912.39208984375
# Adaptive_Threshold - Epoch 74: Train Loss: 5863.13623046875, Val Loss: 5851.033203125
# Adaptive_Threshold - Epoch 75: Train Loss: 5802.26416015625, Val Loss: 5793.83203125
# Adaptive_Threshold - Epoch 76: Train Loss: 5745.5546875, Val Loss: 5740.60986328125
# Adaptive_Threshold - Epoch 77: Train Loss: 5692.7607421875, Val Loss: 5691.05322265625
# Adaptive_Threshold - Epoch 78: Train Loss: 5643.53173828125, Val Loss: 5644.89404296875
# Adaptive_Threshold - Epoch 79: Train Loss: 5597.61474609375, Val Loss: 5601.98681640625
# Adaptive_Threshold - Epoch 80: Train Loss: 5554.876953125, Val Loss: 5562.12939453125
# Adaptive_Threshold - Epoch 81: Train Loss: 5515.16455078125, Val Loss: 5524.98583984375
# Adaptive_Threshold - Epoch 82: Train Loss: 5478.21044921875, Val Loss: 5490.2646484375
# Adaptive_Threshold - Epoch 83: Train Loss: 5443.7216796875, Val Loss: 5457.783203125
# Adaptive_Threshold - Epoch 84: Train Loss: 5411.49072265625, Val Loss: 5427.43359375
# Adaptive_Threshold - Epoch 85: Train Loss: 5381.38916015625, Val Loss: 5399.095703125
# Adaptive_Threshold - Epoch 86: Train Loss: 5353.3046875, Val Loss: 5372.599609375
# Adaptive_Threshold - Epoch 87: Train Loss: 5327.05078125, Val Loss: 5347.671875
# Adaptive_Threshold - Epoch 88: Train Loss: 5302.37890625, Val Loss: 5324.27978515625
# Adaptive_Threshold - Epoch 89: Train Loss: 5279.23095703125, Val Loss: 5302.29345703125
# Adaptive_Threshold - Epoch 90: Train Loss: 5257.517578125, Val Loss: 5281.53173828125
# Adaptive_Threshold - Epoch 91: Train Loss: 5237.06640625, Val Loss: 5261.8623046875
# Adaptive_Threshold - Epoch 92: Train Loss: 5217.7607421875, Val Loss: 5243.27294921875
# Adaptive_Threshold - Epoch 93: Train Loss: 5199.57080078125, Val Loss: 5225.7568359375
# Adaptive_Threshold - Epoch 94: Train Loss: 5182.4462890625, Val Loss: 5209.2021484375
# Adaptive_Threshold - Epoch 95: Train Loss: 5166.2568359375, Val Loss: 5193.50390625
# Adaptive_Threshold - Epoch 96: Train Loss: 5150.8935546875, Val Loss: 5178.65771484375
# Adaptive_Threshold - Epoch 97: Train Loss: 5136.3212890625, Val Loss: 5164.6259765625
# Adaptive_Threshold - Epoch 98: Train Loss: 5122.5078125, Val Loss: 5151.3046875
# Adaptive_Threshold - Epoch 99: Train Loss: 5109.3564453125, Val Loss: 5138.52587890625
# Adaptive_Threshold - Epoch 100: Train Loss: 5096.736328125, Val Loss: 5126.17578125
# Adaptive_Threshold - Epoch 101: Train Loss: 5084.5703125, Val Loss: 5114.259765625
# Adaptive_Threshold - Epoch 102: Train Loss: 5072.81982421875, Val Loss: 5102.71875
# Adaptive_Threshold - Epoch 103: Train Loss: 5061.4560546875, Val Loss: 5091.56103515625
# Adaptive_Threshold - Epoch 104: Train Loss: 5050.47900390625, Val Loss: 5080.79052734375
# Adaptive_Threshold - Epoch 105: Train Loss: 5039.91845703125, Val Loss: 5070.41455078125
# Adaptive_Threshold - Epoch 106: Train Loss: 5029.65380859375, Val Loss: 5060.44677734375
# Adaptive_Threshold - Epoch 107: Train Loss: 5019.73095703125, Val Loss: 5050.6953125
# Adaptive_Threshold - Epoch 108: Train Loss: 5010.04541015625, Val Loss: 5041.24267578125
# Adaptive_Threshold - Epoch 109: Train Loss: 5000.6337890625, Val Loss: 5032.1376953125
# Adaptive_Threshold - Epoch 110: Train Loss: 4991.52734375, Val Loss: 5023.27978515625
# Adaptive_Threshold - Epoch 111: Train Loss: 4982.62841796875, Val Loss: 5014.6357421875
# Adaptive_Threshold - Epoch 112: Train Loss: 4973.921875, Val Loss: 5006.2099609375
# Adaptive_Threshold - Epoch 113: Train Loss: 4965.451171875, Val Loss: 4997.90625
# Adaptive_Threshold - Epoch 114: Train Loss: 4957.17529296875, Val Loss: 4989.63427734375
# Adaptive_Threshold - Epoch 115: Train Loss: 4949.009765625, Val Loss: 4981.40771484375
# Adaptive_Threshold - Epoch 116: Train Loss: 4940.95947265625, Val Loss: 4973.3125
# Adaptive_Threshold - Epoch 117: Train Loss: 4933.072265625, Val Loss: 4965.36962890625
# Adaptive_Threshold - Epoch 118: Train Loss: 4925.32177734375, Val Loss: 4957.548828125
# Adaptive_Threshold - Epoch 119: Train Loss: 4917.63916015625, Val Loss: 4949.84814453125
# Adaptive_Threshold - Epoch 120: Train Loss: 4910.0126953125, Val Loss: 4942.2763671875
# Adaptive_Threshold - Epoch 121: Train Loss: 4902.45263671875, Val Loss: 4934.775390625
# Adaptive_Threshold - Epoch 122: Train Loss: 4894.9580078125, Val Loss: 4927.29150390625
# Adaptive_Threshold - Epoch 123: Train Loss: 4887.5146484375, Val Loss: 4919.79248046875
# Adaptive_Threshold - Epoch 124: Train Loss: 4880.099609375, Val Loss: 4912.26513671875
# Adaptive_Threshold - Epoch 125: Train Loss: 4872.69384765625, Val Loss: 4904.724609375
# Adaptive_Threshold - Epoch 126: Train Loss: 4865.2978515625, Val Loss: 4897.203125
# Adaptive_Threshold - Epoch 127: Train Loss: 4857.92041015625, Val Loss: 4889.7060546875
# Adaptive_Threshold - Epoch 128: Train Loss: 4850.5595703125, Val Loss: 4882.2138671875
# Adaptive_Threshold - Epoch 129: Train Loss: 4843.18310546875, Val Loss: 4874.7119140625
# Adaptive_Threshold - Epoch 130: Train Loss: 4835.787109375, Val Loss: 4867.20849609375
# Adaptive_Threshold - Epoch 131: Train Loss: 4828.37939453125, Val Loss: 4859.69775390625
# Adaptive_Threshold - Epoch 132: Train Loss: 4820.9609375, Val Loss: 4852.1611328125
# Adaptive_Threshold - Epoch 133: Train Loss: 4813.5185546875, Val Loss: 4844.5908203125
# Adaptive_Threshold - Epoch 134: Train Loss: 4806.04443359375, Val Loss: 4836.97607421875
# Adaptive_Threshold - Epoch 135: Train Loss: 4798.5400390625, Val Loss: 4829.32275390625
# Adaptive_Threshold - Epoch 136: Train Loss: 4791.00048828125, Val Loss: 4821.6279296875
# Adaptive_Threshold - Epoch 137: Train Loss: 4783.42333984375, Val Loss: 4813.90185546875
# Adaptive_Threshold - Epoch 138: Train Loss: 4775.81298828125, Val Loss: 4806.13916015625
# Adaptive_Threshold - Epoch 139: Train Loss: 4768.16357421875, Val Loss: 4798.330078125
# Adaptive_Threshold - Epoch 140: Train Loss: 4760.4658203125, Val Loss: 4790.45947265625
# Adaptive_Threshold - Epoch 141: Train Loss: 4752.7177734375, Val Loss: 4782.54345703125
# Adaptive_Threshold - Epoch 142: Train Loss: 4744.92041015625, Val Loss: 4774.5791015625
# Adaptive_Threshold - Epoch 143: Train Loss: 4737.07275390625, Val Loss: 4766.56982421875
# Adaptive_Threshold - Epoch 144: Train Loss: 4729.17626953125, Val Loss: 4758.515625
# Adaptive_Threshold - Epoch 145: Train Loss: 4721.22802734375, Val Loss: 4750.416015625
# Adaptive_Threshold - Epoch 146: Train Loss: 4713.2236328125, Val Loss: 4742.25390625
# Adaptive_Threshold - Epoch 147: Train Loss: 4705.16162109375, Val Loss: 4734.025390625
# Adaptive_Threshold - Epoch 148: Train Loss: 4697.04052734375, Val Loss: 4725.7294921875
# Adaptive_Threshold - Epoch 149: Train Loss: 4688.859375, Val Loss: 4717.37158203125
# Adaptive_Threshold - Epoch 150: Train Loss: 4680.611328125, Val Loss: 4708.94580078125
# Adaptive_Threshold - Epoch 151: Train Loss: 4672.29931640625, Val Loss: 4700.45458984375
# Adaptive_Threshold - Epoch 152: Train Loss: 4663.9189453125, Val Loss: 4691.896484375
# Adaptive_Threshold - Epoch 153: Train Loss: 4655.46728515625, Val Loss: 4683.2734375
# Adaptive_Threshold - Epoch 154: Train Loss: 4646.9462890625, Val Loss: 4674.58251953125
# Adaptive_Threshold - Epoch 155: Train Loss: 4638.353515625, Val Loss: 4665.81640625
# Adaptive_Threshold - Epoch 156: Train Loss: 4629.68701171875, Val Loss: 4656.98193359375
# Adaptive_Threshold - Epoch 157: Train Loss: 4620.9443359375, Val Loss: 4648.0693359375
# Adaptive_Threshold - Epoch 158: Train Loss: 4612.1220703125, Val Loss: 4639.07666015625
# Adaptive_Threshold - Epoch 159: Train Loss: 4603.2177734375, Val Loss: 4629.994140625
# Adaptive_Threshold - Epoch 160: Train Loss: 4594.22802734375, Val Loss: 4620.83349609375
# Adaptive_Threshold - Epoch 161: Train Loss: 4585.150390625, Val Loss: 4611.5673828125
# Adaptive_Threshold - Epoch 162: Train Loss: 4575.9873046875, Val Loss: 4602.2197265625
# Adaptive_Threshold - Epoch 163: Train Loss: 4566.75732421875, Val Loss: 4592.79345703125
# Adaptive_Threshold - Epoch 164: Train Loss: 4557.4765625, Val Loss: 4583.310546875
# Adaptive_Threshold - Epoch 165: Train Loss: 4548.1435546875, Val Loss: 4573.7880859375
# Adaptive_Threshold - Epoch 166: Train Loss: 4538.74267578125, Val Loss: 4564.22314453125
# Adaptive_Threshold - Epoch 167: Train Loss: 4529.27294921875, Val Loss: 4554.62109375
# Adaptive_Threshold - Epoch 168: Train Loss: 4519.74853515625, Val Loss: 4544.97998046875
# Adaptive_Threshold - Epoch 169: Train Loss: 4510.18310546875, Val Loss: 4535.2978515625
# Adaptive_Threshold - Epoch 170: Train Loss: 4500.57470703125, Val Loss: 4525.56884765625
# Adaptive_Threshold - Epoch 171: Train Loss: 4490.9130859375, Val Loss: 4515.771484375
# Adaptive_Threshold - Epoch 172: Train Loss: 4481.19384765625, Val Loss: 4505.9130859375
# Adaptive_Threshold - Epoch 173: Train Loss: 4471.41552734375, Val Loss: 4495.98974609375
# Adaptive_Threshold - Epoch 174: Train Loss: 4461.5830078125, Val Loss: 4485.98779296875
# Adaptive_Threshold - Epoch 175: Train Loss: 4451.69384765625, Val Loss: 4475.8994140625
# Adaptive_Threshold - Epoch 176: Train Loss: 4441.748046875, Val Loss: 4465.75244140625
# Adaptive_Threshold - Epoch 177: Train Loss: 4431.763671875, Val Loss: 4455.61376953125
# Adaptive_Threshold - Epoch 178: Train Loss: 4421.7470703125, Val Loss: 4445.4482421875

# %%
# Print the last loss of each model
for model_name, result in results.items():
    print(f"{model_name} - Test Loss: {result['test_loss']}")
# Out:
# Distance_Weighted - Test Loss: 883.553955078125
# Adaptive_Threshold - Test Loss: 1087.8638916015625
# Dynamic_Weight - Test Loss: 917.48388671875

# %% [markdown]
# ## Trying to evalute the grpah more

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Compute evaluation metrics
def evaluate_model(actual, predicted):
    mae = mean_absolute_error(actual, predicted)
    rmse = np.sqrt(mean_squared_error(actual, predicted))
    mape = np.mean(np.abs((actual - predicted) / actual)) * 100
    r2 = r2_score(actual, predicted)
    return {'MAE': mae, 'RMSE': rmse, 'MAPE': mape, 'R^2': r2}

# Evaluate each model
for model_name, result in results.items():
    actual = result['actual_values']
    predicted = result['predicted_values']
    metrics = evaluate_model(actual, predicted)
    results[model_name].update(metrics)


from torch_geometric.nn import GNNExplainer

explainer = GNNExplainer(model, epochs=200)
node_idx = 42  # Node to explain
node_feat_mask, edge_mask = explainer.explain_node(node_idx, data.x, data.edge_index)
explainer.visualize_subgraph(node_idx, data.edge_index, edge_mask, y=data.y)

model.eval()
with torch.no_grad():
    predictions = [model(data) for _ in range(100)]
predictions = torch.stack(predictions)
mean_prediction = predictions.mean(dim=0)
std_prediction = predictions.std(dim=0)

# Naive Persistence Model
def persistence_model(X):
    return X[:, -1]  # Predict the last observed value

y_pred_baseline = persistence_model(X_test.numpy())
mae_baseline = mean_absolute_error(y_test.numpy(), y_pred_baseline)
print(f"Baseline MAE: {mae_baseline}")
# Out:
# C:\Users\gonde\AppData\Local\Temp\ipykernel_13576\133237990.py:7: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((actual - predicted) / actual)) * 100
# C:\Users\gonde\AppData\Local\Temp\ipykernel_13576\133237990.py:7: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((actual - predicted) / actual)) * 100
# C:\Users\gonde\AppData\Local\Temp\ipykernel_13576\133237990.py:7: RuntimeWarning: divide by zero encountered in divide
#   mape = np.mean(np.abs((actual - predicted) / actual)) * 100

# %%
# Combined plot for train and validation losses
plt.figure(figsize=(12, 8))
for model_name, result in results.items():
    plt.plot(result['train_losses'][20:], label=f'{model_name} - Training Loss')
    # also print the last value as a reference
    print(f"{model_name} - Last Training Loss: {result['train_losses'][-1]}")
plt.title("Training Loss for All Models")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.yscale('log')
plt.legend(loc='upper right')
plt.show()

# Combined actual vs predicted plots in subplots
fig, axs = plt.subplots(len(results), 1, figsize=(12, 8), sharex=True)
fig.suptitle("Actual vs Predicted Traffic Flow (200-point Intervals)")
start = np.random.randint(0, len(results['Distance_Weighted']['actual_values']) - 1600)
end = start + 1600

for idx, (model_name, result) in enumerate(results.items()):
    actual = result['actual_values']
    predicted = result['predicted_values']

    axs[idx].plot(actual[start:end], label='Actual')
    axs[idx].plot(predicted[start:end], label='Predicted')
    axs[idx].set_title(f"{model_name}")
    axs[idx].set_ylabel("Traffic Flow")
    axs[idx].legend(loc='upper left')


plt.xlabel("Time Steps")
plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust layout to fit title
plt.show()
# Out:
# Distance_Weighted - Last Training Loss: 1083.337890625
# Adaptive_Threshold - Last Training Loss: 1274.634033203125
# Dynamic_Weight - Last Training Loss: 1075.25439453125
# C:\Users\gonde\AppData\Local\Temp\ipykernel_13576\3295683635.py:32: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust layout to fit title

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Compute evaluation metrics
def evaluate_model(actual, predicted):
    mae = mean_absolute_error(actual, predicted)
    rmse = np.sqrt(mean_squared_error(actual, predicted))
    mape = np.mean(np.abs((actual - predicted) / actual)) * 100
    r2 = r2_score(actual, predicted)
    return {'MAE': mae, 'RMSE': rmse, 'MAPE': mape, 'R^2': r2}

# %%
# Initialize model, optimizer, and loss function
hc = 32
#model = Baseline_updatet(in_channels=lookback, hidden_channels=hc, out_channels=pred_horizon, dropout_rate=0.5)
model = TrafficGCN(in_channels=lookback, hidden_channels=hc, out_channels=pred_horizon)
optimizer = Adam(model.parameters(), lr=0.01, amsgrad=False)
criterion = torch.nn.MSELoss()
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10, cooldown=10)

# Early stopping parameters
early_stopping_patience = 50
best_val_loss = float('inf')
epochs_no_improve = 0

# Initialize lists to store training and validation losses and metrics
train_losses = []
val_losses = []
train_maes = []
val_maes = []
train_rmses = []
val_rmses = []

# Lists to store actual and predicted values for plotting
actual_values = []
predicted_values = []


# Training loop with validation and early stopping
model.train()
print("Lookback: ", lookback, " Pred Horizon: ", pred_horizon, " Hidden Channels: ", hc)
for epoch in range(1_000):
    optimizer.zero_grad()
    
    # Forward pass on training data
    out = model(train_data)
    train_loss = criterion(out, train_data.y)
    train_rmse = torch.sqrt(train_loss).item()
    train_mae = torch.mean(torch.abs(out - train_data.y)).item()
    
    # Backward pass
    train_loss.backward()
    optimizer.step()
    
    # Evaluate on validation set
    model.eval()
    with torch.no_grad():
        val_out = model(val_data)
        val_loss = criterion(val_out, val_data.y)
        val_rmse = torch.sqrt(val_loss).item()
        val_mae = torch.mean(torch.abs(val_out - val_data.y)).item()

        # Store actual and predicted values after each epoch
        actual_values = val_data.y.cpu().numpy()
        predicted_values = val_out.cpu().numpy()
    
    model.train()  # Switch back to training mode

    # Learning rate scheduling
    scheduler.step(val_loss)

    # Store losses and metrics for plotting
    train_losses.append(train_loss.item())
    val_losses.append(val_loss.item())
    train_maes.append(train_mae)
    val_maes.append(val_mae)
    train_rmses.append(train_rmse)
    val_rmses.append(val_rmse)
    
    # Early stopping check
    if val_loss.item() < best_val_loss:
        best_val_loss = val_loss.item()
        epochs_no_improve = 0
    else:
        epochs_no_improve += 1
        if epochs_no_improve >= early_stopping_patience:
            print(f"Early stopping at epoch {epoch}")
            break

    # Get current learning rate
    current_lr = optimizer.param_groups[0]['lr']

    # Print loss and metrics every 10 epochs
    if epoch % 1 == 0:
        print(f"Epoch {epoch}, LR: { optimizer.param_groups[0]['lr']:.6f}, Train Loss: {train_loss.item():.2f}, "
              f"Val Loss: {val_loss.item():.2f}, Train MAE: {train_mae:.2f}, "
              f"Val MAE: {val_mae:.2f}")

# %%
# Eval model
model.eval()
test_out = model(test_data)
test_loss = criterion(test_out, test_data.y)
test_rmse = torch.sqrt(test_loss).item()
test_mae = torch.mean(torch.abs(test_out - test_data.y)).item()
print(f"Test Loss: {test_loss.item():.2f}, Test MAE: {test_mae:.2f}, Test RMSE: {test_rmse:.2f}")
# Out:
# Test Loss: 308.39, Test MAE: 8.88, Test RMSE: 17.56

# %%
# Plot training and validation losses
plt.figure(figsize=(10, 6))
plt.plot(train_losses[10:250], label='Train Loss')
plt.plot(val_losses[10:250], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training and validation RMSE
plt.figure(figsize=(10, 6))
plt.plot(train_rmses[10:250], label='Train RMSE')  
plt.plot(val_rmses[10:250], label='Validation RMSE')
plt.xlabel('Epoch')
plt.ylabel('RMSE')
plt.legend()
plt.show()

# Plot training and validation MAE
plt.figure(figsize=(10, 6))
plt.plot(train_maes[10:250], label='Train MAE')
plt.plot(val_maes[10:250], label='Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 12
#      10 # Plot training and validation RMSE
#      11 plt.figure(figsize=(10, 6))
# ---> 12 plt.plot(train_rmses[10:250], label='Train RMSE')
#      13 plt.plot(val_rmses[10:250], label='Validation RMSE')
#      14 plt.xlabel('Epoch')
#
# NameError: name 'train_rmses' is not defined

# %%
# Convert actual and predicted values to numpy arrays for plotting
actual_values_stack = np.vstack(actual_values)
predicted_values_stack = np.vstack(predicted_values)

# Flatten the predicted and actual values
actual_values_flat = actual_values_stack.reshape(-1)
predicted_values_flat = predicted_values_stack.reshape(-1)

# Plot the difference between actual and predicted values
plt.figure(figsize=(12, 4))
plt.title("Difference between Actual and Predicted Traffic Flow (Flattened)")
plt.plot(predicted_values_flat[0:200] - actual_values_flat[0:200])
plt.show()

# Plot predicted vs actual traffic flow
plt.figure(figsize=(12, 4))
plt.title("Predicted vs Actual Traffic Flow (Flattened)")
plt.plot(predicted_values_flat[0:200], label='Predicted')
plt.plot(actual_values_flat[0:200], label='Actual')
plt.legend()
plt.show()

# Scatter plot
plt.figure(figsize=(5, 5))
plt.scatter(predicted_values_flat[:2000], actual_values_flat[:2000], s=10)
plt.xlabel('Predicted Traffic Flow')
plt.ylabel('Actual Traffic Flow')
plt.title('Predicted vs Actual Traffic Flow (Flattened)')
plt.show()

# %%
# Flatten the sequences
actual_values_flat = actual_values_stack.reshape(-1)
predicted_values_flat = predicted_values_stack.reshape(-1)

# Make 4 subplots showing 4 randomly chosen intervals of 250 predictions
fig, axs = plt.subplots(4, 1, figsize=(12, 6))
fig.suptitle('Predicted vs Actual Traffic Flow in Random Intervals (Flattened)')

interval_length = 1000  # You can adjust this value
start = np.random.randint(0, len(predicted_values_flat) - interval_length)
for i, ax in enumerate(axs.flat):
    
    end = start + interval_length

    ax.plot(predicted_values_flat[start:end], label='Predicted')
    ax.plot(actual_values_flat[start:end], label='Actual')
    ax.set_title(f'Interval {i+1}')
    ax.legend()

plt.tight_layout()
plt.show()
