# %%
import networkx as nx
import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import geopandas as gpd
import math
import time

# %%
final_dataframes = pickle.load(open("final_dataframes.pkl", "rb"))

# %%
# Define the train ratio
train_ratio = 0.8  # 80% training data
df_dict = final_dataframes

# Split each DataFrame into training and testing parts based on time
df_dict_train = {}
df_dict_test = {}
for key, df in final_dataframes.items():
    n_time_steps = len(df['traffic_flow'])
    train_size = int(n_time_steps * train_ratio)
    df_train = df.iloc[:train_size].copy()
    df_test = df.iloc[train_size:].copy()
    df_dict_train[key] = df_train
    df_dict_test[key] = df_test


def create_sliding_window_data(df_dict, lookback, pred_horizon):
    X_dict = {}
    y_dict = {}
    for key, df in df_dict.items():
        node_series = df['traffic_flow'].values
        X_node = []
        y_node = []
        for i in range(len(node_series) - lookback - pred_horizon + 1):
            X_node.append(node_series[i:i + lookback])  # Input: Lookback window
            y_node.append(node_series[i + lookback:i + lookback + pred_horizon])  # Output: Next step(s)
        X_dict[key] = np.array(X_node)
        y_dict[key] = np.array(y_node)
    return X_dict, y_dict


# Sliding window parameters
lookback = 50  # Number of time steps to look back
pred_horizon = 1  # Predict the next time step

# Generate sliding window data for training and testing sets
X_train_dict, y_train_dict = create_sliding_window_data(df_dict_train, lookback, pred_horizon)
X_test_dict, y_test_dict = create_sliding_window_data(df_dict_test, lookback, pred_horizon)

# %%
def clean_graph(graph):
    # Remove self-loops
    graph = graph.copy()  # Avoid modifying the
    self_loops = list(nx.selfloop_edges(graph))
    graph.remove_edges_from(self_loops)
    
    # Remove duplicate edges (not necessary for undirected graphs in NetworkX)
    # Here just in case your graph is directed or you need further verification
    edges_to_remove = []
    for u, v, data in graph.edges(data=True):
        if graph.number_of_edges(u, v) > 1:  # More than one edge exists
            edges_to_remove.append((u, v))
    
    graph.remove_edges_from(edges_to_remove)
    largest_component = max(nx.connected_components(graph), key=len)
    graph = graph.subgraph(largest_component)

    print(f"Removed {len(self_loops)} self-loops and {len(edges_to_remove)} duplicate edges. Choose the Largest Component: {len(largest_component)} nodes.")
    # extract largest component

    return graph

# def create_correlation_graph(df_dict, threshold=0.5, weighted=False, degree=4):
#     """
#     Create a correlation graph with a maximum degree constraint.
#     """
#     correlation_graph = nx.Graph()
#     correlations_dict = {}

#     # Add nodes to the graph
#     for key, df in df_dict.items():
#         correlation_graph.add_node(
#             key, 
#             x=df['Xkoordinat'].iloc[0], 
#             y=df['Ykoordinat'].iloc[0], 
#             traffic_flow=df['traffic_flow'].values
#         )

#     # Calculate correlations and store in a dictionary
#     for key1, df1 in df_dict.items():
#         for key2, df2 in df_dict.items():
#             if key1 == key2:
#                 continue
#             # Depending on split size only use test 
#             correlation = np.corrcoef(df1['traffic_flow'], df2['traffic_flow'])[0, 1]
#             correlations_dict[key1, key2] = correlation

#     # Add edges based on correlation, enforcing degree constraint
#     for key1 in df_dict.keys():
#         # Sort potential connections by correlation (highest first)
#         potential_edges = [
#             (key2, correlations_dict[key1, key2])
#             for key2 in df_dict.keys() if key1 != key2 and (key1, key2) in correlations_dict
#         ]
#         potential_edges = sorted(potential_edges, key=lambda x: -x[1])  # Sort by descending correlation
        
#         for key2, corr in potential_edges:
#             if correlation_graph.degree[key1] < degree and correlation_graph.degree[key2] < degree:
#                 if corr > threshold:
#                     if weighted:
#                         correlation_graph.add_edge(key1, key2, weight=corr)
#                     else:
#                         correlation_graph.add_edge(key1, key2)

#     # Clean graph
#     correlation_graph = clean_graph(correlation_graph)
#     return correlation_graph, correlations_dict

def create_correlation_graph(df_dict_full, df_dict_train, threshold=0.5, weighted=False,degree=4):
    """
    Create a correlation graph with a maximum degree constraint using only the training data for correlations.
    """
    correlation_graph = nx.Graph()
    correlations_dict = {}

    # Add nodes to the graph using the full data
    for key, df in df_dict_full.items():
        correlation_graph.add_node(
            key,
            x=df['Xkoordinat'].iloc[0],
            y=df['Ykoordinat'].iloc[0],
            traffic_flow=df['traffic_flow'].values  # Full traffic data
        )

    # Calculate correlations using the training data
    for key1, df1_train in df_dict_train.items():
        for key2, df2_train in df_dict_train.items():
            if key1 >= key2:  # Avoid duplicate computations
                continue
            correlation = np.corrcoef(df1_train['traffic_flow'], df2_train['traffic_flow'])[0, 1]
            correlations_dict[key1, key2] = correlation
            correlations_dict[key2, key1] = correlation  # Symmetric for undirected graph

    # Add edges based on correlation, enforcing degree constraint
    for key1 in df_dict_full.keys():
        # Sort potential connections by correlation (highest first)
        potential_edges = [
            (key2, correlations_dict[key1, key2])
            for key2 in df_dict_full.keys() if key1 != key2 and (key1, key2) in correlations_dict
        ]
        potential_edges = sorted(potential_edges, key=lambda x: -x[1])  # Sort by descending correlation

        for key2, corr in potential_edges:
            if correlation_graph.degree[key1] < degree and correlation_graph.degree[key2] < degree:
                if corr > threshold:
                    if weighted:
                        correlation_graph.add_edge(key1, key2, weight=corr)
                    else:
                        correlation_graph.add_edge(key1, key2)

    # Clean graph
    correlation_graph = clean_graph(correlation_graph)
    return correlation_graph, correlations_dict

def create_distance_graph(df_dict, weighted=False, degree=4):
    """
    Create a distance graph with a maximum degree constraint.
    """
    distance_graph = nx.Graph()
    distance_dict = {}

    # Add nodes to the graph
    for key, df in df_dict.items():
        distance_graph.add_node(
            key, 
            x=df['Xkoordinat'].iloc[0], 
            y=df['Ykoordinat'].iloc[0], 
            traffic_flow=df['traffic_flow'].values
        )

    # Calculate distances and store in a dictionary
    for key1, df1 in df_dict.items():
        for key2, df2 in df_dict.items():
            if key1 == key2:
                continue
            idx = df1['traffic_flow'].first_valid_index()
            distance = math.sqrt(
                (df1['Xkoordinat'][idx] - df2['Xkoordinat'][idx])**2 +
                (df1['Ykoordinat'][idx] - df2['Ykoordinat'][idx])**2
            )
            distance_dict[key1, key2] = distance

    # Add edges based on distance, enforcing degree constraint
    threshold = (sum(distance_dict.values()) / len(distance_dict)) * 2  # Distance threshold
    for key1 in df_dict.keys():
        # Sort potential connections by distance (shortest first)
        potential_edges = [
            (key2, distance_dict[key1, key2])
            for key2 in df_dict.keys() if key1 != key2 and (key1, key2) in distance_dict
        ]
        potential_edges = sorted(potential_edges, key=lambda x: x[1])  # Sort by ascending distance
        
        for key2, dist in potential_edges:
            if distance_graph.degree[key1] < degree and distance_graph.degree[key2] < degree:
                if dist < threshold:
                    if weighted:
                        max_distance = max(distance_dict.values())
                        min_distance = min(distance_dict.values())
                        normalised_distance = (dist - min_distance) / (max_distance - min_distance)
                        distance_graph.add_edge(key1, key2, weight=normalised_distance)
                    else:
                        distance_graph.add_edge(key1, key2)

    # Clean graph
    distance_graph = clean_graph(distance_graph)
    return distance_graph, distance_dict

def create_fully_connected_graph(df_dict):
    # Connect every node to every other node without weights 
    fully_connected_graph = nx.complete_graph(len(df_dict))

    # Add attributes to the nodes
    for i, (key, df) in enumerate(df_dict.items()):
        fully_connected_graph.nodes[i]['x'] = df['Xkoordinat'].iloc[0]
        fully_connected_graph.nodes[i]['y'] = df['Ykoordinat'].iloc[0]
        fully_connected_graph.nodes[i]['traffic_flow'] = df['traffic_flow'].values
        
    return fully_connected_graph

def create_fully_connected_graph_RANDOM_WEIGHTS(df_dict):
    # Connect every node to every other node without weights 
    fully_connected_graph = nx.complete_graph(len(df_dict))

    # Add attributes to the nodes
    for i, (key, df) in enumerate(df_dict.items()):
        fully_connected_graph.nodes[i]['x'] = df['Xkoordinat'].iloc[0]
        fully_connected_graph.nodes[i]['y'] = df['Ykoordinat'].iloc[0]
        fully_connected_graph.nodes[i]['traffic_flow'] = df['traffic_flow'].values

    # Add random weights to the edges
    for u, v in fully_connected_graph.edges:
        fully_connected_graph[u][v]['weight'] = np.random.rand()
        
    return fully_connected_graph, nx.get_edge_attributes(fully_connected_graph, 'weight')

distance_graph_weighted, distance_dict = create_distance_graph(final_dataframes, weighted=True, degree=4)
distance_graph_unweighted, _ = create_distance_graph(final_dataframes, weighted=False, degree=4)


#correlation_graph_weighted, correlation_dict = create_correlation_graph(final_dataframes, threshold=0.7, weighted=True, degree=20)
correlation_graph_weighted_edited, correlation_dict_edited = create_correlation_graph(df_dict_full=df_dict, df_dict_train=df_dict_train, threshold=0.7, weighted=True, degree=10)


#correlation_graph_unweighted, _ = create_correlation_graph(final_dataframes, threshold=0.7, weighted=False, degree=20)
correlation_graph_unweighted_edited, _ = create_correlation_graph(df_dict_full=df_dict, df_dict_train=df_dict_train, threshold=0.7, weighted=False, degree=10)

fully_connected_graph = create_fully_connected_graph(final_dataframes)
fully_connected_graph_RANDOM_WEIGHTS, fully_connected_weights = create_fully_connected_graph_RANDOM_WEIGHTS(final_dataframes)
# Out:
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 26 nodes.
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 26 nodes.
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 25 nodes.
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 25 nodes.

# %%
# Plot the Correlation graph without labels or edge attributes, use a spring layout, with a title that explain how they where plotted
plt.figure(figsize=(6, 6))
plt.title("Correlation Graph with Spring Layout")
pos = nx.spring_layout(correlation_graph_weighted)
nx.draw(correlation_graph_weighted, pos, with_labels=False, node_size=50, node_color='blue', edge_color='gray')
plt.show()


# Plot the Correlation graph without labels or edge attributes, use a spring layout, with a title that explain how they where plotted
plt.figure(figsize=(6, 6))
plt.title("Correlation Graph with Spring Layout (Edited)")
pos = nx.spring_layout(correlation_graph_weighted_edited)
nx.draw(correlation_graph_weighted_edited, pos, with_labels=False, node_size=50, node_color='blue', edge_color='gray')
plt.show()


# Extract positions from the graph's node attributes
pos = {node: (data['x'], data['y']) for node, data in distance_graph_weighted.nodes(data=True)}
x_values = [coord[0] for coord in pos.values()]
y_values = [coord[1] for coord in pos.values()]
plt.figure(figsize=(8, 8))
plt.title("Distance Graph with Geographic Layout", fontsize=14)


plt.grid(True, linestyle='--', alpha=0.5)
plt.scatter(x_values, y_values, c='blue', s=50, label='Nodes')
for edge in distance_graph_weighted.edges():
    x_coords = [pos[edge[0]][0], pos[edge[1]][0]]
    y_coords = [pos[edge[0]][1], pos[edge[1]][1]]
    plt.plot(x_coords, y_coords, color='gray', alpha=0.7)
plt.xlabel("X Coordinate", fontsize=12)
plt.ylabel("Y Coordinate", fontsize=12)
plt.legend()
plt.show()


# Plot the Correlation graph without labels or edge attributes, use a spring layout, with a title that explain how they where plotted
plt.figure(figsize=(6, 6))
plt.title("Fully Connected Graph with Spring Layout")
pos = nx.spring_layout(fully_connected_graph)
nx.draw(fully_connected_graph, pos, with_labels=False, node_size=50, node_color='blue', edge_color='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       2 plt.figure(figsize=(6, 6))
#       3 plt.title("Correlation Graph with Spring Layout")
# ----> 4 pos = nx.spring_layout(correlation_graph_weighted)
#       5 nx.draw(correlation_graph_weighted, pos, with_labels=False, node_size=50, node_color='blue', edge_color='gray')
#       6 plt.show()
#
# NameError: name 'correlation_graph_weighted' is not defined

# %% [markdown]
# Pytorch

# %%
import torch
import numpy as np
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
import torch.nn.functional as F
from torch.optim import Adam
from sklearn.model_selection import train_test_split

# %%
# Define GNN model
class Baseline(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.fc = torch.nn.Linear(hidden_channels, out_channels)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        x = self.fc(x)
        return x
    

# Define GNN model
class TrafficGCN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.conv4 = GCNConv(hidden_channels, hidden_channels)
        self.fc = torch.nn.Linear(hidden_channels, out_channels)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        x = self.conv4(x, edge_index)
        x = self.fc(x)
        return x

# %%
def create_sliding_window_data(df_dict, lookback, pred_horizon):
    X_dict = {}
    y_dict = {}
    for key, df in df_dict.items():
        node_series = df['traffic_flow'].values
        X_node = []
        y_node = []
        for i in range(len(node_series) - lookback - pred_horizon + 1):
            X_node.append(node_series[i:i + lookback])  # Input: Lookback window
            y_node.append(node_series[i + lookback:i + lookback + pred_horizon])  # Output: Next step(s)
        X_dict[key] = np.array(X_node)
        y_dict[key] = np.array(y_node)
    return X_dict, y_dict

# %%
# Sliding window parameters
lookback = 50  # Number of time steps to look back
pred_horizon = 5  # Predict the next time step

# Generate sliding window data for training and testing sets
X_train_dict, y_train_dict = create_sliding_window_data(df_dict_train, lookback, pred_horizon)
X_test_dict, y_test_dict = create_sliding_window_data(df_dict_test, lookback, pred_horizon)

# Combine data from all nodes
X_train_list = []
y_train_list = []
for key in X_train_dict:
    X_train_list.append(X_train_dict[key])
    y_train_list.append(y_train_dict[key])

X_train = np.concatenate(X_train_list, axis=0)
y_train = np.concatenate(y_train_list, axis=0)

X_test_list = []
y_test_list = []
for key in X_test_dict:
    X_test_list.append(X_test_dict[key])
    y_test_list.append(y_test_dict[key])

X_test = np.concatenate(X_test_list, axis=0)
y_test = np.concatenate(y_test_list, axis=0)

# Convert to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float)
y_train = torch.tensor(y_train, dtype=torch.float)

X_test = torch.tensor(X_test, dtype=torch.float)
y_test = torch.tensor(y_test, dtype=torch.float)

# Split training data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.1, random_state=42
)

# Prepare graph edges with integer mapping
node_mapping = {node: idx for idx, node in enumerate(correlation_graph_weighted_edited.nodes())}

edge_index = torch.tensor(
    [[node_mapping[edge[0]], node_mapping[edge[1]]] for edge in correlation_graph_weighted_edited.edges],
    dtype=torch.long
).t().contiguous()

# Create PyTorch Geometric Data objects
train_data = Data(x=X_train, edge_index=edge_index, y=y_train.view(-1, pred_horizon))
val_data = Data(x=X_val, edge_index=edge_index, y=y_val.view(-1, pred_horizon))
test_data = Data(x=X_test, edge_index=edge_index, y=y_test.view(-1, pred_horizon))

# %% [markdown]
# Test Everything

# %%
def split_dataframes(df_dict, train_ratio=0.7):
    """
    Splits each DataFrame in df_dict into training and testing parts based on time indices.

    Returns:
        df_dict_train: Dictionary of training DataFrames.
        df_dict_test: Dictionary of testing DataFrames.
    """
    df_dict_train = {}
    df_dict_test = {}
    for key, df in df_dict.items():
        n_time_steps = len(df['traffic_flow'])
        train_size = int(n_time_steps * train_ratio)
        df_train = df.iloc[:train_size].copy()
        df_test = df.iloc[train_size:].copy()
        df_dict_train[key] = df_train
        df_dict_test[key] = df_test
    return df_dict_train, df_dict_test

def combine_node_data(X_dict, y_dict):
    """
    Combines data from all nodes.

    Returns:
        X_combined: Combined input sequences from all nodes.
        y_combined: Combined target sequences from all nodes.
    """
    X_list = []
    y_list = []
    for key in X_dict:
        X_list.append(X_dict[key])
        y_list.append(y_dict[key])
    X_combined = np.concatenate(X_list, axis=0)
    y_combined = np.concatenate(y_list, axis=0)
    return X_combined, y_combined

def convert_to_tensors_and_split(X, y, val_ratio=0.1, random_state=42):
    """
    Converts data to PyTorch tensors and splits into train and validation sets.

    Returns:
        X_train: Training input tensor.
        X_val: Validation input tensor.
        y_train: Training target tensor.
        y_val: Validation target tensor.
    """
    # Convert to PyTorch tensors
    X_tensor = torch.tensor(X, dtype=torch.float)
    y_tensor = torch.tensor(y, dtype=torch.float)

    # Split into training and validation sets
    X_train, X_val, y_train, y_val = train_test_split(
        X_tensor, y_tensor, test_size=val_ratio, random_state=random_state
    )
    return X_train, X_val, y_train, y_val

def prepare_pyg_data(X_train, y_train, X_val, y_val, X_test, y_test, edge_index, pred_horizon):
    """
    Prepares PyTorch Geometric Data objects for training, validation, and testing.

    Returns:
        train_data: Data object for training.
        val_data: Data object for validation.
        test_data: Data object for testing.
    """
    train_data = Data(x=X_train, edge_index=edge_index, y=y_train.view(-1, pred_horizon))
    val_data = Data(x=X_val, edge_index=edge_index, y=y_val.view(-1, pred_horizon))
    test_data = Data(x=X_test, edge_index=edge_index, y=y_test.view(-1, pred_horizon))
    return train_data, val_data, test_data


train_ratio = 0.7  # 70% training data
df_dict_train, df_dict_test = split_dataframes(final_dataframes, train_ratio)
amount_degrees = 10
# Models to evaluate
graph_models = {
    #"Distance_Weighted": lambda: create_distance_graph(final_dataframes, weighted=True, degree=amount_degrees),
    #"Distance_Unweighted": lambda: create_distance_graph(final_dataframes, weighted=False, degree=amount_degrees),
    "Correlation_Weighted": lambda: create_correlation_graph(final_dataframes, df_dict_train, threshold=0.6, weighted=True, degree=amount_degrees),
    #"Correlation_Unweighted": lambda: create_correlation_graph(final_dataframes, threshold=0.6, weighted=False, degree=amount_degrees),
    
    #"Fully_Connected": lambda: (create_fully_connected_graph(final_dataframes), None),
    #"Fully_Connected_random_weights": lambda: (create_fully_connected_graph_RANDOM_WEIGHTS(final_dataframes))
}

# Initialize results dictionary
results = {}

# Model parameters
hc = 32
lookback = 50
pred_horizon = 5

# Train and evaluate each model
for model_name, graph_fn in graph_models.items():
    print(f"Running model: {model_name}")
    
    # Create graph and prepare data
    graph, _ = graph_fn()

    node_mapping = {node: idx for idx, node in enumerate(graph.nodes())}
    
    edge_index = torch.tensor(
        [[node_mapping[edge[0]], node_mapping[edge[1]]] for edge in graph.edges],
        dtype=torch.long
    ).t().contiguous()
    
    # Create sliding window data per node for training and testing
    X_train_dict, y_train_dict = create_sliding_window_data_per_node(df_dict_train, lookback, pred_horizon)
    X_test_dict, y_test_dict = create_sliding_window_data_per_node(df_dict_test, lookback, pred_horizon)
    
    # Combine data from all nodes
    X_train, y_train = combine_node_data(X_train_dict, y_train_dict)
    X_test, y_test = combine_node_data(X_test_dict, y_test_dict)
    
    # Convert to tensors and split training data into train and validation sets
    X_train, X_val, y_train, y_val = convert_to_tensors_and_split(X_train, y_train, val_ratio=0.1, random_state=42)
    
    # Convert test data to tensors
    X_test = torch.tensor(X_test, dtype=torch.float)
    y_test = torch.tensor(y_test, dtype=torch.float)
    
    print(f"{model_name} - Training samples: {X_train.shape[0]}")
    print(f"{model_name} - Validation samples: {X_val.shape[0]}")
    print(f"{model_name} - Test samples: {X_test.shape[0]}")
    
    # Prepare PyTorch Geometric Data objects
    train_data, val_data, test_data = prepare_pyg_data(X_train, y_train, X_val, y_val, X_test, y_test, edge_index, pred_horizon)
    
    # Initialize model
    model = TrafficGCN(in_channels=lookback, hidden_channels=hc, out_channels=pred_horizon)
    optimizer = Adam(model.parameters(), lr=0.0001)
    criterion = torch.nn.MSELoss()
    
    # Train model
    train_losses = []
    val_losses = []
    for epoch in range(1000):
        optimizer.zero_grad()
        
        # Training
        model.train()
        out = model(train_data)
        train_loss = criterion(out, train_data.y)
        train_loss.backward()
        optimizer.step()
        
        # Validation
        model.eval()
        with torch.no_grad():
            val_out = model(val_data)
            val_loss = criterion(val_out, val_data.y)
        
        # Track losses
        train_losses.append(train_loss.item())
        val_losses.append(val_loss.item())
        
        if epoch % 1 == 0:
            print(f"{model_name} - Epoch {epoch}: Train Loss: {train_loss.item()}, Val Loss: {val_loss.item()}")
    
    # Evaluate on test data
    model.eval()
    with torch.no_grad():
        test_out = model(test_data)
        test_loss = criterion(test_out, test_data.y)
        actual_values = test_data.y.cpu().numpy()
        predicted_values = test_out.cpu().numpy()
    
    print(f"{model_name} - Test Loss: {test_loss.item()}")
    
    # Save results
    results[model_name] = {
        "train_losses": train_losses,
        "val_losses": val_losses,
        "test_loss": test_loss.item(),
        "actual_values": actual_values,
        "predicted_values": predicted_values
    }
# Out:
# Running model: Correlation_Weighted
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 25 nodes.
# Correlation_Weighted - Training samples: 563004
# Correlation_Weighted - Validation samples: 62556
# Correlation_Weighted - Test samples: 267306
# Correlation_Weighted - Epoch 0: Train Loss: 3709.138916015625, Val Loss: 3623.253173828125
# Correlation_Weighted - Epoch 1: Train Loss: 3691.308349609375, Val Loss: 3605.6201171875
# Correlation_Weighted - Epoch 2: Train Loss: 3673.53955078125, Val Loss: 3588.046875
# Correlation_Weighted - Epoch 3: Train Loss: 3655.8330078125, Val Loss: 3570.5322265625
# Correlation_Weighted - Epoch 4: Train Loss: 3638.186767578125, Val Loss: 3553.075927734375
# Correlation_Weighted - Epoch 5: Train Loss: 3620.599365234375, Val Loss: 3535.676513671875
# Correlation_Weighted - Epoch 6: Train Loss: 3603.068359375, Val Loss: 3518.340087890625
# Correlation_Weighted - Epoch 7: Train Loss: 3585.5947265625, Val Loss: 3501.060302734375
# Correlation_Weighted - Epoch 8: Train Loss: 3568.173828125, Val Loss: 3483.83203125
# Correlation_Weighted - Epoch 9: Train Loss: 3550.803466796875, Val Loss: 3466.649169921875
# Correlation_Weighted - Epoch 10: Train Loss: 3533.478759765625, Val Loss: 3449.50830078125
# Correlation_Weighted - Epoch 11: Train Loss: 3516.1953125, Val Loss: 3432.408203125
# Correlation_Weighted - Epoch 12: Train Loss: 3498.947509765625, Val Loss: 3415.341796875
# Correlation_Weighted - Epoch 13: Train Loss: 3481.732666015625, Val Loss: 3398.298828125
# Correlation_Weighted - Epoch 14: Train Loss: 3464.544921875, Val Loss: 3381.268310546875
# Correlation_Weighted - Epoch 15: Train Loss: 3447.380126953125, Val Loss: 3364.2548828125
# Correlation_Weighted - Epoch 16: Train Loss: 3430.2333984375, Val Loss: 3347.252685546875
# Correlation_Weighted - Epoch 17: Train Loss: 3413.09619140625, Val Loss: 3330.248291015625
# Correlation_Weighted - Epoch 18: Train Loss: 3395.962890625, Val Loss: 3313.24169921875
# Correlation_Weighted - Epoch 19: Train Loss: 3378.8271484375, Val Loss: 3296.223876953125
# Correlation_Weighted - Epoch 20: Train Loss: 3361.680908203125, Val Loss: 3279.1943359375
# Correlation_Weighted - Epoch 21: Train Loss: 3344.520751953125, Val Loss: 3262.143310546875
# Correlation_Weighted - Epoch 22: Train Loss: 3327.343017578125, Val Loss: 3245.06103515625
# Correlation_Weighted - Epoch 23: Train Loss: 3310.13818359375, Val Loss: 3227.940185546875
# Correlation_Weighted - Epoch 24: Train Loss: 3292.901611328125, Val Loss: 3210.779296875
# Correlation_Weighted - Epoch 25: Train Loss: 3275.628662109375, Val Loss: 3193.572998046875
# Correlation_Weighted - Epoch 26: Train Loss: 3258.31494140625, Val Loss: 3176.318603515625
# Correlation_Weighted - Epoch 27: Train Loss: 3240.955810546875, Val Loss: 3159.01171875
# Correlation_Weighted - Epoch 28: Train Loss: 3223.5458984375, Val Loss: 3141.6513671875
# Correlation_Weighted - Epoch 29: Train Loss: 3206.0830078125, Val Loss: 3124.240234375
# Correlation_Weighted - Epoch 30: Train Loss: 3188.564208984375, Val Loss: 3106.777587890625
# Correlation_Weighted - Epoch 31: Train Loss: 3170.9892578125, Val Loss: 3089.26220703125
# Correlation_Weighted - Epoch 32: Train Loss: 3153.356201171875, Val Loss: 3071.697509765625
# Correlation_Weighted - Epoch 33: Train Loss: 3135.657470703125, Val Loss: 3054.075927734375
# Correlation_Weighted - Epoch 34: Train Loss: 3117.896728515625, Val Loss: 3036.394775390625
# Correlation_Weighted - Epoch 35: Train Loss: 3100.077392578125, Val Loss: 3018.653564453125
# Correlation_Weighted - Epoch 36: Train Loss: 3082.20166015625, Val Loss: 3000.859375
# Correlation_Weighted - Epoch 37: Train Loss: 3064.269287109375, Val Loss: 2983.006591796875
# Correlation_Weighted - Epoch 38: Train Loss: 3046.279296875, Val Loss: 2965.097900390625
# Correlation_Weighted - Epoch 39: Train Loss: 3028.23095703125, Val Loss: 2947.13232421875
# Correlation_Weighted - Epoch 40: Train Loss: 3010.12548828125, Val Loss: 2929.12255859375
# Correlation_Weighted - Epoch 41: Train Loss: 2991.967041015625, Val Loss: 2911.076416015625
# Correlation_Weighted - Epoch 42: Train Loss: 2973.7568359375, Val Loss: 2892.99560546875
# Correlation_Weighted - Epoch 43: Train Loss: 2955.497314453125, Val Loss: 2874.87158203125
# Correlation_Weighted - Epoch 44: Train Loss: 2937.19775390625, Val Loss: 2856.71875
# Correlation_Weighted - Epoch 45: Train Loss: 2918.86572265625, Val Loss: 2838.540283203125
# Correlation_Weighted - Epoch 46: Train Loss: 2900.505126953125, Val Loss: 2820.337646484375
# Correlation_Weighted - Epoch 47: Train Loss: 2882.117431640625, Val Loss: 2802.118896484375
# Correlation_Weighted - Epoch 48: Train Loss: 2863.7099609375, Val Loss: 2783.88720703125
# Correlation_Weighted - Epoch 49: Train Loss: 2845.28955078125, Val Loss: 2765.642578125
# Correlation_Weighted - Epoch 50: Train Loss: 2826.862060546875, Val Loss: 2747.394287109375
# Correlation_Weighted - Epoch 51: Train Loss: 2808.431396484375, Val Loss: 2729.136474609375
# Correlation_Weighted - Epoch 52: Train Loss: 2790.001220703125, Val Loss: 2710.88525390625
# Correlation_Weighted - Epoch 53: Train Loss: 2771.5751953125, Val Loss: 2692.640380859375
# Correlation_Weighted - Epoch 54: Train Loss: 2753.158203125, Val Loss: 2674.40625
# Correlation_Weighted - Epoch 55: Train Loss: 2734.7548828125, Val Loss: 2656.192626953125
# Correlation_Weighted - Epoch 56: Train Loss: 2716.3671875, Val Loss: 2637.99365234375
# Correlation_Weighted - Epoch 57: Train Loss: 2697.996337890625, Val Loss: 2619.815185546875
# Correlation_Weighted - Epoch 58: Train Loss: 2679.64208984375, Val Loss: 2601.658203125
# Correlation_Weighted - Epoch 59: Train Loss: 2661.30908203125, Val Loss: 2583.522216796875
# Correlation_Weighted - Epoch 60: Train Loss: 2642.99951171875, Val Loss: 2565.40869140625
# Correlation_Weighted - Epoch 61: Train Loss: 2624.7080078125, Val Loss: 2547.313720703125
# Correlation_Weighted - Epoch 62: Train Loss: 2606.440185546875, Val Loss: 2529.234130859375
# Correlation_Weighted - Epoch 63: Train Loss: 2588.197509765625, Val Loss: 2511.180419921875
# Correlation_Weighted - Epoch 64: Train Loss: 2569.98046875, Val Loss: 2493.162353515625
# Correlation_Weighted - Epoch 65: Train Loss: 2551.7890625, Val Loss: 2475.173828125
# Correlation_Weighted - Epoch 66: Train Loss: 2533.628173828125, Val Loss: 2457.225341796875
# Correlation_Weighted - Epoch 67: Train Loss: 2515.494873046875, Val Loss: 2439.31689453125
# Correlation_Weighted - Epoch 68: Train Loss: 2497.39013671875, Val Loss: 2421.446044921875
# Correlation_Weighted - Epoch 69: Train Loss: 2479.318603515625, Val Loss: 2403.615966796875
# Correlation_Weighted - Epoch 70: Train Loss: 2461.282958984375, Val Loss: 2385.8193359375
# Correlation_Weighted - Epoch 71: Train Loss: 2443.286376953125, Val Loss: 2368.067138671875
# Correlation_Weighted - Epoch 72: Train Loss: 2425.329345703125, Val Loss: 2350.362548828125
# Correlation_Weighted - Epoch 73: Train Loss: 2407.41943359375, Val Loss: 2332.705322265625
# Correlation_Weighted - Epoch 74: Train Loss: 2389.557861328125, Val Loss: 2315.10546875
# Correlation_Weighted - Epoch 75: Train Loss: 2371.75048828125, Val Loss: 2297.57666015625
# Correlation_Weighted - Epoch 76: Train Loss: 2354.005859375, Val Loss: 2280.115478515625
# Correlation_Weighted - Epoch 77: Train Loss: 2336.327392578125, Val Loss: 2262.7265625
# Correlation_Weighted - Epoch 78: Train Loss: 2318.7177734375, Val Loss: 2245.406494140625
# Correlation_Weighted - Epoch 79: Train Loss: 2301.1826171875, Val Loss: 2228.167236328125
# Correlation_Weighted - Epoch 80: Train Loss: 2283.728515625, Val Loss: 2211.019775390625
# Correlation_Weighted - Epoch 81: Train Loss: 2266.361328125, Val Loss: 2193.96435546875
# Correlation_Weighted - Epoch 82: Train Loss: 2249.087158203125, Val Loss: 2176.99853515625
# Correlation_Weighted - Epoch 83: Train Loss: 2231.90869140625, Val Loss: 2160.135986328125
# Correlation_Weighted - Epoch 84: Train Loss: 2214.833251953125, Val Loss: 2143.379638671875
# Correlation_Weighted - Epoch 85: Train Loss: 2197.86572265625, Val Loss: 2126.7353515625
# Correlation_Weighted - Epoch 86: Train Loss: 2181.009033203125, Val Loss: 2110.20458984375
# Correlation_Weighted - Epoch 87: Train Loss: 2164.267822265625, Val Loss: 2093.794677734375
# Correlation_Weighted - Epoch 88: Train Loss: 2147.6474609375, Val Loss: 2077.51171875
# Correlation_Weighted - Epoch 89: Train Loss: 2131.150634765625, Val Loss: 2061.358642578125
# Correlation_Weighted - Epoch 90: Train Loss: 2114.783203125, Val Loss: 2045.332763671875
# Correlation_Weighted - Epoch 91: Train Loss: 2098.547119140625, Val Loss: 2029.436767578125
# Correlation_Weighted - Epoch 92: Train Loss: 2082.44482421875, Val Loss: 2013.6785888671875
# Correlation_Weighted - Epoch 93: Train Loss: 2066.479248046875, Val Loss: 1998.064697265625
# Correlation_Weighted - Epoch 94: Train Loss: 2050.65234375, Val Loss: 1982.59326171875
# Correlation_Weighted - Epoch 95: Train Loss: 2034.9683837890625, Val Loss: 1967.2691650390625
# Correlation_Weighted - Epoch 96: Train Loss: 2019.4300537109375, Val Loss: 1952.0943603515625
# Correlation_Weighted - Epoch 97: Train Loss: 2004.041259765625, Val Loss: 1937.0687255859375
# Correlation_Weighted - Epoch 98: Train Loss: 1988.8009033203125, Val Loss: 1922.19677734375
# Correlation_Weighted - Epoch 99: Train Loss: 1973.7099609375, Val Loss: 1907.4794921875
# Correlation_Weighted - Epoch 100: Train Loss: 1958.77099609375, Val Loss: 1892.91650390625
# Correlation_Weighted - Epoch 101: Train Loss: 1943.9866943359375, Val Loss: 1878.5101318359375
# Correlation_Weighted - Epoch 102: Train Loss: 1929.358154296875, Val Loss: 1864.261962890625
# Correlation_Weighted - Epoch 103: Train Loss: 1914.8878173828125, Val Loss: 1850.173095703125
# Correlation_Weighted - Epoch 104: Train Loss: 1900.5777587890625, Val Loss: 1836.242431640625
# Correlation_Weighted - Epoch 105: Train Loss: 1886.42919921875, Val Loss: 1822.4737548828125
# Correlation_Weighted - Epoch 106: Train Loss: 1872.4454345703125, Val Loss: 1808.8677978515625
# Correlation_Weighted - Epoch 107: Train Loss: 1858.625244140625, Val Loss: 1795.425048828125
# Correlation_Weighted - Epoch 108: Train Loss: 1844.969482421875, Val Loss: 1782.1455078125
# Correlation_Weighted - Epoch 109: Train Loss: 1831.478271484375, Val Loss: 1769.0352783203125
# Correlation_Weighted - Epoch 110: Train Loss: 1818.15380859375, Val Loss: 1756.094482421875
# Correlation_Weighted - Epoch 111: Train Loss: 1804.996337890625, Val Loss: 1743.3228759765625
# Correlation_Weighted - Epoch 112: Train Loss: 1792.0076904296875, Val Loss: 1730.72119140625
# Correlation_Weighted - Epoch 113: Train Loss: 1779.1873779296875, Val Loss: 1718.2845458984375
# Correlation_Weighted - Epoch 114: Train Loss: 1766.5360107421875, Val Loss: 1706.018798828125
# Correlation_Weighted - Epoch 115: Train Loss: 1754.0537109375, Val Loss: 1693.919921875
# Correlation_Weighted - Epoch 116: Train Loss: 1741.7401123046875, Val Loss: 1681.98828125
# Correlation_Weighted - Epoch 117: Train Loss: 1729.5938720703125, Val Loss: 1670.2269287109375
# Correlation_Weighted - Epoch 118: Train Loss: 1717.6148681640625, Val Loss: 1658.633544921875
# Correlation_Weighted - Epoch 119: Train Loss: 1705.801513671875, Val Loss: 1647.2047119140625
# Correlation_Weighted - Epoch 120: Train Loss: 1694.152099609375, Val Loss: 1635.935546875
# Correlation_Weighted - Epoch 121: Train Loss: 1682.6658935546875, Val Loss: 1624.8251953125
# Correlation_Weighted - Epoch 122: Train Loss: 1671.3406982421875, Val Loss: 1613.87451171875
# Correlation_Weighted - Epoch 123: Train Loss: 1660.17578125, Val Loss: 1603.0806884765625
# Correlation_Weighted - Epoch 124: Train Loss: 1649.1683349609375, Val Loss: 1592.441162109375
# Correlation_Weighted - Epoch 125: Train Loss: 1638.316650390625, Val Loss: 1581.9530029296875
# Correlation_Weighted - Epoch 126: Train Loss: 1627.6175537109375, Val Loss: 1571.6126708984375
# Correlation_Weighted - Epoch 127: Train Loss: 1617.0672607421875, Val Loss: 1561.4154052734375
# Correlation_Weighted - Epoch 128: Train Loss: 1606.6636962890625, Val Loss: 1551.3560791015625
# Correlation_Weighted - Epoch 129: Train Loss: 1596.4034423828125, Val Loss: 1541.434814453125
# Correlation_Weighted - Epoch 130: Train Loss: 1586.2840576171875, Val Loss: 1531.64794921875
# Correlation_Weighted - Epoch 131: Train Loss: 1576.3018798828125, Val Loss: 1521.992919921875
# Correlation_Weighted - Epoch 132: Train Loss: 1566.4559326171875, Val Loss: 1512.47021484375
# Correlation_Weighted - Epoch 133: Train Loss: 1556.7410888671875, Val Loss: 1503.075439453125
# Correlation_Weighted - Epoch 134: Train Loss: 1547.1539306640625, Val Loss: 1493.80419921875
# Correlation_Weighted - Epoch 135: Train Loss: 1537.6927490234375, Val Loss: 1484.6558837890625
# Correlation_Weighted - Epoch 136: Train Loss: 1528.352783203125, Val Loss: 1475.623779296875
# Correlation_Weighted - Epoch 137: Train Loss: 1519.1295166015625, Val Loss: 1466.7003173828125
# Correlation_Weighted - Epoch 138: Train Loss: 1510.020263671875, Val Loss: 1457.883056640625
# Correlation_Weighted - Epoch 139: Train Loss: 1501.0213623046875, Val Loss: 1449.1685791015625
# Correlation_Weighted - Epoch 140: Train Loss: 1492.1295166015625, Val Loss: 1440.5528564453125
# Correlation_Weighted - Epoch 141: Train Loss: 1483.3414306640625, Val Loss: 1432.03564453125
# Correlation_Weighted - Epoch 142: Train Loss: 1474.6551513671875, Val Loss: 1423.613525390625
# Correlation_Weighted - Epoch 143: Train Loss: 1466.067138671875, Val Loss: 1415.28369140625
# Correlation_Weighted - Epoch 144: Train Loss: 1457.572509765625, Val Loss: 1407.04150390625
# Correlation_Weighted - Epoch 145: Train Loss: 1449.1688232421875, Val Loss: 1398.8839111328125
# Correlation_Weighted - Epoch 146: Train Loss: 1440.853759765625, Val Loss: 1390.8106689453125
# Correlation_Weighted - Epoch 147: Train Loss: 1432.6248779296875, Val Loss: 1382.8184814453125
# Correlation_Weighted - Epoch 148: Train Loss: 1424.478515625, Val Loss: 1374.906982421875
# Correlation_Weighted - Epoch 149: Train Loss: 1416.4129638671875, Val Loss: 1367.0701904296875
# Correlation_Weighted - Epoch 150: Train Loss: 1408.4246826171875, Val Loss: 1359.3048095703125
# Correlation_Weighted - Epoch 151: Train Loss: 1400.5115966796875, Val Loss: 1351.6087646484375
# Correlation_Weighted - Epoch 152: Train Loss: 1392.670166015625, Val Loss: 1343.9786376953125
# Correlation_Weighted - Epoch 153: Train Loss: 1384.8980712890625, Val Loss: 1336.4117431640625
# Correlation_Weighted - Epoch 154: Train Loss: 1377.19287109375, Val Loss: 1328.9049072265625
# Correlation_Weighted - Epoch 155: Train Loss: 1369.5528564453125, Val Loss: 1321.4632568359375
# Correlation_Weighted - Epoch 156: Train Loss: 1361.9757080078125, Val Loss: 1314.0821533203125
# Correlation_Weighted - Epoch 157: Train Loss: 1354.4600830078125, Val Loss: 1306.759765625
# Correlation_Weighted - Epoch 158: Train Loss: 1347.004638671875, Val Loss: 1299.493896484375
# Correlation_Weighted - Epoch 159: Train Loss: 1339.60595703125, Val Loss: 1292.282958984375
# Correlation_Weighted - Epoch 160: Train Loss: 1332.262939453125, Val Loss: 1285.1246337890625
# Correlation_Weighted - Epoch 161: Train Loss: 1324.9742431640625, Val Loss: 1278.0186767578125
# Correlation_Weighted - Epoch 162: Train Loss: 1317.7386474609375, Val Loss: 1270.9632568359375
# Correlation_Weighted - Epoch 163: Train Loss: 1310.555419921875, Val Loss: 1263.9561767578125
# Correlation_Weighted - Epoch 164: Train Loss: 1303.422607421875, Val Loss: 1256.99560546875
# Correlation_Weighted - Epoch 165: Train Loss: 1296.339111328125, Val Loss: 1250.0831298828125
# Correlation_Weighted - Epoch 166: Train Loss: 1289.302978515625, Val Loss: 1243.21533203125
# Correlation_Weighted - Epoch 167: Train Loss: 1282.3121337890625, Val Loss: 1236.3927001953125
# Correlation_Weighted - Epoch 168: Train Loss: 1275.36474609375, Val Loss: 1229.611083984375
# Correlation_Weighted - Epoch 169: Train Loss: 1268.4613037109375, Val Loss: 1222.873291015625
# Correlation_Weighted - Epoch 170: Train Loss: 1261.5989990234375, Val Loss: 1216.1767578125
# Correlation_Weighted - Epoch 171: Train Loss: 1254.7769775390625, Val Loss: 1209.5196533203125
# Correlation_Weighted - Epoch 172: Train Loss: 1247.9951171875, Val Loss: 1202.9017333984375
# Correlation_Weighted - Epoch 173: Train Loss: 1241.252197265625, Val Loss: 1196.3267822265625
# Correlation_Weighted - Epoch 174: Train Loss: 1234.5472412109375, Val Loss: 1189.789306640625
# Correlation_Weighted - Epoch 175: Train Loss: 1227.879638671875, Val Loss: 1183.2900390625
# Correlation_Weighted - Epoch 176: Train Loss: 1221.2489013671875, Val Loss: 1176.82666015625
# Correlation_Weighted - Epoch 177: Train Loss: 1214.652587890625, Val Loss: 1170.39794921875
# Correlation_Weighted - Epoch 178: Train Loss: 1208.09033203125, Val Loss: 1164.0042724609375
# Correlation_Weighted - Epoch 179: Train Loss: 1201.5623779296875, Val Loss: 1157.644287109375
# Correlation_Weighted - Epoch 180: Train Loss: 1195.0667724609375, Val Loss: 1151.319091796875
# Correlation_Weighted - Epoch 181: Train Loss: 1188.604248046875, Val Loss: 1145.0277099609375
# Correlation_Weighted - Epoch 182: Train Loss: 1182.17236328125, Val Loss: 1138.7686767578125
# Correlation_Weighted - Epoch 183: Train Loss: 1175.771240234375, Val Loss: 1132.5384521484375
# Correlation_Weighted - Epoch 184: Train Loss: 1169.4000244140625, Val Loss: 1126.335205078125
# Correlation_Weighted - Epoch 185: Train Loss: 1163.058837890625, Val Loss: 1120.1544189453125
# Correlation_Weighted - Epoch 186: Train Loss: 1156.7457275390625, Val Loss: 1114.0013427734375
# Correlation_Weighted - Epoch 187: Train Loss: 1150.4615478515625, Val Loss: 1107.876953125
# Correlation_Weighted - Epoch 188: Train Loss: 1144.204833984375, Val Loss: 1101.781005859375
# Correlation_Weighted - Epoch 189: Train Loss: 1137.97509765625, Val Loss: 1095.71240234375
# Correlation_Weighted - Epoch 190: Train Loss: 1131.7728271484375, Val Loss: 1089.672119140625
# Correlation_Weighted - Epoch 191: Train Loss: 1125.5975341796875, Val Loss: 1083.659912109375
# Correlation_Weighted - Epoch 192: Train Loss: 1119.44970703125, Val Loss: 1077.6768798828125
# Correlation_Weighted - Epoch 193: Train Loss: 1113.3291015625, Val Loss: 1071.7208251953125
# Correlation_Weighted - Epoch 194: Train Loss: 1107.234619140625, Val Loss: 1065.7896728515625
# Correlation_Weighted - Epoch 195: Train Loss: 1101.1668701171875, Val Loss: 1059.88916015625
# Correlation_Weighted - Epoch 196: Train Loss: 1095.1270751953125, Val Loss: 1054.018310546875
# Correlation_Weighted - Epoch 197: Train Loss: 1089.113525390625, Val Loss: 1048.173828125
# Correlation_Weighted - Epoch 198: Train Loss: 1083.127685546875, Val Loss: 1042.3599853515625
# Correlation_Weighted - Epoch 199: Train Loss: 1077.1693115234375, Val Loss: 1036.5726318359375
# Correlation_Weighted - Epoch 200: Train Loss: 1071.23779296875, Val Loss: 1030.8134765625
# Correlation_Weighted - Epoch 201: Train Loss: 1065.333251953125, Val Loss: 1025.0826416015625
# Correlation_Weighted - Epoch 202: Train Loss: 1059.45556640625, Val Loss: 1019.3823852539062
# Correlation_Weighted - Epoch 203: Train Loss: 1053.605712890625, Val Loss: 1013.7107543945312
# Correlation_Weighted - Epoch 204: Train Loss: 1047.7822265625, Val Loss: 1008.0697631835938
# Correlation_Weighted - Epoch 205: Train Loss: 1041.986083984375, Val Loss: 1002.4568481445312
# Correlation_Weighted - Epoch 206: Train Loss: 1036.217041015625, Val Loss: 996.8700561523438
# Correlation_Weighted - Epoch 207: Train Loss: 1030.475341796875, Val Loss: 991.307861328125
# Correlation_Weighted - Epoch 208: Train Loss: 1024.76123046875, Val Loss: 985.7711791992188
# Correlation_Weighted - Epoch 209: Train Loss: 1019.0747680664062, Val Loss: 980.2581787109375
# Correlation_Weighted - Epoch 210: Train Loss: 1013.4157104492188, Val Loss: 974.7722778320312
# Correlation_Weighted - Epoch 211: Train Loss: 1007.7835083007812, Val Loss: 969.3161010742188
# Correlation_Weighted - Epoch 212: Train Loss: 1002.1780395507812, Val Loss: 963.888916015625
# Correlation_Weighted - Epoch 213: Train Loss: 996.5980834960938, Val Loss: 958.487060546875
# Correlation_Weighted - Epoch 214: Train Loss: 991.0440063476562, Val Loss: 953.1121215820312
# Correlation_Weighted - Epoch 215: Train Loss: 985.51513671875, Val Loss: 947.7606201171875
# Correlation_Weighted - Epoch 216: Train Loss: 980.010986328125, Val Loss: 942.4337768554688
# Correlation_Weighted - Epoch 217: Train Loss: 974.5302124023438, Val Loss: 937.1270141601562
# Correlation_Weighted - Epoch 218: Train Loss: 969.0721435546875, Val Loss: 931.8419799804688
# Correlation_Weighted - Epoch 219: Train Loss: 963.6361083984375, Val Loss: 926.576904296875
# Correlation_Weighted - Epoch 220: Train Loss: 958.2203979492188, Val Loss: 921.327880859375
# Correlation_Weighted - Epoch 221: Train Loss: 952.8237915039062, Val Loss: 916.0968627929688
# Correlation_Weighted - Epoch 222: Train Loss: 947.4453735351562, Val Loss: 910.8828125
# Correlation_Weighted - Epoch 223: Train Loss: 942.0831909179688, Val Loss: 905.6862182617188
# Correlation_Weighted - Epoch 224: Train Loss: 936.7368774414062, Val Loss: 900.5055541992188
# Correlation_Weighted - Epoch 225: Train Loss: 931.4052124023438, Val Loss: 895.3402099609375
# Correlation_Weighted - Epoch 226: Train Loss: 926.0875854492188, Val Loss: 890.1904296875
# Correlation_Weighted - Epoch 227: Train Loss: 920.7821044921875, Val Loss: 885.0509643554688
# Correlation_Weighted - Epoch 228: Train Loss: 915.4881591796875, Val Loss: 879.9220581054688
# Correlation_Weighted - Epoch 229: Train Loss: 910.2042846679688, Val Loss: 874.8048706054688
# Correlation_Weighted - Epoch 230: Train Loss: 904.9299926757812, Val Loss: 869.6995239257812
# Correlation_Weighted - Epoch 231: Train Loss: 899.6637573242188, Val Loss: 864.60791015625
# Correlation_Weighted - Epoch 232: Train Loss: 894.4056396484375, Val Loss: 859.5218505859375
# Correlation_Weighted - Epoch 233: Train Loss: 889.1557006835938, Val Loss: 854.4432983398438
# Correlation_Weighted - Epoch 234: Train Loss: 883.9122314453125, Val Loss: 849.3721313476562
# Correlation_Weighted - Epoch 235: Train Loss: 878.674072265625, Val Loss: 844.3031616210938
# Correlation_Weighted - Epoch 236: Train Loss: 873.4422607421875, Val Loss: 839.2406616210938
# Correlation_Weighted - Epoch 237: Train Loss: 868.2166137695312, Val Loss: 834.18896484375
# Correlation_Weighted - Epoch 238: Train Loss: 862.9968872070312, Val Loss: 829.1465454101562
# Correlation_Weighted - Epoch 239: Train Loss: 857.7832641601562, Val Loss: 824.1074829101562
# Correlation_Weighted - Epoch 240: Train Loss: 852.5758056640625, Val Loss: 819.0729370117188
# Correlation_Weighted - Epoch 241: Train Loss: 847.3750610351562, Val Loss: 814.0432739257812
# Correlation_Weighted - Epoch 242: Train Loss: 842.1812744140625, Val Loss: 809.0206298828125
# Correlation_Weighted - Epoch 243: Train Loss: 836.9948120117188, Val Loss: 804.010986328125
# Correlation_Weighted - Epoch 244: Train Loss: 831.81640625, Val Loss: 799.0191650390625
# Correlation_Weighted - Epoch 245: Train Loss: 826.6480712890625, Val Loss: 794.0421142578125
# Correlation_Weighted - Epoch 246: Train Loss: 821.4910888671875, Val Loss: 789.0792236328125
# Correlation_Weighted - Epoch 247: Train Loss: 816.3468017578125, Val Loss: 784.1256103515625
# Correlation_Weighted - Epoch 248: Train Loss: 811.2166748046875, Val Loss: 779.1842041015625
# Correlation_Weighted - Epoch 249: Train Loss: 806.1022338867188, Val Loss: 774.2647705078125
# Correlation_Weighted - Epoch 250: Train Loss: 801.0040283203125, Val Loss: 769.3680419921875
# Correlation_Weighted - Epoch 251: Train Loss: 795.9236450195312, Val Loss: 764.4931030273438
# Correlation_Weighted - Epoch 252: Train Loss: 790.8624267578125, Val Loss: 759.6380615234375
# Correlation_Weighted - Epoch 253: Train Loss: 785.8203125, Val Loss: 754.80419921875
# Correlation_Weighted - Epoch 254: Train Loss: 780.7993774414062, Val Loss: 749.9945678710938
# Correlation_Weighted - Epoch 255: Train Loss: 775.7994384765625, Val Loss: 745.20849609375
# Correlation_Weighted - Epoch 256: Train Loss: 770.8226318359375, Val Loss: 740.4485473632812
# Correlation_Weighted - Epoch 257: Train Loss: 765.8689575195312, Val Loss: 735.7144165039062
# Correlation_Weighted - Epoch 258: Train Loss: 760.941162109375, Val Loss: 731.0040283203125
# Correlation_Weighted - Epoch 259: Train Loss: 756.0386352539062, Val Loss: 726.3224487304688
# Correlation_Weighted - Epoch 260: Train Loss: 751.1605224609375, Val Loss: 721.6685180664062
# Correlation_Weighted - Epoch 261: Train Loss: 746.3067016601562, Val Loss: 717.036865234375
# Correlation_Weighted - Epoch 262: Train Loss: 741.4783935546875, Val Loss: 712.4291381835938
# Correlation_Weighted - Epoch 263: Train Loss: 736.6754150390625, Val Loss: 707.845947265625
# Correlation_Weighted - Epoch 264: Train Loss: 731.8983154296875, Val Loss: 703.2907104492188
# Correlation_Weighted - Epoch 265: Train Loss: 727.1477661132812, Val Loss: 698.7635498046875
# Correlation_Weighted - Epoch 266: Train Loss: 722.4238891601562, Val Loss: 694.2615356445312
# Correlation_Weighted - Epoch 267: Train Loss: 717.7269287109375, Val Loss: 689.7853393554688
# Correlation_Weighted - Epoch 268: Train Loss: 713.057861328125, Val Loss: 685.3336181640625
# Correlation_Weighted - Epoch 269: Train Loss: 708.4156494140625, Val Loss: 680.9082641601562
# Correlation_Weighted - Epoch 270: Train Loss: 703.8005981445312, Val Loss: 676.508056640625
# Correlation_Weighted - Epoch 271: Train Loss: 699.2122192382812, Val Loss: 672.136962890625
# Correlation_Weighted - Epoch 272: Train Loss: 694.6514892578125, Val Loss: 667.7925415039062
# Correlation_Weighted - Epoch 273: Train Loss: 690.1192016601562, Val Loss: 663.4749755859375
# Correlation_Weighted - Epoch 274: Train Loss: 685.6155395507812, Val Loss: 659.1849975585938
# Correlation_Weighted - Epoch 275: Train Loss: 681.140380859375, Val Loss: 654.9225463867188
# Correlation_Weighted - Epoch 276: Train Loss: 676.6925659179688, Val Loss: 650.6907348632812
# Correlation_Weighted - Epoch 277: Train Loss: 672.2730712890625, Val Loss: 646.4904174804688
# Correlation_Weighted - Epoch 278: Train Loss: 667.8825073242188, Val Loss: 642.3236083984375
# Correlation_Weighted - Epoch 279: Train Loss: 663.5218505859375, Val Loss: 638.192138671875
# Correlation_Weighted - Epoch 280: Train Loss: 659.1904296875, Val Loss: 634.0919799804688
# Correlation_Weighted - Epoch 281: Train Loss: 654.88916015625, Val Loss: 630.0242309570312
# Correlation_Weighted - Epoch 282: Train Loss: 650.6185302734375, Val Loss: 625.988037109375
# Correlation_Weighted - Epoch 283: Train Loss: 646.3782348632812, Val Loss: 621.9862060546875
# Correlation_Weighted - Epoch 284: Train Loss: 642.169189453125, Val Loss: 618.0206298828125
# Correlation_Weighted - Epoch 285: Train Loss: 637.9931640625, Val Loss: 614.0868530273438
# Correlation_Weighted - Epoch 286: Train Loss: 633.8516235351562, Val Loss: 610.1838989257812
# Correlation_Weighted - Epoch 287: Train Loss: 629.7446899414062, Val Loss: 606.31494140625
# Correlation_Weighted - Epoch 288: Train Loss: 625.6727294921875, Val Loss: 602.4878540039062
# Correlation_Weighted - Epoch 289: Train Loss: 621.6353759765625, Val Loss: 598.6976318359375
# Correlation_Weighted - Epoch 290: Train Loss: 617.634033203125, Val Loss: 594.9400024414062
# Correlation_Weighted - Epoch 291: Train Loss: 613.6705932617188, Val Loss: 591.2188110351562
# Correlation_Weighted - Epoch 292: Train Loss: 609.7459106445312, Val Loss: 587.5375366210938
# Correlation_Weighted - Epoch 293: Train Loss: 605.8600463867188, Val Loss: 583.8986206054688
# Correlation_Weighted - Epoch 294: Train Loss: 602.0137329101562, Val Loss: 580.2979736328125
# Correlation_Weighted - Epoch 295: Train Loss: 598.20751953125, Val Loss: 576.7381591796875
# Correlation_Weighted - Epoch 296: Train Loss: 594.4420776367188, Val Loss: 573.2188720703125
# Correlation_Weighted - Epoch 297: Train Loss: 590.7188720703125, Val Loss: 569.7406005859375
# Correlation_Weighted - Epoch 298: Train Loss: 587.03955078125, Val Loss: 566.3030395507812
# Correlation_Weighted - Epoch 299: Train Loss: 583.4044189453125, Val Loss: 562.9066162109375
# Correlation_Weighted - Epoch 300: Train Loss: 579.81298828125, Val Loss: 559.5513916015625
# Correlation_Weighted - Epoch 301: Train Loss: 576.26611328125, Val Loss: 556.2421875
# Correlation_Weighted - Epoch 302: Train Loss: 572.762939453125, Val Loss: 552.977294921875
# Correlation_Weighted - Epoch 303: Train Loss: 569.3040771484375, Val Loss: 549.7564697265625
# Correlation_Weighted - Epoch 304: Train Loss: 565.8871459960938, Val Loss: 546.5769653320312
# Correlation_Weighted - Epoch 305: Train Loss: 562.5130615234375, Val Loss: 543.4386596679688
# Correlation_Weighted - Epoch 306: Train Loss: 559.1820678710938, Val Loss: 540.3447875976562
# Correlation_Weighted - Epoch 307: Train Loss: 555.8934326171875, Val Loss: 537.2906494140625
# Correlation_Weighted - Epoch 308: Train Loss: 552.6459350585938, Val Loss: 534.277099609375
# Correlation_Weighted - Epoch 309: Train Loss: 549.4393310546875, Val Loss: 531.3060302734375
# Correlation_Weighted - Epoch 310: Train Loss: 546.2737426757812, Val Loss: 528.3741455078125
# Correlation_Weighted - Epoch 311: Train Loss: 543.1484985351562, Val Loss: 525.4791259765625
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import networkx as nx
import os

# Directory to save the graphs
output_dir = 'saved_graphs'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Save each graph with node data
for model_name, graph_fn in graph_models.items():
    print(f"Creating and saving graph: {model_name}")
    graph, _ = graph_fn()
    
    # Save the graph using pickle
    output_path = os.path.join(output_dir, f"{model_name}.pkl")
    pickle.dump(graph, open(output_path, "wb"))
    print(f"Graph '{model_name}' saved to '{output_path}'")
# Out:
# Creating and saving graph: Distance_Weighted
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 26 nodes.
# Graph 'Distance_Weighted' saved to 'saved_graphs\Distance_Weighted.pkl'
# Creating and saving graph: Distance_Unweighted
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 26 nodes.
# Graph 'Distance_Unweighted' saved to 'saved_graphs\Distance_Unweighted.pkl'
# Creating and saving graph: Correlation_Weighted
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 25 nodes.
# Graph 'Correlation_Weighted' saved to 'saved_graphs\Correlation_Weighted.pkl'
# Creating and saving graph: Correlation_Unweighted
# Removed 0 self-loops and 0 duplicate edges. Choose the Largest Component: 25 nodes.
# Graph 'Correlation_Unweighted' saved to 'saved_graphs\Correlation_Unweighted.pkl'

# %%
# Combined plot for train and validation losses
plt.figure(figsize=(12, 8))
for model_name, result in results.items():
    plt.plot(result['train_losses'][0:400], label=f'{model_name} - Training Loss')
    # also print the last value as a reference
    print(f"{model_name} - Last Training Loss: {result['train_losses'][-1]}")
plt.title("Training Loss for All Models")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(loc='upper right')
plt.show()

# Combined actual vs predicted plots in subplots
fig, axs = plt.subplots(len(results), 1, figsize=(12, 8), sharex=True)
fig.suptitle("Actual vs Predicted Traffic Flow (200-point Intervals)")
start = np.random.randint(0, 267410)
end = start + 1600

for idx, (model_name, result) in enumerate(results.items()):
    actual = result['actual_values']
    predicted = result['predicted_values']

    axs[idx].plot(actual[start:end], label='Actual')
    axs[idx].plot(predicted[start:end], label='Predicted')
    axs[idx].set_title(f"{model_name}")
    axs[idx].set_ylabel("Traffic Flow")
    axs[idx].legend(loc='upper left')


plt.xlabel("Time Steps")
plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust layout to fit title
plt.show()
# Out:
# Distance_Weighted - Last Training Loss: 71.6123046875
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 23
#      20 actual = result['actual_values']
#      21 predicted = result['predicted_values']
# ---> 23 axs[idx].plot(actual[start:end], label='Actual')
#      24 axs[idx].plot(predicted[start:end], label='Predicted')
#      25 axs[idx].set_title(f"{model_name}")
#
# TypeError: 'Axes' object is not subscriptable
