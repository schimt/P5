# %%
import pandas as pd 
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from shapely.geometry import LineString
import pyproj
import pandas as pd
import regex as reg
import networkx as nx
import osmnx as ox
import geopandas as gpd

# %%
# Load the Time-Series data from Mastra
mastra_df = pd.read_csv('mastra.csv')

# Load GraphML for Aalborg Municipality
G = ox.load_graphml('aalborg_network.graphml')

# Project the graph to UTM (osmnx will automatically select the appropriate UTM zone)
G_proj = ox.project_graph(G)
nodes_proj, edges_proj = ox.graph_to_gdfs(G_proj)

# %% [markdown]
# Clean Mastra

# %%
# Verify the column names in the DataFrame
print(mastra_df.columns)

# reg ex to replace , with . on the whole document
mastra_df = mastra_df.replace({',': '.'}, regex=True)
mastra_df = mastra_df.replace({'LÃ¸rdag': "Loerdag"}, regex=True)
mastra_df = mastra_df.replace({'SÃ¸ndag': "Soendag"}, regex=True)


mastra_df.rename(columns={'MÃ¥ned': 'Maened'}, inplace=True)
mastra_df.rename(columns={'Ãrstal': 'Aarstal'}, inplace=True)
mastra_df.rename(columns={'ï»¿Vej-Id': 'Vej-Id'}, inplace=True)

#mastra_df.drop(columns=['Unnamed: 1', 'Unnamed: 2'], inplace=True)

# Correct column names if necessary
columns_to_convert = [
    'Trafiktype',
    'Dagtype',
    'Vej-Id',
    'Retning',
    'Trafiktype'
]

# Convert the specified columns to float64
mastra_df = mastra_df.astype({col: 'string' for col in columns_to_convert})

mastra_df = mastra_df.replace({'<NA>': ""}, regex=True)

# Identify the columns that are not part of the time intervals
id_vars_columns = [
    'Vej-Id', 'Kilometer', 'Retning', 'Spor', 'Dato', 'Aarstal', 
    'Maened', 'Dag', 'Dagtype', 'Trafiktype', 'Xkoordinat', 'Ykoordinat'
]

# The time interval columns
time_columns = [
    "00:00-00:15","00:15-00:30","00:30-00:45","00:45-01:00","01:00-01:15","01:15-01:30","01:30-01:45","01:45-02:00","02:00-02:15","02:15-02:30","02:30-02:45","02:45-03:00","03:00-03:15","03:15-03:30","03:30-03:45","03:45-04:00","04:00-04:15","04:15-04:30","04:30-04:45","04:45-05:00","05:00-05:15","05:15-05:30","05:30-05:45","05:45-06:00","06:00-06:15","06:15-06:30","06:30-06:45","06:45-07:00","07:00-07:15","07:15-07:30","07:30-07:45","07:45-08:00","08:00-08:15","08:15-08:30","08:30-08:45","08:45-09:00","09:00-09:15","09:15-09:30","09:30-09:45","09:45-10:00","10:00-10:15","10:15-10:30","10:30-10:45","10:45-11:00","11:00-11:15","11:15-11:30","11:30-11:45","11:45-12:00","12:00-12:15","12:15-12:30","12:30-12:45","12:45-13:00","13:00-13:15","13:15-13:30","13:30-13:45","13:45-14:00","14:00-14:15","14:15-14:30","14:30-14:45","14:45-15:00","15:00-15:15","15:15-15:30","15:30-15:45","15:45-16:00","16:00-16:15","16:15-16:30","16:30-16:45","16:45-17:00","17:00-17:15","17:15-17:30","17:30-17:45","17:45-18:00","18:00-18:15","18:15-18:30","18:30-18:45","18:45-19:00","19:00-19:15","19:15-19:30","19:30-19:45","19:45-20:00","20:00-20:15","20:15-20:30","20:30-20:45","20:45-21:00","21:00-21:15","21:15-21:30","21:30-21:45","21:45-22:00","22:00-22:15","22:15-22:30","22:30-22:45","22:45-23:00","23:00-23:15","23:15-23:30","23:30-23:45","23:45-24:00"
]

# Melt the DataFrame to reshape it from wide format to long format
mastra_long = pd.melt(
    mastra_df,
    id_vars=id_vars_columns,  # Columns that uniquely identify each row
    value_vars=time_columns,  # Time interval columns
    var_name='time_interval',  # Name of the new column for the time intervals
    value_name='traffic_flow'  # Name for the traffic flow data
)

# Extract the start time from 'time_interval'
mastra_long['time_start'] = mastra_long['time_interval'].str[:5]  # Extracts the "00:00" part for sorting

mastra_long['datetime'] = pd.to_datetime(mastra_long['Dato'] + " " + mastra_long['time_start'], dayfirst=True)

mastra_long = mastra_long.sort_values(by=['Vej-Id', 'Dato', 'time_start'])

# Result
mastra_long.head()
# Out:
# Index(['ï»¿Vej-Id', 'Unnamed: 1', 'Unnamed: 2', 'Kilometer', 'Retning', 'Spor',
#        'Xkoordinat', 'Ykoordinat', 'Dato', 'Ãrstal',
#        ...
#        '21:30-21:45', '21:45-22:00', '22:00-22:15', '22:15-22:30',
#        '22:30-22:45', '22:45-23:00', '23:00-23:15', '23:15-23:30',
#        '23:30-23:45', '23:45-24:00'],
#       dtype='object', length=110)
#                    Vej-Id  Kilometer Retning  Spor        Dato  Aarstal  \
# 33655    0 450-0 7/ 300 +        7.0       +   NaN  01.02.2023   2023.0
# 302697   0 450-0 7/ 300 +        7.0       +   NaN  01.02.2023   2023.0
# 571739   0 450-0 7/ 300 +        7.0       +   NaN  01.02.2023   2023.0
# 840781   0 450-0 7/ 300 +        7.0       +   NaN  01.02.2023   2023.0
# 1109823  0 450-0 7/ 300 +        7.0       +   NaN  01.02.2023   2023.0
#
#          Maened  Dag  Dagtype Trafiktype  Xkoordinat  Ykoordinat  \
# 33655       2.0  1.0  Hverdag         BY    552601.0   6329842.0
# 302697      2.0  1.0  Hverdag         BY    552601.0   6329842.0
# 571739      2.0  1.0  Hverdag         BY    552601.0   6329842.0
# 840781      2.0  1.0  Hverdag         BY    552601.0   6329842.0
# 1109823     2.0  1.0  Hverdag         BY    552601.0   6329842.0
#
#         time_interval  traffic_flow time_start            datetime
# 33655     00:00-00:15          10.0      00:00 2023-02-01 00:00:00
# 302697    00:15-00:30          10.0      00:15 2023-02-01 00:15:00
# 571739    00:30-00:45           7.0      00:30 2023-02-01 00:30:00
# 840781    00:45-01:00           3.0      00:45 2023-02-01 00:45:00
# 1109823   01:00-01:15           3.0      01:00 2023-02-01 01:00:00

# %% [markdown]
# Group Time Series data

# %%
# Create a dictionary to store the DataFrames with unique key identifiers
grouped_dataframes = {}

# Group by the specified columns
for key, group in mastra_long.groupby(["Vej-Id", "Xkoordinat", "Ykoordinat"]):
    # Use the unique key for naming or accessing each DataFrame
    sorted_group = group.sort_values(by=['Vej-Id', 'Dato', 'time_start'])
    grouped_dataframes[key] = sorted_group.reset_index(drop=True,inplace=False).set_index('datetime', inplace=False)

# %%
grouped_dataframes[key]
# Out:
#                                      Vej-Id  Kilometer Retning  Spor  \
# datetime
# 2023-01-01 00:00:00  851 8519680-0 0/ 470 T        0.0       T   NaN
# 2023-01-01 00:15:00  851 8519680-0 0/ 470 T        0.0       T   NaN
# 2023-01-01 00:30:00  851 8519680-0 0/ 470 T        0.0       T   NaN
# 2023-01-01 00:45:00  851 8519680-0 0/ 470 T        0.0       T   NaN
# 2023-01-01 01:00:00  851 8519680-0 0/ 470 T        0.0       T   NaN
# ...                                     ...        ...     ...   ...
# 2023-12-31 22:45:00  851 8519680-0 0/ 470 T        0.0       T   NaN
# 2023-12-31 23:00:00  851 8519680-0 0/ 470 T        0.0       T   NaN
# 2023-12-31 23:15:00  851 8519680-0 0/ 470 T        0.0       T   NaN
# 2023-12-31 23:30:00  851 8519680-0 0/ 470 T        0.0       T   NaN
# 2023-12-31 23:45:00  851 8519680-0 0/ 470 T        0.0       T   NaN
#
#                            Dato  Aarstal  Maened   Dag    Dagtype Trafiktype  \
# datetime
# 2023-01-01 00:00:00  01.01.2023   2023.0     1.0   1.0  Helligdag         BY
# 2023-01-01 00:15:00  01.01.2023   2023.0     1.0   1.0  Helligdag         BY
# 2023-01-01 00:30:00  01.01.2023   2023.0     1.0   1.0  Helligdag         BY
# 2023-01-01 00:45:00  01.01.2023   2023.0     1.0   1.0  Helligdag         BY
# 2023-01-01 01:00:00  01.01.2023   2023.0     1.0   1.0  Helligdag         BY
# ...                         ...      ...     ...   ...        ...        ...
# 2023-12-31 22:45:00  31.12.2023   2023.0    12.0  31.0  Helligdag         BY
# 2023-12-31 23:00:00  31.12.2023   2023.0    12.0  31.0  Helligdag         BY
# 2023-12-31 23:15:00  31.12.2023   2023.0    12.0  31.0  Helligdag         BY
# 2023-12-31 23:30:00  31.12.2023   2023.0    12.0  31.0  Helligdag         BY
# 2023-12-31 23:45:00  31.12.2023   2023.0    12.0  31.0  Helligdag         BY
#
#                      Xkoordinat  Ykoordinat time_interval  traffic_flow  \
# datetime
# 2023-01-01 00:00:00    556617.0   6324515.0   00:00-00:15          21.0
# 2023-01-01 00:15:00    556617.0   6324515.0   00:15-00:30          65.0
# 2023-01-01 00:30:00    556617.0   6324515.0   00:30-00:45          65.0
# 2023-01-01 00:45:00    556617.0   6324515.0   00:45-01:00          65.0
# 2023-01-01 01:00:00    556617.0   6324515.0   01:00-01:15          69.0
# ...                         ...         ...           ...           ...
# 2023-12-31 22:45:00    556617.0   6324515.0   22:45-23:00          50.0
# 2023-12-31 23:00:00    556617.0   6324515.0   23:00-23:15          70.0
# 2023-12-31 23:15:00    556617.0   6324515.0   23:15-23:30          75.0
# 2023-12-31 23:30:00    556617.0   6324515.0   23:30-23:45          64.0
# 2023-12-31 23:45:00    556617.0   6324515.0   23:45-24:00          65.0
#
#                     time_start
# datetime
# 2023-01-01 00:00:00      00:00
# 2023-01-01 00:15:00      00:15
# 2023-01-01 00:30:00      00:30
# 2023-01-01 00:45:00      00:45
# 2023-01-01 01:00:00      01:00
# ...                        ...
# 2023-12-31 22:45:00      22:45
# 2023-12-31 23:00:00      23:00
# 2023-12-31 23:15:00      23:15
# 2023-12-31 23:30:00      23:30
# 2023-12-31 23:45:00      23:45
#
# [61344 rows x 15 columns]

# %%
grouped_dataframes[key]['traffic_flow']
# Out:
# datetime
# 2023-01-01 00:00:00    21.0
# 2023-01-01 00:15:00    65.0
# 2023-01-01 00:30:00    65.0
# 2023-01-01 00:45:00    65.0
# 2023-01-01 01:00:00    69.0
#                        ...
# 2023-12-31 22:45:00    50.0
# 2023-12-31 23:00:00    70.0
# 2023-12-31 23:15:00    75.0
# 2023-12-31 23:30:00    64.0
# 2023-12-31 23:45:00    65.0
# Name: traffic_flow, Length: 61344, dtype: float64

# %%
import math
import time
import pandas as pd
import osmnx as ox

# Ensure the graph has node and edge identifiers
edges_proj = ox.graph_to_gdfs(G_proj, nodes=False, edges=True).reset_index()  # Include 'u', 'v', and 'key'

# Add a 'time_series_data' column to hold the time series information
edges_proj['time_series_data'] = pd.Series([None] * len(edges_proj), dtype="object")

# Function to calculate Euclidean distance between two points
def euclidean_distance(x1, y1, x2, y2):
    return math.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2)

# Track progress and statistics
total_dataframes = len(grouped_dataframes)
start_time = time.time()
x = 5  # Status print interval
high_distance_threshold = 1000  # Threshold in meters

# Initialize distance metrics
total_distance, min_distance, max_distance = 0, float('inf'), float('-inf')
distance_count = 0

# Process each DataFrame in `grouped_dataframes`
for df_index, (key, df) in enumerate(grouped_dataframes.items(), start=1):
    vej_id, df_x, df_y = key
    closest_edge, closest_distance = None, float('inf')

    # Find the closest edge
    for _, edge_data in edges_proj.iterrows():
        # Midpoint coordinates of the edge
        edge_geometry = edge_data['geometry']
        midpoint_index = len(edge_geometry.coords.xy[0]) // 2
        edge_x = edge_geometry.coords.xy[0][midpoint_index]
        edge_y = edge_geometry.coords.xy[1][midpoint_index]

        # Calculate the distance to the current DataFrame's location
        distance = euclidean_distance(edge_x, edge_y, df_x, df_y)
        if distance < closest_distance:
            closest_distance = distance
            closest_edge = (edge_data['u'], edge_data['v'], edge_data['key'])

    # Assign time-series data if within threshold
    if closest_edge and closest_distance <= high_distance_threshold:
        time_series_data = list(zip(df.index.to_pydatetime(), df['traffic_flow'].tolist()))

        # Update both `G_proj` and `edges_proj`
        u, v, key = closest_edge
        if (u, v, key) in G_proj.edges(keys=True):
            G_proj[u][v][key]['time_series_data'] = time_series_data

        # Use pd.Series to wrap time_series_data as a single object
        edges_proj.loc[(edges_proj['u'] == u) & (edges_proj['v'] == v) & (edges_proj['key'] == key), 'time_series_data'] = pd.Series([time_series_data], dtype="object")

        # Update distance stats
        total_distance += closest_distance
        min_distance = min(min_distance, closest_distance)
        max_distance = max(max_distance, closest_distance)
        distance_count += 1
        print(f"Edge found within threshold for DataFrame {df_index}/{total_dataframes}")
    else:
        print(f"No edge found within threshold for DataFrame {df_index}/{total_dataframes}")

    # Status print every x dataframes
    if df_index % x == 0:
        avg_distance = total_distance / distance_count if distance_count > 0 else 0
        avg_time_per_df = (time.time() - start_time) / df_index
        estimated_total_time = avg_time_per_df * total_dataframes
        remaining_time = estimated_total_time - (time.time() - start_time)

        # Print progress and distance stats
        print(f"Processed {df_index}/{total_dataframes} DataFrames. Estimated remaining time: {remaining_time / 60:.2f} minutes")
        print(f"Min Distance: {min_distance:.2f} meters, Max Distance: {max_distance:.2f} meters, Avg Distance: {avg_distance:.2f} meters")

# Print final summary
print("\nProcessing complete.")
print(f"Total edges with time series data in G_proj: {sum(1 for _, _, _, data in G_proj.edges(keys=True, data=True) if 'time_series_data' in data)}")
print(f"Distance stats - Min: {min_distance:.2f}m, Max: {max_distance:.2f}m, Avg: {total_distance / distance_count if distance_count > 0 else 0:.2f}m")

# Verify that time series data is actually assigned in `edges_proj`
print("\nVerification of assigned data in `edges_proj`:")
print(edges_proj['time_series_data'].dropna().head())
# Out:
# Edge found within threshold for DataFrame 1/485
# Edge found within threshold for DataFrame 2/485
# Edge found within threshold for DataFrame 3/485
# Edge found within threshold for DataFrame 4/485
# Edge found within threshold for DataFrame 5/485
# Processed 5/485 DataFrames. Estimated remaining time: 15.41 minutes
# Min Distance: 97.58 meters, Max Distance: 97.58 meters, Avg Distance: 97.58 meters
# Edge found within threshold for DataFrame 6/485
# Edge found within threshold for DataFrame 7/485
# Edge found within threshold for DataFrame 8/485
# Edge found within threshold for DataFrame 9/485
# Edge found within threshold for DataFrame 10/485
# Processed 10/485 DataFrames. Estimated remaining time: 15.09 minutes
# Min Distance: 97.58 meters, Max Distance: 366.85 meters, Avg Distance: 178.36 meters
# Edge found within threshold for DataFrame 11/485
# Edge found within threshold for DataFrame 12/485
# Edge found within threshold for DataFrame 13/485
# Edge found within threshold for DataFrame 14/485
# Edge found within threshold for DataFrame 15/485
# Processed 15/485 DataFrames. Estimated remaining time: 15.44 minutes
# Min Distance: 97.58 meters, Max Distance: 366.85 meters, Avg Distance: 238.17 meters
# Edge found within threshold for DataFrame 16/485
# Edge found within threshold for DataFrame 17/485
# Edge found within threshold for DataFrame 18/485
# Edge found within threshold for DataFrame 19/485
# Edge found within threshold for DataFrame 20/485
# Processed 20/485 DataFrames. Estimated remaining time: 26.42 minutes
# Min Distance: 71.31 meters, Max Distance: 366.85 meters, Avg Distance: 196.45 meters
# Edge found within threshold for DataFrame 21/485
# Edge found within threshold for DataFrame 22/485
# Edge found within threshold for DataFrame 23/485
# Edge found within threshold for DataFrame 24/485
# Edge found within threshold for DataFrame 25/485
# Processed 25/485 DataFrames. Estimated remaining time: 24.02 minutes
# Min Distance: 71.31 meters, Max Distance: 378.85 meters, Avg Distance: 208.33 meters
# Edge found within threshold for DataFrame 26/485
# Edge found within threshold for DataFrame 27/485
# Edge found within threshold for DataFrame 28/485
# Edge found within threshold for DataFrame 29/485
# Edge found within threshold for DataFrame 30/485
# Processed 30/485 DataFrames. Estimated remaining time: 23.20 minutes
# Min Distance: 19.75 meters, Max Distance: 378.85 meters, Avg Distance: 192.57 meters
# Edge found within threshold for DataFrame 31/485
# Edge found within threshold for DataFrame 32/485
# Edge found within threshold for DataFrame 33/485
# Edge found within threshold for DataFrame 34/485
# Edge found within threshold for DataFrame 35/485
# Processed 35/485 DataFrames. Estimated remaining time: 24.53 minutes
# Min Distance: 19.75 meters, Max Distance: 378.85 meters, Avg Distance: 174.86 meters
# Edge found within threshold for DataFrame 36/485
# Edge found within threshold for DataFrame 37/485
# Edge found within threshold for DataFrame 38/485
# Edge found within threshold for DataFrame 39/485
# Edge found within threshold for DataFrame 40/485
# Processed 40/485 DataFrames. Estimated remaining time: 25.38 minutes
# Min Distance: 19.75 meters, Max Distance: 378.85 meters, Avg Distance: 163.16 meters
# Edge found within threshold for DataFrame 41/485
# Edge found within threshold for DataFrame 42/485
# Edge found within threshold for DataFrame 43/485
# Edge found within threshold for DataFrame 44/485
# Edge found within threshold for DataFrame 45/485
# Processed 45/485 DataFrames. Estimated remaining time: 26.18 minutes
# Min Distance: 19.75 meters, Max Distance: 378.85 meters, Avg Distance: 151.80 meters
# Edge found within threshold for DataFrame 46/485
# Edge found within threshold for DataFrame 47/485
# Edge found within threshold for DataFrame 48/485
# Edge found within threshold for DataFrame 49/485
# Edge found within threshold for DataFrame 50/485
# Processed 50/485 DataFrames. Estimated remaining time: 26.43 minutes
# Min Distance: 19.75 meters, Max Distance: 378.85 meters, Avg Distance: 143.83 meters
# Edge found within threshold for DataFrame 51/485
# Edge found within threshold for DataFrame 52/485
# Edge found within threshold for DataFrame 53/485
# Edge found within threshold for DataFrame 54/485
# Edge found within threshold for DataFrame 55/485
# Processed 55/485 DataFrames. Estimated remaining time: 26.52 minutes
# Min Distance: 19.75 meters, Max Distance: 378.85 meters, Avg Distance: 136.35 meters
# Edge found within threshold for DataFrame 56/485
# Edge found within threshold for DataFrame 57/485
# Edge found within threshold for DataFrame 58/485
# Edge found within threshold for DataFrame 59/485
# Edge found within threshold for DataFrame 60/485
# Processed 60/485 DataFrames. Estimated remaining time: 26.51 minutes
# Min Distance: 19.75 meters, Max Distance: 378.85 meters, Avg Distance: 136.34 meters
# Edge found within threshold for DataFrame 61/485
# Edge found within threshold for DataFrame 62/485
# Edge found within threshold for DataFrame 63/485
# Edge found within threshold for DataFrame 64/485
# Edge found within threshold for DataFrame 65/485
# Processed 65/485 DataFrames. Estimated remaining time: 26.44 minutes
# Min Distance: 19.75 meters, Max Distance: 378.85 meters, Avg Distance: 135.74 meters
# Edge found within threshold for DataFrame 66/485
# Edge found within threshold for DataFrame 67/485
# Edge found within threshold for DataFrame 68/485
# Edge found within threshold for DataFrame 69/485
# Edge found within threshold for DataFrame 70/485
# Processed 70/485 DataFrames. Estimated remaining time: 26.37 minutes
# Min Distance: 19.75 meters, Max Distance: 378.85 meters, Avg Distance: 129.07 meters
# Edge found within threshold for DataFrame 71/485
# Edge found within threshold for DataFrame 72/485
# Edge found within threshold for DataFrame 73/485
# Edge found within threshold for DataFrame 74/485
# Edge found within threshold for DataFrame 75/485
# Processed 75/485 DataFrames. Estimated remaining time: 26.30 minutes
# Min Distance: 19.75 meters, Max Distance: 378.85 meters, Avg Distance: 125.13 meters
# Edge found within threshold for DataFrame 76/485
# Edge found within threshold for DataFrame 77/485
# Edge found within threshold for DataFrame 78/485
# Edge found within threshold for DataFrame 79/485
# Edge found within threshold for DataFrame 80/485
# Processed 80/485 DataFrames. Estimated remaining time: 26.17 minutes
# Min Distance: 19.75 meters, Max Distance: 378.85 meters, Avg Distance: 120.18 meters
# Edge found within threshold for DataFrame 81/485
# Edge found within threshold for DataFrame 82/485
# Edge found within threshold for DataFrame 83/485
# Edge found within threshold for DataFrame 84/485
# Edge found within threshold for DataFrame 85/485
# Processed 85/485 DataFrames. Estimated remaining time: 26.03 minutes
# Min Distance: 19.75 meters, Max Distance: 378.85 meters, Avg Distance: 114.70 meters
# Edge found within threshold for DataFrame 86/485
# Edge found within threshold for DataFrame 87/485
# Edge found within threshold for DataFrame 88/485
# Edge found within threshold for DataFrame 89/485
# Edge found within threshold for DataFrame 90/485
# Processed 90/485 DataFrames. Estimated remaining time: 25.92 minutes
# Min Distance: 19.75 meters, Max Distance: 378.85 meters, Avg Distance: 109.92 meters
# Edge found within threshold for DataFrame 91/485
# Edge found within threshold for DataFrame 92/485
# Edge found within threshold for DataFrame 93/485
# Edge found within threshold for DataFrame 94/485
# Edge found within threshold for DataFrame 95/485
# Processed 95/485 DataFrames. Estimated remaining time: 25.77 minutes
# Min Distance: 9.10 meters, Max Distance: 378.85 meters, Avg Distance: 104.62 meters
# Edge found within threshold for DataFrame 96/485
# Edge found within threshold for DataFrame 97/485
# Edge found within threshold for DataFrame 98/485
# Edge found within threshold for DataFrame 99/485
# Edge found within threshold for DataFrame 100/485
# Processed 100/485 DataFrames. Estimated remaining time: 25.57 minutes
# Min Distance: 9.10 meters, Max Distance: 378.85 meters, Avg Distance: 104.14 meters
# Edge found within threshold for DataFrame 101/485
# Edge found within threshold for DataFrame 102/485
# Edge found within threshold for DataFrame 103/485
# Edge found within threshold for DataFrame 104/485
# Edge found within threshold for DataFrame 105/485
# Processed 105/485 DataFrames. Estimated remaining time: 25.37 minutes
# Min Distance: 9.10 meters, Max Distance: 378.85 meters, Avg Distance: 100.62 meters
# Edge found within threshold for DataFrame 106/485
# Edge found within threshold for DataFrame 107/485
# Edge found within threshold for DataFrame 108/485
# Edge found within threshold for DataFrame 109/485
# Edge found within threshold for DataFrame 110/485
# Processed 110/485 DataFrames. Estimated remaining time: 25.14 minutes
# Min Distance: 9.10 meters, Max Distance: 378.85 meters, Avg Distance: 98.73 meters
# Edge found within threshold for DataFrame 111/485
# Edge found within threshold for DataFrame 112/485
# Edge found within threshold for DataFrame 113/485
# Edge found within threshold for DataFrame 114/485
# Edge found within threshold for DataFrame 115/485
# Processed 115/485 DataFrames. Estimated remaining time: 24.90 minutes
# Min Distance: 9.10 meters, Max Distance: 378.85 meters, Avg Distance: 98.28 meters
# Edge found within threshold for DataFrame 116/485
# Edge found within threshold for DataFrame 117/485
# Edge found within threshold for DataFrame 118/485
# Edge found within threshold for DataFrame 119/485
# Edge found within threshold for DataFrame 120/485
# Processed 120/485 DataFrames. Estimated remaining time: 24.64 minutes
# Min Distance: 9.10 meters, Max Distance: 378.85 meters, Avg Distance: 100.43 meters
# Edge found within threshold for DataFrame 121/485
# Edge found within threshold for DataFrame 122/485
# Edge found within threshold for DataFrame 123/485
# Edge found within threshold for DataFrame 124/485
# Edge found within threshold for DataFrame 125/485
# Processed 125/485 DataFrames. Estimated remaining time: 24.36 minutes
# Min Distance: 9.10 meters, Max Distance: 378.85 meters, Avg Distance: 106.40 meters
# Edge found within threshold for DataFrame 126/485
# Edge found within threshold for DataFrame 127/485
# Edge found within threshold for DataFrame 128/485
# Edge found within threshold for DataFrame 129/485
# Edge found within threshold for DataFrame 130/485
# Processed 130/485 DataFrames. Estimated remaining time: 24.09 minutes
# Min Distance: 9.10 meters, Max Distance: 378.85 meters, Avg Distance: 105.93 meters
# Edge found within threshold for DataFrame 131/485
# Edge found within threshold for DataFrame 132/485
# Edge found within threshold for DataFrame 133/485
# Edge found within threshold for DataFrame 134/485
# Edge found within threshold for DataFrame 135/485
# Processed 135/485 DataFrames. Estimated remaining time: 23.80 minutes
# Min Distance: 9.10 meters, Max Distance: 378.85 meters, Avg Distance: 104.22 meters
# Edge found within threshold for DataFrame 136/485
# Edge found within threshold for DataFrame 137/485
# Edge found within threshold for DataFrame 138/485
# Edge found within threshold for DataFrame 139/485
# Edge found within threshold for DataFrame 140/485
# Processed 140/485 DataFrames. Estimated remaining time: 23.52 minutes
# Min Distance: 9.10 meters, Max Distance: 378.85 meters, Avg Distance: 102.05 meters
# Edge found within threshold for DataFrame 141/485
# Edge found within threshold for DataFrame 142/485
# Edge found within threshold for DataFrame 143/485
# Edge found within threshold for DataFrame 144/485
# Edge found within threshold for DataFrame 145/485
# Processed 145/485 DataFrames. Estimated remaining time: 23.25 minutes
# Min Distance: 9.10 meters, Max Distance: 378.85 meters, Avg Distance: 99.99 meters
# Edge found within threshold for DataFrame 146/485
# Edge found within threshold for DataFrame 147/485
# Edge found within threshold for DataFrame 148/485
# Edge found within threshold for DataFrame 149/485
# Edge found within threshold for DataFrame 150/485
# Processed 150/485 DataFrames. Estimated remaining time: 22.96 minutes
# Min Distance: 9.10 meters, Max Distance: 378.85 meters, Avg Distance: 98.84 meters
# Edge found within threshold for DataFrame 151/485
# Edge found within threshold for DataFrame 152/485
# Edge found within threshold for DataFrame 153/485
# Edge found within threshold for DataFrame 154/485
# Edge found within threshold for DataFrame 155/485
# Processed 155/485 DataFrames. Estimated remaining time: 22.67 minutes
# Min Distance: 9.10 meters, Max Distance: 378.85 meters, Avg Distance: 97.77 meters
# Edge found within threshold for DataFrame 156/485
# Edge found within threshold for DataFrame 157/485
# Edge found within threshold for DataFrame 158/485
# Edge found within threshold for DataFrame 159/485
# Edge found within threshold for DataFrame 160/485
# Processed 160/485 DataFrames. Estimated remaining time: 22.37 minutes
# Min Distance: 8.64 meters, Max Distance: 378.85 meters, Avg Distance: 95.05 meters
# Edge found within threshold for DataFrame 161/485
# Edge found within threshold for DataFrame 162/485
# Edge found within threshold for DataFrame 163/485
# Edge found within threshold for DataFrame 164/485
# Edge found within threshold for DataFrame 165/485
# Processed 165/485 DataFrames. Estimated remaining time: 22.07 minutes
# Min Distance: 8.64 meters, Max Distance: 378.85 meters, Avg Distance: 93.68 meters
# Edge found within threshold for DataFrame 166/485
# Edge found within threshold for DataFrame 167/485
# Edge found within threshold for DataFrame 168/485
# Edge found within threshold for DataFrame 169/485
# Edge found within threshold for DataFrame 170/485
# Processed 170/485 DataFrames. Estimated remaining time: 21.77 minutes
# Min Distance: 8.64 meters, Max Distance: 378.85 meters, Avg Distance: 94.96 meters
# Edge found within threshold for DataFrame 171/485
# Edge found within threshold for DataFrame 172/485
# Edge found within threshold for DataFrame 173/485
# Edge found within threshold for DataFrame 174/485
# Edge found within threshold for DataFrame 175/485
# Processed 175/485 DataFrames. Estimated remaining time: 21.46 minutes
# Min Distance: 8.64 meters, Max Distance: 378.85 meters, Avg Distance: 94.52 meters
# Edge found within threshold for DataFrame 176/485
# Edge found within threshold for DataFrame 177/485
# Edge found within threshold for DataFrame 178/485
# Edge found within threshold for DataFrame 179/485
# Edge found within threshold for DataFrame 180/485
# Processed 180/485 DataFrames. Estimated remaining time: 21.15 minutes
# Min Distance: 8.64 meters, Max Distance: 378.85 meters, Avg Distance: 93.98 meters
# Edge found within threshold for DataFrame 181/485
# Edge found within threshold for DataFrame 182/485
# Edge found within threshold for DataFrame 183/485
# Edge found within threshold for DataFrame 184/485
# Edge found within threshold for DataFrame 185/485
# Processed 185/485 DataFrames. Estimated remaining time: 20.83 minutes
# Min Distance: 8.64 meters, Max Distance: 378.85 meters, Avg Distance: 94.33 meters
# Edge found within threshold for DataFrame 186/485
# Edge found within threshold for DataFrame 187/485
# Edge found within threshold for DataFrame 188/485
# Edge found within threshold for DataFrame 189/485
# Edge found within threshold for DataFrame 190/485
# Processed 190/485 DataFrames. Estimated remaining time: 20.51 minutes
# Min Distance: 8.64 meters, Max Distance: 378.85 meters, Avg Distance: 95.84 meters
# Edge found within threshold for DataFrame 191/485
# Edge found within threshold for DataFrame 192/485
# Edge found within threshold for DataFrame 193/485
# Edge found within threshold for DataFrame 194/485
# Edge found within threshold for DataFrame 195/485
# Processed 195/485 DataFrames. Estimated remaining time: 20.19 minutes
# Min Distance: 8.64 meters, Max Distance: 378.85 meters, Avg Distance: 95.91 meters
# Edge found within threshold for DataFrame 196/485
# Edge found within threshold for DataFrame 197/485
# Edge found within threshold for DataFrame 198/485
# Edge found within threshold for DataFrame 199/485
# Edge found within threshold for DataFrame 200/485
# Processed 200/485 DataFrames. Estimated remaining time: 19.87 minutes
# Min Distance: 8.64 meters, Max Distance: 378.85 meters, Avg Distance: 97.47 meters
# Edge found within threshold for DataFrame 201/485
# Edge found within threshold for DataFrame 202/485
# Edge found within threshold for DataFrame 203/485
# Edge found within threshold for DataFrame 204/485
# Edge found within threshold for DataFrame 205/485
# Processed 205/485 DataFrames. Estimated remaining time: 19.54 minutes
# Min Distance: 8.64 meters, Max Distance: 378.85 meters, Avg Distance: 98.80 meters
# Edge found within threshold for DataFrame 206/485
# Edge found within threshold for DataFrame 207/485
# Edge found within threshold for DataFrame 208/485
# Edge found within threshold for DataFrame 209/485
# Edge found within threshold for DataFrame 210/485
# Processed 210/485 DataFrames. Estimated remaining time: 19.22 minutes
# Min Distance: 8.64 meters, Max Distance: 378.85 meters, Avg Distance: 97.69 meters
# Edge found within threshold for DataFrame 211/485
# Edge found within threshold for DataFrame 212/485
# Edge found within threshold for DataFrame 213/485
# Edge found within threshold for DataFrame 214/485
# Edge found within threshold for DataFrame 215/485
# Processed 215/485 DataFrames. Estimated remaining time: 18.90 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 96.43 meters
# Edge found within threshold for DataFrame 216/485
# Edge found within threshold for DataFrame 217/485
# Edge found within threshold for DataFrame 218/485
# Edge found within threshold for DataFrame 219/485
# Edge found within threshold for DataFrame 220/485
# Processed 220/485 DataFrames. Estimated remaining time: 18.57 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 95.45 meters
# Edge found within threshold for DataFrame 221/485
# Edge found within threshold for DataFrame 222/485
# Edge found within threshold for DataFrame 223/485
# Edge found within threshold for DataFrame 224/485
# Edge found within threshold for DataFrame 225/485
# Processed 225/485 DataFrames. Estimated remaining time: 18.12 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 95.05 meters
# Edge found within threshold for DataFrame 226/485
# Edge found within threshold for DataFrame 227/485
# Edge found within threshold for DataFrame 228/485
# Edge found within threshold for DataFrame 229/485
# Edge found within threshold for DataFrame 230/485
# Processed 230/485 DataFrames. Estimated remaining time: 17.59 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 95.40 meters
# Edge found within threshold for DataFrame 231/485
# Edge found within threshold for DataFrame 232/485
# Edge found within threshold for DataFrame 233/485
# Edge found within threshold for DataFrame 234/485
# Edge found within threshold for DataFrame 235/485
# Processed 235/485 DataFrames. Estimated remaining time: 17.07 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 94.97 meters
# Edge found within threshold for DataFrame 236/485
# Edge found within threshold for DataFrame 237/485
# Edge found within threshold for DataFrame 238/485
# Edge found within threshold for DataFrame 239/485
# Edge found within threshold for DataFrame 240/485
# Processed 240/485 DataFrames. Estimated remaining time: 16.58 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 93.56 meters
# Edge found within threshold for DataFrame 241/485
# Edge found within threshold for DataFrame 242/485
# Edge found within threshold for DataFrame 243/485
# Edge found within threshold for DataFrame 244/485
# Edge found within threshold for DataFrame 245/485
# Processed 245/485 DataFrames. Estimated remaining time: 16.27 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 92.47 meters
# Edge found within threshold for DataFrame 246/485
# Edge found within threshold for DataFrame 247/485
# Edge found within threshold for DataFrame 248/485
# Edge found within threshold for DataFrame 249/485
# Edge found within threshold for DataFrame 250/485
# Processed 250/485 DataFrames. Estimated remaining time: 15.96 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 91.79 meters
# Edge found within threshold for DataFrame 251/485
# Edge found within threshold for DataFrame 252/485
# Edge found within threshold for DataFrame 253/485
# Edge found within threshold for DataFrame 254/485
# Edge found within threshold for DataFrame 255/485
# Processed 255/485 DataFrames. Estimated remaining time: 15.65 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 91.06 meters
# Edge found within threshold for DataFrame 256/485
# Edge found within threshold for DataFrame 257/485
# Edge found within threshold for DataFrame 258/485
# Edge found within threshold for DataFrame 259/485
# Edge found within threshold for DataFrame 260/485
# Processed 260/485 DataFrames. Estimated remaining time: 15.33 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 90.95 meters
# Edge found within threshold for DataFrame 261/485
# Edge found within threshold for DataFrame 262/485
# Edge found within threshold for DataFrame 263/485
# Edge found within threshold for DataFrame 264/485
# Edge found within threshold for DataFrame 265/485
# Processed 265/485 DataFrames. Estimated remaining time: 15.01 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 90.14 meters
# Edge found within threshold for DataFrame 266/485
# Edge found within threshold for DataFrame 267/485
# Edge found within threshold for DataFrame 268/485
# Edge found within threshold for DataFrame 269/485
# Edge found within threshold for DataFrame 270/485
# Processed 270/485 DataFrames. Estimated remaining time: 14.69 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 89.74 meters
# Edge found within threshold for DataFrame 271/485
# Edge found within threshold for DataFrame 272/485
# Edge found within threshold for DataFrame 273/485
# Edge found within threshold for DataFrame 274/485
# Edge found within threshold for DataFrame 275/485
# Processed 275/485 DataFrames. Estimated remaining time: 14.36 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 89.81 meters
# Edge found within threshold for DataFrame 276/485
# Edge found within threshold for DataFrame 277/485
# Edge found within threshold for DataFrame 278/485
# Edge found within threshold for DataFrame 279/485
# Edge found within threshold for DataFrame 280/485
# Processed 280/485 DataFrames. Estimated remaining time: 14.03 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 89.19 meters
# Edge found within threshold for DataFrame 281/485
# Edge found within threshold for DataFrame 282/485
# Edge found within threshold for DataFrame 283/485
# Edge found within threshold for DataFrame 284/485
# Edge found within threshold for DataFrame 285/485
# Processed 285/485 DataFrames. Estimated remaining time: 13.70 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 88.64 meters
# Edge found within threshold for DataFrame 286/485
# Edge found within threshold for DataFrame 287/485
# Edge found within threshold for DataFrame 288/485
# Edge found within threshold for DataFrame 289/485
# Edge found within threshold for DataFrame 290/485
# Processed 290/485 DataFrames. Estimated remaining time: 13.37 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 88.26 meters
# Edge found within threshold for DataFrame 291/485
# Edge found within threshold for DataFrame 292/485
# Edge found within threshold for DataFrame 293/485
# Edge found within threshold for DataFrame 294/485
# Edge found within threshold for DataFrame 295/485
# Processed 295/485 DataFrames. Estimated remaining time: 13.04 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 87.34 meters
# Edge found within threshold for DataFrame 296/485
# Edge found within threshold for DataFrame 297/485
# Edge found within threshold for DataFrame 298/485
# Edge found within threshold for DataFrame 299/485
# Edge found within threshold for DataFrame 300/485
# Processed 300/485 DataFrames. Estimated remaining time: 12.71 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 86.44 meters
# Edge found within threshold for DataFrame 301/485
# Edge found within threshold for DataFrame 302/485
# Edge found within threshold for DataFrame 303/485
# Edge found within threshold for DataFrame 304/485
# Edge found within threshold for DataFrame 305/485
# Processed 305/485 DataFrames. Estimated remaining time: 12.38 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 85.95 meters
# Edge found within threshold for DataFrame 306/485
# Edge found within threshold for DataFrame 307/485
# Edge found within threshold for DataFrame 308/485
# Edge found within threshold for DataFrame 309/485
# Edge found within threshold for DataFrame 310/485
# Processed 310/485 DataFrames. Estimated remaining time: 12.04 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 86.78 meters
# Edge found within threshold for DataFrame 311/485
# Edge found within threshold for DataFrame 312/485
# Edge found within threshold for DataFrame 313/485
# Edge found within threshold for DataFrame 314/485
# Edge found within threshold for DataFrame 315/485
# Processed 315/485 DataFrames. Estimated remaining time: 11.71 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 86.91 meters
# Edge found within threshold for DataFrame 316/485
# Edge found within threshold for DataFrame 317/485
# Edge found within threshold for DataFrame 318/485
# Edge found within threshold for DataFrame 319/485
# Edge found within threshold for DataFrame 320/485
# Processed 320/485 DataFrames. Estimated remaining time: 11.37 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 86.54 meters
# Edge found within threshold for DataFrame 321/485
# Edge found within threshold for DataFrame 322/485
# Edge found within threshold for DataFrame 323/485
# Edge found within threshold for DataFrame 324/485
# Edge found within threshold for DataFrame 325/485
# Processed 325/485 DataFrames. Estimated remaining time: 11.04 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 86.68 meters
# Edge found within threshold for DataFrame 326/485
# Edge found within threshold for DataFrame 327/485
# Edge found within threshold for DataFrame 328/485
# Edge found within threshold for DataFrame 329/485
# Edge found within threshold for DataFrame 330/485
# Processed 330/485 DataFrames. Estimated remaining time: 10.70 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 86.46 meters
# Edge found within threshold for DataFrame 331/485
# Edge found within threshold for DataFrame 332/485
# Edge found within threshold for DataFrame 333/485
# Edge found within threshold for DataFrame 334/485
# Edge found within threshold for DataFrame 335/485
# Processed 335/485 DataFrames. Estimated remaining time: 10.37 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 86.38 meters
# Edge found within threshold for DataFrame 336/485
# Edge found within threshold for DataFrame 337/485
# Edge found within threshold for DataFrame 338/485
# Edge found within threshold for DataFrame 339/485
# Edge found within threshold for DataFrame 340/485
# Processed 340/485 DataFrames. Estimated remaining time: 10.03 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 86.41 meters
# Edge found within threshold for DataFrame 341/485
# Edge found within threshold for DataFrame 342/485
# Edge found within threshold for DataFrame 343/485
# Edge found within threshold for DataFrame 344/485
# Edge found within threshold for DataFrame 345/485
# Processed 345/485 DataFrames. Estimated remaining time: 9.69 minutes
# Min Distance: 4.26 meters, Max Distance: 378.85 meters, Avg Distance: 85.75 meters
# Edge found within threshold for DataFrame 346/485
# Edge found within threshold for DataFrame 347/485
# Edge found within threshold for DataFrame 348/485
# Edge found within threshold for DataFrame 349/485
# Edge found within threshold for DataFrame 350/485
# Processed 350/485 DataFrames. Estimated remaining time: 9.35 minutes
# Min Distance: 4.26 meters, Max Distance: 417.73 meters, Avg Distance: 88.59 meters
# Edge found within threshold for DataFrame 351/485
# Edge found within threshold for DataFrame 352/485
# Edge found within threshold for DataFrame 353/485
# No edge found within threshold for DataFrame 354/485
# Edge found within threshold for DataFrame 355/485
# Processed 355/485 DataFrames. Estimated remaining time: 9.01 minutes
# Min Distance: 4.26 meters, Max Distance: 417.73 meters, Avg Distance: 88.27 meters
# Edge found within threshold for DataFrame 356/485
# Edge found within threshold for DataFrame 357/485
# Edge found within threshold for DataFrame 358/485
# Edge found within threshold for DataFrame 359/485
# Edge found within threshold for DataFrame 360/485
# Processed 360/485 DataFrames. Estimated remaining time: 8.67 minutes
# Min Distance: 4.26 meters, Max Distance: 417.73 meters, Avg Distance: 87.54 meters
# Edge found within threshold for DataFrame 361/485
# Edge found within threshold for DataFrame 362/485
# Edge found within threshold for DataFrame 363/485
# Edge found within threshold for DataFrame 364/485
# Edge found within threshold for DataFrame 365/485
# Processed 365/485 DataFrames. Estimated remaining time: 8.33 minutes
# Min Distance: 4.26 meters, Max Distance: 417.73 meters, Avg Distance: 87.46 meters
# Edge found within threshold for DataFrame 366/485
# Edge found within threshold for DataFrame 367/485
# Edge found within threshold for DataFrame 368/485
# Edge found within threshold for DataFrame 369/485
# Edge found within threshold for DataFrame 370/485
# Processed 370/485 DataFrames. Estimated remaining time: 7.99 minutes
# Min Distance: 2.29 meters, Max Distance: 417.73 meters, Avg Distance: 86.87 meters
# Edge found within threshold for DataFrame 371/485
# Edge found within threshold for DataFrame 372/485
# Edge found within threshold for DataFrame 373/485
# Edge found within threshold for DataFrame 374/485
# Edge found within threshold for DataFrame 375/485
# Processed 375/485 DataFrames. Estimated remaining time: 7.64 minutes
# Min Distance: 2.29 meters, Max Distance: 417.73 meters, Avg Distance: 85.82 meters
# Edge found within threshold for DataFrame 376/485
# Edge found within threshold for DataFrame 377/485
# Edge found within threshold for DataFrame 378/485
# Edge found within threshold for DataFrame 379/485
# Edge found within threshold for DataFrame 380/485
# Processed 380/485 DataFrames. Estimated remaining time: 7.30 minutes
# Min Distance: 2.29 meters, Max Distance: 417.73 meters, Avg Distance: 85.04 meters
# Edge found within threshold for DataFrame 381/485
# Edge found within threshold for DataFrame 382/485
# Edge found within threshold for DataFrame 383/485
# Edge found within threshold for DataFrame 384/485
# Edge found within threshold for DataFrame 385/485
# Processed 385/485 DataFrames. Estimated remaining time: 6.96 minutes
# Min Distance: 2.29 meters, Max Distance: 417.73 meters, Avg Distance: 86.22 meters
# Edge found within threshold for DataFrame 386/485
# Edge found within threshold for DataFrame 387/485
# Edge found within threshold for DataFrame 388/485
# Edge found within threshold for DataFrame 389/485
# Edge found within threshold for DataFrame 390/485
# Processed 390/485 DataFrames. Estimated remaining time: 6.61 minutes
# Min Distance: 2.29 meters, Max Distance: 417.73 meters, Avg Distance: 85.60 meters
# Edge found within threshold for DataFrame 391/485
# Edge found within threshold for DataFrame 392/485
# Edge found within threshold for DataFrame 393/485
# Edge found within threshold for DataFrame 394/485
# Edge found within threshold for DataFrame 395/485
# Processed 395/485 DataFrames. Estimated remaining time: 6.27 minutes
# Min Distance: 2.29 meters, Max Distance: 417.73 meters, Avg Distance: 85.28 meters
# Edge found within threshold for DataFrame 396/485
# Edge found within threshold for DataFrame 397/485
# Edge found within threshold for DataFrame 398/485
# Edge found within threshold for DataFrame 399/485
# Edge found within threshold for DataFrame 400/485
# Processed 400/485 DataFrames. Estimated remaining time: 5.93 minutes
# Min Distance: 2.29 meters, Max Distance: 538.85 meters, Avg Distance: 87.91 meters
# Edge found within threshold for DataFrame 401/485
# Edge found within threshold for DataFrame 402/485
# Edge found within threshold for DataFrame 403/485
# Edge found within threshold for DataFrame 404/485
# Edge found within threshold for DataFrame 405/485
# Processed 405/485 DataFrames. Estimated remaining time: 5.58 minutes
# Min Distance: 2.29 meters, Max Distance: 538.85 meters, Avg Distance: 88.47 meters
# Edge found within threshold for DataFrame 406/485
# Edge found within threshold for DataFrame 407/485
# Edge found within threshold for DataFrame 408/485
# Edge found within threshold for DataFrame 409/485
# Edge found within threshold for DataFrame 410/485
# Processed 410/485 DataFrames. Estimated remaining time: 5.24 minutes
# Min Distance: 2.29 meters, Max Distance: 538.85 meters, Avg Distance: 89.80 meters
# Edge found within threshold for DataFrame 411/485
# Edge found within threshold for DataFrame 412/485
# Edge found within threshold for DataFrame 413/485
# Edge found within threshold for DataFrame 414/485
# Edge found within threshold for DataFrame 415/485
# Processed 415/485 DataFrames. Estimated remaining time: 4.89 minutes
# Min Distance: 2.29 meters, Max Distance: 797.29 meters, Avg Distance: 91.94 meters
# Edge found within threshold for DataFrame 416/485
# Edge found within threshold for DataFrame 417/485
# Edge found within threshold for DataFrame 418/485
# Edge found within threshold for DataFrame 419/485
# Edge found within threshold for DataFrame 420/485
# Processed 420/485 DataFrames. Estimated remaining time: 4.55 minutes
# Min Distance: 2.29 meters, Max Distance: 797.29 meters, Avg Distance: 91.45 meters
# Edge found within threshold for DataFrame 421/485
# Edge found within threshold for DataFrame 422/485
# Edge found within threshold for DataFrame 423/485
# Edge found within threshold for DataFrame 424/485
# Edge found within threshold for DataFrame 425/485
# Processed 425/485 DataFrames. Estimated remaining time: 4.20 minutes
# Min Distance: 2.29 meters, Max Distance: 797.29 meters, Avg Distance: 91.44 meters
# Edge found within threshold for DataFrame 426/485
# Edge found within threshold for DataFrame 427/485
# Edge found within threshold for DataFrame 428/485
# Edge found within threshold for DataFrame 429/485
# Edge found within threshold for DataFrame 430/485
# Processed 430/485 DataFrames. Estimated remaining time: 3.85 minutes
# Min Distance: 2.29 meters, Max Distance: 797.29 meters, Avg Distance: 91.30 meters
# Edge found within threshold for DataFrame 431/485
# Edge found within threshold for DataFrame 432/485
# Edge found within threshold for DataFrame 433/485
# Edge found within threshold for DataFrame 434/485
# Edge found within threshold for DataFrame 435/485
# Processed 435/485 DataFrames. Estimated remaining time: 3.50 minutes
# Min Distance: 2.29 meters, Max Distance: 797.29 meters, Avg Distance: 90.60 meters
# Edge found within threshold for DataFrame 436/485
# Edge found within threshold for DataFrame 437/485
# Edge found within threshold for DataFrame 438/485
# Edge found within threshold for DataFrame 439/485
# Edge found within threshold for DataFrame 440/485
# Processed 440/485 DataFrames. Estimated remaining time: 3.15 minutes
# Min Distance: 2.29 meters, Max Distance: 797.29 meters, Avg Distance: 93.24 meters
# Edge found within threshold for DataFrame 441/485
# Edge found within threshold for DataFrame 442/485
# Edge found within threshold for DataFrame 443/485
# Edge found within threshold for DataFrame 444/485
# Edge found within threshold for DataFrame 445/485
# Processed 445/485 DataFrames. Estimated remaining time: 2.80 minutes
# Min Distance: 1.59 meters, Max Distance: 797.29 meters, Avg Distance: 93.68 meters
# Edge found within threshold for DataFrame 446/485
# Edge found within threshold for DataFrame 447/485
# Edge found within threshold for DataFrame 448/485
# Edge found within threshold for DataFrame 449/485
# Edge found within threshold for DataFrame 450/485
# Processed 450/485 DataFrames. Estimated remaining time: 2.45 minutes
# Min Distance: 1.59 meters, Max Distance: 797.29 meters, Avg Distance: 92.98 meters
# Edge found within threshold for DataFrame 451/485
# Edge found within threshold for DataFrame 452/485
# Edge found within threshold for DataFrame 453/485
# Edge found within threshold for DataFrame 454/485
# Edge found within threshold for DataFrame 455/485
# Processed 455/485 DataFrames. Estimated remaining time: 2.10 minutes
# Min Distance: 1.59 meters, Max Distance: 797.29 meters, Avg Distance: 92.75 meters
# Edge found within threshold for DataFrame 456/485
# Edge found within threshold for DataFrame 457/485
# Edge found within threshold for DataFrame 458/485
# Edge found within threshold for DataFrame 459/485
# Edge found within threshold for DataFrame 460/485
# Processed 460/485 DataFrames. Estimated remaining time: 1.75 minutes
# Min Distance: 1.59 meters, Max Distance: 797.29 meters, Avg Distance: 92.30 meters
# Edge found within threshold for DataFrame 461/485
# Edge found within threshold for DataFrame 462/485
# Edge found within threshold for DataFrame 463/485
# Edge found within threshold for DataFrame 464/485
# Edge found within threshold for DataFrame 465/485
# Processed 465/485 DataFrames. Estimated remaining time: 1.40 minutes
# Min Distance: 1.59 meters, Max Distance: 797.29 meters, Avg Distance: 91.87 meters
# Edge found within threshold for DataFrame 466/485
# Edge found within threshold for DataFrame 467/485
# Edge found within threshold for DataFrame 468/485
# Edge found within threshold for DataFrame 469/485
# Edge found within threshold for DataFrame 470/485
# Processed 470/485 DataFrames. Estimated remaining time: 1.05 minutes
# Min Distance: 1.59 meters, Max Distance: 797.29 meters, Avg Distance: 91.16 meters
# Edge found within threshold for DataFrame 471/485
# Edge found within threshold for DataFrame 472/485
# Edge found within threshold for DataFrame 473/485
# Edge found within threshold for DataFrame 474/485
# Edge found within threshold for DataFrame 475/485
# Processed 475/485 DataFrames. Estimated remaining time: 0.70 minutes
# Min Distance: 1.59 meters, Max Distance: 797.29 meters, Avg Distance: 90.28 meters
# Edge found within threshold for DataFrame 476/485
# Edge found within threshold for DataFrame 477/485
# Edge found within threshold for DataFrame 478/485
# Edge found within threshold for DataFrame 479/485
# Edge found within threshold for DataFrame 480/485
# Processed 480/485 DataFrames. Estimated remaining time: 0.35 minutes
# Min Distance: 1.59 meters, Max Distance: 797.29 meters, Avg Distance: 89.68 meters
# Edge found within threshold for DataFrame 481/485
# Edge found within threshold for DataFrame 482/485
# Edge found within threshold for DataFrame 483/485
# Edge found within threshold for DataFrame 484/485
# Edge found within threshold for DataFrame 485/485
# Processed 485/485 DataFrames. Estimated remaining time: 0.00 minutes
# Min Distance: 1.59 meters, Max Distance: 797.29 meters, Avg Distance: 89.06 meters
#
# Processing complete.
# Total edges with time series data in G_proj: 125
# Distance stats - Min: 1.59m, Max: 797.29m, Avg: 89.06m
#
# Verification of assigned data in `edges_proj`:
# Series([], Name: time_series_data, dtype: object)

# %%
# import math
# import time
# import pandas as pd

# # Function to calculate Euclidean distance between two points
# def euclidean_distance(x1, y1, x2, y2):
#     return math.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2)

# # Initialize total progress tracking
# total_dataframes = len(grouped_dataframes)
# start_time = time.time()
# x = 5  # Print status every x DataFrames processed
# initial_threshold = 10  # Start with 10 meters and increase if no match
# max_threshold = 500000000000  # Maximum distance to prevent excessive searches

# # Variables to track distances
# total_distance = 0
# min_distance = float('inf')
# max_distance = float('-inf')
# distance_count = 0  # Count of distances for averaging

# # Ensure 'time_series_data' column in edges_proj can store complex data
# edges_proj['time_series_data'] = pd.Series([None] * len(edges_proj), dtype="object")

# # Iterate over each grouped DataFrame in `grouped_dataframes`
# for df_index, (key, df) in enumerate(grouped_dataframes.items(), start=1):
#     vej_id, df_x, df_y = key

#     # Initialize variables for closest match search
#     closest_edge = None
#     closest_distance = float('inf')
#     distance_threshold = initial_threshold  # Start with initial threshold

#     # Gradually increase threshold if no match is found within the current threshold
#     while closest_edge is None and distance_threshold <= max_threshold:
#         # Check each edge in `edges_proj` to find the closest to (df_x, df_y) within the current threshold
#         for edge_index, edge_data in edges_proj.iterrows():
#             # Get the midpoint coordinates of the current edge
#             edge_geometry = edge_data['geometry']
#             midpoint_index = len(edge_geometry.coords.xy[0]) // 2
#             edge_x = edge_geometry.coords.xy[0][midpoint_index]
#             edge_y = edge_geometry.coords.xy[1][midpoint_index]

#             # Calculate distance between edge and DataFrame coordinates
#             distance = euclidean_distance(edge_x, edge_y, df_x, df_y)

#             # Track the closest edge if within the current threshold
#             if distance < closest_distance and distance <= distance_threshold:
#                 closest_distance = distance
#                 closest_edge = edge_index

#         # Increase threshold if no match found within current threshold
#         if closest_edge is None:
#             distance_threshold += 100  # Increase by 100 meters

#     # If a closest edge is found within an acceptable threshold, add time-series data
#     if closest_edge is not None and closest_distance <= max_threshold:
#         # Convert the time series data to a list of (datetime, traffic_flow) tuples
#         time_series_data = list(zip(df.index.to_pydatetime(), df['traffic_flow'].tolist()))

#         # Attach the time series data to the edge in both `edges_proj` and `G_proj`
#         edges_proj.at[closest_edge, 'time_series_data'] = time_series_data

#         # Retrieve u, v, key identifiers from `edges_proj` to match in `G_proj`
#         u, v, key = edges_proj.loc[closest_edge, ['u', 'v', 'key']]
#         if (u, v, key) in G_proj.edges(keys=True):
#             G_proj[u][v][key]['time_series_data'] = time_series_data

#         # Update distance statistics
#         total_distance += closest_distance
#         min_distance = min(min_distance, closest_distance)
#         max_distance = max(max_distance, closest_distance)
#         distance_count += 1
#         print(f"Edge found within {closest_distance:.2f} meters for DataFrame {df_index}/{total_dataframes}")
#     else:
#         print(f"No edge found within {max_threshold} meters for DataFrame {df_index}/{total_dataframes}")

#     # Print status every x DataFrames
#     if df_index % x == 0:
#         avg_distance = total_distance / distance_count if distance_count > 0 else 0
#         avg_time_per_df = (time.time() - start_time) / df_index
#         estimated_total_time = avg_time_per_df * total_dataframes
#         remaining_time = estimated_total_time - (time.time() - start_time)

#         # Print progress and distance stats
#         print(f"Processed {df_index}/{total_dataframes} DataFrames. Estimated remaining time: {remaining_time / 60:.2f} minutes")
#         print(f"Min Distance: {min_distance:.2f} meters, Max Distance: {max_distance:.2f} meters, Avg Distance: {avg_distance:.2f} meters")

# # Print final summary
# print("\nProcessing complete.")
# print(f"Total DataFrames processed: {total_dataframes}")
# print(f"Total edges with time series data: {distance_count}")
# print(f"Min Distance: {min_distance:.2f} meters, Max Distance: {max_distance:.2f} meters, Avg Distance: {total_distance / distance_count if distance_count > 0 else 0:.2f} meters")

# # Verify that time series data is actually assigned
# print("\nVerification of assigned data in `edges_proj`:")
# print(edges_proj['time_series_data'].dropna().head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 65
#      62 edges_proj.at[closest_edge, 'time_series_data'] = time_series_data
#      64 # Retrieve u, v, key identifiers from `edges_proj` to match in `G_proj`
# ---> 65 u, v, key = edges_proj.loc[closest_edge, ['u', 'v', 'key']]
#      66 if (u, v, key) in G_proj.edges(keys=True):
#      67     G_proj[u][v][key]['time_series_data'] = time_series_data
#
# File c:\Users\gonde\anaconda3\envs\pyhope\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\gonde\anaconda3\envs\pyhope\Lib\site-packages\pandas\core\indexing.py:1368, in _LocIndexer._getitem_tuple(self, tup)
#    1366 with suppress(IndexingError):
#    1367     tup = self._expand_ellipsis(tup)
# -> 1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
#    1371 tup = self._validate_tuple_indexer(tup)
#
# File c:\Users\gonde\anaconda3\envs\pyhope\Lib\site-packages\pandas\core\indexing.py:1041, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1039 # we may have a nested tuples indexer here
#    1040 if self._is_nested_tuple_indexer(tup):
# -> 1041     return self._getitem_nested_tuple(tup)
#    1043 # we maybe be using a tuple to represent multiple dimensions here
#    1044 ax0 = self.obj._get_axis(0)
#
# File c:\Users\gonde\anaconda3\envs\pyhope\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer._getitem_nested_tuple(self, tup)
#    1150     axis -= 1
#    1151     continue
# -> 1153 obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#    1154 axis -= 1
#    1156 # if we have a scalar, we are done
#
# File c:\Users\gonde\anaconda3\envs\pyhope\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File c:\Users\gonde\anaconda3\envs\pyhope\Lib\site-packages\pandas\core\indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File c:\Users\gonde\anaconda3\envs\pyhope\Lib\site-packages\pandas\core\indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File c:\Users\gonde\anaconda3\envs\pyhope\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\gonde\anaconda3\envs\pyhope\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['u', 'v', 'key'], dtype='object')] are in the [columns]"

# %%
# Verification in G_proj
missing_data_edges = 0
total_edges = len(G_proj.edges())

print("\nVerification of assigned data in `G_proj`:")
for u, v, key, edge_data in G_proj.edges(keys=True, data=True):
    if 'time_series_data' in edge_data:
        print(f"Edge ({u}, {v}, {key}) has time series data.")
    else:
        missing_data_edges += 1

print(f"\nTotal edges in G_proj: {total_edges}")
print(f"Edges with missing time series data: {missing_data_edges}")
print(f"Edges with time series data: {total_edges - missing_data_edges}")
# Out:
# Verification of assigned data in `G_proj`:
# Edge (28390914, 1031808321, 0) has time series data.
# Edge (28390935, 323187714, 0) has time series data.
# Edge (323187714, 29551197, 0) has time series data.
# Edge (29551197, 32993239, 0) has time series data.
# Edge (32993239, 1801882912, 0) has time series data.
# Edge (29977423, 6150580690, 0) has time series data.
# Edge (29972545, 3708603819, 0) has time series data.
# Edge (29972545, 29972549, 0) has time series data.
# Edge (29972575, 29972525, 0) has time series data.
# Edge (1801885465, 1801885466, 0) has time series data.
# Edge (29972655, 29972684, 0) has time series data.
# Edge (32993241, 3465083213, 0) has time series data.
# Edge (2720419870, 29973010, 0) has time series data.
# Edge (29973010, 29972684, 0) has time series data.
# Edge (6150580690, 5970912136, 0) has time series data.
# Edge (324154751, 2753877799, 0) has time series data.
# Edge (324154751, 310129156, 0) has time series data.
# Edge (29977650, 3684837993, 0) has time series data.
# Edge (29977650, 29977655, 0) has time series data.
# Edge (1586264480, 1801887374, 0) has time series data.
# Edge (1801882912, 64856402, 0) has time series data.
# Edge (1801882912, 29972655, 0) has time series data.
# Edge (32993253, 76812647, 0) has time series data.
# Edge (32993253, 76812641, 0) has time series data.
# Edge (76812641, 32993258, 0) has time series data.
# Edge (32993258, 32994085, 0) has time series data.
# Edge (32994931, 76812690, 0) has time series data.
# Edge (32994931, 32994938, 0) has time series data.
# Edge (32993263, 32993269, 0) has time series data.
# Edge (32993269, 1590804211, 0) has time series data.
# Edge (1590804211, 76812468, 0) has time series data.
# Edge (1590804211, 1801882963, 0) has time series data.
# Edge (76812861, 32994087, 0) has time series data.
# Edge (32994087, 76812934, 0) has time series data.
# Edge (76812934, 32994091, 0) has time series data.
# Edge (76813011, 32994098, 0) has time series data.
# Edge (32994105, 309880622, 0) has time series data.
# Edge (76813064, 309880622, 0) has time series data.
# Edge (32994492, 32994499, 0) has time series data.
# Edge (32994506, 76812893, 0) has time series data.
# Edge (32994510, 32994512, 0) has time series data.
# Edge (76812860, 32994512, 0) has time series data.
# Edge (32994514, 76812663, 0) has time series data.
# Edge (76812663, 32993263, 0) has time series data.
# Edge (32994923, 8313842372, 0) has time series data.
# Edge (251740524, 251740519, 0) has time series data.
# Edge (251740472, 279839063, 0) has time series data.
# Edge (251740472, 32995547, 0) has time series data.
# Edge (4511732972, 278169570, 0) has time series data.
# Edge (2498378530, 2498378528, 0) has time series data.
# Edge (2931636338, 1322117687, 0) has time series data.
# Edge (60207151, 29977443, 0) has time series data.
# Edge (63757773, 1668433853, 0) has time series data.
# Edge (64856365, 64856418, 0) has time series data.
# Edge (2720419873, 29973010, 0) has time series data.
# Edge (64919346, 64919351, 0) has time series data.
# Edge (76557327, 76557336, 0) has time series data.
# Edge (76812468, 2720419886, 0) has time series data.
# Edge (76812590, 32993269, 0) has time series data.
# Edge (287098286, 32994938, 0) has time series data.
# Edge (8313845539, 32994091, 0) has time series data.
# Edge (76812973, 32994502, 0) has time series data.
# Edge (670500878, 321365582, 0) has time series data.
# Edge (76813045, 32994098, 0) has time series data.
# Edge (76813059, 76813064, 0) has time series data.
# Edge (76832267, 76832270, 0) has time series data.
# Edge (76832340, 1032373491, 0) has time series data.
# Edge (911620005, 280821804, 0) has time series data.
# Edge (251740030, 279838048, 0) has time series data.
# Edge (279838048, 32995528, 0) has time series data.
# Edge (251740394, 279837753, 0) has time series data.
# Edge (252109019, 316289422, 0) has time series data.
# Edge (255381851, 252111181, 0) has time series data.
# Edge (466433786, 316289421, 0) has time series data.
# Edge (256187426, 1317322523, 0) has time series data.
# Edge (2588150626, 256187592, 0) has time series data.
# Edge (8389512724, 5227891652, 0) has time series data.
# Edge (9531924773, 9531924772, 0) has time series data.
# Edge (277456147, 1091610884, 0) has time series data.
# Edge (1501110654, 1501110706, 0) has time series data.
# Edge (1575304676, 251740302, 0) has time series data.
# Edge (670674060, 670674059, 0) has time series data.
# Edge (4511297422, 32995547, 0) has time series data.
# Edge (279840002, 279840301, 0) has time series data.
# Edge (292585024, 292585024, 0) has time series data.
# Edge (1231339742, 357208393, 0) has time series data.
# Edge (304065583, 361443763, 0) has time series data.
# Edge (307404661, 568477034, 0) has time series data.
# Edge (308821032, 32994492, 0) has time series data.
# Edge (314994879, 2720419875, 0) has time series data.
# Edge (316298224, 1307207926, 0) has time series data.
# Edge (1119147885, 316478823, 0) has time series data.
# Edge (1119147885, 1119147899, 0) has time series data.
# Edge (364386843, 364386841, 0) has time series data.
# Edge (364631109, 365291312, 0) has time series data.
# Edge (3754535427, 1233588453, 0) has time series data.
# Edge (3682876327, 6382121618, 0) has time series data.
# Edge (608588085, 1127736520, 0) has time series data.
# Edge (6583018305, 1127737173, 0) has time series data.
# Edge (860553149, 1025596040, 0) has time series data.
# Edge (924528845, 924528792, 0) has time series data.
# Edge (5808889075, 60207151, 0) has time series data.
# Edge (1032374067, 1032373888, 0) has time series data.
# Edge (1034360290, 1036464956, 0) has time series data.
# Edge (1036556185, 1037679107, 0) has time series data.
# Edge (1036556117, 1036556197, 0) has time series data.
# Edge (1091343330, 1091343346, 0) has time series data.
# Edge (1119147939, 1119279418, 0) has time series data.
# Edge (2710837340, 1127674829, 0) has time series data.
# Edge (1127736710, 1127735850, 0) has time series data.
# Edge (1127735886, 1127736088, 0) has time series data.
# Edge (1153165839, 1153164044, 0) has time series data.
# Edge (1319601091, 1319601172, 0) has time series data.
# Edge (1322117826, 29977454, 0) has time series data.
# Edge (1415036542, 1667019075, 0) has time series data.
# Edge (1514004916, 1514004918, 0) has time series data.
# Edge (1578609268, 1578609284, 0) has time series data.
# Edge (1581576332, 1087112892, 0) has time series data.
# Edge (1801887374, 29972545, 0) has time series data.
# Edge (1801882963, 1116062160, 0) has time series data.
# Edge (1801887371, 29972577, 0) has time series data.
# Edge (1801887371, 29972525, 0) has time series data.
# Edge (4728954544, 4728953870, 0) has time series data.
# Edge (6447435305, 6447435299, 0) has time series data.
# Edge (9665956855, 256188475, 0) has time series data.
#
# Total edges in G_proj: 31470
# Edges with missing time series data: 31345
# Edges with time series data: 125

# %%
len(grouped_dataframes.keys())
# Out:
# 485

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 grouped_dataframes[key]
#
# KeyError: 0

# %%
# Traverse each edge in the projected graph and perform actions based on 'osmid'
for u, v, key, edge_data in G_proj.edges(keys=True, data=True):
    # Chekc if they ahve time series data
# Out:
#   Cell In[9], line 4
#
#     ^
# SyntaxError: incomplete input

# %%
# Traverse each edge in the projected graph and perform actions based on 'osmid'
for u, v, key, edge_data in G_proj.edges(keys=True, data=True):
    print(edge_data)  # Display edge data for reference
    osmid = edge_data.get('osmid')

    for index in stuff:
        if isinstance(stuff[index]['osmid'], int):
            if osmid == stuff[index]['osmid']:
                print("Found1")
                print(stuff[index])
                # Add a custom attribute to the edge
                
                #edge_data['traffic_flow'] = None
        else:
            for osmids in stuff[index]['osmid']:
                if osmid == osmids:
                    print("Found2")
                    # Add a different custom attribute to the edge
                    #edge_data['custom_attribute'] = 'some_value_2'

    # Just breaking to limit the loop as in your example
    break
# Out:
# {'osmid': 26316217, 'lanes': '2', 'name': 'Kirkegade', 'highway': 'tertiary', 'maxspeed': '50', 'oneway': False, 'reversed': True, 'length': 7.838, 'allowed_speed': '50', 'surface_type': 'None', 'is_bridge': 'False', 'is_tunnel': 'False', 'is_oneway': 'False', 'access_restriction': 'None'}
# Found1
# {'osmid': 26316217, 'x': 555709.9852663105, 'y': 6324413.691876737}
# Found1
# {'osmid': 26316217, 'x': 555703.2459350697, 'y': 6324409.648959474}
# Found1
# {'osmid': 26316217, 'x': 555720.5637663284, 'y': 6324420.024219587}

# %%
grouped_dataframes[index]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 grouped_dataframes[index]
#
# KeyError: (12209399551, 12209399583, 0)
