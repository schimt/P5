# %%
import pandas as pd 
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from shapely.geometry import LineString
import pyproj
import pandas as pd
import regex as reg
import networkx as nx
import osmnx as ox
import geopandas as gpd

# %%
# Load the Time-Series data from Mastra
mastra_df = pd.read_csv('mastra.csv')

# Load GraphML for Aalborg Municipality
G = ox.load_graphml('aalborg_network.graphml')

# Project the graph to UTM (osmnx will automatically select the appropriate UTM zone)
G_proj = ox.project_graph(G)
nodes_proj, edges_proj = ox.graph_to_gdfs(G_proj)

# %% [markdown]
# Clean Mastra

# %%
# Verify the column names in the DataFrame
print(mastra_df.columns)

# reg ex to replace , with . on the whole document
mastra_df = mastra_df.replace({',': '.'}, regex=True)
mastra_df = mastra_df.replace({'LÃ¸rdag': "Loerdag"}, regex=True)
mastra_df = mastra_df.replace({'SÃ¸ndag': "Soendag"}, regex=True)


mastra_df.rename(columns={'MÃ¥ned': 'Maened'}, inplace=True)
mastra_df.rename(columns={'Ãrstal': 'Aarstal'}, inplace=True)
mastra_df.rename(columns={'ï»¿Vej-Id': 'Vej-Id'}, inplace=True)

#mastra_df.drop(columns=['Unnamed: 1', 'Unnamed: 2'], inplace=True)

# Correct column names if necessary
columns_to_convert = [
    'Trafiktype',
    'Dagtype',
    'Vej-Id',
    'Retning',
    'Trafiktype'
]

# Convert the specified columns to float64
mastra_df = mastra_df.astype({col: 'string' for col in columns_to_convert})

mastra_df = mastra_df.replace({'<NA>': ""}, regex=True)

# Identify the columns that are not part of the time intervals
id_vars_columns = [
    'Vej-Id', 'Kilometer', 'Retning', 'Spor', 'Dato', 'Aarstal', 
    'Maened', 'Dag', 'Dagtype', 'Trafiktype', 'Xkoordinat', 'Ykoordinat'
]

# The time interval columns
time_columns = [
    "00:00-00:15","00:15-00:30","00:30-00:45","00:45-01:00","01:00-01:15","01:15-01:30","01:30-01:45","01:45-02:00","02:00-02:15","02:15-02:30","02:30-02:45","02:45-03:00","03:00-03:15","03:15-03:30","03:30-03:45","03:45-04:00","04:00-04:15","04:15-04:30","04:30-04:45","04:45-05:00","05:00-05:15","05:15-05:30","05:30-05:45","05:45-06:00","06:00-06:15","06:15-06:30","06:30-06:45","06:45-07:00","07:00-07:15","07:15-07:30","07:30-07:45","07:45-08:00","08:00-08:15","08:15-08:30","08:30-08:45","08:45-09:00","09:00-09:15","09:15-09:30","09:30-09:45","09:45-10:00","10:00-10:15","10:15-10:30","10:30-10:45","10:45-11:00","11:00-11:15","11:15-11:30","11:30-11:45","11:45-12:00","12:00-12:15","12:15-12:30","12:30-12:45","12:45-13:00","13:00-13:15","13:15-13:30","13:30-13:45","13:45-14:00","14:00-14:15","14:15-14:30","14:30-14:45","14:45-15:00","15:00-15:15","15:15-15:30","15:30-15:45","15:45-16:00","16:00-16:15","16:15-16:30","16:30-16:45","16:45-17:00","17:00-17:15","17:15-17:30","17:30-17:45","17:45-18:00","18:00-18:15","18:15-18:30","18:30-18:45","18:45-19:00","19:00-19:15","19:15-19:30","19:30-19:45","19:45-20:00","20:00-20:15","20:15-20:30","20:30-20:45","20:45-21:00","21:00-21:15","21:15-21:30","21:30-21:45","21:45-22:00","22:00-22:15","22:15-22:30","22:30-22:45","22:45-23:00","23:00-23:15","23:15-23:30","23:30-23:45","23:45-24:00"
]

# Melt the DataFrame to reshape it from wide format to long format
mastra_long = pd.melt(
    mastra_df,
    id_vars=id_vars_columns,  # Columns that uniquely identify each row
    value_vars=time_columns,  # Time interval columns
    var_name='time_interval',  # Name of the new column for the time intervals
    value_name='traffic_flow'  # Name for the traffic flow data
)

# Extract the start time from 'time_interval'
mastra_long['time_start'] = mastra_long['time_interval'].str[:5]  # Extracts the "00:00" part for sorting

mastra_long['datetime'] = pd.to_datetime(mastra_long['Dato'] + " " + mastra_long['time_start'], dayfirst=True)

mastra_long = mastra_long.sort_values(by=['Vej-Id', 'Dato', 'time_start'])

# Result
mastra_long.head()
# Out:
# Index(['ï»¿Vej-Id', 'Unnamed: 1', 'Unnamed: 2', 'Kilometer', 'Retning', 'Spor',
#        'Xkoordinat', 'Ykoordinat', 'Dato', 'Ãrstal',
#        ...
#        '21:30-21:45', '21:45-22:00', '22:00-22:15', '22:15-22:30',
#        '22:30-22:45', '22:45-23:00', '23:00-23:15', '23:15-23:30',
#        '23:30-23:45', '23:45-24:00'],
#       dtype='object', length=110)
#                    Vej-Id  Kilometer Retning  Spor        Dato  Aarstal  \
# 33655    0 450-0 7/ 300 +        7.0       +   NaN  01.02.2023   2023.0
# 302697   0 450-0 7/ 300 +        7.0       +   NaN  01.02.2023   2023.0
# 571739   0 450-0 7/ 300 +        7.0       +   NaN  01.02.2023   2023.0
# 840781   0 450-0 7/ 300 +        7.0       +   NaN  01.02.2023   2023.0
# 1109823  0 450-0 7/ 300 +        7.0       +   NaN  01.02.2023   2023.0
#
#          Maened  Dag  Dagtype Trafiktype  Xkoordinat  Ykoordinat  \
# 33655       2.0  1.0  Hverdag         BY    552601.0   6329842.0
# 302697      2.0  1.0  Hverdag         BY    552601.0   6329842.0
# 571739      2.0  1.0  Hverdag         BY    552601.0   6329842.0
# 840781      2.0  1.0  Hverdag         BY    552601.0   6329842.0
# 1109823     2.0  1.0  Hverdag         BY    552601.0   6329842.0
#
#         time_interval  traffic_flow time_start            datetime
# 33655     00:00-00:15          10.0      00:00 2023-02-01 00:00:00
# 302697    00:15-00:30          10.0      00:15 2023-02-01 00:15:00
# 571739    00:30-00:45           7.0      00:30 2023-02-01 00:30:00
# 840781    00:45-01:00           3.0      00:45 2023-02-01 00:45:00
# 1109823   01:00-01:15           3.0      01:00 2023-02-01 01:00:00

# %% [markdown]
# Group Time Series data

# %%
# Create a dictionary to store the DataFrames with unique key identifiers
grouped_dataframes = {}

# Group by the specified columns
for key, group in mastra_long.groupby(["Vej-Id", "Xkoordinat", "Ykoordinat"]):
    # Use the unique key for naming or accessing each DataFrame
    sorted_group = group.sort_values(by=['Vej-Id', 'Dato', 'time_start'])
    grouped_dataframes[key] = sorted_group.reset_index(drop=True,inplace=False).set_index('datetime', inplace=False)

# %%
grouped_dataframes[key]
# Out:
#                                      Vej-Id  Kilometer Retning  Spor  \
# datetime
# 2023-01-01 00:00:00  851 8519680-0 0/ 470 T        0.0       T   NaN
# 2023-01-01 00:15:00  851 8519680-0 0/ 470 T        0.0       T   NaN
# 2023-01-01 00:30:00  851 8519680-0 0/ 470 T        0.0       T   NaN
# 2023-01-01 00:45:00  851 8519680-0 0/ 470 T        0.0       T   NaN
# 2023-01-01 01:00:00  851 8519680-0 0/ 470 T        0.0       T   NaN
# ...                                     ...        ...     ...   ...
# 2023-12-31 22:45:00  851 8519680-0 0/ 470 T        0.0       T   NaN
# 2023-12-31 23:00:00  851 8519680-0 0/ 470 T        0.0       T   NaN
# 2023-12-31 23:15:00  851 8519680-0 0/ 470 T        0.0       T   NaN
# 2023-12-31 23:30:00  851 8519680-0 0/ 470 T        0.0       T   NaN
# 2023-12-31 23:45:00  851 8519680-0 0/ 470 T        0.0       T   NaN
#
#                            Dato  Aarstal  Maened   Dag    Dagtype Trafiktype  \
# datetime
# 2023-01-01 00:00:00  01.01.2023   2023.0     1.0   1.0  Helligdag         BY
# 2023-01-01 00:15:00  01.01.2023   2023.0     1.0   1.0  Helligdag         BY
# 2023-01-01 00:30:00  01.01.2023   2023.0     1.0   1.0  Helligdag         BY
# 2023-01-01 00:45:00  01.01.2023   2023.0     1.0   1.0  Helligdag         BY
# 2023-01-01 01:00:00  01.01.2023   2023.0     1.0   1.0  Helligdag         BY
# ...                         ...      ...     ...   ...        ...        ...
# 2023-12-31 22:45:00  31.12.2023   2023.0    12.0  31.0  Helligdag         BY
# 2023-12-31 23:00:00  31.12.2023   2023.0    12.0  31.0  Helligdag         BY
# 2023-12-31 23:15:00  31.12.2023   2023.0    12.0  31.0  Helligdag         BY
# 2023-12-31 23:30:00  31.12.2023   2023.0    12.0  31.0  Helligdag         BY
# 2023-12-31 23:45:00  31.12.2023   2023.0    12.0  31.0  Helligdag         BY
#
#                      Xkoordinat  Ykoordinat time_interval  traffic_flow  \
# datetime
# 2023-01-01 00:00:00    556617.0   6324515.0   00:00-00:15          21.0
# 2023-01-01 00:15:00    556617.0   6324515.0   00:15-00:30          65.0
# 2023-01-01 00:30:00    556617.0   6324515.0   00:30-00:45          65.0
# 2023-01-01 00:45:00    556617.0   6324515.0   00:45-01:00          65.0
# 2023-01-01 01:00:00    556617.0   6324515.0   01:00-01:15          69.0
# ...                         ...         ...           ...           ...
# 2023-12-31 22:45:00    556617.0   6324515.0   22:45-23:00          50.0
# 2023-12-31 23:00:00    556617.0   6324515.0   23:00-23:15          70.0
# 2023-12-31 23:15:00    556617.0   6324515.0   23:15-23:30          75.0
# 2023-12-31 23:30:00    556617.0   6324515.0   23:30-23:45          64.0
# 2023-12-31 23:45:00    556617.0   6324515.0   23:45-24:00          65.0
#
#                     time_start
# datetime
# 2023-01-01 00:00:00      00:00
# 2023-01-01 00:15:00      00:15
# 2023-01-01 00:30:00      00:30
# 2023-01-01 00:45:00      00:45
# 2023-01-01 01:00:00      01:00
# ...                        ...
# 2023-12-31 22:45:00      22:45
# 2023-12-31 23:00:00      23:00
# 2023-12-31 23:15:00      23:15
# 2023-12-31 23:30:00      23:30
# 2023-12-31 23:45:00      23:45
#
# [61344 rows x 15 columns]

# %%
grouped_dataframes[key]['traffic_flow']
# Out:
# datetime
# 2023-01-01 00:00:00    21.0
# 2023-01-01 00:15:00    65.0
# 2023-01-01 00:30:00    65.0
# 2023-01-01 00:45:00    65.0
# 2023-01-01 01:00:00    69.0
#                        ...
# 2023-12-31 22:45:00    50.0
# 2023-12-31 23:00:00    70.0
# 2023-12-31 23:15:00    75.0
# 2023-12-31 23:30:00    64.0
# 2023-12-31 23:45:00    65.0
# Name: traffic_flow, Length: 61344, dtype: float64

# %%
len(edges_proj)
# Out:
# 31470

# %%
# import math
# import time
# import pandas as pd

# # Function to calculate Euclidean distance between two points
# def euclidean_distance(x1, y1, x2, y2):
#     return math.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2)

# # Initialize tracking and parameters
# total_dataframes = len(grouped_dataframes)
# start_time = time.time()
# x = 5  # Print status every x DataFrames processed
# distance_threshold = 10000000  # Set higher to test distance limitation
# assigned_edges = set()  # Track which edges have been assigned data

# # Ensure 'time_series_data' column in edges_proj can store complex data
# edges_proj['time_series_data'] = pd.Series([None] * len(edges_proj), dtype="object")

# # Iterate over each grouped DataFrame in `grouped_dataframes`
# for df_index, (key, df) in enumerate(grouped_dataframes.items(), start=1):
#     vej_id, df_x, df_y = key

#     # List to store edges by distance
#     edge_distances = []

#     # Loop over all edges in `edges_proj` and calculate distances
#     for edge_index, edge_data in edges_proj.iterrows():
#         if edge_index in assigned_edges:  # Skip edges already assigned data
#             continue

#         edge_geometry = edge_data['geometry']
#         midpoint_index = len(edge_geometry.coords.xy[0]) // 2
#         edge_x = edge_geometry.coords.xy[0][midpoint_index]
#         edge_y = edge_geometry.coords.xy[1][midpoint_index]

#         # Calculate distance from edge to DataFrame's x, y
#         distance = euclidean_distance(edge_x, edge_y, df_x, df_y)

#         # Track each edge with its distance, if within threshold
#         if distance <= distance_threshold:
#             edge_distances.append((edge_index, distance))

#     # Sort edges by distance
#     edge_distances.sort(key=lambda x: x[1])

#     # Assign data to the first unassigned edge within the threshold
#     assigned = False
#     for edge_index, distance in edge_distances:
#         if edge_index not in assigned_edges:  # Ensure edge hasn't been reused
#             time_series_data = list(zip(df.index.to_pydatetime(), df['traffic_flow'].tolist()))
#             edges_proj.at[edge_index, 'time_series_data'] = time_series_data
#             assigned_edges.add(edge_index)  # Mark as assigned
#             print(f"Assigned data to edge {edge_index} for DataFrame {df_index}/{total_dataframes}")
#             assigned = True
#             break

#     # If no edge could be assigned, log the result
#     if not assigned:
#         print(f"No suitable unassigned edge found within threshold for DataFrame {df_index}/{total_dataframes}")

#     # Progress update every x dataframes
#     if df_index % x == 0:
#         avg_time_per_df = (time.time() - start_time) / df_index
#         estimated_total_time = avg_time_per_df * total_dataframes
#         remaining_time = estimated_total_time - (time.time() - start_time)
#         print(f"Processed {df_index}/{total_dataframes} DataFrames. Remaining time: {remaining_time / 60:.2f} minutes")

# # Final summary
# print("\nProcessing complete.")
# print(f"Total DataFrames processed: {total_dataframes}")
# print(f"Total edges assigned time series data: {len(assigned_edges)}")

# # Verification of assigned data
# print("\nVerification of assigned data:")
# print(edges_proj['time_series_data'].dropna().head())
# print("\nEdges with no data assigned:", edges_proj[edges_proj['time_series_data'].isna()])

# %%
# ox.save_graphml(G, filepath='total.graphml')

# ox.save_graphml(G_proj, filepath='total_proj.graphml')

# %%
# G_proj = ox.load_graphml('total_proj.graphml')

# edges_proj = ox.graph_to_gdfs(G_proj)

# %%
# go to cell (29972545, 29972549, 0) of the G graph edge

G_proj[29972545][29972549][0]
# Out:
# {'osmid': [941949214, 9249815],
#  'lanes': '1',
#  'highway': 'motorway_link',
#  'oneway': True,
#  'reversed': False,
#  'length': 88.227,
#  'allowed_speed': 'None',
#  'surface_type': 'None',
#  'is_bridge': 'False',
#  'is_tunnel': 'False',
#  'is_oneway': 'True',
#  'access_restriction': 'None',
#  'geometry': <LINESTRING (558334.637 6319964.764, 558345.969 6319972.416, 558364.02 63199...>}

# %%
# Inspect a few entries to confirm data assignment
print("\nVerification of assigned data:")
print(edges_proj['time_series_data'].dropna().head())
print("\nEdges with no data assigned:", edges_proj[edges_proj['time_series_data'].isna()])
# Out:
# Verification of assigned data:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\gonde\anaconda3\envs\pyhope\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time_series_data'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Inspect a few entries to confirm data assignment
#       2 print("\nVerification of assigned data:")
# ----> 3 print(edges_proj['time_series_data'].dropna().head())
#       4 print("\nEdges with no data assigned:", edges_proj[edges_proj['time_series_data'].isna()])
#
# File c:\Users\gonde\anaconda3\envs\pyhope\Lib\site-packages\geopandas\geodataframe.py:1459, in GeoDataFrame.__getitem__(self, key)
#    1453 def __getitem__(self, key):
#    1454     """
#    1455     If the result is a column containing only 'geometry', return a
#    1456     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1457     return a GeoDataFrame.
#    1458     """
# -> 1459     result = super().__getitem__(key)
#    1460     # Custom logic to avoid waiting for pandas GH51895
#    1461     # result is not geometry dtype for multi-indexes
#    1462     if (
#    1463         pd.api.types.is_scalar(key)
#    1464         and key == ""
#    (...)
#    1467         and not is_geometry_type(result)
#    1468     ):
#
# File c:\Users\gonde\anaconda3\envs\pyhope\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\gonde\anaconda3\envs\pyhope\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'time_series_data'

# %%
# Verification in G_proj
missing_data_edges = 0
total_edges = len(G_proj.edges())

print("\nVerification of assigned data in `G_proj`:")
for u, v, key, edge_data in G_proj.edges(keys=True, data=True):
    if 'time_series_data' in edge_data:
        print(f"Edge ({u}, {v}, {key}) has time series data.")
    else:
        missing_data_edges += 1

print(f"\nTotal edges in G_proj: {total_edges}")
print(f"Edges with missing time series data: {missing_data_edges}")
print(f"Edges with time series data: {total_edges - missing_data_edges}")
# Out:
# Verification of assigned data in `G_proj`:
# Edge (28390914, 1031808321, 0) has time series data.
# Edge (28390914, 84863652, 0) has time series data.
# Edge (1031808321, 28390914, 0) has time series data.
# Edge (28390935, 323187714, 0) has time series data.
# Edge (323187714, 29551197, 0) has time series data.
# Edge (29551197, 1801885466, 0) has time series data.
# Edge (29551197, 32993239, 0) has time series data.
# Edge (1801885466, 28390935, 0) has time series data.
# Edge (32993239, 1801882912, 0) has time series data.
# Edge (29972525, 29977423, 0) has time series data.
# Edge (29977423, 6150580690, 0) has time series data.
# Edge (29972545, 3708603819, 0) has time series data.
# Edge (29972545, 29972549, 0) has time series data.
# Edge (29972575, 29972525, 0) has time series data.
# Edge (1801885465, 1801885466, 0) has time series data.
# Edge (29972655, 29972684, 0) has time series data.
# Edge (29972684, 32993241, 0) has time series data.
# Edge (32993241, 3465083213, 0) has time series data.
# Edge (32993241, 32993253, 0) has time series data.
# Edge (2720419870, 29973010, 0) has time series data.
# Edge (2720419870, 64856515, 0) has time series data.
# Edge (29973010, 29972684, 0) has time series data.
# Edge (6150580690, 5970912136, 0) has time series data.
# Edge (6150580690, 60207151, 0) has time series data.
# Edge (324154751, 2753877799, 0) has time series data.
# Edge (324154751, 310129156, 0) has time series data.
# Edge (29977599, 60114754, 0) has time series data.
# Edge (29977650, 3684837993, 0) has time series data.
# Edge (29977650, 29977655, 0) has time series data.
# Edge (1586264480, 29971886, 0) has time series data.
# Edge (1586264480, 1801887374, 0) has time series data.
# Edge (1801882912, 64856402, 0) has time series data.
# Edge (1801882912, 29972655, 0) has time series data.
# Edge (32993253, 76812647, 0) has time series data.
# Edge (32993253, 76812641, 0) has time series data.
# Edge (76812647, 76812631, 0) has time series data.
# Edge (76812647, 76812655, 0) has time series data.
# Edge (76812641, 32993258, 0) has time series data.
# Edge (32993258, 32994085, 0) has time series data.
# Edge (32994931, 76812690, 0) has time series data.
# Edge (32994931, 32994938, 0) has time series data.
# Edge (32994085, 76812861, 0) has time series data.
# Edge (32994085, 32994087, 0) has time series data.
# Edge (32993263, 32993269, 0) has time series data.
# Edge (32993269, 1590804211, 0) has time series data.
# Edge (1590804211, 76812468, 0) has time series data.
# Edge (1590804211, 1801882963, 0) has time series data.
# Edge (76812861, 76812859, 0) has time series data.
# Edge (76812861, 76812860, 0) has time series data.
# Edge (76812861, 32994087, 0) has time series data.
# Edge (32994087, 76812934, 0) has time series data.
# Edge (76812934, 32994091, 0) has time series data.
# Edge (76812934, 76812955, 0) has time series data.
# Edge (76813011, 32994098, 0) has time series data.
# Edge (32994105, 76813064, 0) has time series data.
# Edge (32994105, 309880622, 0) has time series data.
# Edge (76813064, 76813059, 0) has time series data.
# Edge (76813064, 309880622, 0) has time series data.
# Edge (32994492, 32994499, 0) has time series data.
# Edge (32994499, 76812992, 0) has time series data.
# Edge (32994499, 32994502, 0) has time series data.
# Edge (32994506, 76812893, 0) has time series data.
# Edge (32994506, 32994507, 0) has time series data.
# Edge (76812893, 32994507, 0) has time series data.
# Edge (76812893, 8313845543, 0) has time series data.
# Edge (32994507, 32994510, 0) has time series data.
# Edge (32994510, 76812860, 0) has time series data.
# Edge (32994510, 32994512, 0) has time series data.
# Edge (76812860, 1345581106, 0) has time series data.
# Edge (76812860, 76812861, 0) has time series data.
# Edge (76812860, 32994512, 0) has time series data.
# Edge (32994512, 32994514, 0) has time series data.
# Edge (32994514, 76812663, 0) has time series data.
# Edge (76812663, 1116043011, 0) has time series data.
# Edge (76812663, 32993263, 0) has time series data.
# Edge (32994923, 287098357, 0) has time series data.
# Edge (32994923, 8313842372, 0) has time series data.
# Edge (287098357, 287098286, 0) has time series data.
# Edge (287098357, 76812773, 0) has time series data.
# Edge (76812690, 8313842372, 0) has time series data.
# Edge (251740524, 251740519, 0) has time series data.
# Edge (251740472, 279839063, 0) has time series data.
# Edge (251740472, 32995547, 0) has time series data.
# Edge (1092034041, 1581576330, 0) has time series data.
# Edge (1092034041, 1087112892, 0) has time series data.
# Edge (967895142, 1346907178, 0) has time series data.
# Edge (4511732972, 278169570, 0) has time series data.
# Edge (2498378530, 2498378528, 0) has time series data.
# Edge (2931636338, 1322117687, 0) has time series data.
# Edge (60114760, 60114754, 0) has time series data.
# Edge (60114811, 2753877818, 0) has time series data.
# Edge (670636451, 2753877799, 0) has time series data.
# Edge (6382121618, 3682876327, 0) has time series data.
# Edge (6382121618, 1069286040, 0) has time series data.
# Edge (60207151, 29977443, 0) has time series data.
# Edge (63757773, 1668433853, 0) has time series data.
# Edge (63757773, 63757859, 0) has time series data.
# Edge (63757785, 63757788, 0) has time series data.
# Edge (1668433853, 63757773, 0) has time series data.
# Edge (63757859, 63757880, 0) has time series data.
# Edge (63757859, 63757773, 0) has time series data.
# Edge (63757859, 63757864, 0) has time series data.
# Edge (63757821, 63757844, 0) has time series data.
# Edge (63757821, 63757880, 0) has time series data.
# Edge (63757844, 63757821, 0) has time series data.
# Edge (63757880, 63757821, 0) has time series data.
# Edge (63757880, 63757859, 0) has time series data.
# Edge (63757880, 63757882, 0) has time series data.
# Edge (63757864, 63757859, 0) has time series data.
# Edge (63757882, 63757880, 0) has time series data.
# Edge (64856307, 64856440, 0) has time series data.
# Edge (64856307, 64856498, 0) has time series data.
# Edge (64856440, 64856307, 0) has time series data.
# Edge (64856440, 64856324, 0) has time series data.
# Edge (64856498, 64856307, 0) has time series data.
# Edge (64856498, 2720419873, 0) has time series data.
# Edge (64856352, 1116062160, 0) has time series data.
# Edge (1116062160, 1116062147, 0) has time series data.
# Edge (64856365, 64856352, 0) has time series data.
# Edge (64856365, 64856418, 0) has time series data.
# Edge (64856418, 64856390, 0) has time series data.
# Edge (64856418, 64856365, 0) has time series data.
# Edge (64856379, 64856383, 0) has time series data.
# Edge (64856379, 29972655, 0) has time series data.
# Edge (64856383, 64856390, 0) has time series data.
# Edge (64856383, 64856418, 0) has time series data.
# Edge (64856390, 64856402, 0) has time series data.
# Edge (2720419873, 29973010, 0) has time series data.
# Edge (2720419873, 2720419905, 0) has time series data.
# Edge (64856515, 2720419873, 0) has time series data.
# Edge (64856515, 64856498, 0) has time series data.
# Edge (6379898002, 64856515, 0) has time series data.
# Edge (6379898002, 2720419873, 0) has time series data.
# Edge (64919346, 64919351, 0) has time series data.
# Edge (64919351, 2498537068, 0) has time series data.
# Edge (76557324, 76557327, 0) has time series data.
# Edge (76557327, 76557336, 0) has time series data.
# Edge (76557330, 76557327, 0) has time series data.
# Edge (76812468, 2720419886, 0) has time series data.
# Edge (76812468, 64856538, 0) has time series data.
# Edge (76812590, 32993269, 0) has time series data.
# Edge (76812612, 76812623, 0) has time series data.
# Edge (76812623, 76812612, 0) has time series data.
# Edge (6238500492, 6238500491, 0) has time series data.
# Edge (76812631, 6238500491, 0) has time series data.
# Edge (6238500491, 76812647, 0) has time series data.
# Edge (6238500491, 76812641, 0) has time series data.
# Edge (76812655, 76812654, 0) has time series data.
# Edge (76812655, 76812651, 0) has time series data.
# Edge (76812657, 32993263, 0) has time series data.
# Edge (1116043011, 76812655, 0) has time series data.
# Edge (1116043011, 76812651, 0) has time series data.
# Edge (1161779438, 76812773, 0) has time series data.
# Edge (76812773, 287098357, 0) has time series data.
# Edge (76812773, 1161977473, 0) has time series data.
# Edge (1161977473, 76812773, 0) has time series data.
# Edge (76812793, 287098286, 0) has time series data.
# Edge (287098286, 287098357, 0) has time series data.
# Edge (287098286, 32994938, 0) has time series data.
# Edge (76812827, 1345581106, 0) has time series data.
# Edge (1345581106, 76812860, 0) has time series data.
# Edge (1345581106, 76812827, 0) has time series data.
# Edge (1345581106, 1345581102, 0) has time series data.
# Edge (76812859, 76812861, 0) has time series data.
# Edge (365291312, 364631109, 0) has time series data.
# Edge (365291312, 365291318, 0) has time series data.
# Edge (608608891, 1513022294, 0) has time series data.
# Edge (8313845543, 76812893, 0) has time series data.
# Edge (76812905, 8313845539, 0) has time series data.
# Edge (8313845539, 32994091, 0) has time series data.
# Edge (1513022294, 608608891, 0) has time series data.
# Edge (76812973, 670500878, 0) has time series data.
# Edge (76812973, 32994502, 0) has time series data.
# Edge (670500878, 76812986, 0) has time series data.
# Edge (670500878, 321365582, 0) has time series data.
# Edge (76813045, 321365582, 0) has time series data.
# Edge (76813045, 32994098, 0) has time series data.
# Edge (321365582, 76812986, 0) has time series data.
# Edge (321365582, 76813045, 0) has time series data.
# Edge (76813059, 2588150629, 0) has time series data.
# Edge (76813059, 76813064, 0) has time series data.
# Edge (76813059, 32994492, 0) has time series data.
# Edge (2588150629, 76813059, 0) has time series data.
# Edge (563290978, 76813064, 0) has time series data.
# Edge (76832263, 76832267, 0) has time series data.
# Edge (76832267, 76832270, 0) has time series data.
# Edge (76832270, 76832267, 0) has time series data.
# Edge (76832297, 910868008, 0) has time series data.
# Edge (76832331, 1032373491, 0) has time series data.
# Edge (1032373491, 76832340, 0) has time series data.
# Edge (76832340, 1032373240, 0) has time series data.
# Edge (76832340, 1032373491, 0) has time series data.
# Edge (1032373240, 76832340, 0) has time series data.
# Edge (911620005, 280821804, 0) has time series data.
# Edge (911620005, 128653314, 0) has time series data.
# Edge (128653314, 280821804, 0) has time series data.
# Edge (280821804, 911620005, 0) has time series data.
# Edge (280821804, 128653314, 0) has time series data.
# Edge (251740030, 279838048, 0) has time series data.
# Edge (279838048, 279837845, 0) has time series data.
# Edge (279838048, 32995528, 0) has time series data.
# Edge (251740302, 251740307, 0) has time series data.
# Edge (251740394, 279837753, 0) has time series data.
# Edge (251740394, 251740302, 0) has time series data.
# Edge (252109019, 316289422, 0) has time series data.
# Edge (316289422, 252109019, 0) has time series data.
# Edge (463301508, 252111181, 0) has time series data.
# Edge (255381851, 252111181, 0) has time series data.
# Edge (255381851, 255381852, 0) has time series data.
# Edge (670647166, 1307207926, 0) has time series data.
# Edge (4935247846, 252109019, 0) has time series data.
# Edge (255381858, 316289421, 0) has time series data.
# Edge (316289421, 670647158, 0) has time series data.
# Edge (466433786, 316289421, 0) has time series data.
# Edge (256187426, 1317322523, 0) has time series data.
# Edge (1317322523, 256187426, 0) has time series data.
# Edge (256187592, 2588150626, 0) has time series data.
# Edge (256187592, 1296214266, 0) has time series data.
# Edge (1581711014, 256188300, 0) has time series data.
# Edge (2588150626, 256187592, 0) has time series data.
# Edge (670500010, 2588150629, 0) has time series data.
# Edge (256188300, 1581711014, 0) has time series data.
# Edge (8389512724, 5227891652, 0) has time series data.
# Edge (8389512724, 8389512723, 0) has time series data.
# Edge (256188475, 1514004918, 0) has time series data.
# Edge (1514004918, 256188475, 0) has time series data.
# Edge (1514004918, 1231220780, 0) has time series data.
# Edge (9665956856, 9665956855, 0) has time series data.
# Edge (9665956856, 256188481, 0) has time series data.
# Edge (256188481, 277456096, 0) has time series data.
# Edge (256188481, 9665956856, 0) has time series data.
# Edge (256188674, 364630642, 0) has time series data.
# Edge (364630642, 364631109, 0) has time series data.
# Edge (256188677, 365591018, 0) has time series data.
# Edge (365591018, 256188677, 0) has time series data.
# Edge (277454364, 277455911, 0) has time series data.
# Edge (9531924773, 9531924772, 0) has time series data.
# Edge (9531924773, 9531924774, 0) has time series data.
# Edge (287100150, 1166267805, 0) has time series data.
# Edge (6285219099, 256188481, 0) has time series data.
# Edge (277456147, 1091610884, 0) has time series data.
# Edge (1091610884, 277456147, 0) has time series data.
# Edge (1501110654, 1501110706, 0) has time series data.
# Edge (1501110706, 1501110654, 0) has time series data.
# Edge (1575304676, 251740302, 0) has time series data.
# Edge (279837755, 670674060, 0) has time series data.
# Edge (670674060, 670674059, 0) has time series data.
# Edge (670674060, 279837754, 0) has time series data.
# Edge (279837848, 670674059, 0) has time series data.
# Edge (670674059, 670674060, 0) has time series data.
# Edge (670674059, 279837847, 0) has time series data.
# Edge (279838742, 279839182, 0) has time series data.
# Edge (279838742, 251740451, 0) has time series data.
# Edge (279839182, 279839181, 0) has time series data.
# Edge (279839182, 279840002, 0) has time series data.
# Edge (279838939, 279840301, 0) has time series data.
# Edge (279840301, 279840002, 0) has time series data.
# Edge (4511297422, 32995547, 0) has time series data.
# Edge (279839181, 251740519, 0) has time series data.
# Edge (279840002, 279839181, 0) has time series data.
# Edge (279840002, 279840301, 0) has time series data.
# Edge (282744001, 1119279418, 0) has time series data.
# Edge (348151689, 316478823, 0) has time series data.
# Edge (1166267805, 1166267877, 0) has time series data.
# Edge (1166267805, 287100150, 0) has time series data.
# Edge (2281730733, 568477034, 0) has time series data.
# Edge (292584820, 361443766, 0) has time series data.
# Edge (361443766, 292584820, 0) has time series data.
# Edge (292585024, 1167113660, 0) has time series data.
# Edge (292585024, 292585024, 0) has time series data.
# Edge (1167113660, 292585025, 0) has time series data.
# Edge (1167113660, 292585024, 0) has time series data.
# Edge (1167113660, 359582981, 0) has time series data.
# Edge (292585025, 1167113660, 0) has time series data.
# Edge (292585025, 359582973, 0) has time series data.
# Edge (292585025, 359580430, 0) has time series data.
# Edge (359582973, 292585025, 0) has time series data.
# Edge (359582973, 359582978, 0) has time series data.
# Edge (359582973, 292585026, 0) has time series data.
# Edge (359580430, 292585025, 0) has time series data.
# Edge (292585026, 304065596, 0) has time series data.
# Edge (292585026, 359582973, 0) has time series data.
# Edge (357211857, 357212189, 0) has time series data.
# Edge (1231339742, 357208393, 0) has time series data.
# Edge (296853492, 1166267877, 0) has time series data.
# Edge (296853492, 1166267805, 0) has time series data.
# Edge (1166267877, 296853492, 0) has time series data.
# Edge (1166267877, 364386841, 0) has time series data.
# Edge (11246159016, 1127737173, 0) has time series data.
# Edge (1127736043, 1127736752, 0) has time series data.
# Edge (304065583, 304065584, 0) has time series data.
# Edge (304065583, 361443763, 0) has time series data.
# Edge (304065583, 361443774, 0) has time series data.
# Edge (8219875349, 2799012018, 0) has time series data.
# Edge (307404661, 568477034, 0) has time series data.
# Edge (568477034, 417705062, 0) has time series data.
# Edge (568477034, 2281730733, 0) has time series data.
# Edge (568477034, 307404661, 0) has time series data.
# Edge (308821032, 76813059, 0) has time series data.
# Edge (308821032, 32994492, 0) has time series data.
# Edge (313844702, 1037679107, 0) has time series data.
# Edge (1037679107, 1036556213, 0) has time series data.
# Edge (314994879, 2720419875, 0) has time series data.
# Edge (314994879, 314995133, 0) has time series data.
# Edge (2720419875, 314995121, 0) has time series data.
# Edge (2720419875, 2720419880, 0) has time series data.
# Edge (314995133, 359942378, 0) has time series data.
# Edge (314995133, 314994879, 0) has time series data.
# Edge (314995121, 2720419880, 0) has time series data.
# Edge (314995121, 2752315571, 0) has time series data.
# Edge (2720419880, 908762000, 0) has time series data.
# Edge (2720419880, 314994879, 0) has time series data.
# Edge (2752315571, 314995121, 0) has time series data.
# Edge (359942378, 359942382, 0) has time series data.
# Edge (316298224, 1307207926, 0) has time series data.
# Edge (1307207926, 316298224, 0) has time series data.
# Edge (316478823, 1119147885, 0) has time series data.
# Edge (316478823, 348151689, 0) has time series data.
# Edge (1119147885, 316478823, 0) has time series data.
# Edge (1119147885, 1119147899, 0) has time series data.
# Edge (2753877799, 670636445, 0) has time series data.
# Edge (357208393, 359164152, 0) has time series data.
# Edge (359164152, 357208393, 0) has time series data.
# Edge (359582978, 359582981, 0) has time series data.
# Edge (359582978, 359582973, 0) has time series data.
# Edge (1166335400, 359582978, 0) has time series data.
# Edge (359582981, 1167113660, 0) has time series data.
# Edge (359582981, 1167113659, 0) has time series data.
# Edge (359582981, 359582978, 0) has time series data.
# Edge (1167113659, 359582981, 0) has time series data.
# Edge (1345222737, 1345222697, 0) has time series data.
# Edge (359942382, 359942384, 0) has time series data.
# Edge (359942382, 359942378, 0) has time series data.
# Edge (359942382, 359942391, 0) has time series data.
# Edge (359942403, 359942391, 0) has time series data.
# Edge (359942384, 359942382, 0) has time series data.
# Edge (359942384, 359942386, 0) has time series data.
# Edge (359942391, 359942382, 0) has time series data.
# Edge (359942386, 359942387, 0) has time series data.
# Edge (359942386, 359942384, 0) has time series data.
# Edge (359942387, 359942386, 0) has time series data.
# Edge (1607008333, 359942386, 0) has time series data.
# Edge (359942394, 359942391, 0) has time series data.
# Edge (361443765, 361444213, 0) has time series data.
# Edge (361443776, 361443777, 0) has time series data.
# Edge (361444213, 361443765, 0) has time series data.
# Edge (361443777, 361443776, 0) has time series data.
# Edge (361443778, 361443785, 0) has time series data.
# Edge (361443785, 361443778, 0) has time series data.
# Edge (364386841, 1166267877, 0) has time series data.
# Edge (364386841, 364386843, 0) has time series data.
# Edge (364386843, 364386841, 0) has time series data.
# Edge (364631109, 365291312, 0) has time series data.
# Edge (365294704, 365291318, 0) has time series data.
# Edge (365294704, 365294710, 0) has time series data.
# Edge (365291318, 365291312, 0) has time series data.
# Edge (365291318, 365294704, 0) has time series data.
# Edge (6285218968, 365291318, 0) has time series data.
# Edge (365294710, 365294704, 0) has time series data.
# Edge (391737143, 472370764, 0) has time series data.
# Edge (472370764, 391737143, 0) has time series data.
# Edge (417705062, 568477034, 0) has time series data.
# Edge (418767944, 3754535427, 0) has time series data.
# Edge (3754535427, 1233588453, 0) has time series data.
# Edge (2626887713, 1021312669, 0) has time series data.
# Edge (3682876327, 6382121618, 0) has time series data.
# Edge (1127674829, 2710837340, 0) has time series data.
# Edge (608588085, 1127736520, 0) has time series data.
# Edge (1127736520, 608588085, 0) has time series data.
# Edge (1231220780, 1514004918, 0) has time series data.
# Edge (670636445, 60114811, 0) has time series data.
# Edge (670636445, 2753877818, 0) has time series data.
# Edge (1128077353, 814649533, 0) has time series data.
# Edge (814649533, 1128077353, 0) has time series data.
# Edge (6583018305, 1127737173, 0) has time series data.
# Edge (860553149, 1025596040, 0) has time series data.
# Edge (860553149, 3373514923, 0) has time series data.
# Edge (1025596040, 860553149, 0) has time series data.
# Edge (3373514923, 860553149, 0) has time series data.
# Edge (908762000, 2720419880, 0) has time series data.
# Edge (924528791, 924528845, 0) has time series data.
# Edge (924528845, 924528792, 0) has time series data.
# Edge (924528845, 924528791, 0) has time series data.
# Edge (924528845, 924528813, 0) has time series data.
# Edge (924528792, 924528845, 0) has time series data.
# Edge (924528813, 924528794, 0) has time series data.
# Edge (924528813, 924528845, 0) has time series data.
# Edge (1346907178, 967895142, 0) has time series data.
# Edge (5808889075, 60207151, 0) has time series data.
# Edge (1028767107, 1028769743, 0) has time series data.
# Edge (1028766851, 1028766868, 0) has time series data.
# Edge (1028766868, 1028766851, 0) has time series data.
# Edge (1028767611, 1028766868, 0) has time series data.
# Edge (1028770038, 1028767550, 0) has time series data.
# Edge (1028769743, 1028767107, 0) has time series data.
# Edge (1028767550, 1028770038, 0) has time series data.
# Edge (1032373665, 1032374067, 0) has time series data.
# Edge (1032373665, 1032373712, 0) has time series data.
# Edge (1032374067, 1032373665, 0) has time series data.
# Edge (1032374067, 1032373888, 0) has time series data.
# Edge (1032373679, 1032374087, 0) has time series data.
# Edge (1032374087, 1032373679, 0) has time series data.
# Edge (1032373888, 1032374067, 0) has time series data.
# Edge (1034360290, 1036464956, 0) has time series data.
# Edge (1034360290, 1034360335, 0) has time series data.
# Edge (1034360290, 1036464990, 0) has time series data.
# Edge (1036464956, 1034360290, 0) has time series data.
# Edge (1036464990, 1034360290, 0) has time series data.
# Edge (1036464990, 1036465423, 0) has time series data.
# Edge (1036398569, 1036398856, 0) has time series data.
# Edge (1036464748, 1036464990, 0) has time series data.
# Edge (1036556185, 1037679107, 0) has time series data.
# Edge (1036556117, 1036556197, 0) has time series data.
# Edge (2404076127, 9458548734, 0) has time series data.
# Edge (1069286040, 9458548734, 0) has time series data.
# Edge (1069286040, 6382121618, 0) has time series data.
# Edge (9458548734, 1069286040, 0) has time series data.
# Edge (1091343330, 1091343346, 0) has time series data.
# Edge (1091343330, 10203206710, 0) has time series data.
# Edge (1091343346, 1091343330, 0) has time series data.
# Edge (1126296974, 1126297109, 0) has time series data.
# Edge (3468114004, 1153165839, 0) has time series data.
# Edge (4511297276, 4511297277, 0) has time series data.
# Edge (1116062147, 64856324, 0) has time series data.
# Edge (1116062147, 64856440, 0) has time series data.
# Edge (1119147899, 1119147885, 0) has time series data.
# Edge (1119147939, 1119279418, 0) has time series data.
# Edge (1119279465, 1119279418, 0) has time series data.
# Edge (1126297109, 1126296974, 0) has time series data.
# Edge (2710837340, 1127674829, 0) has time series data.
# Edge (1127675057, 5696276111, 0) has time series data.
# Edge (1127736710, 1127735850, 0) has time series data.
# Edge (1127735850, 1127736710, 0) has time series data.
# Edge (1127737173, 6583018305, 0) has time series data.
# Edge (1127735886, 1127736088, 0) has time series data.
# Edge (4728953870, 837323316, 0) has time series data.
# Edge (1153165763, 1153164240, 0) has time series data.
# Edge (1153165839, 1153164044, 0) has time series data.
# Edge (1540799787, 1540799794, 0) has time series data.
# Edge (1233588453, 3754535427, 0) has time series data.
# Edge (1262085884, 3902399649, 0) has time series data.
# Edge (3902399652, 4688584461, 0) has time series data.
# Edge (1319601091, 1319601172, 0) has time series data.
# Edge (1322117826, 29977454, 0) has time series data.
# Edge (1345222664, 1345222697, 0) has time series data.
# Edge (1345222697, 1345222664, 0) has time series data.
# Edge (1345222697, 1345222737, 0) has time series data.
# Edge (1345222697, 1345222718, 0) has time series data.
# Edge (1345222718, 1345222697, 0) has time series data.
# Edge (1345581102, 1345581106, 0) has time series data.
# Edge (1392063315, 29551197, 0) has time series data.
# Edge (1415036542, 1667019075, 0) has time series data.
# Edge (1667019075, 1415036542, 0) has time series data.
# Edge (9531924772, 9531924774, 0) has time series data.
# Edge (1514004916, 1514004918, 0) has time series data.
# Edge (1540799794, 1540799787, 0) has time series data.
# Edge (1578609274, 1578609266, 0) has time series data.
# Edge (1578609268, 1578609284, 0) has time series data.
# Edge (1578609284, 1578609268, 0) has time series data.
# Edge (1581576332, 1087112892, 0) has time series data.
# Edge (1801887374, 29972545, 0) has time series data.
# Edge (1801887374, 32993223, 0) has time series data.
# Edge (1801882963, 1116062160, 0) has time series data.
# Edge (1801882963, 29972640, 0) has time series data.
# Edge (1801887371, 29972577, 0) has time series data.
# Edge (1801887371, 29972525, 0) has time series data.
# Edge (3358655196, 3358643374, 0) has time series data.
# Edge (2720419905, 2720419886, 0) has time series data.
# Edge (2720419905, 64856517, 0) has time series data.
# Edge (2933412567, 2933412285, 0) has time series data.
# Edge (3358643374, 29972575, 0) has time series data.
# Edge (3468114003, 1153165839, 0) has time series data.
# Edge (3468114003, 3468114004, 0) has time series data.
# Edge (11993463069, 3358655194, 0) has time series data.
# Edge (4511297277, 4511297278, 0) has time series data.
# Edge (4728954544, 837323316, 0) has time series data.
# Edge (4728954544, 4728953870, 0) has time series data.
# Edge (6447435305, 6447435299, 0) has time series data.
# Edge (5227891652, 8389512724, 0) has time series data.
# Edge (5785014006, 29977655, 0) has time series data.
# Edge (6447435293, 6447435294, 0) has time series data.
# Edge (6447435299, 6447435305, 0) has time series data.
# Edge (9665956855, 256188475, 0) has time series data.
#
# Total edges in G_proj: 31470
# Edges with missing time series data: 30987
# Edges with time series data: 483

# %%
len(grouped_dataframes.keys())
# Out:
# 485

# %%
import math
import time
import pandas as pd

# Function to calculate Euclidean distance between two points
def euclidean_distance(x1, y1, x2, y2):
    return math.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2)

# Initialize progress tracking
total_dataframes = len(grouped_dataframes)
start_time = time.time()
x = 5  # Print status every x DataFrames processed
distance_threshold = 1000  # Only assign if edge is within this distance

# Ensure 'time_series_data' column in edges_proj can store complex data
edges_proj['time_series_data'] = pd.Series([None] * len(edges_proj), dtype="object")

# Iterate over each grouped DataFrame in `grouped_dataframes`
for df_index, (key, df) in enumerate(grouped_dataframes.items(), start=1):
    vej_id, df_x, df_y = key

    # List to store edges and distances
    edge_distances = []

    # Loop over all edges in `edges_proj` and calculate distances
    for edge_index, edge_data in edges_proj.iterrows():
        edge_geometry = edge_data['geometry']
        midpoint_index = len(edge_geometry.coords.xy[0]) // 2
        edge_x = edge_geometry.coords.xy[0][midpoint_index]
        edge_y = edge_geometry.coords.xy[1][midpoint_index]
        
        # Calculate distance from edge to DataFrame's x, y
        distance = euclidean_distance(edge_x, edge_y, df_x, df_y)

        # Track each edge with its distance, if within the threshold
        if distance <= distance_threshold:
            edge_distances.append((edge_index, distance))

    # Sort edges by distance in ascending order
    edge_distances.sort(key=lambda x: x[1])

    # Try to assign data to the closest unoccupied edge within the threshold
    assigned = False
    for edge_index, distance in edge_distances:
        # Check if the edge's `time_series_data` is empty
        time_series_content = edges_proj.at[edge_index, 'time_series_data']
        if isinstance(time_series_content, float):
            if pd.isna(time_series_content):
                time_series_data = list(zip(df.index.to_pydatetime(), df['traffic_flow'].tolist()))
                edges_proj.at[edge_index, 'time_series_data'] = time_series_data
                G_proj[edge_index[0]][edge_index[1]][0]['time_series_data'] = time_series_data
                print(f"Assigned data to edge {edge_index} for DataFrame {df_index}/{total_dataframes}")
                assigned = True
                break
        elif time_series_content is None or (isinstance(time_series_content, list) and len(time_series_content) == 0):
            time_series_data = list(zip(df.index.to_pydatetime(), df['traffic_flow'].tolist()))
            edges_proj.at[edge_index, 'time_series_data'] = time_series_data
            G_proj[edge_index[0]][edge_index[1]][0]['time_series_data'] = time_series_data
            print(f"Assigned data to edge {edge_index} for DataFrame {df_index}/{total_dataframes}")
            assigned = True
            break  # Stop once data is assigned

    # If no unoccupied edge is found within the threshold, log the result
    if not assigned:
        print(f"No suitable unoccupied edge found within threshold for DataFrame {df_index}/{total_dataframes}")

    # Progress update every x DataFrames
    if df_index % x == 0:
        avg_time_per_df = (time.time() - start_time) / df_index
        estimated_total_time = avg_time_per_df * total_dataframes
        remaining_time = estimated_total_time - (time.time() - start_time)
        print(f"Processed {df_index}/{total_dataframes} DataFrames. Remaining time: {remaining_time / 60:.2f} minutes")

# Final summary
print("\nProcessing complete.")
print(f"Total DataFrames processed: {total_dataframes}")

# Inspect a few entries to confirm data assignment
print("\nVerification of assigned data:")
print(edges_proj['time_series_data'].dropna().head())
print("\nEdges with no data assigned:", edges_proj[edges_proj['time_series_data'].isna()])
#
# Out:
# Assigned data to edge (1153165839, 1153164044, 0) for DataFrame 1/485
# Assigned data to edge (1126296974, 1126297109, 0) for DataFrame 2/485
# Assigned data to edge (1126297109, 1126296974, 0) for DataFrame 3/485
# Assigned data to edge (1153165763, 1153164240, 0) for DataFrame 4/485
# Assigned data to edge (3468114003, 1153165839, 0) for DataFrame 5/485
# Processed 5/485 DataFrames. Remaining time: 15.72 minutes
# Assigned data to edge (3468114004, 1153165839, 0) for DataFrame 6/485
# Assigned data to edge (3468114003, 3468114004, 0) for DataFrame 7/485
# Assigned data to edge (911620005, 280821804, 0) for DataFrame 8/485
# Assigned data to edge (280821804, 911620005, 0) for DataFrame 9/485
# Assigned data to edge (128653314, 280821804, 0) for DataFrame 10/485
# Processed 10/485 DataFrames. Remaining time: 15.54 minutes
# Assigned data to edge (280821804, 128653314, 0) for DataFrame 11/485
# Assigned data to edge (911620005, 128653314, 0) for DataFrame 12/485
# Assigned data to edge (1415036542, 1667019075, 0) for DataFrame 13/485
# Assigned data to edge (1667019075, 1415036542, 0) for DataFrame 14/485
# Assigned data to edge (2933412567, 2933412285, 0) for DataFrame 15/485
# Processed 15/485 DataFrames. Remaining time: 15.42 minutes
# Assigned data to edge (324154751, 2753877799, 0) for DataFrame 16/485
# Assigned data to edge (60114760, 60114754, 0) for DataFrame 17/485
# Assigned data to edge (670636451, 2753877799, 0) for DataFrame 18/485
# Assigned data to edge (2753877799, 670636445, 0) for DataFrame 19/485
# Assigned data to edge (670636445, 60114811, 0) for DataFrame 20/485
# Processed 20/485 DataFrames. Remaining time: 15.26 minutes
# Assigned data to edge (670636445, 2753877818, 0) for DataFrame 21/485
# Assigned data to edge (60114811, 2753877818, 0) for DataFrame 22/485
# Assigned data to edge (1501110654, 1501110706, 0) for DataFrame 23/485
# Assigned data to edge (1501110706, 1501110654, 0) for DataFrame 24/485
# Assigned data to edge (6447435293, 6447435294, 0) for DataFrame 25/485
# Processed 25/485 DataFrames. Remaining time: 15.08 minutes
# Assigned data to edge (60207151, 29977443, 0) for DataFrame 26/485
# Assigned data to edge (1028767107, 1028769743, 0) for DataFrame 27/485
# Assigned data to edge (1028769743, 1028767107, 0) for DataFrame 28/485
# Assigned data to edge (29977650, 29977655, 0) for DataFrame 29/485
# Assigned data to edge (1028766851, 1028766868, 0) for DataFrame 30/485
# Processed 30/485 DataFrames. Remaining time: 14.93 minutes
# Assigned data to edge (1028766868, 1028766851, 0) for DataFrame 31/485
# Assigned data to edge (5785014006, 29977655, 0) for DataFrame 32/485
# Assigned data to edge (5808889075, 60207151, 0) for DataFrame 33/485
# Assigned data to edge (6150580690, 60207151, 0) for DataFrame 34/485
# Assigned data to edge (1028770038, 1028767550, 0) for DataFrame 35/485
# Processed 35/485 DataFrames. Remaining time: 14.77 minutes
# Assigned data to edge (29977423, 6150580690, 0) for DataFrame 36/485
# Assigned data to edge (1036464990, 1036465423, 0) for DataFrame 37/485
# Assigned data to edge (1034360290, 1036464956, 0) for DataFrame 38/485
# Assigned data to edge (1036464956, 1034360290, 0) for DataFrame 39/485
# Assigned data to edge (1036464990, 1034360290, 0) for DataFrame 40/485
# Processed 40/485 DataFrames. Remaining time: 14.59 minutes
# Assigned data to edge (1036556185, 1037679107, 0) for DataFrame 41/485
# Assigned data to edge (1037679107, 1036556213, 0) for DataFrame 42/485
# Assigned data to edge (313844702, 1037679107, 0) for DataFrame 43/485
# Assigned data to edge (1586264480, 1801887374, 0) for DataFrame 44/485
# Assigned data to edge (29972525, 29977423, 0) for DataFrame 45/485
# Processed 45/485 DataFrames. Remaining time: 14.44 minutes
# Assigned data to edge (1036398569, 1036398856, 0) for DataFrame 46/485
# Assigned data to edge (1578609268, 1578609284, 0) for DataFrame 47/485
# Assigned data to edge (1578609284, 1578609268, 0) for DataFrame 48/485
# Assigned data to edge (1578609274, 1578609266, 0) for DataFrame 49/485
# Assigned data to edge (1801887371, 29972525, 0) for DataFrame 50/485
# Processed 50/485 DataFrames. Remaining time: 14.29 minutes
# Assigned data to edge (1801887374, 29972545, 0) for DataFrame 51/485
# Assigned data to edge (1801887374, 32993223, 0) for DataFrame 52/485
# Assigned data to edge (3358643374, 29972575, 0) for DataFrame 53/485
# Assigned data to edge (29972575, 29972525, 0) for DataFrame 54/485
# Assigned data to edge (3902399652, 4688584461, 0) for DataFrame 55/485
# Processed 55/485 DataFrames. Remaining time: 14.14 minutes
# Assigned data to edge (1801887371, 29972577, 0) for DataFrame 56/485
# Assigned data to edge (76557327, 76557336, 0) for DataFrame 57/485
# Assigned data to edge (76557324, 76557327, 0) for DataFrame 58/485
# Assigned data to edge (76557330, 76557327, 0) for DataFrame 59/485
# Assigned data to edge (391737143, 472370764, 0) for DataFrame 60/485
# Processed 60/485 DataFrames. Remaining time: 13.97 minutes
# Assigned data to edge (472370764, 391737143, 0) for DataFrame 61/485
# Assigned data to edge (1032374067, 1032373888, 0) for DataFrame 62/485
# Assigned data to edge (1032373888, 1032374067, 0) for DataFrame 63/485
# Assigned data to edge (1032373665, 1032374067, 0) for DataFrame 64/485
# Assigned data to edge (1032373665, 1032373712, 0) for DataFrame 65/485
# Processed 65/485 DataFrames. Remaining time: 13.81 minutes
# Assigned data to edge (1032374067, 1032373665, 0) for DataFrame 66/485
# Assigned data to edge (28390935, 323187714, 0) for DataFrame 67/485
# Assigned data to edge (29551197, 1801885466, 0) for DataFrame 68/485
# Assigned data to edge (1801885466, 28390935, 0) for DataFrame 69/485
# Assigned data to edge (323187714, 29551197, 0) for DataFrame 70/485
# Processed 70/485 DataFrames. Remaining time: 13.65 minutes
# Assigned data to edge (29551197, 32993239, 0) for DataFrame 71/485
# Assigned data to edge (1801885465, 1801885466, 0) for DataFrame 72/485
# Assigned data to edge (1032373679, 1032374087, 0) for DataFrame 73/485
# Assigned data to edge (76832267, 76832270, 0) for DataFrame 74/485
# Assigned data to edge (76832263, 76832267, 0) for DataFrame 75/485
# Processed 75/485 DataFrames. Remaining time: 13.49 minutes
# Assigned data to edge (76832270, 76832267, 0) for DataFrame 76/485
# Assigned data to edge (76832340, 1032373491, 0) for DataFrame 77/485
# Assigned data to edge (1032373491, 76832340, 0) for DataFrame 78/485
# Assigned data to edge (76832331, 1032373491, 0) for DataFrame 79/485
# Assigned data to edge (32993239, 1801882912, 0) for DataFrame 80/485
# Processed 80/485 DataFrames. Remaining time: 13.32 minutes
# Assigned data to edge (76832340, 1032373240, 0) for DataFrame 81/485
# Assigned data to edge (1032373240, 76832340, 0) for DataFrame 82/485
# Assigned data to edge (76832297, 910868008, 0) for DataFrame 83/485
# Assigned data to edge (64856365, 64856418, 0) for DataFrame 84/485
# Assigned data to edge (64856418, 64856365, 0) for DataFrame 85/485
# Processed 85/485 DataFrames. Remaining time: 13.16 minutes
# Assigned data to edge (64856418, 64856390, 0) for DataFrame 86/485
# Assigned data to edge (64856383, 64856418, 0) for DataFrame 87/485
# Assigned data to edge (64856383, 64856390, 0) for DataFrame 88/485
# Assigned data to edge (64856390, 64856402, 0) for DataFrame 89/485
# Assigned data to edge (64856379, 64856383, 0) for DataFrame 90/485
# Processed 90/485 DataFrames. Remaining time: 13.00 minutes
# Assigned data to edge (1801882912, 29972655, 0) for DataFrame 91/485
# Assigned data to edge (1801882963, 1116062160, 0) for DataFrame 92/485
# Assigned data to edge (1801882963, 29972640, 0) for DataFrame 93/485
# Assigned data to edge (64856352, 1116062160, 0) for DataFrame 94/485
# Assigned data to edge (1116062160, 1116062147, 0) for DataFrame 95/485
# Processed 95/485 DataFrames. Remaining time: 12.83 minutes
# Assigned data to edge (1116062147, 64856440, 0) for DataFrame 96/485
# Assigned data to edge (64856379, 29972655, 0) for DataFrame 97/485
# Assigned data to edge (1590804211, 1801882963, 0) for DataFrame 98/485
# Assigned data to edge (29972655, 29972684, 0) for DataFrame 99/485
# Assigned data to edge (359942386, 359942387, 0) for DataFrame 100/485
# Processed 100/485 DataFrames. Remaining time: 12.67 minutes
# Assigned data to edge (314994879, 2720419875, 0) for DataFrame 101/485
# Assigned data to edge (314995133, 314994879, 0) for DataFrame 102/485
# Assigned data to edge (314994879, 314995133, 0) for DataFrame 103/485
# Assigned data to edge (924528792, 924528845, 0) for DataFrame 104/485
# Assigned data to edge (924528845, 924528792, 0) for DataFrame 105/485
# Processed 105/485 DataFrames. Remaining time: 12.51 minutes
# Assigned data to edge (29972684, 32993241, 0) for DataFrame 106/485
# Assigned data to edge (924528791, 924528845, 0) for DataFrame 107/485
# Assigned data to edge (924528845, 924528791, 0) for DataFrame 108/485
# Assigned data to edge (32993269, 1590804211, 0) for DataFrame 109/485
# Assigned data to edge (1345222697, 1345222664, 0) for DataFrame 110/485
# Processed 110/485 DataFrames. Remaining time: 12.34 minutes
# Assigned data to edge (1345222697, 1345222718, 0) for DataFrame 111/485
# Assigned data to edge (1345222718, 1345222697, 0) for DataFrame 112/485
# Assigned data to edge (1345222664, 1345222697, 0) for DataFrame 113/485
# Assigned data to edge (1345222737, 1345222697, 0) for DataFrame 114/485
# Assigned data to edge (924528813, 924528794, 0) for DataFrame 115/485
# Processed 115/485 DataFrames. Remaining time: 12.17 minutes
# Assigned data to edge (1345222697, 1345222737, 0) for DataFrame 116/485
# Assigned data to edge (32993263, 32993269, 0) for DataFrame 117/485
# Assigned data to edge (32993241, 32993253, 0) for DataFrame 118/485
# Assigned data to edge (32993241, 3465083213, 0) for DataFrame 119/485
# Assigned data to edge (76812612, 76812623, 0) for DataFrame 120/485
# Processed 120/485 DataFrames. Remaining time: 12.01 minutes
# Assigned data to edge (76812623, 76812612, 0) for DataFrame 121/485
# Assigned data to edge (292585025, 359580430, 0) for DataFrame 122/485
# Assigned data to edge (359580430, 292585025, 0) for DataFrame 123/485
# Assigned data to edge (292585024, 292585024, 0) for DataFrame 124/485
# Assigned data to edge (292585024, 292585024, 1) for DataFrame 125/485
# Processed 125/485 DataFrames. Remaining time: 11.85 minutes
# Assigned data to edge (924528813, 924528845, 0) for DataFrame 126/485
# Assigned data to edge (314995121, 2752315571, 0) for DataFrame 127/485
# Assigned data to edge (2752315571, 314995121, 0) for DataFrame 128/485
# Assigned data to edge (924528845, 924528813, 0) for DataFrame 129/485
# Assigned data to edge (292585026, 304065596, 0) for DataFrame 130/485
# Processed 130/485 DataFrames. Remaining time: 11.68 minutes
# Assigned data to edge (76812590, 32993269, 0) for DataFrame 131/485
# Assigned data to edge (357211857, 357212189, 0) for DataFrame 132/485
# Assigned data to edge (1167113660, 292585024, 0) for DataFrame 133/485
# Assigned data to edge (361443765, 361444213, 0) for DataFrame 134/485
# Assigned data to edge (361444213, 361443765, 0) for DataFrame 135/485
# Processed 135/485 DataFrames. Remaining time: 11.52 minutes
# Assigned data to edge (292585024, 1167113660, 0) for DataFrame 136/485
# Assigned data to edge (292585025, 1167113660, 0) for DataFrame 137/485
# Assigned data to edge (359582981, 1167113660, 0) for DataFrame 138/485
# Assigned data to edge (359582981, 1167113659, 0) for DataFrame 139/485
# Assigned data to edge (1167113659, 359582981, 0) for DataFrame 140/485
# Processed 140/485 DataFrames. Remaining time: 11.35 minutes
# Assigned data to edge (1167113660, 292585025, 0) for DataFrame 141/485
# Assigned data to edge (359582973, 292585025, 0) for DataFrame 142/485
# Assigned data to edge (1167113660, 359582981, 0) for DataFrame 143/485
# Assigned data to edge (292584820, 361443766, 0) for DataFrame 144/485
# Assigned data to edge (361443766, 292584820, 0) for DataFrame 145/485
# Processed 145/485 DataFrames. Remaining time: 11.19 minutes
# Assigned data to edge (359582978, 359582981, 0) for DataFrame 146/485
# Assigned data to edge (292585025, 359582973, 0) for DataFrame 147/485
# Assigned data to edge (361443776, 361443777, 0) for DataFrame 148/485
# Assigned data to edge (361443777, 361443776, 0) for DataFrame 149/485
# Assigned data to edge (361443778, 361443785, 0) for DataFrame 150/485
# Processed 150/485 DataFrames. Remaining time: 11.02 minutes
# Assigned data to edge (361443785, 361443778, 0) for DataFrame 151/485
# Assigned data to edge (76812663, 32993263, 0) for DataFrame 152/485
# Assigned data to edge (76812657, 32993263, 0) for DataFrame 153/485
# Assigned data to edge (304065583, 304065584, 0) for DataFrame 154/485
# Assigned data to edge (304065583, 361443774, 0) for DataFrame 155/485
# Processed 155/485 DataFrames. Remaining time: 10.85 minutes
# Assigned data to edge (32993253, 76812641, 0) for DataFrame 156/485
# Assigned data to edge (6238500491, 76812641, 0) for DataFrame 157/485
# Assigned data to edge (32993253, 76812647, 0) for DataFrame 158/485
# Assigned data to edge (1116043011, 76812655, 0) for DataFrame 159/485
# Assigned data to edge (76812663, 1116043011, 0) for DataFrame 160/485
# Processed 160/485 DataFrames. Remaining time: 10.69 minutes
# Assigned data to edge (1116043011, 76812651, 0) for DataFrame 161/485
# Assigned data to edge (76812655, 76812654, 0) for DataFrame 162/485
# Assigned data to edge (76812647, 76812655, 0) for DataFrame 163/485
# Assigned data to edge (6238500491, 76812647, 0) for DataFrame 164/485
# Assigned data to edge (364631109, 365291312, 0) for DataFrame 165/485
# Processed 165/485 DataFrames. Remaining time: 10.53 minutes
# Assigned data to edge (365291312, 364631109, 0) for DataFrame 166/485
# Assigned data to edge (364630642, 364631109, 0) for DataFrame 167/485
# Assigned data to edge (256188674, 364630642, 0) for DataFrame 168/485
# Assigned data to edge (32994514, 76812663, 0) for DataFrame 169/485
# Assigned data to edge (365291318, 365291312, 0) for DataFrame 170/485
# Processed 170/485 DataFrames. Remaining time: 10.36 minutes
# Assigned data to edge (365291312, 365291318, 0) for DataFrame 171/485
# Assigned data to edge (76812641, 32993258, 0) for DataFrame 172/485
# Assigned data to edge (365294704, 365294710, 0) for DataFrame 173/485
# Assigned data to edge (365294710, 365294704, 0) for DataFrame 174/485
# Assigned data to edge (6285218968, 365291318, 0) for DataFrame 175/485
# Processed 175/485 DataFrames. Remaining time: 10.20 minutes
# Assigned data to edge (365294704, 365291318, 0) for DataFrame 176/485
# Assigned data to edge (365291318, 365294704, 0) for DataFrame 177/485
# Assigned data to edge (64856440, 64856307, 0) for DataFrame 178/485
# Assigned data to edge (64856307, 64856440, 0) for DataFrame 179/485
# Assigned data to edge (64856440, 64856324, 0) for DataFrame 180/485
# Processed 180/485 DataFrames. Remaining time: 10.04 minutes
# Assigned data to edge (29973010, 29972684, 0) for DataFrame 181/485
# Assigned data to edge (1590804211, 76812468, 0) for DataFrame 182/485
# Assigned data to edge (359942387, 359942386, 0) for DataFrame 183/485
# Assigned data to edge (64856307, 64856498, 0) for DataFrame 184/485
# Assigned data to edge (64856498, 64856307, 0) for DataFrame 185/485
# Processed 185/485 DataFrames. Remaining time: 9.87 minutes
# Assigned data to edge (63757821, 63757844, 0) for DataFrame 186/485
# Assigned data to edge (1607008333, 359942386, 0) for DataFrame 187/485
# Assigned data to edge (359942382, 359942384, 0) for DataFrame 188/485
# Assigned data to edge (359942384, 359942382, 0) for DataFrame 189/485
# Assigned data to edge (359942384, 359942386, 0) for DataFrame 190/485
# Processed 190/485 DataFrames. Remaining time: 9.71 minutes
# Assigned data to edge (359942386, 359942384, 0) for DataFrame 191/485
# Assigned data to edge (359942382, 359942391, 0) for DataFrame 192/485
# Assigned data to edge (2931636338, 1322117687, 0) for DataFrame 193/485
# Assigned data to edge (1322117826, 29977454, 0) for DataFrame 194/485
# Assigned data to edge (63757844, 63757821, 0) for DataFrame 195/485
# Processed 195/485 DataFrames. Remaining time: 9.54 minutes
# Assigned data to edge (63757821, 63757880, 0) for DataFrame 196/485
# Assigned data to edge (2720419880, 314994879, 0) for DataFrame 197/485
# Assigned data to edge (359942391, 359942382, 0) for DataFrame 198/485
# Assigned data to edge (2720419880, 908762000, 0) for DataFrame 199/485
# Assigned data to edge (908762000, 2720419880, 0) for DataFrame 200/485
# Processed 200/485 DataFrames. Remaining time: 9.38 minutes
# Assigned data to edge (359942378, 359942382, 0) for DataFrame 201/485
# Assigned data to edge (359942382, 359942378, 0) for DataFrame 202/485
# Assigned data to edge (324154751, 310129156, 0) for DataFrame 203/485
# Assigned data to edge (29977650, 3684837993, 0) for DataFrame 204/485
# Assigned data to edge (1034360290, 1036464990, 0) for DataFrame 205/485
# Processed 205/485 DataFrames. Remaining time: 9.22 minutes
# Assigned data to edge (1036464748, 1036464990, 0) for DataFrame 206/485
# Assigned data to edge (1034360290, 1034360335, 0) for DataFrame 207/485
# Assigned data to edge (11993463069, 3358655194, 0) for DataFrame 208/485
# Assigned data to edge (29972545, 3708603819, 0) for DataFrame 209/485
# Assigned data to edge (64919346, 64919351, 0) for DataFrame 210/485
# Processed 210/485 DataFrames. Remaining time: 9.05 minutes
# Assigned data to edge (1801882912, 64856402, 0) for DataFrame 211/485
# Assigned data to edge (76812631, 6238500491, 0) for DataFrame 212/485
# Assigned data to edge (76812647, 76812631, 0) for DataFrame 213/485
# Assigned data to edge (29972545, 29972549, 0) for DataFrame 214/485
# Assigned data to edge (6447435305, 6447435299, 0) for DataFrame 215/485
# Processed 215/485 DataFrames. Remaining time: 8.89 minutes
# Assigned data to edge (6150580690, 5970912136, 0) for DataFrame 216/485
# Assigned data to edge (1262085884, 3902399649, 0) for DataFrame 217/485
# Assigned data to edge (1032374087, 1032373679, 0) for DataFrame 218/485
# Assigned data to edge (1116062147, 64856324, 0) for DataFrame 219/485
# Assigned data to edge (76812655, 76812651, 0) for DataFrame 220/485
# Processed 220/485 DataFrames. Remaining time: 8.72 minutes
# Assigned data to edge (6447435299, 6447435305, 0) for DataFrame 221/485
# Assigned data to edge (1028767611, 1028766868, 0) for DataFrame 222/485
# Assigned data to edge (2626887713, 1021312669, 0) for DataFrame 223/485
# Assigned data to edge (1392063315, 29551197, 0) for DataFrame 224/485
# Assigned data to edge (64856365, 64856352, 0) for DataFrame 225/485
# Processed 225/485 DataFrames. Remaining time: 8.56 minutes
# Assigned data to edge (6238500492, 6238500491, 0) for DataFrame 226/485
# Assigned data to edge (29977599, 60114754, 0) for DataFrame 227/485
# Assigned data to edge (1028767550, 1028770038, 0) for DataFrame 228/485
# Assigned data to edge (1586264480, 29971886, 0) for DataFrame 229/485
# Assigned data to edge (3358655196, 3358643374, 0) for DataFrame 230/485
# Processed 230/485 DataFrames. Remaining time: 8.39 minutes
# Assigned data to edge (64919351, 2498537068, 0) for DataFrame 231/485
# Assigned data to edge (304065583, 361443763, 0) for DataFrame 232/485
# Assigned data to edge (63757773, 1668433853, 0) for DataFrame 233/485
# Assigned data to edge (1668433853, 63757773, 0) for DataFrame 234/485
# Assigned data to edge (2720419870, 64856515, 0) for DataFrame 235/485
# Processed 235/485 DataFrames. Remaining time: 8.23 minutes
# Assigned data to edge (2720419870, 29973010, 0) for DataFrame 236/485
# Assigned data to edge (2720419905, 2720419886, 0) for DataFrame 237/485
# Assigned data to edge (76812468, 64856538, 0) for DataFrame 238/485
# Assigned data to edge (76812468, 2720419886, 0) for DataFrame 239/485
# Assigned data to edge (2720419873, 29973010, 0) for DataFrame 240/485
# Processed 240/485 DataFrames. Remaining time: 8.06 minutes
# Assigned data to edge (64856498, 2720419873, 0) for DataFrame 241/485
# Assigned data to edge (64856515, 2720419873, 0) for DataFrame 242/485
# Assigned data to edge (64856515, 64856498, 0) for DataFrame 243/485
# Assigned data to edge (2720419873, 2720419905, 0) for DataFrame 244/485
# Assigned data to edge (6379898002, 2720419873, 0) for DataFrame 245/485
# Processed 245/485 DataFrames. Remaining time: 7.90 minutes
# Assigned data to edge (6379898002, 64856515, 0) for DataFrame 246/485
# Assigned data to edge (63757859, 63757864, 0) for DataFrame 247/485
# Assigned data to edge (63757864, 63757859, 0) for DataFrame 248/485
# Assigned data to edge (63757859, 63757880, 0) for DataFrame 249/485
# Assigned data to edge (63757880, 63757859, 0) for DataFrame 250/485
# Processed 250/485 DataFrames. Remaining time: 7.73 minutes
# Assigned data to edge (359942403, 359942391, 0) for DataFrame 251/485
# Assigned data to edge (359942394, 359942391, 0) for DataFrame 252/485
# Assigned data to edge (314995133, 359942378, 0) for DataFrame 253/485
# Assigned data to edge (63757785, 63757788, 0) for DataFrame 254/485
# Assigned data to edge (63757880, 63757882, 0) for DataFrame 255/485
# Processed 255/485 DataFrames. Remaining time: 7.57 minutes
# Assigned data to edge (63757882, 63757880, 0) for DataFrame 256/485
# Assigned data to edge (63757880, 63757821, 0) for DataFrame 257/485
# Assigned data to edge (314995121, 2720419880, 0) for DataFrame 258/485
# Assigned data to edge (2720419875, 2720419880, 0) for DataFrame 259/485
# Assigned data to edge (2720419875, 314995121, 0) for DataFrame 260/485
# Processed 260/485 DataFrames. Remaining time: 7.40 minutes
# Assigned data to edge (2720419905, 64856517, 0) for DataFrame 261/485
# Assigned data to edge (63757773, 63757859, 0) for DataFrame 262/485
# Assigned data to edge (63757859, 63757773, 0) for DataFrame 263/485
# Assigned data to edge (359582981, 359582978, 0) for DataFrame 264/485
# Assigned data to edge (359582973, 359582978, 0) for DataFrame 265/485
# Processed 265/485 DataFrames. Remaining time: 7.24 minutes
# Assigned data to edge (359582978, 359582973, 0) for DataFrame 266/485
# Assigned data to edge (1166335400, 359582978, 0) for DataFrame 267/485
# Assigned data to edge (8219875349, 2799012018, 0) for DataFrame 268/485
# Assigned data to edge (359582973, 292585026, 0) for DataFrame 269/485
# Assigned data to edge (292585026, 359582973, 0) for DataFrame 270/485
# Processed 270/485 DataFrames. Remaining time: 7.07 minutes
# Assigned data to edge (364386843, 364386841, 0) for DataFrame 271/485
# Assigned data to edge (364386841, 364386843, 0) for DataFrame 272/485
# Assigned data to edge (287100150, 1166267805, 0) for DataFrame 273/485
# Assigned data to edge (32994923, 8313842372, 0) for DataFrame 274/485
# Assigned data to edge (76812690, 8313842372, 0) for DataFrame 275/485
# Processed 275/485 DataFrames. Remaining time: 6.91 minutes
# Assigned data to edge (32993258, 32994085, 0) for DataFrame 276/485
# Assigned data to edge (32994512, 32994514, 0) for DataFrame 277/485
# Assigned data to edge (365591018, 256188677, 0) for DataFrame 278/485
# Assigned data to edge (32994931, 76812690, 0) for DataFrame 279/485
# Assigned data to edge (32994931, 32994938, 0) for DataFrame 280/485
# Processed 280/485 DataFrames. Remaining time: 6.74 minutes
# Assigned data to edge (256188677, 365591018, 0) for DataFrame 281/485
# Assigned data to edge (1166267877, 296853492, 0) for DataFrame 282/485
# Assigned data to edge (296853492, 1166267805, 0) for DataFrame 283/485
# Assigned data to edge (1166267805, 1166267877, 0) for DataFrame 284/485
# Assigned data to edge (296853492, 1166267877, 0) for DataFrame 285/485
# Processed 285/485 DataFrames. Remaining time: 6.58 minutes
# Assigned data to edge (76812860, 32994512, 0) for DataFrame 286/485
# Assigned data to edge (32994085, 76812861, 0) for DataFrame 287/485
# Assigned data to edge (1345581106, 1345581102, 0) for DataFrame 288/485
# Assigned data to edge (32994510, 32994512, 0) for DataFrame 289/485
# Assigned data to edge (76812861, 76812860, 0) for DataFrame 290/485
# Processed 290/485 DataFrames. Remaining time: 6.42 minutes
# Assigned data to edge (76812861, 32994087, 0) for DataFrame 291/485
# Assigned data to edge (32994085, 32994087, 0) for DataFrame 292/485
# Assigned data to edge (32994510, 76812860, 0) for DataFrame 293/485
# Assigned data to edge (76812860, 76812861, 0) for DataFrame 294/485
# Assigned data to edge (1345581106, 76812860, 0) for DataFrame 295/485
# Processed 295/485 DataFrames. Remaining time: 6.25 minutes
# Assigned data to edge (9665956856, 256188481, 0) for DataFrame 296/485
# Assigned data to edge (256188481, 9665956856, 0) for DataFrame 297/485
# Assigned data to edge (6285219099, 256188481, 0) for DataFrame 298/485
# Assigned data to edge (256188481, 277456096, 0) for DataFrame 299/485
# Assigned data to edge (76812860, 1345581106, 0) for DataFrame 300/485
# Processed 300/485 DataFrames. Remaining time: 6.09 minutes
# Assigned data to edge (76812827, 1345581106, 0) for DataFrame 301/485
# Assigned data to edge (1345581106, 76812827, 0) for DataFrame 302/485
# Assigned data to edge (76812861, 76812859, 0) for DataFrame 303/485
# Assigned data to edge (9665956855, 256188475, 0) for DataFrame 304/485
# Assigned data to edge (256188475, 1514004918, 0) for DataFrame 305/485
# Processed 305/485 DataFrames. Remaining time: 5.92 minutes
# Assigned data to edge (1514004918, 256188475, 0) for DataFrame 306/485
# Assigned data to edge (1514004916, 1514004918, 0) for DataFrame 307/485
# Assigned data to edge (1231220780, 1514004918, 0) for DataFrame 308/485
# Assigned data to edge (1514004918, 1231220780, 0) for DataFrame 309/485
# Assigned data to edge (32994507, 32994510, 0) for DataFrame 310/485
# Processed 310/485 DataFrames. Remaining time: 5.76 minutes
# Assigned data to edge (32994087, 76812934, 0) for DataFrame 311/485
# Assigned data to edge (1540799787, 1540799794, 0) for DataFrame 312/485
# Assigned data to edge (1540799794, 1540799787, 0) for DataFrame 313/485
# Assigned data to edge (1091343330, 1091343346, 0) for DataFrame 314/485
# Assigned data to edge (1091343346, 1091343330, 0) for DataFrame 315/485
# Processed 315/485 DataFrames. Remaining time: 5.59 minutes
# Assigned data to edge (1091343330, 10203206710, 0) for DataFrame 316/485
# Assigned data to edge (76812934, 32994091, 0) for DataFrame 317/485
# Assigned data to edge (76812893, 32994507, 0) for DataFrame 318/485
# Assigned data to edge (76812934, 76812955, 0) for DataFrame 319/485
# Assigned data to edge (8313845539, 32994091, 0) for DataFrame 320/485
# Processed 320/485 DataFrames. Remaining time: 5.43 minutes
# Assigned data to edge (608608891, 1513022294, 1) for DataFrame 321/485
# Assigned data to edge (1513022294, 608608891, 1) for DataFrame 322/485
# Assigned data to edge (32994506, 32994507, 0) for DataFrame 323/485
# Assigned data to edge (8389512724, 5227891652, 0) for DataFrame 324/485
# Assigned data to edge (8389512724, 8389512723, 0) for DataFrame 325/485
# Processed 325/485 DataFrames. Remaining time: 5.26 minutes
# Assigned data to edge (5227891652, 8389512724, 0) for DataFrame 326/485
# Assigned data to edge (670500878, 321365582, 0) for DataFrame 327/485
# Assigned data to edge (76813011, 32994098, 0) for DataFrame 328/485
# Assigned data to edge (76813045, 321365582, 0) for DataFrame 329/485
# Assigned data to edge (321365582, 76813045, 0) for DataFrame 330/485
# Processed 330/485 DataFrames. Remaining time: 5.10 minutes
# Assigned data to edge (321365582, 76812986, 0) for DataFrame 331/485
# Assigned data to edge (670500878, 76812986, 0) for DataFrame 332/485
# Assigned data to edge (76812973, 670500878, 0) for DataFrame 333/485
# Assigned data to edge (32994492, 32994499, 0) for DataFrame 334/485
# Assigned data to edge (1581711014, 256188300, 0) for DataFrame 335/485
# Processed 335/485 DataFrames. Remaining time: 4.93 minutes
# Assigned data to edge (256188300, 1581711014, 0) for DataFrame 336/485
# Assigned data to edge (2588150626, 256187592, 0) for DataFrame 337/485
# Assigned data to edge (256187592, 2588150626, 0) for DataFrame 338/485
# Assigned data to edge (256187592, 1296214266, 0) for DataFrame 339/485
# Assigned data to edge (76813059, 76813064, 0) for DataFrame 340/485
# Processed 340/485 DataFrames. Remaining time: 4.77 minutes
# Assigned data to edge (32994105, 309880622, 0) for DataFrame 341/485
# Assigned data to edge (76813064, 76813059, 0) for DataFrame 342/485
# Assigned data to edge (308821032, 76813059, 0) for DataFrame 343/485
# Assigned data to edge (32994105, 76813064, 0) for DataFrame 344/485
# Assigned data to edge (308821032, 32994492, 0) for DataFrame 345/485
# Processed 345/485 DataFrames. Remaining time: 4.61 minutes
# Assigned data to edge (76813059, 2588150629, 0) for DataFrame 346/485
# Assigned data to edge (256187426, 1317322523, 0) for DataFrame 347/485
# Assigned data to edge (1317322523, 256187426, 0) for DataFrame 348/485
# Assigned data to edge (76813064, 309880622, 0) for DataFrame 349/485
# Assigned data to edge (1345581102, 1345581106, 0) for DataFrame 350/485
# Processed 350/485 DataFrames. Remaining time: 4.44 minutes
# Assigned data to edge (76812905, 8313845539, 0) for DataFrame 351/485
# Assigned data to edge (76812973, 32994502, 0) for DataFrame 352/485
# Assigned data to edge (76813059, 32994492, 0) for DataFrame 353/485
# No suitable unoccupied edge found within threshold for DataFrame 354/485
# Assigned data to edge (9665956856, 9665956855, 0) for DataFrame 355/485
# Processed 355/485 DataFrames. Remaining time: 4.28 minutes
# Assigned data to edge (32994506, 76812893, 0) for DataFrame 356/485
# Assigned data to edge (76813045, 32994098, 0) for DataFrame 357/485
# Assigned data to edge (2588150629, 76813059, 0) for DataFrame 358/485
# Assigned data to edge (76812859, 76812861, 0) for DataFrame 359/485
# Assigned data to edge (76812893, 8313845543, 0) for DataFrame 360/485
# Processed 360/485 DataFrames. Remaining time: 4.11 minutes
# Assigned data to edge (32994499, 76812992, 0) for DataFrame 361/485
# Assigned data to edge (563290978, 76813064, 0) for DataFrame 362/485
# Assigned data to edge (1166267805, 287100150, 0) for DataFrame 363/485
# Assigned data to edge (8313845543, 76812893, 0) for DataFrame 364/485
# Assigned data to edge (32994499, 32994502, 0) for DataFrame 365/485
# Processed 365/485 DataFrames. Remaining time: 3.95 minutes
# Assigned data to edge (670500010, 2588150629, 0) for DataFrame 366/485
# Assigned data to edge (255381851, 252111181, 0) for DataFrame 367/485
# Assigned data to edge (463301508, 252111181, 0) for DataFrame 368/485
# Assigned data to edge (255381851, 255381852, 0) for DataFrame 369/485
# Assigned data to edge (466433786, 316289421, 0) for DataFrame 370/485
# Processed 370/485 DataFrames. Remaining time: 3.78 minutes
# Assigned data to edge (316289421, 670647158, 0) for DataFrame 371/485
# Assigned data to edge (255381858, 316289421, 0) for DataFrame 372/485
# Assigned data to edge (316298224, 1307207926, 0) for DataFrame 373/485
# Assigned data to edge (670647166, 1307207926, 0) for DataFrame 374/485
# Assigned data to edge (1307207926, 316298224, 0) for DataFrame 375/485
# Processed 375/485 DataFrames. Remaining time: 3.61 minutes
# Assigned data to edge (287098286, 32994938, 0) for DataFrame 376/485
# Assigned data to edge (32994923, 287098357, 0) for DataFrame 377/485
# Assigned data to edge (287098286, 287098357, 0) for DataFrame 378/485
# Assigned data to edge (287098357, 287098286, 0) for DataFrame 379/485
# Assigned data to edge (76812773, 287098357, 0) for DataFrame 380/485
# Processed 380/485 DataFrames. Remaining time: 3.45 minutes
# Assigned data to edge (287098357, 76812773, 0) for DataFrame 381/485
# Assigned data to edge (1161977473, 76812773, 0) for DataFrame 382/485
# Assigned data to edge (608588085, 1127736520, 0) for DataFrame 383/485
# Assigned data to edge (1127736520, 608588085, 0) for DataFrame 384/485
# Assigned data to edge (1127675057, 5696276111, 0) for DataFrame 385/485
# Processed 385/485 DataFrames. Remaining time: 3.28 minutes
# Assigned data to edge (670674060, 670674059, 0) for DataFrame 386/485
# Assigned data to edge (670674059, 670674060, 0) for DataFrame 387/485
# Assigned data to edge (279837755, 670674060, 0) for DataFrame 388/485
# Assigned data to edge (279837848, 670674059, 0) for DataFrame 389/485
# Assigned data to edge (251740394, 251740302, 0) for DataFrame 390/485
# Processed 390/485 DataFrames. Remaining time: 3.11 minutes
# Assigned data to edge (670674059, 279837847, 0) for DataFrame 391/485
# Assigned data to edge (670674060, 279837754, 0) for DataFrame 392/485
# Assigned data to edge (251740030, 279838048, 0) for DataFrame 393/485
# Assigned data to edge (251740302, 251740307, 0) for DataFrame 394/485
# Assigned data to edge (1127736043, 1127736752, 0) for DataFrame 395/485
# Processed 395/485 DataFrames. Remaining time: 2.95 minutes
# Assigned data to edge (277456147, 1091610884, 0) for DataFrame 396/485
# Assigned data to edge (1091610884, 277456147, 0) for DataFrame 397/485
# Assigned data to edge (76812773, 1161977473, 0) for DataFrame 398/485
# Assigned data to edge (251740472, 32995547, 0) for DataFrame 399/485
# Assigned data to edge (4511297277, 4511297278, 0) for DataFrame 400/485
# Processed 400/485 DataFrames. Remaining time: 2.78 minutes
# Assigned data to edge (4511297276, 4511297277, 0) for DataFrame 401/485
# Assigned data to edge (279840002, 279840301, 0) for DataFrame 402/485
# Assigned data to edge (279840301, 279840002, 0) for DataFrame 403/485
# Assigned data to edge (279839182, 279840002, 0) for DataFrame 404/485
# Assigned data to edge (279840002, 279839181, 0) for DataFrame 405/485
# Processed 405/485 DataFrames. Remaining time: 2.62 minutes
# Assigned data to edge (279839182, 279839181, 0) for DataFrame 406/485
# Assigned data to edge (279839181, 251740519, 0) for DataFrame 407/485
# Assigned data to edge (279838939, 279840301, 0) for DataFrame 408/485
# Assigned data to edge (2710837340, 1127674829, 0) for DataFrame 409/485
# Assigned data to edge (279838742, 251740451, 0) for DataFrame 410/485
# Processed 410/485 DataFrames. Remaining time: 2.45 minutes
# Assigned data to edge (1127674829, 2710837340, 0) for DataFrame 411/485
# Assigned data to edge (364386841, 1166267877, 0) for DataFrame 412/485
# Assigned data to edge (1127735886, 1127736088, 0) for DataFrame 413/485
# Assigned data to edge (1166267877, 364386841, 0) for DataFrame 414/485
# Assigned data to edge (251740394, 279837753, 0) for DataFrame 415/485
# Processed 415/485 DataFrames. Remaining time: 2.29 minutes
# Assigned data to edge (251740524, 251740519, 0) for DataFrame 416/485
# Assigned data to edge (1161779438, 76812773, 0) for DataFrame 417/485
# Assigned data to edge (1575304676, 251740302, 0) for DataFrame 418/485
# Assigned data to edge (251740472, 279839063, 0) for DataFrame 419/485
# Assigned data to edge (76812793, 287098286, 0) for DataFrame 420/485
# Processed 420/485 DataFrames. Remaining time: 2.13 minutes
# Assigned data to edge (279838048, 279837845, 0) for DataFrame 421/485
# Assigned data to edge (279838742, 279839182, 0) for DataFrame 422/485
# Assigned data to edge (279838048, 32995528, 0) for DataFrame 423/485
# Assigned data to edge (4511297422, 32995547, 0) for DataFrame 424/485
# Assigned data to edge (1127736710, 1127735850, 0) for DataFrame 425/485
# Processed 425/485 DataFrames. Remaining time: 1.97 minutes
# Assigned data to edge (1127735850, 1127736710, 0) for DataFrame 426/485
# Assigned data to edge (277454364, 277455911, 0) for DataFrame 427/485
# Assigned data to edge (4728954544, 4728953870, 0) for DataFrame 428/485
# Assigned data to edge (4728953870, 837323316, 0) for DataFrame 429/485
# Assigned data to edge (4728954544, 837323316, 0) for DataFrame 430/485
# Processed 430/485 DataFrames. Remaining time: 1.80 minutes
# Assigned data to edge (1119147939, 1119279418, 0) for DataFrame 431/485
# Assigned data to edge (1119279465, 1119279418, 0) for DataFrame 432/485
# Assigned data to edge (282744001, 1119279418, 0) for DataFrame 433/485
# Assigned data to edge (1119147885, 316478823, 0) for DataFrame 434/485
# Assigned data to edge (316478823, 1119147885, 0) for DataFrame 435/485
# Processed 435/485 DataFrames. Remaining time: 1.64 minutes
# Assigned data to edge (348151689, 316478823, 0) for DataFrame 436/485
# Assigned data to edge (307404661, 568477034, 0) for DataFrame 437/485
# Assigned data to edge (568477034, 307404661, 0) for DataFrame 438/485
# Assigned data to edge (2281730733, 568477034, 0) for DataFrame 439/485
# Assigned data to edge (568477034, 417705062, 0) for DataFrame 440/485
# Processed 440/485 DataFrames. Remaining time: 1.47 minutes
# Assigned data to edge (417705062, 568477034, 0) for DataFrame 441/485
# Assigned data to edge (568477034, 2281730733, 0) for DataFrame 442/485
# Assigned data to edge (252109019, 316289422, 0) for DataFrame 443/485
# Assigned data to edge (316289422, 252109019, 0) for DataFrame 444/485
# Assigned data to edge (4935247846, 252109019, 0) for DataFrame 445/485
# Processed 445/485 DataFrames. Remaining time: 1.31 minutes
# Assigned data to edge (6583018305, 1127737173, 0) for DataFrame 446/485
# Assigned data to edge (1127737173, 6583018305, 0) for DataFrame 447/485
# Assigned data to edge (11246159016, 1127737173, 0) for DataFrame 448/485
# Assigned data to edge (9531924773, 9531924772, 0) for DataFrame 449/485
# Assigned data to edge (9531924773, 9531924774, 0) for DataFrame 450/485
# Processed 450/485 DataFrames. Remaining time: 1.15 minutes
# Assigned data to edge (9531924772, 9531924774, 0) for DataFrame 451/485
# Assigned data to edge (1036556117, 1036556197, 0) for DataFrame 452/485
# Assigned data to edge (1119147885, 1119147899, 0) for DataFrame 453/485
# Assigned data to edge (1119147899, 1119147885, 0) for DataFrame 454/485
# Assigned data to edge (316478823, 348151689, 0) for DataFrame 455/485
# Processed 455/485 DataFrames. Remaining time: 0.98 minutes
# Assigned data to edge (3754535427, 1233588453, 0) for DataFrame 456/485
# Assigned data to edge (1233588453, 3754535427, 0) for DataFrame 457/485
# Assigned data to edge (418767944, 3754535427, 0) for DataFrame 458/485
# Assigned data to edge (1319601091, 1319601172, 0) for DataFrame 459/485
# Assigned data to edge (4511732972, 278169570, 0) for DataFrame 460/485
# Processed 460/485 DataFrames. Remaining time: 0.82 minutes
# Assigned data to edge (967895142, 1346907178, 0) for DataFrame 461/485
# Assigned data to edge (1346907178, 967895142, 0) for DataFrame 462/485
# Assigned data to edge (2498378530, 2498378528, 0) for DataFrame 463/485
# Assigned data to edge (1128077353, 814649533, 0) for DataFrame 464/485
# Assigned data to edge (814649533, 1128077353, 0) for DataFrame 465/485
# Processed 465/485 DataFrames. Remaining time: 0.65 minutes
# Assigned data to edge (1581576332, 1087112892, 0) for DataFrame 466/485
# Assigned data to edge (1092034041, 1581576330, 0) for DataFrame 467/485
# Assigned data to edge (1092034041, 1087112892, 0) for DataFrame 468/485
# Assigned data to edge (3682876327, 6382121618, 0) for DataFrame 469/485
# Assigned data to edge (6382121618, 3682876327, 0) for DataFrame 470/485
# Processed 470/485 DataFrames. Remaining time: 0.49 minutes
# Assigned data to edge (6382121618, 1069286040, 0) for DataFrame 471/485
# Assigned data to edge (1069286040, 6382121618, 0) for DataFrame 472/485
# Assigned data to edge (9458548734, 1069286040, 0) for DataFrame 473/485
# Assigned data to edge (2404076127, 9458548734, 0) for DataFrame 474/485
# Assigned data to edge (1069286040, 9458548734, 0) for DataFrame 475/485
# Processed 475/485 DataFrames. Remaining time: 0.33 minutes
# Assigned data to edge (28390914, 1031808321, 0) for DataFrame 476/485
# Assigned data to edge (1031808321, 28390914, 0) for DataFrame 477/485
# Assigned data to edge (28390914, 84863652, 0) for DataFrame 478/485
# Assigned data to edge (860553149, 1025596040, 0) for DataFrame 479/485
# Assigned data to edge (1025596040, 860553149, 0) for DataFrame 480/485
# Processed 480/485 DataFrames. Remaining time: 0.16 minutes
# Assigned data to edge (860553149, 3373514923, 0) for DataFrame 481/485
# Assigned data to edge (3373514923, 860553149, 0) for DataFrame 482/485
# Assigned data to edge (1231339742, 357208393, 0) for DataFrame 483/485
# Assigned data to edge (359164152, 357208393, 0) for DataFrame 484/485
# Assigned data to edge (357208393, 359164152, 0) for DataFrame 485/485
# Processed 485/485 DataFrames. Remaining time: 0.00 minutes
#
# Processing complete.
# Total DataFrames processed: 485
#
# Verification of assigned data:
# u           v           key
# 28390914    1031808321  0      [(2023-01-01 00:00:00, 10.0), (2023-01-01 00:1...
#             84863652    0      [(2023-01-01 00:00:00, 14.0), (2023-01-01 00:1...
# 1031808321  28390914    0      [(2023-01-01 00:00:00, 4.0), (2023-01-01 00:15...
# 28390935    323187714   0      [(2023-01-01 00:00:00, 18.0), (2023-01-01 00:1...
# 323187714   29551197    0      [(2023-01-01 00:00:00, 29.0), (2023-01-01 00:1...
# Name: time_series_data, dtype: object
#
# Edges with no data assigned:                                                                          osmid  \
# u           v           key
# 27464487    3464359269  0                                             26316217
#             358455595   0    [681923789, 496812113, 340533881, 340533878, 3...
# 3464359269  27464487    0                                             26316217
#             1799432068  0                                             26316217
#             28090882    0                               [340533884, 339251095]
# ...                                                                        ...
# 12211730394 12209400205 0                                           1319621862
#             11099356100 0                             [1319621867, 1319621861]
# 12209399551 12211730398 0                                            366868481
#             442910660   0                                           1319301628
#             12209399583 0                                            366868481
#
#                               lanes               name        highway  \
# u           v           key
# 27464487    3464359269  0         2          Kirkegade       tertiary
#             358455595   0    [2, 1]      Vesterbrogade        primary
# 3464359269  27464487    0         2          Kirkegade       tertiary
#             1799432068  0         2          Kirkegade       tertiary
#             28090882    0    [2, 1]         Vestergade        primary
# ...                             ...                ...            ...
# 12211730394 12209400205 0         1  Sohngårdsholmsvej       tertiary
#             11099356100 0         1  Sohngårdsholmsvej    residential
# 12209399551 12211730398 0         2                NaN         busway
#             442910660   0         1                NaN  tertiary_link
#             12209399583 0         2                NaN         busway
#
#                             maxspeed  oneway reversed   length allowed_speed  \
# u           v           key
# 27464487    3464359269  0         50   False     True    7.838            50
#             358455595   0         50    True    False  208.347            50
# 3464359269  27464487    0         50   False    False    7.838            50
#             1799432068  0         50   False     True   22.017            50
#             28090882    0         50    True    False  196.970            50
# ...                              ...     ...      ...      ...           ...
# 12211730394 12209400205 0         50    True    False    7.538            50
#             11099356100 0        NaN    True    False   58.976          None
# 12209399551 12211730398 0         50   False     True    0.875            50
#             442910660   0        NaN    True    False   10.611          None
#             12209399583 0         50   False    False  180.722            50
#
#                             surface_type  ... is_oneway access_restriction  \
# u           v           key               ...
# 27464487    3464359269  0           None  ...     False               None
#             358455595   0           None  ...      True               None
# 3464359269  27464487    0           None  ...     False               None
#             1799432068  0           None  ...     False               None
#             28090882    0           None  ...      True               None
# ...                                  ...  ...       ...                ...
# 12211730394 12209400205 0           None  ...      True               None
#             11099356100 0           None  ...      True               None
# 12209399551 12211730398 0           None  ...     False               None
#             442910660   0           None  ...      True               None
#             12209399583 0           None  ...     False               None
#
#                              ref  \
# u           v           key
# 27464487    3464359269  0    NaN
#             358455595   0     55
# 3464359269  27464487    0    NaN
#             1799432068  0    NaN
#             28090882    0     55
# ...                          ...
# 12211730394 12209400205 0    NaN
#             11099356100 0    NaN
# 12209399551 12211730398 0    NaN
#             442910660   0    NaN
#             12209399583 0    NaN
#
#                                                                       geometry  \
# u           v           key
# 27464487    3464359269  0    LINESTRING (555703.246 6324409.649, 555709.985...
#             358455595   0    LINESTRING (555703.246 6324409.649, 555707.909...
# 3464359269  27464487    0    LINESTRING (555709.985 6324413.692, 555703.246...
#             1799432068  0    LINESTRING (555709.985 6324413.692, 555720.564...
#             28090882    0    LINESTRING (555709.985 6324413.692, 555704.999...
# ...                                                                        ...
# 12211730394 12209400205 0    LINESTRING (557317.741 6320753.000, 557318.341...
#             11099356100 0    LINESTRING (557317.741 6320753.000, 557324.513...
# 12209399551 12211730398 0    LINESTRING (557306.282 6320756.727, 557306.452...
#             442910660   0    LINESTRING (557306.282 6320756.727, 557296.781...
#             12209399583 0    LINESTRING (557306.282 6320756.727, 557303.763...
#
#                             bridge junction width tunnel access  \
# u           v           key
# 27464487    3464359269  0      NaN      NaN   NaN    NaN    NaN
#             358455595   0      NaN      NaN   NaN    NaN    NaN
# 3464359269  27464487    0      NaN      NaN   NaN    NaN    NaN
#             1799432068  0      NaN      NaN   NaN    NaN    NaN
#             28090882    0      NaN      NaN   NaN    NaN    NaN
# ...                            ...      ...   ...    ...    ...
# 12211730394 12209400205 0      NaN      NaN   NaN    NaN    NaN
#             11099356100 0      NaN      NaN   NaN    NaN    NaN
# 12209399551 12211730398 0      NaN      NaN   NaN    NaN    NaN
#             442910660   0      NaN      NaN   NaN    NaN    NaN
#             12209399583 0      NaN      NaN   NaN    NaN    NaN
#
#                             time_series_data
# u           v           key
# 27464487    3464359269  0                NaN
#             358455595   0                NaN
# 3464359269  27464487    0                NaN
#             1799432068  0                NaN
#             28090882    0                NaN
# ...                                      ...
# 12211730394 12209400205 0                NaN
#             11099356100 0                NaN
# 12209399551 12211730398 0                NaN
#             442910660   0                NaN
#             12209399583 0                NaN
#
# [30986 rows x 22 columns]

# %%
# Count edges with assigned time series data
edges_with_data = edges_proj['time_series_data'].notna().sum()
total_edges = len(edges_proj)

# Check and print verification results
print(f"Total edges in graph: {total_edges}")
print(f"Edges with time series data: {edges_with_data}")

# Check if any edges are missing data
missing_data_edges = edges_proj[edges_proj['time_series_data'].isna()]

if edges_with_data == total_edges:
    print("Verification complete: All edges have time series data.")
else:
    print(f"Verification complete: {total_edges - edges_with_data} edges are missing time series data.")
# Out:
# Total edges in graph: 31470
# Edges with time series data: 484
# Verification complete: 30986 edges are missing time series data.

# %%
ox.save_graphml(G_proj, filepath='total_proj.graphml')
